# %%
import pandas as pd

# Load the SNLI test data (including true labels)
snli_test_path = "/kaggle/input/stanford-natural-language-inference-corpus/snli_1.0_test.csv"
snli_test_df = pd.read_csv(snli_test_path)

# Define file paths for SNLI prediction files
snli_predictions_paths = {
    "deberta": "/kaggle/input/deberta-nli/deberta_snli_predictions.csv",
    "roberta": "/kaggle/input/roberta/roberta_snli_predictions.csv",
    "albert": "/kaggle/input/albert/albert_snli_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_snli = "/kaggle/working/combined_snli_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_snli_df = pd.DataFrame(columns=columns)

label_mapping = {'entailment': 0, 'neutral': 1, 'contradiction': 2}

# Load and merge the predictions
for model, path in snli_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_snli_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_snli_df['True_Label'] = snli_test_df['gold_label'].map(label_mapping)

# Convert True_Label to integer type
combined_snli_df['True_Label'] = combined_snli_df['True_Label'].astype('Int64')

# Save the combined DataFrame to CSV
combined_snli_df.to_csv(output_csv_path_snli, index=False)

print(f"Combined SNLI predictions with true labels saved to {output_csv_path_snli}")
# Out:
# Combined SNLI predictions with true labels saved to /kaggle/working/combined_snli_df

# %%
combined_snli_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.034767         0.962592               0.002641
# 1            0.001921         0.319032               0.679047
# 2            0.998783         0.000764               0.000453
# 3            0.001001         0.997708               0.001291
# 4            0.001080         0.301363               0.697557
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.012451         0.927093               0.060457
# 1            0.752766         0.242251               0.004983
# 2            0.000254         0.004494               0.995253
# 3            0.005844         0.990736               0.003419
# 4            0.278348         0.718575               0.003076
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.008653        0.947434              0.043913           1
# 1           0.740332        0.256434              0.003235           0
# 2           0.004677        0.060481              0.934843           2
# 3           0.034056        0.956687              0.009257           1
# 4           0.498761        0.499270              0.001969           0

# %%
# Load the ANLI Round 1 test data (including true labels)
mnli_matched_test_path = "/kaggle/input/nli-dataset-for-sentence-understanding/mnli_validation_matched.csv"
mnli_matched_test_df = pd.read_csv(mnli_matched_test_path)

# Define file paths for ANLI Round 1 prediction files
mnli_matched_predictions_paths = {
    "deberta": "/kaggle/input/validation/deberta_mnli_matched_val_predictions.csv",
    "roberta": "/kaggle/input/validation/roberta_mnli_matched_val_predictions.csv",
    "albert": "/kaggle/input/validation/albert_mnli_matched_val_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_mnli_matched = "/kaggle/working/combined_mnli_matched_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_mnli_matched_df = pd.DataFrame(columns=columns)

# Load and merge the predictions
for model, path in mnli_matched_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_mnli_matched_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_mnli_matched_df['True_Label'] = mnli_matched_test_df['label']

# Save the combined DataFrame to CSV
combined_mnli_matched_df.to_csv(output_csv_path_mnli_matched, index=False)

print(f"Combined MNLI-matched predictions with true labels saved to {output_csv_path_mnli_matched}")
# Out:
# Combined MNLI-matched predictions with true labels saved to /kaggle/working/combined_mnli_matched_df

# %%
combined_mnli_matched_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.005164         0.993364               0.001472
# 1            0.999153         0.000526               0.000321
# 2            0.000989         0.044792               0.954219
# 3            0.994965         0.004808               0.000228
# 4            0.999657         0.000220               0.000123
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.017844         0.950246               0.031909
# 1            0.001413         0.002030               0.996557
# 2            0.954781         0.042249               0.002970
# 3            0.000343         0.003511               0.996146
# 4            0.000079         0.000496               0.999425
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.010844        0.983012              0.006144           1
# 1           0.005388        0.007536              0.987076           2
# 2           0.853862        0.143483              0.002655           0
# 3           0.004128        0.070757              0.925115           2
# 4           0.003864        0.029262              0.966875           2

# %%
# Load the ANLI Round 1 test data (including true labels)
mnli_mismatched_test_path = "/kaggle/input/nli-dataset-for-sentence-understanding/mnli_validation_mismatched.csv"
mnli_mismatched_test_df = pd.read_csv(mnli_mismatched_test_path)

# Define file paths for ANLI Round 1 prediction files
mnli_mismatched_predictions_paths = {
    "deberta": "/kaggle/input/validation/deberta_mnli_mismatched_val_predictions.csv",
    "roberta": "/kaggle/input/validation/roberta_mnli_mismatched_val_predictions.csv",
    "albert": "/kaggle/input/validation/albert_mnli_mismatched_val_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_mnli_mismatched = "/kaggle/working/combined_mnli_mismatched_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_mnli_mismatched_df = pd.DataFrame(columns=columns)

# Load and merge the predictions
for model, path in mnli_mismatched_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_mnli_mismatched_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_mnli_mismatched_df['True_Label'] = mnli_mismatched_test_df['label']

# Save the combined DataFrame to CSV
combined_mnli_mismatched_df.to_csv(output_csv_path_mnli_mismatched, index=False)

print(f"Combined MNLI-mismatched predictions with true labels saved to {output_csv_path_mnli_mismatched}")
# Out:
# Combined MNLI-mismatched predictions with true labels saved to /kaggle/working/combined_mnli_mismatched_df

# %%
combined_mnli_mismatched_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.999667         0.000160               0.000173
# 1            0.998119         0.000962               0.000919
# 2            0.000552         0.004809               0.994639
# 3            0.827653         0.171961               0.000386
# 4            0.000292         0.002875               0.996833
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.000068         0.000402               0.999529
# 1            0.000183         0.001511               0.998306
# 2            0.986062         0.012020               0.001918
# 3            0.000478         0.270953               0.728569
# 4            0.975167         0.021904               0.002929
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.000894        0.003787              0.995318           2
# 1           0.006421        0.010224              0.983355           2
# 2           0.975041        0.023354              0.001605           0
# 3           0.001722        0.796122              0.202156           2
# 4           0.965952        0.032748              0.001300           0

# %%
# Load the ANLI Round 1 test data (including true labels)
anli_r1_test_path = "/kaggle/input/anli-a-large-scale-nli-benchmark-dataset/test_r1.csv"
anli_r1_test_df = pd.read_csv(anli_r1_test_path)

# Define file paths for ANLI Round 1 prediction files
anli_r1_predictions_paths = {
    "deberta": "/kaggle/input/deberta-nli/deberta_anli_r1_predictions.csv",
    "roberta": "/kaggle/input/roberta/roberta_anli_r1_predictions.csv",
    "albert": "/kaggle/input/albert/albert_anli_r1_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_anli_r1 = "/kaggle/working/combined_anli_r1_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_anli_r1_df = pd.DataFrame(columns=columns)

# Load and merge the predictions
for model, path in anli_r1_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_anli_r1_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_anli_r1_df['True_Label'] = anli_r1_test_df['label']

# Save the combined DataFrame to CSV
combined_anli_r1_df.to_csv(output_csv_path_anli_r1, index=False)

print(f"Combined ANLI Round 1 predictions with true labels saved to {output_csv_path_anli_r1}")
# Out:
# Combined ANLI Round 1 predictions with true labels saved to /kaggle/working/combined_anli_r1_df

# %%
combined_anli_r1_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.015388         0.976305               0.008307
# 1            0.224603         0.501549               0.273848
# 2            0.006642         0.976690               0.016669
# 3            0.966494         0.032235               0.001272
# 4            0.880736         0.028293               0.090971
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.996714         0.000376               0.002910
# 1            0.875720         0.000724               0.123556
# 2            0.999484         0.000330               0.000186
# 3            0.000686         0.998181               0.001133
# 4            0.000378         0.000197               0.999425
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.322974        0.667628              0.009398           0
# 1           0.998526        0.000604              0.000869           0
# 2           0.783352        0.212241              0.004407           0
# 3           0.002134        0.989523              0.008343           1
# 4           0.023283        0.013253              0.963464           2

# %%
# Load the ANLI Round 2 test data (including true labels)
anli_r2_test_path = "/kaggle/input/anli-a-large-scale-nli-benchmark-dataset/test_r2.csv"
anli_r2_test_df = pd.read_csv(anli_r2_test_path)

# Define file paths for ANLI Round 2 prediction files
anli_r2_predictions_paths = {
    "deberta": "/kaggle/input/deberta-nli/deberta_anli_r2_predictions.csv",
    "roberta": "/kaggle/input/roberta/roberta_anli_r2_predictions.csv",
    "albert": "/kaggle/input/albert/albert_anli_r2_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_anli_r2 = "/kaggle/working/combined_anli_r2_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_anli_r2_df = pd.DataFrame(columns=columns)

# Load and merge the predictions
for model, path in anli_r2_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_anli_r2_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_anli_r2_df['True_Label'] = anli_r2_test_df['label']

# Save the combined DataFrame to CSV
combined_anli_r2_df.to_csv(output_csv_path_anli_r2, index=False)

print(f"Combined ANLI Round 2 predictions with true labels saved to {output_csv_path_anli_r2}")
# Out:
# Combined ANLI Round 2 predictions with true labels saved to /kaggle/working/combined_anli_r2_df

# %%
combined_anli_r2_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.001309         0.029617               0.969075
# 1            0.724144         0.273676               0.002180
# 2            0.071604         0.917894               0.010503
# 3            0.066162         0.929179               0.004659
# 4            0.906199         0.089873               0.003928
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.999506         0.000264               0.000230
# 1            0.026951         0.054230               0.918819
# 2            0.001282         0.998108               0.000610
# 3            0.007091         0.992694               0.000215
# 4            0.006259         0.989432               0.004309
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.863365        0.133388              0.003246           0
# 1           0.072900        0.904344              0.022756           1
# 2           0.027402        0.972218              0.000380           0
# 3           0.632171        0.365194              0.002635           1
# 4           0.064109        0.234642              0.701249           2

# %%
# Load the ANLI Round 3 test data (including true labels)
anli_r3_test_path = "/kaggle/input/anli-a-large-scale-nli-benchmark-dataset/test_r3.csv"
anli_r3_test_df = pd.read_csv(anli_r3_test_path)

# Define file paths for ANLI Round 2 prediction files
anli_r3_predictions_paths = {
    "deberta": "/kaggle/input/deberta-nli/deberta_anli_r3_predictions.csv",
    "roberta": "/kaggle/input/roberta/roberta_anli_r3_predictions.csv",
    "albert": "/kaggle/input/albert/albert_anli_r3_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_anli_r3 = "/kaggle/working/combined_anli_r3_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_anli_r3_df = pd.DataFrame(columns=columns)

# Load and merge the predictions
for model, path in anli_r3_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_anli_r3_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_anli_r3_df['True_Label'] = anli_r3_test_df['label']

# Save the combined DataFrame to CSV
combined_anli_r3_df.to_csv(output_csv_path_anli_r3, index=False)

print(f"Combined ANLI Round 3 predictions with true labels saved to {output_csv_path_anli_r3}")
# Out:
# Combined ANLI Round 3 predictions with true labels saved to /kaggle/working/combined_anli_r3_df

# %%
combined_anli_r3_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.005921         0.960529               0.033551
# 1            0.009586         0.934714               0.055700
# 2            0.003428         0.976393               0.020179
# 3            0.004633         0.023985               0.971382
# 4            0.017428         0.633695               0.348877
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.022959         0.976533               0.000509
# 1            0.999611         0.000205               0.000185
# 2            0.002020         0.997897               0.000083
# 3            0.974441         0.024459               0.001100
# 4            0.984416         0.011166               0.004419
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.001848        0.998084              0.000067           0
# 1           0.951772        0.048075              0.000153           0
# 2           0.001014        0.998984              0.000002           0
# 3           0.996749        0.000989              0.002262           0
# 4           0.000518        0.128416              0.871066           0

# %%
# Check for missing values
missing_values_anli1 = combined_anli_r1_df.isnull().sum()

missing_values_anli2 = combined_anli_r2_df.isnull().sum()

missing_values_anli3 = combined_anli_r3_df.isnull().sum()

missing_values_snli = combined_snli_df.isnull().sum()

missing_values_mnli_matched = combined_mnli_matched_df.isnull().sum()

missing_values_mnli_mismatched = combined_mnli_mismatched_df.isnull().sum()

# %%
missing_values_anli1
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
missing_values_anli2
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
missing_values_anli3
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
missing_values_snli
# Out:
# Deberta_Entailment         0
# Deberta_Neutral            0
# Deberta_Contradiction      0
# Roberta_Entailment         0
# Roberta_Neutral            0
# Roberta_Contradiction      0
# Albert_Entailment          0
# Albert_Neutral             0
# Albert_Contradiction       0
# True_Label               176
# dtype: int64

# %%
missing_values_mnli_matched
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
missing_values_mnli_mismatched
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
combined_snli_df.dropna(subset=['True_Label'], inplace=True)

# %%
# Verify missing values again after removal
missing_values_snli_after_removal = combined_snli_df.isnull().sum()
print(missing_values_snli_after_removal)
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
combined_snli_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9824 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Deberta_Entailment     9824 non-null   float64
#  1   Deberta_Neutral        9824 non-null   float64
#  2   Deberta_Contradiction  9824 non-null   float64
#  3   Roberta_Entailment     9824 non-null   float64
#  4   Roberta_Neutral        9824 non-null   float64
#  5   Roberta_Contradiction  9824 non-null   float64
#  6   Albert_Entailment      9824 non-null   float64
#  7   Albert_Neutral         9824 non-null   float64
#  8   Albert_Contradiction   9824 non-null   float64
#  9   True_Label             9824 non-null   Int64
# dtypes: Int64(1), float64(9)
# memory usage: 853.8 KB

# %%
combined_snli_df
# Out:
#       Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0               0.034767         0.962592               0.002641
# 1               0.001921         0.319032               0.679047
# 2               0.998783         0.000764               0.000453
# 3               0.001001         0.997708               0.001291
# 4               0.001080         0.301363               0.697557
# ...                  ...              ...                    ...
# 9995            0.998825         0.001033               0.000142
# 9996            0.000704         0.009793               0.989503
# 9997            0.999171         0.000493               0.000336
# 9998            0.000267         0.002178               0.997556
# 9999            0.003641         0.995224               0.001135
#
#       Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0               0.012451         0.927093               0.060457
# 1               0.752766         0.242251               0.004983
# 2               0.000254         0.004494               0.995253
# 3               0.005844         0.990736               0.003419
# 4               0.278348         0.718575               0.003076
# ...                  ...              ...                    ...
# 9995            0.001264         0.028942               0.969794
# 9996            0.780946         0.217053               0.002001
# 9997            0.000054         0.000765               0.999181
# 9998            0.983402         0.015884               0.000714
# 9999            0.000904         0.995495               0.003601
#
#       Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0              0.008653        0.947434              0.043913           1
# 1              0.740332        0.256434              0.003235           0
# 2              0.004677        0.060481              0.934843           2
# 3              0.034056        0.956687              0.009257           1
# 4              0.498761        0.499270              0.001969           0
# ...                 ...             ...                   ...         ...
# 9995           0.006420        0.057240              0.936340           2
# 9996           0.894637        0.104095              0.001267           0
# 9997           0.000838        0.002670              0.996493           2
# 9998           0.984347        0.015223              0.000430           0
# 9999           0.005047        0.990218              0.004735           1
#
# [9824 rows x 10 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf



# Features and Labels
X_snli = combined_snli_df.drop(['True_Label'], axis=1).values
y_snli = combined_snli_df['True_Label'].values

# Features and Labels
X_mnli_matched = combined_mnli_matched_df.drop(['True_Label'], axis=1).values
y_mnli_matched = combined_mnli_matched_df['True_Label'].values

# Features and Labels
X_mnli_mismatched = combined_mnli_mismatched_df.drop(['True_Label'], axis=1).values
y_mnli_mismatched = combined_mnli_mismatched_df['True_Label'].values

# Features and Labels
X_anli_r1 = combined_anli_r1_df.drop(['True_Label'], axis=1).values
y_anli_r1 = combined_anli_r1_df['True_Label'].values

# Features and Labels
X_anli_r2 = combined_anli_r2_df.drop(['True_Label'], axis=1).values
y_anli_r2 = combined_anli_r2_df['True_Label'].values

# Features and Labels
X_anli_r3 = combined_anli_r3_df.drop(['True_Label'], axis=1).values
y_anli_r3 = combined_anli_r3_df['True_Label'].values

# %%
X_snli
# Out:
# array([[3.4766793e-02, 9.6259177e-01, 2.6414103e-03, ..., 8.6525280e-03,
#         9.4743400e-01, 4.3913495e-02],
#        [1.9208064e-03, 3.1903190e-01, 6.7904730e-01, ..., 7.4033150e-01,
#         2.5643367e-01, 3.2348454e-03],
#        [9.9878270e-01, 7.6433434e-04, 4.5297167e-04, ..., 4.6765395e-03,
#         6.0480673e-02, 9.3484277e-01],
#        ...,
#        [9.9917114e-01, 4.9286430e-04, 3.3603658e-04, ..., 8.3751883e-04,
#         2.6697412e-03, 9.9649280e-01],
#        [2.6664520e-04, 2.1777824e-03, 9.9755560e-01, ..., 9.8434700e-01,
#         1.5223468e-02, 4.2961346e-04],
#        [3.6407644e-03, 9.9522394e-01, 1.1352752e-03, ..., 5.0470065e-03,
#         9.9021820e-01, 4.7347180e-03]])

# %%
X_snli.shape
# Out:
# (9824, 9)

# %%
y_snli.shape
# Out:
# (9824,)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Step 1: Feature Scaling
scaler = StandardScaler()

# Fit the scaler to each task's feature data
X_snli_scaled = scaler.fit_transform(X_snli)
X_mnli_matched_scaled = scaler.fit_transform(X_mnli_matched)
X_mnli_mismatched_scaled = scaler.fit_transform(X_mnli_mismatched)
X_anli_r1_scaled = scaler.fit_transform(X_anli_r1)
X_anli_r2_scaled = scaler.fit_transform(X_anli_r2)
X_anli_r3_scaled = scaler.fit_transform(X_anli_r3)

# Step 2: Label Encoding (One-Hot Encoding) - Updated to prevent FutureWarning
encoder = OneHotEncoder()  # No need to specify sparse=False, default is now dense output

# Encode the labels for each task
y_snli_encoded = encoder.fit_transform(y_snli.reshape(-1, 1))
y_mnli_matched_encoded = encoder.fit_transform(y_mnli_matched.reshape(-1, 1))
y_mnli_mismatched_encoded = encoder.fit_transform(y_mnli_mismatched.reshape(-1, 1))
y_anli_r1_encoded = encoder.fit_transform(y_anli_r1.reshape(-1, 1))
y_anli_r2_encoded = encoder.fit_transform(y_anli_r2.reshape(-1, 1))
y_anli_r3_encoded = encoder.fit_transform(y_anli_r3.reshape(-1, 1))

# %%
from sklearn.model_selection import train_test_split

# Define the test size and random state for reproducibility
test_size = 0.2
random_state = 42

# Split data for SNLI task
X_snli_train, X_snli_test, y_snli_train, y_snli_test = train_test_split(
    X_snli_scaled, y_snli_encoded, test_size=test_size, random_state=random_state
)

# Split data for MNLI-matched task
X_mnli_matched_train, X_mnli_matched_test, y_mnli_matched_train, y_mnli_matched_test = train_test_split(
    X_mnli_matched_scaled, y_mnli_matched_encoded, test_size=test_size, random_state=random_state
)

# Split data for MNLI-mismatched task
X_mnli_mismatched_train, X_mnli_mismatched_test, y_mnli_mismatched_train, y_mnli_mismatched_test = train_test_split(
    X_mnli_mismatched_scaled, y_mnli_mismatched_encoded, test_size=test_size, random_state=random_state
)

# Split data for ANLI Round 1 task
X_anli_r1_train, X_anli_r1_test, y_anli_r1_train, y_anli_r1_test = train_test_split(
    X_anli_r1_scaled, y_anli_r1_encoded, test_size=test_size, random_state=random_state
)

# Split data for ANLI Round 2 task
X_anli_r2_train, X_anli_r2_test, y_anli_r2_train, y_anli_r2_test = train_test_split(
    X_anli_r2_scaled, y_anli_r2_encoded, test_size=test_size, random_state=random_state
)

# Split data for ANLI Round 3 task
X_anli_r3_train, X_anli_r3_test, y_anli_r3_train, y_anli_r3_test = train_test_split(
    X_anli_r3_scaled, y_anli_r3_encoded, test_size=test_size, random_state=random_state
)

# %%
X_snli_train.shape
# Out:
# (7859, 9)

# %%
X_anli_r2_train.shape
# Out:
# (800, 9)

# %%
X_anli_r3_train.shape
# Out:
# (960, 9)

# %%
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

# Adjusted Capsule Layer
class CapsuleLayer(layers.Layer):
    def __init__(self, num_capsules, dim_capsules, num_routing=3, **kwargs):
        super(CapsuleLayer, self).__init__(**kwargs)
        self.num_capsules = num_capsules
        self.dim_capsules = dim_capsules
        self.num_routing = num_routing
    
    def build(self, input_shape):
        self.kernel = self.add_weight(
            shape=(input_shape[-1], self.num_capsules * self.dim_capsules),
            initializer="glorot_uniform",
            name="capsule_kernel",
        )
    
    def call(self, inputs):
        outputs = tf.matmul(inputs, self.kernel)
        outputs = tf.reshape(outputs, (-1, self.num_capsules, self.dim_capsules))
        
        b = tf.zeros(shape=(tf.shape(inputs)[0], self.num_capsules, 1))
        for _ in range(self.num_routing):
            c = tf.nn.softmax(b, axis=1)
            outputs = c * outputs
            outputs = self.squash(outputs)
            b += tf.reduce_sum(outputs * outputs, axis=-1, keepdims=True)
        
        return outputs
    
    @staticmethod
    def squash(vector):
        squared_norm = tf.reduce_sum(tf.square(vector), axis=-1, keepdims=True)
        scale = squared_norm / (1 + squared_norm) / tf.sqrt(squared_norm)
        return scale * vector

# %%
# Ensure Data is in Correct Format
def ensure_dense(data):
    if hasattr(data, 'toarray'):
        return data.toarray()
    return data

# Apply Data Conversion and Reshaping for Other Tasks
X_snli_train = ensure_dense(X_snli_train)
X_snli_test = ensure_dense(X_snli_test)
y_snli_train = ensure_dense(y_snli_train)
y_snli_test = ensure_dense(y_snli_test)

# Apply Data Conversion and Reshaping for Other Tasks
X_mnli_matched_train = ensure_dense(X_mnli_matched_train)
X_mnli_matched_test = ensure_dense(X_mnli_matched_test)
y_mnli_matched_train = ensure_dense(y_mnli_matched_train)
y_mnli_matched_test = ensure_dense(y_mnli_matched_test)

X_mnli_mismatched_train = ensure_dense(X_mnli_mismatched_train)
X_mnli_mismatched_test = ensure_dense(X_mnli_mismatched_test)
y_mnli_mismatched_train = ensure_dense(y_mnli_mismatched_train)
y_mnli_mismatched_test = ensure_dense(y_mnli_mismatched_test)

X_anli_r1_train = ensure_dense(X_anli_r1_train)
X_anli_r1_test = ensure_dense(X_anli_r1_test)
y_anli_r1_train = ensure_dense(y_anli_r1_train)
y_anli_r1_test = ensure_dense(y_anli_r1_test)

X_anli_r2_train = ensure_dense(X_anli_r2_train)
X_anli_r2_test = ensure_dense(X_anli_r2_test)
y_anli_r2_train = ensure_dense(y_anli_r2_train)
y_anli_r2_test = ensure_dense(y_anli_r2_test)

X_anli_r3_train = ensure_dense(X_anli_r3_train)
X_anli_r3_test = ensure_dense(X_anli_r3_test)
y_anli_r3_train = ensure_dense(y_anli_r3_train)
y_anli_r3_test = ensure_dense(y_anli_r3_test)

# %%
# Function to reshape 1D arrays into 2D if needed
def ensure_reshaped(data):
    if len(data.shape) == 1:
        return data.reshape((-1, 1))
    return data

# Reshape the training and test sets for all tasks
# SNLI
X_snli_train = ensure_reshaped(X_snli_train)
X_snli_test = ensure_reshaped(X_snli_test)

# Reshape the training and test sets for all tasks
# MNLI Matched
X_mnli_matched_train = ensure_reshaped(X_mnli_matched_train)
X_mnli_matched_test = ensure_reshaped(X_mnli_matched_test)

# MNLI Mismatched
X_mnli_mismatched_train = ensure_reshaped(X_mnli_mismatched_train)
X_mnli_mismatched_test = ensure_reshaped(X_mnli_mismatched_test)

# ANLI Round 1
X_anli_r1_train = ensure_reshaped(X_anli_r1_train)
X_anli_r1_test = ensure_reshaped(X_anli_r1_test)

# ANLI Round 2
X_anli_r2_train = ensure_reshaped(X_anli_r2_train)
X_anli_r2_test = ensure_reshaped(X_anli_r2_test)

# ANLI Round 3
X_anli_r3_train = ensure_reshaped(X_anli_r3_train)
X_anli_r3_test = ensure_reshaped(X_anli_r3_test)

# Reshape the labels as well if required
y_mnli_matched_train = ensure_reshaped(y_mnli_matched_train)
y_mnli_matched_test = ensure_reshaped(y_mnli_matched_test)

y_mnli_mismatched_train = ensure_reshaped(y_mnli_mismatched_train)
y_mnli_mismatched_test = ensure_reshaped(y_mnli_mismatched_test)

y_anli_r1_train = ensure_reshaped(y_anli_r1_train)
y_anli_r1_test = ensure_reshaped(y_anli_r1_test)

y_anli_r2_train = ensure_reshaped(y_anli_r2_train)
y_anli_r2_test = ensure_reshaped(y_anli_r2_test)

y_anli_r3_train = ensure_reshaped(y_anli_r3_train)
y_anli_r3_test = ensure_reshaped(y_anli_r3_test)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import f1_score, recall_score

# Function to create a simple dense model with regularization
def create_simple_dense_model(input_shape, num_classes):
    inputs = keras.Input(shape=(input_shape,))
    dense_layer = layers.Dense(64, activation='relu')(inputs)  # Simplified model
    dropout_layer = layers.Dropout(0.2)(dense_layer)  # Reduced dropout
    dense_layer_2 = layers.Dense(32, activation='relu')(dropout_layer)
    outputs = layers.Dense(num_classes, activation='softmax')(dense_layer_2)
    
    model = keras.Model(inputs=inputs, outputs=outputs)
    return model



def train_and_evaluate(X_train, y_train, X_test, y_test, epochs=20, batch_size=32):
    model = create_simple_dense_model(
        input_shape=X_train.shape[1],  # Input feature count
        num_classes=y_train.shape[1],  # Number of output classes
    )
    
    optimizer = keras.optimizers.Adam(learning_rate=0.0005)  # Set learning rate
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=[tf.keras.metrics.Recall(), tf.keras.metrics.Precision()])
    
    # Callbacks for early stopping and learning rate adjustment
    callbacks = [
        EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3)
    ]
    
    # Fit the model with validation data and callbacks
    history = model.fit(
        X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test), callbacks=callbacks
    )
    
    # Evaluate the model on the test set
    y_pred_prob = model.predict(X_test)
    y_pred = y_pred_prob.argmax(axis=-1)
    y_true = y_test.argmax(axis=-1)
    
    recall = recall_score(y_true, y_pred, average='weighted')
    f1 = f1_score(y_true, y_pred, average='weighted')
    
    # Return history, recall, f1-score, and the model
    return history, recall, f1, model

# %%
# For SNLI
history_snli, recall_snli, f1_snli, trained_model_snli = train_and_evaluate(
    X_snli_train, y_snli_train, X_snli_test, y_snli_test, epochs=20, batch_size=32
)
print("Recall on SNLI:", recall_snli)
print("F1-score on SNLI:", f1_snli)
# Out:
# Epoch 1/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 0.5031 - precision_7: 0.9354 - recall_7: 0.7073 - val_loss: 0.2207 - val_precision_7: 0.9319 - val_recall_7: 0.9267 - learning_rate: 5.0000e-04
# Epoch 2/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2440 - precision_7: 0.9250 - recall_7: 0.9180 - val_loss: 0.2156 - val_precision_7: 0.9305 - val_recall_7: 0.9267 - learning_rate: 5.0000e-04
# Epoch 3/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2264 - precision_7: 0.9280 - recall_7: 0.9228 - val_loss: 0.2125 - val_precision_7: 0.9321 - val_recall_7: 0.9298 - learning_rate: 5.0000e-04
# Epoch 4/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2350 - precision_7: 0.9267 - recall_7: 0.9186 - val_loss: 0.2111 - val_precision_7: 0.9310 - val_recall_7: 0.9267 - learning_rate: 5.0000e-04
# Epoch 5/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2153 - precision_7: 0.9326 - recall_7: 0.9273 - val_loss: 0.2096 - val_precision_7: 0.9349 - val_recall_7: 0.9288 - learning_rate: 5.0000e-04
# Epoch 6/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2122 - precision_7: 0.9355 - recall_7: 0.9306 - val_loss: 0.2091 - val_precision_7: 0.9320 - val_recall_7: 0.9282 - learning_rate: 5.0000e-04
# Epoch 7/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2206 - precision_7: 0.9280 - recall_7: 0.9230 - val_loss: 0.2066 - val_precision_7: 0.9315 - val_recall_7: 0.9272 - learning_rate: 5.0000e-04
# Epoch 8/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2250 - precision_7: 0.9279 - recall_7: 0.9235 - val_loss: 0.2072 - val_precision_7: 0.9341 - val_recall_7: 0.9308 - learning_rate: 5.0000e-04
# Epoch 9/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2230 - precision_7: 0.9278 - recall_7: 0.9241 - val_loss: 0.2044 - val_precision_7: 0.9346 - val_recall_7: 0.9308 - learning_rate: 5.0000e-04
# Epoch 10/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2251 - precision_7: 0.9324 - recall_7: 0.9260 - val_loss: 0.2072 - val_precision_7: 0.9332 - val_recall_7: 0.9313 - learning_rate: 5.0000e-04
# Epoch 11/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2108 - precision_7: 0.9327 - recall_7: 0.9282 - val_loss: 0.2053 - val_precision_7: 0.9340 - val_recall_7: 0.9288 - learning_rate: 5.0000e-04
# Epoch 12/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2160 - precision_7: 0.9292 - recall_7: 0.9241 - val_loss: 0.2032 - val_precision_7: 0.9340 - val_recall_7: 0.9298 - learning_rate: 5.0000e-04
# Epoch 13/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2142 - precision_7: 0.9305 - recall_7: 0.9275 - val_loss: 0.2035 - val_precision_7: 0.9341 - val_recall_7: 0.9308 - learning_rate: 5.0000e-04
# Epoch 14/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2079 - precision_7: 0.9367 - recall_7: 0.9313 - val_loss: 0.2062 - val_precision_7: 0.9346 - val_recall_7: 0.9303 - learning_rate: 5.0000e-04
# Epoch 15/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2159 - precision_7: 0.9274 - recall_7: 0.9224 - val_loss: 0.2046 - val_precision_7: 0.9346 - val_recall_7: 0.9308 - learning_rate: 5.0000e-04
# Epoch 16/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2177 - precision_7: 0.9320 - recall_7: 0.9261 - val_loss: 0.2035 - val_precision_7: 0.9336 - val_recall_7: 0.9308 - learning_rate: 2.5000e-04
# Epoch 17/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2116 - precision_7: 0.9342 - recall_7: 0.9302 - val_loss: 0.2039 - val_precision_7: 0.9346 - val_recall_7: 0.9308 - learning_rate: 2.5000e-04
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Recall on SNLI: 0.9323155216284987
# F1-score on SNLI: 0.9323990443024368

# %%
# For MNLI matched
history_mnli_matched, recall_mnli_matched, f1_mnli_matched, trained_model_mnli_matched = train_and_evaluate(
    X_mnli_matched_train, y_mnli_matched_train, X_mnli_matched_test, y_mnli_matched_test, epochs=20, batch_size=32
)
print("Recall on MNLI matched:", recall_mnli_matched)
print("F1-score on MNLI matched:", f1_mnli_matched)
# Out:
# Epoch 1/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.6156 - precision_8: 0.8726 - recall_8: 0.6032 - val_loss: 0.2375 - val_precision_8: 0.9241 - val_recall_8: 0.9124 - learning_rate: 5.0000e-04
# Epoch 2/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2682 - precision_8: 0.9204 - recall_8: 0.9068 - val_loss: 0.2296 - val_precision_8: 0.9238 - val_recall_8: 0.9139 - learning_rate: 5.0000e-04
# Epoch 3/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2538 - precision_8: 0.9196 - recall_8: 0.9081 - val_loss: 0.2282 - val_precision_8: 0.9249 - val_recall_8: 0.9159 - learning_rate: 5.0000e-04
# Epoch 4/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2519 - precision_8: 0.9212 - recall_8: 0.9134 - val_loss: 0.2234 - val_precision_8: 0.9232 - val_recall_8: 0.9119 - learning_rate: 5.0000e-04
# Epoch 5/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2335 - precision_8: 0.9269 - recall_8: 0.9209 - val_loss: 0.2198 - val_precision_8: 0.9228 - val_recall_8: 0.9129 - learning_rate: 5.0000e-04
# Epoch 6/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2557 - precision_8: 0.9158 - recall_8: 0.9089 - val_loss: 0.2206 - val_precision_8: 0.9178 - val_recall_8: 0.9098 - learning_rate: 5.0000e-04
# Epoch 7/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2375 - precision_8: 0.9198 - recall_8: 0.9148 - val_loss: 0.2167 - val_precision_8: 0.9219 - val_recall_8: 0.9134 - learning_rate: 5.0000e-04
# Epoch 8/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2460 - precision_8: 0.9196 - recall_8: 0.9126 - val_loss: 0.2161 - val_precision_8: 0.9209 - val_recall_8: 0.9139 - learning_rate: 5.0000e-04
# Epoch 9/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2420 - precision_8: 0.9239 - recall_8: 0.9169 - val_loss: 0.2154 - val_precision_8: 0.9209 - val_recall_8: 0.9139 - learning_rate: 5.0000e-04
# Epoch 10/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2404 - precision_8: 0.9203 - recall_8: 0.9166 - val_loss: 0.2147 - val_precision_8: 0.9203 - val_recall_8: 0.9119 - learning_rate: 5.0000e-04
# Epoch 11/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2399 - precision_8: 0.9217 - recall_8: 0.9163 - val_loss: 0.2135 - val_precision_8: 0.9204 - val_recall_8: 0.9134 - learning_rate: 5.0000e-04
# Epoch 12/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2369 - precision_8: 0.9215 - recall_8: 0.9155 - val_loss: 0.2146 - val_precision_8: 0.9204 - val_recall_8: 0.9134 - learning_rate: 5.0000e-04
# Epoch 13/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2338 - precision_8: 0.9226 - recall_8: 0.9178 - val_loss: 0.2158 - val_precision_8: 0.9173 - val_recall_8: 0.9098 - learning_rate: 5.0000e-04
# Epoch 14/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2489 - precision_8: 0.9163 - recall_8: 0.9128 - val_loss: 0.2130 - val_precision_8: 0.9171 - val_recall_8: 0.9129 - learning_rate: 5.0000e-04
# Epoch 15/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2373 - precision_8: 0.9230 - recall_8: 0.9172 - val_loss: 0.2126 - val_precision_8: 0.9189 - val_recall_8: 0.9119 - learning_rate: 5.0000e-04
# Epoch 16/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2406 - precision_8: 0.9173 - recall_8: 0.9130 - val_loss: 0.2132 - val_precision_8: 0.9203 - val_recall_8: 0.9114 - learning_rate: 5.0000e-04
# Epoch 17/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2418 - precision_8: 0.9201 - recall_8: 0.9156 - val_loss: 0.2137 - val_precision_8: 0.9168 - val_recall_8: 0.9088 - learning_rate: 5.0000e-04
# Epoch 18/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2339 - precision_8: 0.9193 - recall_8: 0.9132 - val_loss: 0.2140 - val_precision_8: 0.9182 - val_recall_8: 0.9093 - learning_rate: 5.0000e-04
# Epoch 19/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2521 - precision_8: 0.9156 - recall_8: 0.9089 - val_loss: 0.2127 - val_precision_8: 0.9191 - val_recall_8: 0.9139 - learning_rate: 2.5000e-04
# Epoch 20/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2229 - precision_8: 0.9249 - recall_8: 0.9185 - val_loss: 0.2127 - val_precision_8: 0.9194 - val_recall_8: 0.9124 - learning_rate: 2.5000e-04
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Test loss on MNLI-m: 0.9149261334691798
# Test accuracy on MNLI-m: 0.9145791945197315

# %%
# For MNLI mismatched
history_mnli_mismatched, recall_mnli_mismatched, f1_mnli_mismatched, trained_model_mnli_mismatched = train_and_evaluate(
    X_mnli_mismatched_train, y_mnli_mismatched_train, X_mnli_mismatched_test, y_mnli_mismatched_test, epochs=20, batch_size=32
)
print("Recall on MNLI mismatched:", recall_mnli_mismatched)
print("F1-score on MNLI mismatched:", f1_mnli_mismatched)
# Out:
# Epoch 1/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - loss: 0.5755 - precision_10: 0.8698 - recall_10: 0.6498 - val_loss: 0.2645 - val_precision_10: 0.9189 - val_recall_10: 0.9105 - learning_rate: 5.0000e-04
# Epoch 2/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2468 - precision_10: 0.9260 - recall_10: 0.9176 - val_loss: 0.2538 - val_precision_10: 0.9210 - val_recall_10: 0.9126 - learning_rate: 5.0000e-04
# Epoch 3/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2663 - precision_10: 0.9130 - recall_10: 0.9037 - val_loss: 0.2494 - val_precision_10: 0.9221 - val_recall_10: 0.9151 - learning_rate: 5.0000e-04
# Epoch 4/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2486 - precision_10: 0.9192 - recall_10: 0.9118 - val_loss: 0.2450 - val_precision_10: 0.9216 - val_recall_10: 0.9146 - learning_rate: 5.0000e-04
# Epoch 5/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2383 - precision_10: 0.9213 - recall_10: 0.9142 - val_loss: 0.2431 - val_precision_10: 0.9220 - val_recall_10: 0.9136 - learning_rate: 5.0000e-04
# Epoch 6/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2495 - precision_10: 0.9168 - recall_10: 0.9084 - val_loss: 0.2428 - val_precision_10: 0.9226 - val_recall_10: 0.9156 - learning_rate: 5.0000e-04
# Epoch 7/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2456 - precision_10: 0.9171 - recall_10: 0.9082 - val_loss: 0.2421 - val_precision_10: 0.9221 - val_recall_10: 0.9146 - learning_rate: 5.0000e-04
# Epoch 8/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2423 - precision_10: 0.9204 - recall_10: 0.9137 - val_loss: 0.2432 - val_precision_10: 0.9222 - val_recall_10: 0.9161 - learning_rate: 5.0000e-04
# Epoch 9/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2388 - precision_10: 0.9184 - recall_10: 0.9121 - val_loss: 0.2422 - val_precision_10: 0.9221 - val_recall_10: 0.9151 - learning_rate: 5.0000e-04
# Epoch 10/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2481 - precision_10: 0.9180 - recall_10: 0.9085 - val_loss: 0.2423 - val_precision_10: 0.9221 - val_recall_10: 0.9151 - learning_rate: 5.0000e-04
# Epoch 11/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2447 - precision_10: 0.9183 - recall_10: 0.9105 - val_loss: 0.2410 - val_precision_10: 0.9206 - val_recall_10: 0.9136 - learning_rate: 2.5000e-04
# Epoch 12/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2300 - precision_10: 0.9208 - recall_10: 0.9114 - val_loss: 0.2408 - val_precision_10: 0.9220 - val_recall_10: 0.9136 - learning_rate: 2.5000e-04
# Epoch 13/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2358 - precision_10: 0.9192 - recall_10: 0.9119 - val_loss: 0.2409 - val_precision_10: 0.9211 - val_recall_10: 0.9141 - learning_rate: 2.5000e-04
# Epoch 14/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2409 - precision_10: 0.9197 - recall_10: 0.9107 - val_loss: 0.2399 - val_precision_10: 0.9208 - val_recall_10: 0.9156 - learning_rate: 2.5000e-04
# Epoch 15/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2336 - precision_10: 0.9217 - recall_10: 0.9149 - val_loss: 0.2393 - val_precision_10: 0.9208 - val_recall_10: 0.9156 - learning_rate: 2.5000e-04
# Epoch 16/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2347 - precision_10: 0.9225 - recall_10: 0.9156 - val_loss: 0.2407 - val_precision_10: 0.9225 - val_recall_10: 0.9136 - learning_rate: 2.5000e-04
# Epoch 17/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2316 - precision_10: 0.9263 - recall_10: 0.9174 - val_loss: 0.2400 - val_precision_10: 0.9211 - val_recall_10: 0.9146 - learning_rate: 2.5000e-04
# Epoch 18/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2362 - precision_10: 0.9178 - recall_10: 0.9083 - val_loss: 0.2402 - val_precision_10: 0.9215 - val_recall_10: 0.9136 - learning_rate: 2.5000e-04
# Epoch 19/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2300 - precision_10: 0.9239 - recall_10: 0.9159 - val_loss: 0.2411 - val_precision_10: 0.9232 - val_recall_10: 0.9161 - learning_rate: 1.2500e-04
# Epoch 20/20
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2324 - precision_10: 0.9230 - recall_10: 0.9145 - val_loss: 0.2406 - val_precision_10: 0.9217 - val_recall_10: 0.9156 - learning_rate: 1.2500e-04
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Recall on MNLI mismatched: 0.9196746314184037
# F1-score on MNLI mismatched: 0.9198701517572294

# %%
# For ANLI Round 1
history_anli_r1, recall_anli_r1, f1_anli_r1, trained_model_anli_r1 = train_and_evaluate(
    X_anli_r1_train, y_anli_r1_train, X_anli_r1_test, y_anli_r1_test, epochs=20, batch_size=32
)
print("Recall on ANLI R1:", recall_anli_r1)
print("F1-score on ANLI R1:", f1_anli_r1)
# Out:
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - loss: 1.1975 - precision_11: 0.2667 - recall_11: 0.0377 - val_loss: 0.9613 - val_precision_11: 0.8293 - val_recall_11: 0.1700 - learning_rate: 5.0000e-04
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9129 - precision_11: 0.8493 - recall_11: 0.2779 - val_loss: 0.8538 - val_precision_11: 0.7438 - val_recall_11: 0.4500 - learning_rate: 5.0000e-04
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7849 - precision_11: 0.8279 - recall_11: 0.4833 - val_loss: 0.7999 - val_precision_11: 0.7312 - val_recall_11: 0.5850 - learning_rate: 5.0000e-04
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7531 - precision_11: 0.7846 - recall_11: 0.6078 - val_loss: 0.7755 - val_precision_11: 0.7368 - val_recall_11: 0.6300 - learning_rate: 5.0000e-04
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6512 - precision_11: 0.8120 - recall_11: 0.6571 - val_loss: 0.7677 - val_precision_11: 0.7299 - val_recall_11: 0.6350 - learning_rate: 5.0000e-04
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6718 - precision_11: 0.7699 - recall_11: 0.6738 - val_loss: 0.7610 - val_precision_11: 0.7330 - val_recall_11: 0.6450 - learning_rate: 5.0000e-04
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6575 - precision_11: 0.7743 - recall_11: 0.6844 - val_loss: 0.7596 - val_precision_11: 0.7293 - val_recall_11: 0.6600 - learning_rate: 5.0000e-04
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6473 - precision_11: 0.7608 - recall_11: 0.6955 - val_loss: 0.7519 - val_precision_11: 0.7389 - val_recall_11: 0.6650 - learning_rate: 5.0000e-04
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5522 - precision_11: 0.8060 - recall_11: 0.7555 - val_loss: 0.7534 - val_precision_11: 0.7293 - val_recall_11: 0.6600 - learning_rate: 5.0000e-04
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6506 - precision_11: 0.7603 - recall_11: 0.7030 - val_loss: 0.7509 - val_precision_11: 0.7312 - val_recall_11: 0.6800 - learning_rate: 5.0000e-04
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6118 - precision_11: 0.7806 - recall_11: 0.7434 - val_loss: 0.7547 - val_precision_11: 0.7337 - val_recall_11: 0.6750 - learning_rate: 5.0000e-04
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5674 - precision_11: 0.7824 - recall_11: 0.7415 - val_loss: 0.7547 - val_precision_11: 0.7297 - val_recall_11: 0.6750 - learning_rate: 5.0000e-04
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6192 - precision_11: 0.7824 - recall_11: 0.7206 - val_loss: 0.7487 - val_precision_11: 0.7308 - val_recall_11: 0.6650 - learning_rate: 5.0000e-04
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6219 - precision_11: 0.7811 - recall_11: 0.7192 - val_loss: 0.7455 - val_precision_11: 0.7366 - val_recall_11: 0.6850 - learning_rate: 5.0000e-04
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5931 - precision_11: 0.7797 - recall_11: 0.7234 - val_loss: 0.7484 - val_precision_11: 0.7273 - val_recall_11: 0.6800 - learning_rate: 5.0000e-04
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6307 - precision_11: 0.7878 - recall_11: 0.7241 - val_loss: 0.7491 - val_precision_11: 0.7312 - val_recall_11: 0.6800 - learning_rate: 5.0000e-04
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5818 - precision_11: 0.7955 - recall_11: 0.7333 - val_loss: 0.7452 - val_precision_11: 0.7268 - val_recall_11: 0.6650 - learning_rate: 5.0000e-04
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5488 - precision_11: 0.8136 - recall_11: 0.7507 - val_loss: 0.7470 - val_precision_11: 0.7312 - val_recall_11: 0.6800 - learning_rate: 5.0000e-04
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5988 - precision_11: 0.7893 - recall_11: 0.7449 - val_loss: 0.7438 - val_precision_11: 0.7377 - val_recall_11: 0.6750 - learning_rate: 5.0000e-04
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5865 - precision_11: 0.7883 - recall_11: 0.7378 - val_loss: 0.7445 - val_precision_11: 0.7351 - val_recall_11: 0.6800 - learning_rate: 5.0000e-04
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Recall on ANLI R1: 0.705
# F1-score on ANLI R1: 0.7061531439004907

# %%
# For ANLI Round 2
history_anli_r2, recall_anli_r2, f1_anli_r2, trained_model_anli_r2 = train_and_evaluate(
    X_anli_r2_train, y_anli_r2_train, X_anli_r2_test, y_anli_r2_test, epochs=20, batch_size=32
)
print("Recall on ANLI R2:", recall_anli_r2)
print("F1-score on ANLI R2:", f1_anli_r2)
# Out:
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 1.1285 - precision_12: 0.2792 - recall_12: 0.0328 - val_loss: 0.9843 - val_precision_12: 0.7931 - val_recall_12: 0.1150 - learning_rate: 5.0000e-04
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9730 - precision_12: 0.6907 - recall_12: 0.1636 - val_loss: 0.8731 - val_precision_12: 0.7848 - val_recall_12: 0.3100 - learning_rate: 5.0000e-04
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8847 - precision_12: 0.7071 - recall_12: 0.3826 - val_loss: 0.8150 - val_precision_12: 0.7744 - val_recall_12: 0.5150 - learning_rate: 5.0000e-04
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8625 - precision_12: 0.6864 - recall_12: 0.4581 - val_loss: 0.7838 - val_precision_12: 0.7756 - val_recall_12: 0.6050 - learning_rate: 5.0000e-04
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8030 - precision_12: 0.7200 - recall_12: 0.5327 - val_loss: 0.7652 - val_precision_12: 0.7692 - val_recall_12: 0.6500 - learning_rate: 5.0000e-04
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8159 - precision_12: 0.6762 - recall_12: 0.5539 - val_loss: 0.7544 - val_precision_12: 0.7644 - val_recall_12: 0.6650 - learning_rate: 5.0000e-04
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7798 - precision_12: 0.6980 - recall_12: 0.5730 - val_loss: 0.7477 - val_precision_12: 0.7667 - val_recall_12: 0.6900 - learning_rate: 5.0000e-04
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7732 - precision_12: 0.7223 - recall_12: 0.6140 - val_loss: 0.7419 - val_precision_12: 0.7667 - val_recall_12: 0.6900 - learning_rate: 5.0000e-04
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7700 - precision_12: 0.7201 - recall_12: 0.5885 - val_loss: 0.7405 - val_precision_12: 0.7654 - val_recall_12: 0.6850 - learning_rate: 5.0000e-04
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7496 - precision_12: 0.7350 - recall_12: 0.6034 - val_loss: 0.7393 - val_precision_12: 0.7697 - val_recall_12: 0.6850 - learning_rate: 5.0000e-04
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8120 - precision_12: 0.6906 - recall_12: 0.5880 - val_loss: 0.7369 - val_precision_12: 0.7654 - val_recall_12: 0.6850 - learning_rate: 5.0000e-04
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7977 - precision_12: 0.6905 - recall_12: 0.5788 - val_loss: 0.7334 - val_precision_12: 0.7611 - val_recall_12: 0.6850 - learning_rate: 5.0000e-04
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7493 - precision_12: 0.7155 - recall_12: 0.6077 - val_loss: 0.7329 - val_precision_12: 0.7709 - val_recall_12: 0.6900 - learning_rate: 5.0000e-04
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7326 - precision_12: 0.7252 - recall_12: 0.6234 - val_loss: 0.7357 - val_precision_12: 0.7759 - val_recall_12: 0.6750 - learning_rate: 5.0000e-04
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7775 - precision_12: 0.6743 - recall_12: 0.5632 - val_loss: 0.7356 - val_precision_12: 0.7746 - val_recall_12: 0.6700 - learning_rate: 5.0000e-04
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7711 - precision_12: 0.7026 - recall_12: 0.6055 - val_loss: 0.7335 - val_precision_12: 0.7654 - val_recall_12: 0.6850 - learning_rate: 5.0000e-04
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7483 - precision_12: 0.7006 - recall_12: 0.6129 - val_loss: 0.7337 - val_precision_12: 0.7727 - val_recall_12: 0.6800 - learning_rate: 2.5000e-04
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7283 - precision_12: 0.7303 - recall_12: 0.6404 - val_loss: 0.7313 - val_precision_12: 0.7740 - val_recall_12: 0.6850 - learning_rate: 2.5000e-04
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8071 - precision_12: 0.6799 - recall_12: 0.6008 - val_loss: 0.7335 - val_precision_12: 0.7791 - val_recall_12: 0.6700 - learning_rate: 2.5000e-04
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7395 - precision_12: 0.7116 - recall_12: 0.6104 - val_loss: 0.7334 - val_precision_12: 0.7759 - val_recall_12: 0.6750 - learning_rate: 2.5000e-04
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Recall on ANLI R2: 0.74
# F1-score on ANLI R2: 0.7404140487915322

# %%
# For ANLI Round 3
history_anli_r3, recall_anli_r3, f1_anli_r3, trained_model_anli_r3 = train_and_evaluate(
    X_anli_r3_train, y_anli_r3_train, X_anli_r3_test, y_anli_r3_test, epochs=20, batch_size=32
)
print("Recall on ANLI R3:", recall_anli_r3)
print("F1-score on ANLI R3:", f1_anli_r3)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 1.1492 - precision_13: 0.2550 - recall_13: 0.0485 - val_loss: 0.9528 - val_precision_13: 0.7778 - val_recall_13: 0.0583 - learning_rate: 5.0000e-04
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9576 - precision_13: 0.6706 - recall_13: 0.1610 - val_loss: 0.8166 - val_precision_13: 0.8143 - val_recall_13: 0.4750 - learning_rate: 5.0000e-04
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8599 - precision_13: 0.7319 - recall_13: 0.3718 - val_loss: 0.7437 - val_precision_13: 0.7541 - val_recall_13: 0.5750 - learning_rate: 5.0000e-04
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8309 - precision_13: 0.7089 - recall_13: 0.4897 - val_loss: 0.7091 - val_precision_13: 0.7313 - val_recall_13: 0.6125 - learning_rate: 5.0000e-04
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7713 - precision_13: 0.7194 - recall_13: 0.5639 - val_loss: 0.6918 - val_precision_13: 0.7238 - val_recall_13: 0.6333 - learning_rate: 5.0000e-04
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7698 - precision_13: 0.7090 - recall_13: 0.5773 - val_loss: 0.6818 - val_precision_13: 0.7176 - val_recall_13: 0.6458 - learning_rate: 5.0000e-04
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7781 - precision_13: 0.6959 - recall_13: 0.5864 - val_loss: 0.6766 - val_precision_13: 0.7078 - val_recall_13: 0.6458 - learning_rate: 5.0000e-04
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7705 - precision_13: 0.7039 - recall_13: 0.5874 - val_loss: 0.6705 - val_precision_13: 0.7136 - val_recall_13: 0.6542 - learning_rate: 5.0000e-04
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7783 - precision_13: 0.7012 - recall_13: 0.5779 - val_loss: 0.6705 - val_precision_13: 0.7117 - val_recall_13: 0.6583 - learning_rate: 5.0000e-04
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7431 - precision_13: 0.7262 - recall_13: 0.6148 - val_loss: 0.6651 - val_precision_13: 0.7168 - val_recall_13: 0.6750 - learning_rate: 5.0000e-04
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7730 - precision_13: 0.6944 - recall_13: 0.5749 - val_loss: 0.6655 - val_precision_13: 0.7149 - val_recall_13: 0.6583 - learning_rate: 5.0000e-04
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7509 - precision_13: 0.7221 - recall_13: 0.6228 - val_loss: 0.6660 - val_precision_13: 0.7143 - val_recall_13: 0.6667 - learning_rate: 5.0000e-04
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7031 - precision_13: 0.7340 - recall_13: 0.6249 - val_loss: 0.6633 - val_precision_13: 0.7188 - val_recall_13: 0.6708 - learning_rate: 5.0000e-04
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7449 - precision_13: 0.7321 - recall_13: 0.6139 - val_loss: 0.6648 - val_precision_13: 0.7207 - val_recall_13: 0.6667 - learning_rate: 5.0000e-04
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7463 - precision_13: 0.7109 - recall_13: 0.6180 - val_loss: 0.6608 - val_precision_13: 0.7143 - val_recall_13: 0.6667 - learning_rate: 5.0000e-04
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7465 - precision_13: 0.7186 - recall_13: 0.6280 - val_loss: 0.6605 - val_precision_13: 0.7175 - val_recall_13: 0.6667 - learning_rate: 5.0000e-04
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7445 - precision_13: 0.7060 - recall_13: 0.6067 - val_loss: 0.6609 - val_precision_13: 0.7200 - val_recall_13: 0.6750 - learning_rate: 5.0000e-04
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7789 - precision_13: 0.6708 - recall_13: 0.5795 - val_loss: 0.6605 - val_precision_13: 0.7175 - val_recall_13: 0.6667 - learning_rate: 5.0000e-04
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7120 - precision_13: 0.7151 - recall_13: 0.6354 - val_loss: 0.6570 - val_precision_13: 0.7168 - val_recall_13: 0.6750 - learning_rate: 5.0000e-04
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7338 - precision_13: 0.7010 - recall_13: 0.6204 - val_loss: 0.6586 - val_precision_13: 0.7297 - val_recall_13: 0.6750 - learning_rate: 5.0000e-04
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Recall on ANLI R3: 0.7
# F1-score on ANLI R3: 0.6958105744518337

# %%
from sklearn.model_selection import train_test_split

# Concatenate the training data for X and y from all tasks
X_combined = np.concatenate([X_snli, X_mnli_matched, X_mnli_mismatched, X_anli_r1, X_anli_r2, X_anli_r3])
y_combined = np.concatenate([y_snli, y_mnli_matched, y_mnli_mismatched, y_anli_r1, y_anli_r2, y_anli_r3])

# Fit the scaler to each task's feature data
X_combined_scaled = scaler.fit_transform(X_combined)
y_combined_encoded = encoder.fit_transform(y_combined.reshape(-1, 1))

# Define the test size and random state for reproducibility
test_size = 0.2
random_state = 42

# Split data for SNLI task
X_combined_train, X_combined_test, y_combined_train, y_combined_test = train_test_split(
    X_combined_scaled, y_combined_encoded, test_size=test_size, random_state=random_state
)


# Apply Data Conversion and Reshaping for Other Tasks
X_combined_train = ensure_dense(X_combined_train)
X_combined_test = ensure_dense(X_combined_test)
y_combined_train = ensure_dense(y_combined_train)
y_combined_test = ensure_dense(y_combined_test)

# combined
X_combined_train = ensure_reshaped(X_combined_train)
X_combined_test = ensure_reshaped(X_combined_test)



# For the combined task
history_combined, recall_combined, f1_combined, trained_model_combined = train_and_evaluate(
    X_combined_train, y_combined_train, X_combined_test, y_combined_test, epochs=20, batch_size=32
)
print("Recall on Combined tasks:", recall_combined)
print("F1-score on Combined tasks:", f1_combined)
# Out:
# Epoch 1/20
# 817/817 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 0.4874 - precision_14: 0.8643 - recall_14: 0.7440 - val_loss: 0.3062 - val_precision_14: 0.8988 - val_recall_14: 0.8863 - learning_rate: 5.0000e-04
# Epoch 2/20
# 817/817 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.3054 - precision_14: 0.9039 - recall_14: 0.8885 - val_loss: 0.3028 - val_precision_14: 0.8993 - val_recall_14: 0.8881 - learning_rate: 5.0000e-04
# Epoch 3/20
# 817/817 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2969 - precision_14: 0.9053 - recall_14: 0.8902 - val_loss: 0.2985 - val_precision_14: 0.9006 - val_recall_14: 0.8883 - learning_rate: 5.0000e-04
# Epoch 4/20
# 817/817 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2931 - precision_14: 0.9051 - recall_14: 0.8925 - val_loss: 0.2983 - val_precision_14: 0.9006 - val_recall_14: 0.8875 - learning_rate: 5.0000e-04
# Epoch 5/20
# 817/817 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2930 - precision_14: 0.9026 - recall_14: 0.8885 - val_loss: 0.2975 - val_precision_14: 0.8993 - val_recall_14: 0.8878 - learning_rate: 5.0000e-04
# Epoch 6/20
# 817/817 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2906 - precision_14: 0.9039 - recall_14: 0.8913 - val_loss: 0.2958 - val_precision_14: 0.8996 - val_recall_14: 0.8886 - learning_rate: 5.0000e-04
# Epoch 7/20
# 817/817 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2935 - precision_14: 0.9046 - recall_14: 0.8915 - val_loss: 0.2998 - val_precision_14: 0.8966 - val_recall_14: 0.8874 - learning_rate: 5.0000e-04
# Epoch 8/20
# 817/817 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2963 - precision_14: 0.9028 - recall_14: 0.8895 - val_loss: 0.2950 - val_precision_14: 0.9008 - val_recall_14: 0.8891 - learning_rate: 5.0000e-04
# Epoch 9/20
# 817/817 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2909 - precision_14: 0.9049 - recall_14: 0.8916 - val_loss: 0.2949 - val_precision_14: 0.8997 - val_recall_14: 0.8871 - learning_rate: 5.0000e-04
# Epoch 10/20
# 817/817 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2914 - precision_14: 0.9031 - recall_14: 0.8890 - val_loss: 0.2941 - val_precision_14: 0.8999 - val_recall_14: 0.8884 - learning_rate: 5.0000e-04
# Epoch 11/20
# 817/817 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.3013 - precision_14: 0.8989 - recall_14: 0.8831 - val_loss: 0.2944 - val_precision_14: 0.8988 - val_recall_14: 0.8891 - learning_rate: 5.0000e-04
# Epoch 12/20
# 817/817 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2930 - precision_14: 0.9027 - recall_14: 0.8890 - val_loss: 0.2932 - val_precision_14: 0.9004 - val_recall_14: 0.8895 - learning_rate: 5.0000e-04
# Epoch 13/20
# 817/817 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2871 - precision_14: 0.9038 - recall_14: 0.8900 - val_loss: 0.2933 - val_precision_14: 0.9002 - val_recall_14: 0.8884 - learning_rate: 5.0000e-04
# Epoch 14/20
# 817/817 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2821 - precision_14: 0.9063 - recall_14: 0.8931 - val_loss: 0.2935 - val_precision_14: 0.8997 - val_recall_14: 0.8878 - learning_rate: 5.0000e-04
# Epoch 15/20
# 817/817 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2900 - precision_14: 0.9047 - recall_14: 0.8897 - val_loss: 0.2948 - val_precision_14: 0.9000 - val_recall_14: 0.8894 - learning_rate: 5.0000e-04
# Epoch 16/20
# 817/817 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2937 - precision_14: 0.9037 - recall_14: 0.8891 - val_loss: 0.2913 - val_precision_14: 0.8998 - val_recall_14: 0.8880 - learning_rate: 2.5000e-04
# Epoch 17/20
# 817/817 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2789 - precision_14: 0.9097 - recall_14: 0.8960 - val_loss: 0.2914 - val_precision_14: 0.9001 - val_recall_14: 0.8883 - learning_rate: 2.5000e-04
# Epoch 18/20
# 817/817 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2818 - precision_14: 0.9081 - recall_14: 0.8939 - val_loss: 0.2918 - val_precision_14: 0.9004 - val_recall_14: 0.8891 - learning_rate: 2.5000e-04
# Epoch 19/20
# 817/817 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2919 - precision_14: 0.9038 - recall_14: 0.8902 - val_loss: 0.2906 - val_precision_14: 0.9013 - val_recall_14: 0.8874 - learning_rate: 2.5000e-04
# Epoch 20/20
# 817/817 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2869 - precision_14: 0.9068 - recall_14: 0.8915 - val_loss: 0.2906 - val_precision_14: 0.9010 - val_recall_14: 0.8888 - learning_rate: 2.5000e-04
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Recall on Combined tasks: 0.8948737566947207
# F1-score on Combined tasks: 0.8949093550060861
