# %%
import pandas as pd

# Load the SNLI test data (including true labels)
snli_test_path = "/kaggle/input/stanford-natural-language-inference-corpus/snli_1.0_test.csv"
snli_test_df = pd.read_csv(snli_test_path)

# Define file paths for SNLI prediction files
snli_predictions_paths = {
    "deberta": "/kaggle/input/deberta-nli/deberta_snli_predictions.csv",
    "roberta": "/kaggle/input/roberta/roberta_snli_predictions.csv",
    "albert": "/kaggle/input/albert/albert_snli_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_snli = "/kaggle/working/combined_snli_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_snli_df = pd.DataFrame(columns=columns)

label_mapping = {'entailment': 0, 'neutral': 1, 'contradiction': 2}

# Load and merge the predictions
for model, path in snli_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_snli_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_snli_df['True_Label'] = snli_test_df['gold_label'].map(label_mapping)

# Convert True_Label to integer type
combined_snli_df['True_Label'] = combined_snli_df['True_Label'].astype('Int64')

# Save the combined DataFrame to CSV
combined_snli_df.to_csv(output_csv_path_snli, index=False)

print(f"Combined SNLI predictions with true labels saved to {output_csv_path_snli}")
# Out:
# Combined SNLI predictions with true labels saved to /kaggle/working/combined_snli_df

# %%
combined_snli_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.034767         0.962592               0.002641
# 1            0.001921         0.319032               0.679047
# 2            0.998783         0.000764               0.000453
# 3            0.001001         0.997708               0.001291
# 4            0.001080         0.301363               0.697557
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.012451         0.927093               0.060457
# 1            0.752766         0.242251               0.004983
# 2            0.000254         0.004494               0.995253
# 3            0.005844         0.990736               0.003419
# 4            0.278348         0.718575               0.003076
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.008653        0.947434              0.043913           1
# 1           0.740332        0.256434              0.003235           0
# 2           0.004677        0.060481              0.934843           2
# 3           0.034056        0.956687              0.009257           1
# 4           0.498761        0.499270              0.001969           0

# %%
# Load the ANLI Round 1 test data (including true labels)
mnli_matched_test_path = "/kaggle/input/nli-dataset-for-sentence-understanding/mnli_validation_matched.csv"
mnli_matched_test_df = pd.read_csv(mnli_matched_test_path)

# Define file paths for ANLI Round 1 prediction files
mnli_matched_predictions_paths = {
    "deberta": "/kaggle/input/validation/deberta_mnli_matched_val_predictions.csv",
    "roberta": "/kaggle/input/validation/roberta_mnli_matched_val_predictions.csv",
    "albert": "/kaggle/input/validation/albert_mnli_matched_val_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_mnli_matched = "/kaggle/working/combined_mnli_matched_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_mnli_matched_df = pd.DataFrame(columns=columns)

# Load and merge the predictions
for model, path in mnli_matched_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_mnli_matched_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_mnli_matched_df['True_Label'] = mnli_matched_test_df['label']

# Save the combined DataFrame to CSV
combined_mnli_matched_df.to_csv(output_csv_path_mnli_matched, index=False)

print(f"Combined MNLI-matched predictions with true labels saved to {output_csv_path_mnli_matched}")
# Out:
# Combined MNLI-matched predictions with true labels saved to /kaggle/working/combined_mnli_matched_df

# %%
combined_mnli_matched_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.005164         0.993364               0.001472
# 1            0.999153         0.000526               0.000321
# 2            0.000989         0.044792               0.954219
# 3            0.994965         0.004808               0.000228
# 4            0.999657         0.000220               0.000123
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.017844         0.950246               0.031909
# 1            0.001413         0.002030               0.996557
# 2            0.954781         0.042249               0.002970
# 3            0.000343         0.003511               0.996146
# 4            0.000079         0.000496               0.999425
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.010844        0.983012              0.006144           1
# 1           0.005388        0.007536              0.987076           2
# 2           0.853862        0.143483              0.002655           0
# 3           0.004128        0.070757              0.925115           2
# 4           0.003864        0.029262              0.966875           2

# %%
# Load the ANLI Round 1 test data (including true labels)
mnli_mismatched_test_path = "/kaggle/input/nli-dataset-for-sentence-understanding/mnli_validation_mismatched.csv"
mnli_mismatched_test_df = pd.read_csv(mnli_mismatched_test_path)

# Define file paths for ANLI Round 1 prediction files
mnli_mismatched_predictions_paths = {
    "deberta": "/kaggle/input/validation/deberta_mnli_mismatched_val_predictions.csv",
    "roberta": "/kaggle/input/validation/roberta_mnli_mismatched_val_predictions.csv",
    "albert": "/kaggle/input/validation/albert_mnli_mismatched_val_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_mnli_mismatched = "/kaggle/working/combined_mnli_mismatched_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_mnli_mismatched_df = pd.DataFrame(columns=columns)

# Load and merge the predictions
for model, path in mnli_mismatched_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_mnli_mismatched_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_mnli_mismatched_df['True_Label'] = mnli_mismatched_test_df['label']

# Save the combined DataFrame to CSV
combined_mnli_mismatched_df.to_csv(output_csv_path_mnli_mismatched, index=False)

print(f"Combined MNLI-mismatched predictions with true labels saved to {output_csv_path_mnli_mismatched}")
# Out:
# Combined MNLI-mismatched predictions with true labels saved to /kaggle/working/combined_mnli_mismatched_df

# %%
combined_mnli_mismatched_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.999667         0.000160               0.000173
# 1            0.998119         0.000962               0.000919
# 2            0.000552         0.004809               0.994639
# 3            0.827653         0.171961               0.000386
# 4            0.000292         0.002875               0.996833
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.000068         0.000402               0.999529
# 1            0.000183         0.001511               0.998306
# 2            0.986062         0.012020               0.001918
# 3            0.000478         0.270953               0.728569
# 4            0.975167         0.021904               0.002929
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.000894        0.003787              0.995318           2
# 1           0.006421        0.010224              0.983355           2
# 2           0.975041        0.023354              0.001605           0
# 3           0.001722        0.796122              0.202156           2
# 4           0.965952        0.032748              0.001300           0

# %%
# Load the ANLI Round 1 test data (including true labels)
anli_r1_test_path = "/kaggle/input/anli-a-large-scale-nli-benchmark-dataset/test_r1.csv"
anli_r1_test_df = pd.read_csv(anli_r1_test_path)

# Define file paths for ANLI Round 1 prediction files
anli_r1_predictions_paths = {
    "deberta": "/kaggle/input/deberta-nli/deberta_anli_r1_predictions.csv",
    "roberta": "/kaggle/input/roberta/roberta_anli_r1_predictions.csv",
    "albert": "/kaggle/input/albert/albert_anli_r1_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_anli_r1 = "/kaggle/working/combined_anli_r1_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_anli_r1_df = pd.DataFrame(columns=columns)

# Load and merge the predictions
for model, path in anli_r1_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_anli_r1_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_anli_r1_df['True_Label'] = anli_r1_test_df['label']

# Save the combined DataFrame to CSV
combined_anli_r1_df.to_csv(output_csv_path_anli_r1, index=False)

print(f"Combined ANLI Round 1 predictions with true labels saved to {output_csv_path_anli_r1}")
# Out:
# Combined ANLI Round 1 predictions with true labels saved to /kaggle/working/combined_anli_r1_df

# %%
combined_anli_r1_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.015388         0.976305               0.008307
# 1            0.224603         0.501549               0.273848
# 2            0.006642         0.976690               0.016669
# 3            0.966494         0.032235               0.001272
# 4            0.880736         0.028293               0.090971
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.996714         0.000376               0.002910
# 1            0.875720         0.000724               0.123556
# 2            0.999484         0.000330               0.000186
# 3            0.000686         0.998181               0.001133
# 4            0.000378         0.000197               0.999425
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.322974        0.667628              0.009398           0
# 1           0.998526        0.000604              0.000869           0
# 2           0.783352        0.212241              0.004407           0
# 3           0.002134        0.989523              0.008343           1
# 4           0.023283        0.013253              0.963464           2

# %%
# Load the ANLI Round 2 test data (including true labels)
anli_r2_test_path = "/kaggle/input/anli-a-large-scale-nli-benchmark-dataset/test_r2.csv"
anli_r2_test_df = pd.read_csv(anli_r2_test_path)

# Define file paths for ANLI Round 2 prediction files
anli_r2_predictions_paths = {
    "deberta": "/kaggle/input/deberta-nli/deberta_anli_r2_predictions.csv",
    "roberta": "/kaggle/input/roberta/roberta_anli_r2_predictions.csv",
    "albert": "/kaggle/input/albert/albert_anli_r2_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_anli_r2 = "/kaggle/working/combined_anli_r2_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_anli_r2_df = pd.DataFrame(columns=columns)

# Load and merge the predictions
for model, path in anli_r2_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_anli_r2_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_anli_r2_df['True_Label'] = anli_r2_test_df['label']

# Save the combined DataFrame to CSV
combined_anli_r2_df.to_csv(output_csv_path_anli_r2, index=False)

print(f"Combined ANLI Round 2 predictions with true labels saved to {output_csv_path_anli_r2}")
# Out:
# Combined ANLI Round 2 predictions with true labels saved to /kaggle/working/combined_anli_r2_df

# %%
combined_anli_r2_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.001309         0.029617               0.969075
# 1            0.724144         0.273676               0.002180
# 2            0.071604         0.917894               0.010503
# 3            0.066162         0.929179               0.004659
# 4            0.906199         0.089873               0.003928
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.999506         0.000264               0.000230
# 1            0.026951         0.054230               0.918819
# 2            0.001282         0.998108               0.000610
# 3            0.007091         0.992694               0.000215
# 4            0.006259         0.989432               0.004309
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.863365        0.133388              0.003246           0
# 1           0.072900        0.904344              0.022756           1
# 2           0.027402        0.972218              0.000380           0
# 3           0.632171        0.365194              0.002635           1
# 4           0.064109        0.234642              0.701249           2

# %%
# Load the ANLI Round 3 test data (including true labels)
anli_r3_test_path = "/kaggle/input/anli-a-large-scale-nli-benchmark-dataset/test_r3.csv"
anli_r3_test_df = pd.read_csv(anli_r3_test_path)

# Define file paths for ANLI Round 2 prediction files
anli_r3_predictions_paths = {
    "deberta": "/kaggle/input/deberta-nli/deberta_anli_r3_predictions.csv",
    "roberta": "/kaggle/input/roberta/roberta_anli_r3_predictions.csv",
    "albert": "/kaggle/input/albert/albert_anli_r3_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_anli_r3 = "/kaggle/working/combined_anli_r3_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_anli_r3_df = pd.DataFrame(columns=columns)

# Load and merge the predictions
for model, path in anli_r3_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_anli_r3_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_anli_r3_df['True_Label'] = anli_r3_test_df['label']

# Save the combined DataFrame to CSV
combined_anli_r3_df.to_csv(output_csv_path_anli_r3, index=False)

print(f"Combined ANLI Round 3 predictions with true labels saved to {output_csv_path_anli_r3}")
# Out:
# Combined ANLI Round 3 predictions with true labels saved to /kaggle/working/combined_anli_r3_df

# %%
combined_anli_r3_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.005921         0.960529               0.033551
# 1            0.009586         0.934714               0.055700
# 2            0.003428         0.976393               0.020179
# 3            0.004633         0.023985               0.971382
# 4            0.017428         0.633695               0.348877
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.022959         0.976533               0.000509
# 1            0.999611         0.000205               0.000185
# 2            0.002020         0.997897               0.000083
# 3            0.974441         0.024459               0.001100
# 4            0.984416         0.011166               0.004419
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.001848        0.998084              0.000067           0
# 1           0.951772        0.048075              0.000153           0
# 2           0.001014        0.998984              0.000002           0
# 3           0.996749        0.000989              0.002262           0
# 4           0.000518        0.128416              0.871066           0

# %%
# Check for missing values
missing_values_anli1 = combined_anli_r1_df.isnull().sum()

missing_values_anli2 = combined_anli_r2_df.isnull().sum()

missing_values_anli3 = combined_anli_r3_df.isnull().sum()

missing_values_snli = combined_snli_df.isnull().sum()

missing_values_mnli_matched = combined_mnli_matched_df.isnull().sum()

missing_values_mnli_mismatched = combined_mnli_mismatched_df.isnull().sum()

# %%
missing_values_anli1
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
missing_values_anli2
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
missing_values_anli3
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
missing_values_snli
# Out:
# Deberta_Entailment         0
# Deberta_Neutral            0
# Deberta_Contradiction      0
# Roberta_Entailment         0
# Roberta_Neutral            0
# Roberta_Contradiction      0
# Albert_Entailment          0
# Albert_Neutral             0
# Albert_Contradiction       0
# True_Label               176
# dtype: int64

# %%
missing_values_mnli_matched
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
missing_values_mnli_mismatched
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
combined_snli_df.dropna(subset=['True_Label'], inplace=True)

# %%
# Verify missing values again after removal
missing_values_snli_after_removal = combined_snli_df.isnull().sum()
print(missing_values_snli_after_removal)
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
combined_snli_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9824 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Deberta_Entailment     9824 non-null   float64
#  1   Deberta_Neutral        9824 non-null   float64
#  2   Deberta_Contradiction  9824 non-null   float64
#  3   Roberta_Entailment     9824 non-null   float64
#  4   Roberta_Neutral        9824 non-null   float64
#  5   Roberta_Contradiction  9824 non-null   float64
#  6   Albert_Entailment      9824 non-null   float64
#  7   Albert_Neutral         9824 non-null   float64
#  8   Albert_Contradiction   9824 non-null   float64
#  9   True_Label             9824 non-null   Int64
# dtypes: Int64(1), float64(9)
# memory usage: 853.8 KB

# %%
combined_snli_df
# Out:
#       Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0               0.034767         0.962592               0.002641
# 1               0.001921         0.319032               0.679047
# 2               0.998783         0.000764               0.000453
# 3               0.001001         0.997708               0.001291
# 4               0.001080         0.301363               0.697557
# ...                  ...              ...                    ...
# 9995            0.998825         0.001033               0.000142
# 9996            0.000704         0.009793               0.989503
# 9997            0.999171         0.000493               0.000336
# 9998            0.000267         0.002178               0.997556
# 9999            0.003641         0.995224               0.001135
#
#       Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0               0.012451         0.927093               0.060457
# 1               0.752766         0.242251               0.004983
# 2               0.000254         0.004494               0.995253
# 3               0.005844         0.990736               0.003419
# 4               0.278348         0.718575               0.003076
# ...                  ...              ...                    ...
# 9995            0.001264         0.028942               0.969794
# 9996            0.780946         0.217053               0.002001
# 9997            0.000054         0.000765               0.999181
# 9998            0.983402         0.015884               0.000714
# 9999            0.000904         0.995495               0.003601
#
#       Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0              0.008653        0.947434              0.043913           1
# 1              0.740332        0.256434              0.003235           0
# 2              0.004677        0.060481              0.934843           2
# 3              0.034056        0.956687              0.009257           1
# 4              0.498761        0.499270              0.001969           0
# ...                 ...             ...                   ...         ...
# 9995           0.006420        0.057240              0.936340           2
# 9996           0.894637        0.104095              0.001267           0
# 9997           0.000838        0.002670              0.996493           2
# 9998           0.984347        0.015223              0.000430           0
# 9999           0.005047        0.990218              0.004735           1
#
# [9824 rows x 10 columns]

# %%
import numpy as np

def calculate_margin(row):
    # Assuming the row only contains the probabilities
    sorted_probs = np.sort(row)  # Sort probabilities in ascending order
    if len(sorted_probs) > 1:
        return sorted_probs[-1] - sorted_probs[-2]  # Difference between the highest and second highest
    else:
        return 0  # This handles the edge case where there is only one probability value

# %%
# Applying to a sample DataFrame with made-up column names
combined_snli_df['confidence_margin_entailment'] = combined_snli_df[['Deberta_Entailment', 'Roberta_Entailment', 'Albert_Entailment']].apply(calculate_margin, axis=1)
combined_snli_df['confidence_margin_neutral'] = combined_snli_df[['Deberta_Neutral', 'Roberta_Neutral', 'Albert_Neutral']].apply(calculate_margin, axis=1)
combined_snli_df['confidence_margin_contradiction'] = combined_snli_df[['Deberta_Contradiction', 'Roberta_Contradiction', 'Albert_Contradiction']].apply(calculate_margin, axis=1)


# Applying to a sample DataFrame with made-up column names
combined_mnli_matched_df['confidence_margin_entailment'] = combined_mnli_matched_df[['Deberta_Entailment', 'Roberta_Entailment', 'Albert_Entailment']].apply(calculate_margin, axis=1)
combined_mnli_matched_df['confidence_margin_neutral'] = combined_mnli_matched_df[['Deberta_Neutral', 'Roberta_Neutral', 'Albert_Neutral']].apply(calculate_margin, axis=1)
combined_mnli_matched_df['confidence_margin_contradiction'] = combined_mnli_matched_df[['Deberta_Contradiction', 'Roberta_Contradiction', 'Albert_Contradiction']].apply(calculate_margin, axis=1)

# Applying to a sample DataFrame with made-up column names
combined_mnli_mismatched_df['confidence_margin_entailment'] = combined_mnli_mismatched_df[['Deberta_Entailment', 'Roberta_Entailment', 'Albert_Entailment']].apply(calculate_margin, axis=1)
combined_mnli_mismatched_df['confidence_margin_neutral'] = combined_mnli_mismatched_df[['Deberta_Neutral', 'Roberta_Neutral', 'Albert_Neutral']].apply(calculate_margin, axis=1)
combined_mnli_mismatched_df['confidence_margin_contradiction'] = combined_mnli_mismatched_df[['Deberta_Contradiction', 'Roberta_Contradiction', 'Albert_Contradiction']].apply(calculate_margin, axis=1)

# Applying to a sample DataFrame with made-up column names
combined_anli_r1_df['confidence_margin_entailment'] = combined_anli_r1_df[['Deberta_Entailment', 'Roberta_Entailment', 'Albert_Entailment']].apply(calculate_margin, axis=1)
combined_anli_r1_df['confidence_margin_neutral'] = combined_anli_r1_df[['Deberta_Neutral', 'Roberta_Neutral', 'Albert_Neutral']].apply(calculate_margin, axis=1)
combined_anli_r1_df['confidence_margin_contradiction'] = combined_anli_r1_df[['Deberta_Contradiction', 'Roberta_Contradiction', 'Albert_Contradiction']].apply(calculate_margin, axis=1)


# Applying to a sample DataFrame with made-up column names
combined_anli_r2_df['confidence_margin_entailment'] = combined_anli_r2_df[['Deberta_Entailment', 'Roberta_Entailment', 'Albert_Entailment']].apply(calculate_margin, axis=1)
combined_anli_r2_df['confidence_margin_neutral'] = combined_anli_r2_df[['Deberta_Neutral', 'Roberta_Neutral', 'Albert_Neutral']].apply(calculate_margin, axis=1)
combined_anli_r2_df['confidence_margin_contradiction'] = combined_anli_r2_df[['Deberta_Contradiction', 'Roberta_Contradiction', 'Albert_Contradiction']].apply(calculate_margin, axis=1)


# Applying to a sample DataFrame with made-up column names
combined_anli_r3_df['confidence_margin_entailment'] = combined_anli_r3_df[['Deberta_Entailment', 'Roberta_Entailment', 'Albert_Entailment']].apply(calculate_margin, axis=1)
combined_anli_r3_df['confidence_margin_neutral'] = combined_anli_r3_df[['Deberta_Neutral', 'Roberta_Neutral', 'Albert_Neutral']].apply(calculate_margin, axis=1)
combined_anli_r3_df['confidence_margin_contradiction'] = combined_anli_r3_df[['Deberta_Contradiction', 'Roberta_Contradiction', 'Albert_Contradiction']].apply(calculate_margin, axis=1)

# %%
combined_anli_r3_df
# Out:
#       Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0               0.005921         0.960529               0.033551
# 1               0.009586         0.934714               0.055700
# 2               0.003428         0.976393               0.020179
# 3               0.004633         0.023985               0.971382
# 4               0.017428         0.633695               0.348877
# ...                  ...              ...                    ...
# 1195            0.150312         0.806051               0.043637
# 1196            0.971834         0.026294               0.001872
# 1197            0.973818         0.025074               0.001109
# 1198            0.341781         0.226539               0.431681
# 1199            0.472737         0.477215               0.050049
#
#       Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0               0.022959         0.976533               0.000509
# 1               0.999611         0.000205               0.000185
# 2               0.002020         0.997897               0.000083
# 3               0.974441         0.024459               0.001100
# 4               0.984416         0.011166               0.004419
# ...                  ...              ...                    ...
# 1195            0.032452         0.068553               0.898994
# 1196            0.009070         0.824654               0.166276
# 1197            0.000352         0.000972               0.998677
# 1198            0.006147         0.073669               0.920184
# 1199            0.000420         0.991832               0.007748
#
#       Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label  \
# 0              0.001848        0.998084              0.000067           0
# 1              0.951772        0.048075              0.000153           0
# 2              0.001014        0.998984              0.000002           0
# 3              0.996749        0.000989              0.002262           0
# 4              0.000518        0.128416              0.871066           0
# ...                 ...             ...                   ...         ...
# 1195           0.122045        0.254093              0.623862           2
# 1196           0.001115        0.003229              0.995656           2
# 1197           0.310862        0.618914              0.070225           2
# 1198           0.054172        0.317935              0.627893           2
# 1199           0.015091        0.121354              0.863554           2
#
#       confidence_margin_entailment  confidence_margin_neutral  \
# 0                         0.017038                   0.021552
# 1                         0.047839                   0.886640
# 2                         0.001408                   0.001087
# 3                         0.022308                   0.000474
# 4                         0.966988                   0.505279
# ...                            ...                        ...
# 1195                      0.028268                   0.551958
# 1196                      0.962764                   0.798360
# 1197                      0.662956                   0.593840
# 1198                      0.287609                   0.091397
# 1199                      0.457646                   0.514617
#
#       confidence_margin_contradiction
# 0                            0.033042
# 1                            0.055515
# 2                            0.020096
# 3                            0.969120
# 4                            0.522189
# ...                               ...
# 1195                         0.275132
# 1196                         0.829379
# 1197                         0.928452
# 1198                         0.292291
# 1199                         0.813506
#
# [1200 rows x 13 columns]

# %%
import matplotlib.pyplot as plt

# Plot histograms for the confidence margins
def plot_confidence_margins(df):
    plt.figure(figsize=(15, 5))
    plt.subplot(1, 3, 1)
    plt.hist(df['confidence_margin_entailment'], bins=50, alpha=0.75, label='Entailment')
    plt.title('Confidence Margin Histogram - Entailment')
    plt.xlabel('Margin')
    plt.ylabel('Frequency')
    
    plt.subplot(1, 3, 2)
    plt.hist(df['confidence_margin_neutral'], bins=50, alpha=0.75, label='Neutral', color='green')
    plt.title('Confidence Margin Histogram - Neutral')
    plt.xlabel('Margin')
    plt.ylabel('Frequency')
    
    plt.subplot(1, 3, 3)
    plt.hist(df['confidence_margin_contradiction'], bins=50, alpha=0.75, label='Contradiction', color='red')
    plt.title('Confidence Margin Histogram - Contradiction')
    plt.xlabel('Margin')
    plt.ylabel('Frequency')
    
    plt.tight_layout()
    plt.show()

plot_confidence_margins(combined_snli_df)

# %%
# Define thresholds based on the distribution
confidence_threshold = 0.8

# Apply threshold and create a new copy of the DataFrame
high_confidence_snli = combined_snli_df[
    (combined_snli_df['confidence_margin_entailment'] >= confidence_threshold) | 
    (combined_snli_df['confidence_margin_neutral'] >= confidence_threshold) |
    (combined_snli_df['confidence_margin_contradiction'] >= confidence_threshold)
].copy()


# Apply threshold and create a new copy of the DataFrame
high_confidence_mnli_matched = combined_mnli_matched_df[
    (combined_mnli_matched_df['confidence_margin_entailment'] >= confidence_threshold) | 
    (combined_mnli_matched_df['confidence_margin_neutral'] >= confidence_threshold) |
    (combined_mnli_matched_df['confidence_margin_contradiction'] >= confidence_threshold)
].copy()

# Apply threshold and create a new copy of the DataFrame
high_confidence_mnli_mismatched = combined_mnli_mismatched_df[
    (combined_mnli_mismatched_df['confidence_margin_entailment'] >= confidence_threshold) | 
    (combined_mnli_mismatched_df['confidence_margin_neutral'] >= confidence_threshold) |
    (combined_mnli_mismatched_df['confidence_margin_contradiction'] >= confidence_threshold)
].copy()

# Filter high confidence samples for ANLI round 1
high_confidence_anli_r1 = combined_anli_r1_df[
    (combined_anli_r1_df['confidence_margin_entailment'] >= confidence_threshold) | 
    (combined_anli_r1_df['confidence_margin_neutral'] >= confidence_threshold) |
    (combined_anli_r1_df['confidence_margin_contradiction'] >= confidence_threshold)
].copy()

# Filter high confidence samples for ANLI round 2
high_confidence_anli_r2 = combined_anli_r2_df[
    (combined_anli_r2_df['confidence_margin_entailment'] >= confidence_threshold) | 
    (combined_anli_r2_df['confidence_margin_neutral'] >= confidence_threshold) |
    (combined_anli_r2_df['confidence_margin_contradiction'] >= confidence_threshold)
].copy()

# Filter high confidence samples for ANLI round 3
high_confidence_anli_r3 = combined_anli_r3_df[
    (combined_anli_r3_df['confidence_margin_entailment'] >= confidence_threshold) | 
    (combined_anli_r3_df['confidence_margin_neutral'] >= confidence_threshold) |
    (combined_anli_r3_df['confidence_margin_contradiction'] >= confidence_threshold)
].copy()

# %%
# Majority vote logic with weights for numeric labels
def majority_vote_with_threshold(row):
    votes = [0, 0, 0]  # Index 0 for entailment, 1 for neutral, 2 for contradiction
    if row['confidence_margin_entailment'] >= confidence_threshold:
        votes[0] += row['confidence_margin_entailment']
    if row['confidence_margin_neutral'] >= confidence_threshold:
        votes[1] += row['confidence_margin_neutral']
    if row['confidence_margin_contradiction'] >= confidence_threshold:
        votes[2] += row['confidence_margin_contradiction']
    
    # Return the index of the highest vote
    return np.argmax(votes)

# Apply the majority vote logic using .loc
high_confidence_snli.loc[:, 'majority_vote'] = high_confidence_snli.apply(majority_vote_with_threshold, axis=1)
# Apply the majority vote logic using .loc
high_confidence_mnli_matched.loc[:, 'majority_vote'] = high_confidence_mnli_matched.apply(majority_vote_with_threshold, axis=1)
# Apply majority vote logic
high_confidence_mnli_mismatched.loc[:, 'majority_vote'] = high_confidence_mnli_mismatched.apply(majority_vote_with_threshold, axis=1)
# Apply majority vote logic
high_confidence_anli_r1.loc[:, 'majority_vote'] = high_confidence_anli_r1.apply(majority_vote_with_threshold, axis=1)
# Apply majority vote logic
high_confidence_anli_r2.loc[:, 'majority_vote'] = high_confidence_anli_r2.apply(majority_vote_with_threshold, axis=1)
# Apply majority vote logic
high_confidence_anli_r3.loc[:, 'majority_vote'] = high_confidence_anli_r3.apply(majority_vote_with_threshold, axis=1)

# %%
high_confidence_anli_r3
# Out:
#       Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 1               0.009586         0.934714               0.055700
# 3               0.004633         0.023985               0.971382
# 4               0.017428         0.633695               0.348877
# 5               0.002461         0.150678               0.846861
# 8               0.131793         0.776056               0.092151
# ...                  ...              ...                    ...
# 1193            0.957103         0.040533               0.002363
# 1194            0.945850         0.052813               0.001337
# 1196            0.971834         0.026294               0.001872
# 1197            0.973818         0.025074               0.001109
# 1199            0.472737         0.477215               0.050049
#
#       Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 1               0.999611         0.000205               0.000185
# 3               0.974441         0.024459               0.001100
# 4               0.984416         0.011166               0.004419
# 5               0.999220         0.000554               0.000227
# 8               0.000384         0.002570               0.997046
# ...                  ...              ...                    ...
# 1193            0.000066         0.000316               0.999618
# 1194            0.000607         0.000853               0.998540
# 1196            0.009070         0.824654               0.166276
# 1197            0.000352         0.000972               0.998677
# 1199            0.000420         0.991832               0.007748
#
#       Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label  \
# 1              0.951772        0.048075              0.000153           0
# 3              0.996749        0.000989              0.002262           0
# 4              0.000518        0.128416              0.871066           0
# 5              0.985221        0.014745              0.000034           0
# 8              0.049409        0.904356              0.046236           0
# ...                 ...             ...                   ...         ...
# 1193           0.009265        0.016116              0.974619           2
# 1194           0.000205        0.000291              0.999504           2
# 1196           0.001115        0.003229              0.995656           2
# 1197           0.310862        0.618914              0.070225           2
# 1199           0.015091        0.121354              0.863554           2
#
#       confidence_margin_entailment  confidence_margin_neutral  \
# 1                         0.047839                   0.886640
# 3                         0.022308                   0.000474
# 4                         0.966988                   0.505279
# 5                         0.013998                   0.135933
# 8                         0.082384                   0.128299
# ...                            ...                        ...
# 1193                      0.947838                   0.024417
# 1194                      0.945243                   0.051960
# 1196                      0.962764                   0.798360
# 1197                      0.662956                   0.593840
# 1199                      0.457646                   0.514617
#
#       confidence_margin_contradiction  majority_vote
# 1                            0.055515              1
# 3                            0.969120              2
# 4                            0.522189              0
# 5                            0.846635              2
# 8                            0.904895              2
# ...                               ...            ...
# 1193                         0.024999              0
# 1194                         0.000965              0
# 1196                         0.829379              0
# 1197                         0.928452              2
# 1199                         0.813506              2
#
# [530 rows x 14 columns]

# %%
high_confidence_mnli_mismatched
# Out:
#       Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0               0.999667         0.000160               0.000173
# 1               0.998119         0.000962               0.000919
# 2               0.000552         0.004809               0.994639
# 3               0.827653         0.171961               0.000386
# 4               0.000292         0.002875               0.996833
# ...                  ...              ...                    ...
# 9824            0.000760         0.013837               0.985402
# 9825            0.000145         0.003906               0.995949
# 9826            0.996226         0.003656               0.000118
# 9828            0.997044         0.001226               0.001730
# 9829            0.999685         0.000112               0.000202
#
#       Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0               0.000068         0.000402               0.999529
# 1               0.000183         0.001511               0.998306
# 2               0.986062         0.012020               0.001918
# 3               0.000478         0.270953               0.728569
# 4               0.975167         0.021904               0.002929
# ...                  ...              ...                    ...
# 9824            0.972984         0.025382               0.001634
# 9825            0.952827         0.045891               0.001281
# 9826            0.000353         0.104717               0.894930
# 9828            0.000364         0.000717               0.998919
# 9829            0.000085         0.000289               0.999626
#
#       Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label  \
# 0              0.000894        0.003787              0.995318           2
# 1              0.006421        0.010224              0.983355           2
# 2              0.975041        0.023354              0.001605           0
# 3              0.001722        0.796122              0.202156           2
# 4              0.965952        0.032748              0.001300           0
# ...                 ...             ...                   ...         ...
# 9824           0.925212        0.069991              0.004798           0
# 9825           0.965645        0.032757              0.001598           0
# 9826           0.004991        0.039946              0.955062           2
# 9828           0.019078        0.039258              0.941663           2
# 9829           0.000420        0.001810              0.997770           2
#
#       confidence_margin_entailment  confidence_margin_neutral  \
# 0                         0.998773                   0.003385
# 1                         0.991698                   0.008714
# 2                         0.011021                   0.011334
# 3                         0.825931                   0.525168
# 4                         0.009215                   0.010844
# ...                            ...                        ...
# 9824                      0.047772                   0.044608
# 9825                      0.012818                   0.013134
# 9826                      0.991234                   0.064771
# 9828                      0.977966                   0.038033
# 9829                      0.999265                   0.001521
#
#       confidence_margin_contradiction  majority_vote
# 0                            0.004211              0
# 1                            0.014951              0
# 2                            0.992721              2
# 3                            0.526413              0
# 4                            0.993904              2
# ...                               ...            ...
# 9824                         0.980605              2
# 9825                         0.994351              2
# 9826                         0.060132              0
# 9828                         0.057256              0
# 9829                         0.001856              0
#
# [5910 rows x 14 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf



# Features and Labels
X_snli = high_confidence_snli.drop(['True_Label','confidence_margin_entailment','confidence_margin_neutral','confidence_margin_contradiction','majority_vote'], axis=1).values
y_snli = high_confidence_snli['True_Label'].values

# Features and Labels
X_mnli_matched = high_confidence_mnli_matched.drop(['True_Label','confidence_margin_entailment','confidence_margin_neutral','confidence_margin_contradiction','majority_vote'], axis=1).values
y_mnli_matched = high_confidence_mnli_matched['True_Label'].values

# Features and Labels
X_mnli_mismatched = high_confidence_mnli_mismatched.drop(['True_Label','confidence_margin_entailment','confidence_margin_neutral','confidence_margin_contradiction','majority_vote'], axis=1).values
y_mnli_mismatched = high_confidence_mnli_mismatched['True_Label'].values

# Features and Labels
X_anli_r1 = high_confidence_anli_r1.drop(['True_Label','confidence_margin_entailment','confidence_margin_neutral','confidence_margin_contradiction','majority_vote'], axis=1).values
y_anli_r1 = high_confidence_anli_r1['True_Label'].values

# Features and Labels
X_anli_r2 = high_confidence_anli_r2.drop(['True_Label','confidence_margin_entailment','confidence_margin_neutral','confidence_margin_contradiction','majority_vote'], axis=1).values
y_anli_r2 = high_confidence_anli_r2['True_Label'].values

# Features and Labels
X_anli_r3 = high_confidence_anli_r3.drop(['True_Label','confidence_margin_entailment','confidence_margin_neutral','confidence_margin_contradiction','majority_vote'], axis=1).values
y_anli_r3 = high_confidence_anli_r3['True_Label'].values
# Out:
# 2024-04-18 18:50:40.339950: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-18 18:50:40.340055: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-18 18:50:40.470001: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Extract only the additional features from each dataset
features_snli = high_confidence_snli[['confidence_margin_entailment', 'confidence_margin_neutral', 'confidence_margin_contradiction']].values
features_mnli_matched = high_confidence_mnli_matched[[ 'confidence_margin_entailment', 'confidence_margin_neutral', 'confidence_margin_contradiction']].values
features_mnli_mismatched = high_confidence_mnli_mismatched[[ 'confidence_margin_entailment', 'confidence_margin_neutral', 'confidence_margin_contradiction']].values
features_anli_r1 = high_confidence_anli_r1[[ 'confidence_margin_entailment', 'confidence_margin_neutral', 'confidence_margin_contradiction']].values
features_anli_r2 = high_confidence_anli_r2[[ 'confidence_margin_entailment', 'confidence_margin_neutral', 'confidence_margin_contradiction']].values
features_anli_r3 = high_confidence_anli_r3[[ 'confidence_margin_entailment', 'confidence_margin_neutral', 'confidence_margin_contradiction']].values

# %%
X_snli
# Out:
# array([[9.9878270e-01, 7.6433434e-04, 4.5297167e-04, ..., 4.6765395e-03,
#         6.0480673e-02, 9.3484277e-01],
#        [5.0442386e-04, 4.3001700e-03, 9.9519530e-01, ..., 9.7817034e-01,
#         2.1051416e-02, 7.7824460e-04],
#        [9.8957914e-01, 5.4418677e-03, 4.9790350e-03, ..., 8.5550435e-02,
#         7.5036585e-02, 8.3941300e-01],
#        ...,
#        [7.0376875e-04, 9.7931010e-03, 9.8950315e-01, ..., 8.9463750e-01,
#         1.0409502e-01, 1.2674012e-03],
#        [9.9917114e-01, 4.9286430e-04, 3.3603658e-04, ..., 8.3751883e-04,
#         2.6697412e-03, 9.9649280e-01],
#        [2.6664520e-04, 2.1777824e-03, 9.9755560e-01, ..., 9.8434700e-01,
#         1.5223468e-02, 4.2961346e-04]])

# %%
features_snli
# Out:
# array([[9.94106161e-01, 5.59870956e-02, 6.04100800e-02],
#        [5.73736000e-03, 5.89017100e-03, 9.94264296e-01],
#        [9.04028705e-01, 1.89172950e-02, 3.66324000e-02],
#        ...,
#        [1.13691360e-01, 1.12957690e-01, 9.87502096e-01],
#        [9.98333621e-01, 1.90469200e-03, 2.68793000e-03],
#        [9.45200000e-04, 6.61004000e-04, 9.96841898e-01]])

# %%
# One-hot encode labels for each dataset using TensorFlow/Keras utility
y_encoded_snli = tf.keras.utils.to_categorical(y_snli)
y_encoded_mnli_matched = tf.keras.utils.to_categorical(y_mnli_matched)
y_encoded_mnli_mismatched = tf.keras.utils.to_categorical(y_mnli_mismatched)
y_encoded_anli_r1 = tf.keras.utils.to_categorical(y_anli_r1)
y_encoded_anli_r2 = tf.keras.utils.to_categorical(y_anli_r2)
y_encoded_anli_r3 = tf.keras.utils.to_categorical(y_anli_r3)

# %%
X_snli_rnn = X_snli.reshape(X_snli.shape[0], 1, X_snli.shape[1])
X_mnli_matched_rnn = X_mnli_matched.reshape(X_mnli_matched.shape[0], 1, X_mnli_matched.shape[1])
X_mnli_mismatched_rnn = X_mnli_mismatched.reshape(X_mnli_mismatched.shape[0], 1, X_mnli_mismatched.shape[1])
X_anli_r1_rnn = X_anli_r1.reshape(X_anli_r1.shape[0], 1, X_anli_r1.shape[1])
X_anli_r2_rnn = X_anli_r2.reshape(X_anli_r2.shape[0], 1, X_anli_r2.shape[1])
X_anli_r3_rnn = X_anli_r3.reshape(X_anli_r3.shape[0], 1, X_anli_r3.shape[1])

# %%
# Reshape feature arrays to match the RNN input shape
features_snli = features_snli.reshape(features_snli.shape[0], 1, features_snli.shape[1])
features_mnli_matched = features_mnli_matched.reshape(features_mnli_matched.shape[0], 1, features_mnli_matched.shape[1])
features_mnli_mismatched = features_mnli_mismatched.reshape(features_mnli_mismatched.shape[0], 1, features_mnli_mismatched.shape[1])
features_anli_r1 = features_anli_r1.reshape(features_anli_r1.shape[0], 1, features_anli_r1.shape[1])
features_anli_r2 = features_anli_r2.reshape(features_anli_r2.shape[0], 1, features_anli_r2.shape[1])
features_anli_r3 = features_anli_r3.reshape(features_anli_r3.shape[0], 1, features_anli_r3.shape[1])

# %%
features_snli.shape
# Out:
# (6032, 1, 3)

# %%
X_snli_rnn
# Out:
# array([[[9.9878270e-01, 7.6433434e-04, 4.5297167e-04, ...,
#          4.6765395e-03, 6.0480673e-02, 9.3484277e-01]],
#
#        [[5.0442386e-04, 4.3001700e-03, 9.9519530e-01, ...,
#          9.7817034e-01, 2.1051416e-02, 7.7824460e-04]],
#
#        [[9.8957914e-01, 5.4418677e-03, 4.9790350e-03, ...,
#          8.5550435e-02, 7.5036585e-02, 8.3941300e-01]],
#
#        ...,
#
#        [[7.0376875e-04, 9.7931010e-03, 9.8950315e-01, ...,
#          8.9463750e-01, 1.0409502e-01, 1.2674012e-03]],
#
#        [[9.9917114e-01, 4.9286430e-04, 3.3603658e-04, ...,
#          8.3751883e-04, 2.6697412e-03, 9.9649280e-01]],
#
#        [[2.6664520e-04, 2.1777824e-03, 9.9755560e-01, ...,
#          9.8434700e-01, 1.5223468e-02, 4.2961346e-04]]])

# %%
X_snli_rnn.shape
# Out:
# (6032, 1, 9)

# %%
from sklearn.model_selection import train_test_split

def prepare_data_splits(X_rnn, features, y_encoded, test_size=0.1, random_state=42):
    # Split the data for the RNN inputs
    X_train_rnn, X_val_rnn, y_train, y_val = train_test_split(
        X_rnn, y_encoded, test_size=test_size, random_state=random_state, stratify=y_encoded)

    # Split the data for the additional features
    features_train, features_val, _, _ = train_test_split(
        features, y_encoded, test_size=test_size, random_state=random_state, stratify=y_encoded)

    return X_train_rnn, X_val_rnn, features_train, features_val, y_train, y_val

# Example for SNLI data
X_train_snli_rnn, X_val_snli_rnn, features_train_snli, features_val_snli, y_train_snli, y_val_snli = prepare_data_splits(X_snli_rnn, features_snli, y_encoded_snli)
# Example for MNLI-m data
X_train_mnli_matched_rnn, X_val_mnli_matched_rnn, features_train_mnli_matched, features_val_mnli_matched, y_train_mnli_matched, y_val_mnli_matched = prepare_data_splits(X_mnli_matched_rnn, features_mnli_matched, y_encoded_mnli_matched)
# Example for MNLI-mm data
X_train_mnli_mismatched_rnn, X_val_mnli_mismatched_rnn, features_train_mnli_mismatched, features_val_mnli_mismatched, y_train_mnli_mismatched, y_val_mnli_mismatched = prepare_data_splits(X_mnli_mismatched_rnn, features_mnli_mismatched, y_encoded_mnli_mismatched)
# Example for ANLI round 1 data
X_train_anli_r1_rnn, X_val_anli_r1_rnn, features_train_anli_r1, features_val_anli_r1, y_train_anli_r1, y_val_anli_r1 = prepare_data_splits(X_anli_r1_rnn, features_anli_r1, y_encoded_anli_r1)
# Example for ANLI round 2 data
X_train_anli_r2_rnn, X_val_anli_r2_rnn, features_train_anli_r2, features_val_anli_r2, y_train_anli_r2, y_val_anli_r2 = prepare_data_splits(X_anli_r2_rnn, features_anli_r2, y_encoded_anli_r2)
# Example for ANLI round 3 data
X_train_anli_r3_rnn, X_val_anli_r3_rnn, features_train_anli_r3, features_val_anli_r3, y_train_anli_r3, y_val_anli_r3 = prepare_data_splits(X_anli_r3_rnn, features_anli_r3, y_encoded_anli_r3)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input,  LSTM, Dense, Dropout, Concatenate
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Flatten


def build_and_train_lstm_model(X_train_rnn, features_train, y_train, X_val_rnn, features_val, y_val, epochs=20, batch_size=32):
    sequence_input_shape = X_train_rnn.shape[1:]
    features_input_shape = features_train.shape[1:]

    sequence_input = Input(shape=sequence_input_shape, name='sequence_input')
    lstm = LSTM(64, return_sequences=False)(sequence_input)
    lstm = Dropout(0.5)(lstm)

    features_input = Input(shape=features_input_shape, name='features_input')
    features_layer = Dense(32, activation='relu')(features_input)
    features_layer = Dropout(0.2)(features_layer)
    features_layer = Flatten()(features_layer)

    concatenated = Concatenate()([lstm, features_layer])
    output = Dense(3, activation='softmax')(concatenated)

    model = Model(inputs=[sequence_input, features_input], outputs=output)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    early_stopping = EarlyStopping(monitor='val_loss', patience=3)

    history = model.fit(
        [X_train_rnn, features_train], y_train,
        validation_data=([X_val_rnn, features_val], y_val),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=[early_stopping]
    )

    evaluation = model.evaluate([X_val_rnn, features_val], y_val, verbose=1)
    return model, history, evaluation

# %%
# Training and evaluation for the SNLI data with LSTM
model_snli_lstm, history_snli_lstm, evaluation_snli_lstm = build_and_train_lstm_model(
    X_train_snli_rnn, features_train_snli, y_train_snli, 
    X_val_snli_rnn, features_val_snli, y_val_snli, 
    epochs=20, batch_size=32
)

print("Evaluation on SNLI Validation Data with LSTM:", evaluation_snli_lstm)
print("History keys:", history_snli_lstm.history.keys())
# Out:
# Epoch 1/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9240 - loss: 0.6497 - val_accuracy: 0.9536 - val_loss: 0.1766
# Epoch 2/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9550 - loss: 0.1730 - val_accuracy: 0.9536 - val_loss: 0.1430
# Epoch 3/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9567 - loss: 0.1508 - val_accuracy: 0.9603 - val_loss: 0.1250
# Epoch 4/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9595 - loss: 0.1444 - val_accuracy: 0.9619 - val_loss: 0.1199
# Epoch 5/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9604 - loss: 0.1381 - val_accuracy: 0.9636 - val_loss: 0.1190
# Epoch 6/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9593 - loss: 0.1376 - val_accuracy: 0.9652 - val_loss: 0.1183
# Epoch 7/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9613 - loss: 0.1385 - val_accuracy: 0.9619 - val_loss: 0.1183
# Epoch 8/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9631 - loss: 0.1358 - val_accuracy: 0.9619 - val_loss: 0.1177
# Epoch 9/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9621 - loss: 0.1362 - val_accuracy: 0.9636 - val_loss: 0.1176
# Epoch 10/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9597 - loss: 0.1359 - val_accuracy: 0.9619 - val_loss: 0.1179
# Epoch 11/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9625 - loss: 0.1360 - val_accuracy: 0.9619 - val_loss: 0.1172
# Epoch 12/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9643 - loss: 0.1252 - val_accuracy: 0.9619 - val_loss: 0.1175
# Epoch 13/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9652 - loss: 0.1320 - val_accuracy: 0.9636 - val_loss: 0.1177
# Epoch 14/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9591 - loss: 0.1511 - val_accuracy: 0.9619 - val_loss: 0.1170
# Epoch 15/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9642 - loss: 0.1296 - val_accuracy: 0.9619 - val_loss: 0.1181
# Epoch 16/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9608 - loss: 0.1328 - val_accuracy: 0.9636 - val_loss: 0.1174
# Epoch 17/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9628 - loss: 0.1327 - val_accuracy: 0.9619 - val_loss: 0.1174
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9608 - loss: 0.1058
# Evaluation on SNLI Validation Data with LSTM: [0.11737567186355591, 0.9619205594062805]
# History keys: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Train and evaluate LSTM model on MNLI Matched data
model_mnli_matched_lstm, history_mnli_matched_lstm, evaluation_mnli_matched_lstm = build_and_train_lstm_model(
    X_train_mnli_matched_rnn, features_train_mnli_matched, y_train_mnli_matched,
    X_val_mnli_matched_rnn, features_val_mnli_matched, y_val_mnli_matched,
    epochs=20, batch_size=32
)

print("Evaluation on MNLI Matched Validation Data with LSTM:", evaluation_mnli_matched_lstm)
print("History keys:", history_mnli_matched_lstm.history.keys())
# Out:
# Epoch 1/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8159 - loss: 0.7089 - val_accuracy: 0.9659 - val_loss: 0.1687
# Epoch 2/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9648 - loss: 0.1636 - val_accuracy: 0.9659 - val_loss: 0.1436
# Epoch 3/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9653 - loss: 0.1473 - val_accuracy: 0.9659 - val_loss: 0.1352
# Epoch 4/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9659 - loss: 0.1424 - val_accuracy: 0.9659 - val_loss: 0.1305
# Epoch 5/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9666 - loss: 0.1371 - val_accuracy: 0.9676 - val_loss: 0.1281
# Epoch 6/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9678 - loss: 0.1310 - val_accuracy: 0.9693 - val_loss: 0.1263
# Epoch 7/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9624 - loss: 0.1461 - val_accuracy: 0.9693 - val_loss: 0.1251
# Epoch 8/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9665 - loss: 0.1403 - val_accuracy: 0.9693 - val_loss: 0.1244
# Epoch 9/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9651 - loss: 0.1474 - val_accuracy: 0.9693 - val_loss: 0.1242
# Epoch 10/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9672 - loss: 0.1392 - val_accuracy: 0.9676 - val_loss: 0.1238
# Epoch 11/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9662 - loss: 0.1414 - val_accuracy: 0.9676 - val_loss: 0.1239
# Epoch 12/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9663 - loss: 0.1335 - val_accuracy: 0.9676 - val_loss: 0.1238
# Epoch 13/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9653 - loss: 0.1329 - val_accuracy: 0.9693 - val_loss: 0.1239
# Epoch 14/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9627 - loss: 0.1492 - val_accuracy: 0.9676 - val_loss: 0.1238
# Epoch 15/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9660 - loss: 0.1348 - val_accuracy: 0.9693 - val_loss: 0.1247
# Epoch 16/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9653 - loss: 0.1418 - val_accuracy: 0.9676 - val_loss: 0.1239
# Epoch 17/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9663 - loss: 0.1339 - val_accuracy: 0.9676 - val_loss: 0.1235
# Epoch 18/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9654 - loss: 0.1436 - val_accuracy: 0.9693 - val_loss: 0.1237
# Epoch 19/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9682 - loss: 0.1342 - val_accuracy: 0.9693 - val_loss: 0.1239
# Epoch 20/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9707 - loss: 0.1282 - val_accuracy: 0.9693 - val_loss: 0.1240
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9674 - loss: 0.1449
# Evaluation on MNLI Matched Validation Data with LSTM: [0.1240299642086029, 0.9692832827568054]
# History keys: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Train and evaluate LSTM model on MNLI Mismatched data
model_mnli_mismatched_lstm, history_mnli_mismatched_lstm, evaluation_mnli_mismatched_lstm = build_and_train_lstm_model(
    X_train_mnli_mismatched_rnn, features_train_mnli_mismatched, y_train_mnli_mismatched,
    X_val_mnli_mismatched_rnn, features_val_mnli_mismatched, y_val_mnli_mismatched,
    epochs=20, batch_size=32
)

print("Evaluation on MNLI Mismatched Validation Data with LSTM:", evaluation_mnli_mismatched_lstm)

print("History keys:", history_mnli_mismatched_lstm.history.keys())
# Out:
# Epoch 1/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8524 - loss: 0.7168 - val_accuracy: 0.9628 - val_loss: 0.1770
# Epoch 2/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9670 - loss: 0.1516 - val_accuracy: 0.9628 - val_loss: 0.1558
# Epoch 3/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9616 - loss: 0.1526 - val_accuracy: 0.9628 - val_loss: 0.1518
# Epoch 4/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9662 - loss: 0.1366 - val_accuracy: 0.9628 - val_loss: 0.1502
# Epoch 5/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9696 - loss: 0.1189 - val_accuracy: 0.9628 - val_loss: 0.1500
# Epoch 6/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9689 - loss: 0.1177 - val_accuracy: 0.9628 - val_loss: 0.1481
# Epoch 7/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9651 - loss: 0.1188 - val_accuracy: 0.9645 - val_loss: 0.1497
# Epoch 8/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9660 - loss: 0.1238 - val_accuracy: 0.9611 - val_loss: 0.1488
# Epoch 9/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9687 - loss: 0.1184 - val_accuracy: 0.9628 - val_loss: 0.1483
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9471 - loss: 0.1863
# Evaluation on MNLI Mismatched Validation Data with LSTM: [0.1483343094587326, 0.962774932384491]
# History keys: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Train and evaluate LSTM model on ANLI Round 1 data
model_anli_r1_lstm, history_anli_r1_lstm, evaluation_anli_r1_lstm = build_and_train_lstm_model(
    X_train_anli_r1_rnn, features_train_anli_r1, y_train_anli_r1,
    X_val_anli_r1_rnn, features_val_anli_r1, y_val_anli_r1,
    epochs=20, batch_size=32
)
print("Evaluation on ANLI Round 1 Validation Data with LSTM:", evaluation_anli_r1_lstm)

print("History keys:", history_anli_r1_lstm.history.keys())
# Out:
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.3551 - loss: 1.1063 - val_accuracy: 0.5814 - val_loss: 1.0498
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5550 - loss: 1.0299 - val_accuracy: 0.6512 - val_loss: 0.9904
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6227 - loss: 0.9856 - val_accuracy: 0.6279 - val_loss: 0.9384
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6647 - loss: 0.9409 - val_accuracy: 0.5814 - val_loss: 0.8890
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6796 - loss: 0.8797 - val_accuracy: 0.5814 - val_loss: 0.8414
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6719 - loss: 0.8336 - val_accuracy: 0.5814 - val_loss: 0.7953
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7150 - loss: 0.7562 - val_accuracy: 0.6744 - val_loss: 0.7521
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6992 - loss: 0.7390 - val_accuracy: 0.6744 - val_loss: 0.7101
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7361 - loss: 0.6749 - val_accuracy: 0.6977 - val_loss: 0.6740
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7635 - loss: 0.6591 - val_accuracy: 0.7209 - val_loss: 0.6434
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7702 - loss: 0.6263 - val_accuracy: 0.7442 - val_loss: 0.6187
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8126 - loss: 0.5704 - val_accuracy: 0.7442 - val_loss: 0.5973
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8184 - loss: 0.5665 - val_accuracy: 0.7442 - val_loss: 0.5798
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7607 - loss: 0.5983 - val_accuracy: 0.7442 - val_loss: 0.5634
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8049 - loss: 0.5424 - val_accuracy: 0.7442 - val_loss: 0.5512
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8261 - loss: 0.5437 - val_accuracy: 0.7442 - val_loss: 0.5440
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8092 - loss: 0.5332 - val_accuracy: 0.7442 - val_loss: 0.5332
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8206 - loss: 0.5541 - val_accuracy: 0.7442 - val_loss: 0.5289
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8286 - loss: 0.5012 - val_accuracy: 0.7442 - val_loss: 0.5273
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8220 - loss: 0.4997 - val_accuracy: 0.7442 - val_loss: 0.5218
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7461 - loss: 0.5746
# Evaluation on ANLI Round 1 Validation Data with LSTM: [0.5217747092247009, 0.7441860437393188]
# History keys: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Train and evaluate LSTM model on ANLI Round 2 data
model_anli_r2_lstm, history_anli_r2_lstm, evaluation_anli_r2_lstm = build_and_train_lstm_model(
    X_train_anli_r2_rnn, features_train_anli_r2, y_train_anli_r2,
    X_val_anli_r2_rnn, features_val_anli_r2, y_val_anli_r2,
    epochs=20, batch_size=32
)

print("Evaluation on ANLI Round 2 Validation Data with LSTM:", evaluation_anli_r2_lstm)

print("History keys:", history_anli_r2_lstm.history.keys())
# Out:
# Epoch 1/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.3833 - loss: 1.0820 - val_accuracy: 0.5333 - val_loss: 1.0558
# Epoch 2/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6303 - loss: 1.0174 - val_accuracy: 0.6444 - val_loss: 1.0201
# Epoch 3/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5859 - loss: 1.0066 - val_accuracy: 0.6889 - val_loss: 0.9865
# Epoch 4/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6551 - loss: 0.9573 - val_accuracy: 0.6889 - val_loss: 0.9502
# Epoch 5/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6342 - loss: 0.9362 - val_accuracy: 0.6889 - val_loss: 0.9161
# Epoch 6/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6616 - loss: 0.9060 - val_accuracy: 0.6889 - val_loss: 0.8805
# Epoch 7/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6531 - loss: 0.8669 - val_accuracy: 0.6889 - val_loss: 0.8470
# Epoch 8/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6684 - loss: 0.8367 - val_accuracy: 0.6889 - val_loss: 0.8160
# Epoch 9/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6842 - loss: 0.8060 - val_accuracy: 0.7111 - val_loss: 0.7897
# Epoch 10/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7164 - loss: 0.7396 - val_accuracy: 0.6667 - val_loss: 0.7676
# Epoch 11/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7088 - loss: 0.7728 - val_accuracy: 0.7111 - val_loss: 0.7498
# Epoch 12/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7128 - loss: 0.7311 - val_accuracy: 0.7556 - val_loss: 0.7350
# Epoch 13/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7434 - loss: 0.7209 - val_accuracy: 0.7556 - val_loss: 0.7208
# Epoch 14/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7361 - loss: 0.7229 - val_accuracy: 0.7556 - val_loss: 0.7101
# Epoch 15/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7479 - loss: 0.6957 - val_accuracy: 0.7556 - val_loss: 0.7007
# Epoch 16/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7478 - loss: 0.6965 - val_accuracy: 0.7778 - val_loss: 0.6926
# Epoch 17/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7507 - loss: 0.6814 - val_accuracy: 0.7778 - val_loss: 0.6857
# Epoch 18/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7124 - loss: 0.7164 - val_accuracy: 0.7778 - val_loss: 0.6820
# Epoch 19/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7315 - loss: 0.7096 - val_accuracy: 0.7778 - val_loss: 0.6774
# Epoch 20/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7209 - loss: 0.7144 - val_accuracy: 0.7778 - val_loss: 0.6751
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7789 - loss: 0.6646
# Evaluation on ANLI Round 2 Validation Data with LSTM: [0.6751465797424316, 0.7777777910232544]
# History keys: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Train and evaluate LSTM model on ANLI Round 3 data
model_anli_r3_lstm, history_anli_r3_lstm, evaluation_anli_r3_lstm = build_and_train_lstm_model(
    X_train_anli_r3_rnn, features_train_anli_r3, y_train_anli_r3,
    X_val_anli_r3_rnn, features_val_anli_r3, y_val_anli_r3,
    epochs=20, batch_size=32
)


print("Evaluation on ANLI Round 3 Validation Data with LSTM:", evaluation_anli_r3_lstm)
print("History keys:", history_anli_r3_lstm.history.keys())
# Out:
# Epoch 1/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.3395 - loss: 1.0900 - val_accuracy: 0.5472 - val_loss: 1.0373
# Epoch 2/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5995 - loss: 1.0261 - val_accuracy: 0.6038 - val_loss: 0.9851
# Epoch 3/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5805 - loss: 0.9705 - val_accuracy: 0.6415 - val_loss: 0.9381
# Epoch 4/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5685 - loss: 0.9435 - val_accuracy: 0.6415 - val_loss: 0.8948
# Epoch 5/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6135 - loss: 0.8903 - val_accuracy: 0.6226 - val_loss: 0.8538
# Epoch 6/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6563 - loss: 0.8345 - val_accuracy: 0.6604 - val_loss: 0.8162
# Epoch 7/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6379 - loss: 0.8241 - val_accuracy: 0.6415 - val_loss: 0.7839
# Epoch 8/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6874 - loss: 0.7784 - val_accuracy: 0.6792 - val_loss: 0.7590
# Epoch 9/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7129 - loss: 0.7318 - val_accuracy: 0.6792 - val_loss: 0.7405
# Epoch 10/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7102 - loss: 0.7305 - val_accuracy: 0.6792 - val_loss: 0.7257
# Epoch 11/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7112 - loss: 0.7158 - val_accuracy: 0.6604 - val_loss: 0.7154
# Epoch 12/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7124 - loss: 0.6992 - val_accuracy: 0.6792 - val_loss: 0.7077
# Epoch 13/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7152 - loss: 0.7201 - val_accuracy: 0.6792 - val_loss: 0.7009
# Epoch 14/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7294 - loss: 0.6832 - val_accuracy: 0.6792 - val_loss: 0.6998
# Epoch 15/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7564 - loss: 0.6490 - val_accuracy: 0.6792 - val_loss: 0.6921
# Epoch 16/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7313 - loss: 0.6820 - val_accuracy: 0.6792 - val_loss: 0.6883
# Epoch 17/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7153 - loss: 0.7072 - val_accuracy: 0.6792 - val_loss: 0.6869
# Epoch 18/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7215 - loss: 0.6998 - val_accuracy: 0.6792 - val_loss: 0.6857
# Epoch 19/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7075 - loss: 0.6566 - val_accuracy: 0.6792 - val_loss: 0.6813
# Epoch 20/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7431 - loss: 0.6770 - val_accuracy: 0.6604 - val_loss: 0.6821
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6798 - loss: 0.6411
# Evaluation on ANLI Round 3 Validation Data with LSTM: [0.6820501089096069, 0.6603773832321167]
# History keys: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Combining all datasets for a comprehensive training set
X_rnn_all_tasks = np.concatenate([
    X_snli_rnn, X_mnli_matched_rnn, X_mnli_mismatched_rnn,
    X_anli_r1_rnn, X_anli_r2_rnn, X_anli_r3_rnn
])

features_all_tasks = np.concatenate([
    features_snli, features_mnli_matched, features_mnli_mismatched,
    features_anli_r1, features_anli_r2, features_anli_r3
])

y_encoded_all_tasks = np.concatenate([
    y_encoded_snli, y_encoded_mnli_matched, y_encoded_mnli_mismatched,
    y_encoded_anli_r1, y_encoded_anli_r2, y_encoded_anli_r3
])

# Prepare data splits for combined dataset
X_train_all_rnn, X_val_all_rnn, features_train_all, features_val_all, y_train_all, y_val_all = prepare_data_splits(
    X_rnn_all_tasks, features_all_tasks, y_encoded_all_tasks
)

# Train and evaluate the LSTM model using the combined data from all tasks
model_all, history_all, evaluation_all = build_and_train_lstm_model(
    X_train_all_rnn, features_train_all, y_train_all,
    X_val_all_rnn, features_val_all, y_val_all,
    epochs=20, batch_size=32
)

print("Evaluation on All Tasks Validation Data with LSTM:", evaluation_all)
print("History keys:", history_all.history.keys())
# Out:
# Epoch 1/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8845 - loss: 0.4420 - val_accuracy: 0.9464 - val_loss: 0.1741
# Epoch 2/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9438 - loss: 0.1901 - val_accuracy: 0.9469 - val_loss: 0.1725
# Epoch 3/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9456 - loss: 0.1921 - val_accuracy: 0.9484 - val_loss: 0.1718
# Epoch 4/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9489 - loss: 0.1761 - val_accuracy: 0.9474 - val_loss: 0.1717
# Epoch 5/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9480 - loss: 0.1804 - val_accuracy: 0.9495 - val_loss: 0.1710
# Epoch 6/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9511 - loss: 0.1689 - val_accuracy: 0.9484 - val_loss: 0.1714
# Epoch 7/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9477 - loss: 0.1812 - val_accuracy: 0.9479 - val_loss: 0.1711
# Epoch 8/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9473 - loss: 0.1793 - val_accuracy: 0.9453 - val_loss: 0.1719
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9423 - loss: 0.1641
# Evaluation on All Tasks Validation Data with LSTM: [0.17187859117984772, 0.9453125]
# History keys: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# After training the model
model_all.save('LSTM_feature_ensemble.h5')  # Saves the model in HDF5 format

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    plt.show()

plot_training_history(history_snli_lstm)

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    plt.show()

plot_training_history(history_mnli_matched_lstm)

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    plt.show()

plot_training_history(history_mnli_mismatched_lstm)

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    plt.show()

plot_training_history(history_anli_r1_lstm)

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    plt.show()

plot_training_history(history_anli_r2_lstm)

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    plt.show()

plot_training_history(history_anli_r3_lstm)

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    plt.show()

plot_training_history(history_all)

# %%
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, Concatenate, Flatten
from tensorflow.keras.models import Model



# Function to build the LSTM model
def create_lstm_model(sequence_input_shape, features_input_shape):
    sequence_input = Input(shape=sequence_input_shape, name='sequence_input')
    lstm = LSTM(64, return_sequences=False)(sequence_input)
    lstm = Dropout(0.5)(lstm)

    features_input = Input(shape=features_input_shape, name='features_input')
    features = Dense(32, activation='relu')(features_input)
    features = Dropout(0.2)(features)
    features = Flatten()(features)

    concatenated = Concatenate()([lstm, features])
    final_output = Dense(3, activation='softmax')(concatenated)

    model = Model(inputs=[sequence_input, features_input], outputs=final_output)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

def cross_validate_lstm_model(X_rnn, features, y_encoded, num_folds=5):
    # Convert labels to single integers for stratified split
    y_single = np.argmax(y_encoded, axis=1)
    kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)
    fold_no = 1
    acc_per_fold = []
    loss_per_fold = []
    histories = []  # List to store history for each fold

    for train, test in kfold.split(X_rnn, y_single):
        X_train_rnn, X_test_rnn = X_rnn[train], X_rnn[test]
        features_train, features_test = features[train], features[test]
        y_train, y_test = y_encoded[train], y_encoded[test]

        model = create_lstm_model(X_train_rnn.shape[1:], features_train.shape[1:])

        print(f'Training on fold {fold_no}...')
        history = model.fit([X_train_rnn, features_train], y_train, epochs=20, batch_size=32, verbose=1, validation_data=([X_test_rnn, features_test], y_test))
        histories.append(history)

        scores = model.evaluate([X_test_rnn, features_test], y_test, verbose=0)
        print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
        acc_per_fold.append(scores[1] * 100)
        loss_per_fold.append(scores[0])

        fold_no += 1

    print('------------------------------------------------------------------------')
    print('Score per fold')
    for i in range(0, len(acc_per_fold)):
        print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
    print('------------------------------------------------------------------------')
    print('Average scores for all folds:')
    print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
    print(f'> Loss: {np.mean(loss_per_fold)}')
    print('------------------------------------------------------------------------')
    
    return histories

# %%
histories_snli = cross_validate_lstm_model(X_snli_rnn, features_snli, y_encoded_snli)
# Out:
# Training on fold 1...
# Epoch 1/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7168 - loss: 0.8160 - val_accuracy: 0.9544 - val_loss: 0.1882
# Epoch 2/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9511 - loss: 0.1909 - val_accuracy: 0.9544 - val_loss: 0.1427
# Epoch 3/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9603 - loss: 0.1481 - val_accuracy: 0.9611 - val_loss: 0.1261
# Epoch 4/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9551 - loss: 0.1549 - val_accuracy: 0.9627 - val_loss: 0.1189
# Epoch 5/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9627 - loss: 0.1359 - val_accuracy: 0.9660 - val_loss: 0.1180
# Epoch 6/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9651 - loss: 0.1371 - val_accuracy: 0.9652 - val_loss: 0.1179
# Epoch 7/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9607 - loss: 0.1490 - val_accuracy: 0.9635 - val_loss: 0.1168
# Epoch 8/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9573 - loss: 0.1573 - val_accuracy: 0.9635 - val_loss: 0.1168
# Epoch 9/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9582 - loss: 0.1500 - val_accuracy: 0.9644 - val_loss: 0.1181
# Epoch 10/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9637 - loss: 0.1376 - val_accuracy: 0.9644 - val_loss: 0.1163
# Epoch 11/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9614 - loss: 0.1394 - val_accuracy: 0.9627 - val_loss: 0.1164
# Epoch 12/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9624 - loss: 0.1330 - val_accuracy: 0.9619 - val_loss: 0.1168
# Epoch 13/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9590 - loss: 0.1539 - val_accuracy: 0.9644 - val_loss: 0.1176
# Epoch 14/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9578 - loss: 0.1531 - val_accuracy: 0.9644 - val_loss: 0.1182
# Epoch 15/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9579 - loss: 0.1455 - val_accuracy: 0.9635 - val_loss: 0.1179
# Epoch 16/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9588 - loss: 0.1368 - val_accuracy: 0.9635 - val_loss: 0.1178
# Epoch 17/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9592 - loss: 0.1479 - val_accuracy: 0.9627 - val_loss: 0.1195
# Epoch 18/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9640 - loss: 0.1402 - val_accuracy: 0.9627 - val_loss: 0.1195
# Epoch 19/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9624 - loss: 0.1451 - val_accuracy: 0.9611 - val_loss: 0.1174
# Epoch 20/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9610 - loss: 0.1446 - val_accuracy: 0.9602 - val_loss: 0.1177
# Score for fold 1: loss of 0.1177327111363411; compile_metrics of 96.02319598197937%
# Training on fold 2...
# Epoch 1/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8750 - loss: 0.7111 - val_accuracy: 0.9544 - val_loss: 0.1861
# Epoch 2/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9527 - loss: 0.1827 - val_accuracy: 0.9544 - val_loss: 0.1484
# Epoch 3/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9518 - loss: 0.1634 - val_accuracy: 0.9586 - val_loss: 0.1329
# Epoch 4/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9562 - loss: 0.1564 - val_accuracy: 0.9627 - val_loss: 0.1251
# Epoch 5/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9623 - loss: 0.1385 - val_accuracy: 0.9602 - val_loss: 0.1243
# Epoch 6/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9595 - loss: 0.1363 - val_accuracy: 0.9627 - val_loss: 0.1229
# Epoch 7/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9602 - loss: 0.1379 - val_accuracy: 0.9602 - val_loss: 0.1231
# Epoch 8/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9584 - loss: 0.1457 - val_accuracy: 0.9611 - val_loss: 0.1223
# Epoch 9/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9603 - loss: 0.1481 - val_accuracy: 0.9602 - val_loss: 0.1222
# Epoch 10/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9659 - loss: 0.1307 - val_accuracy: 0.9594 - val_loss: 0.1227
# Epoch 11/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9651 - loss: 0.1287 - val_accuracy: 0.9602 - val_loss: 0.1224
# Epoch 12/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9557 - loss: 0.1446 - val_accuracy: 0.9602 - val_loss: 0.1234
# Epoch 13/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9626 - loss: 0.1296 - val_accuracy: 0.9602 - val_loss: 0.1225
# Epoch 14/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9609 - loss: 0.1386 - val_accuracy: 0.9602 - val_loss: 0.1220
# Epoch 15/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9612 - loss: 0.1448 - val_accuracy: 0.9611 - val_loss: 0.1217
# Epoch 16/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9572 - loss: 0.1523 - val_accuracy: 0.9611 - val_loss: 0.1221
# Epoch 17/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9586 - loss: 0.1469 - val_accuracy: 0.9611 - val_loss: 0.1218
# Epoch 18/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9571 - loss: 0.1524 - val_accuracy: 0.9611 - val_loss: 0.1217
# Epoch 19/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9614 - loss: 0.1377 - val_accuracy: 0.9619 - val_loss: 0.1217
# Epoch 20/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9590 - loss: 0.1449 - val_accuracy: 0.9594 - val_loss: 0.1224
# Score for fold 2: loss of 0.12240155041217804; compile_metrics of 95.94034552574158%
# Training on fold 3...
# Epoch 1/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8394 - loss: 0.7401 - val_accuracy: 0.9519 - val_loss: 0.1991
# Epoch 2/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9513 - loss: 0.1943 - val_accuracy: 0.9527 - val_loss: 0.1610
# Epoch 3/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9598 - loss: 0.1363 - val_accuracy: 0.9585 - val_loss: 0.1482
# Epoch 4/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9581 - loss: 0.1406 - val_accuracy: 0.9610 - val_loss: 0.1444
# Epoch 5/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9628 - loss: 0.1260 - val_accuracy: 0.9635 - val_loss: 0.1438
# Epoch 6/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9612 - loss: 0.1431 - val_accuracy: 0.9602 - val_loss: 0.1442
# Epoch 7/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9631 - loss: 0.1244 - val_accuracy: 0.9602 - val_loss: 0.1440
# Epoch 8/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9581 - loss: 0.1442 - val_accuracy: 0.9602 - val_loss: 0.1437
# Epoch 9/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9627 - loss: 0.1370 - val_accuracy: 0.9610 - val_loss: 0.1443
# Epoch 10/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9586 - loss: 0.1434 - val_accuracy: 0.9594 - val_loss: 0.1437
# Epoch 11/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9635 - loss: 0.1273 - val_accuracy: 0.9602 - val_loss: 0.1435
# Epoch 12/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9619 - loss: 0.1379 - val_accuracy: 0.9594 - val_loss: 0.1431
# Epoch 13/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9612 - loss: 0.1323 - val_accuracy: 0.9594 - val_loss: 0.1432
# Epoch 14/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9593 - loss: 0.1384 - val_accuracy: 0.9585 - val_loss: 0.1448
# Epoch 15/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9595 - loss: 0.1412 - val_accuracy: 0.9594 - val_loss: 0.1433
# Epoch 16/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9623 - loss: 0.1320 - val_accuracy: 0.9594 - val_loss: 0.1437
# Epoch 17/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9603 - loss: 0.1335 - val_accuracy: 0.9594 - val_loss: 0.1433
# Epoch 18/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9587 - loss: 0.1249 - val_accuracy: 0.9594 - val_loss: 0.1438
# Epoch 19/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9584 - loss: 0.1410 - val_accuracy: 0.9602 - val_loss: 0.1429
# Epoch 20/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9617 - loss: 0.1289 - val_accuracy: 0.9594 - val_loss: 0.1426
# Score for fold 3: loss of 0.14263683557510376; compile_metrics of 95.93698382377625%
# Training on fold 4...
# Epoch 1/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8919 - loss: 0.6832 - val_accuracy: 0.9536 - val_loss: 0.1884
# Epoch 2/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9507 - loss: 0.1852 - val_accuracy: 0.9536 - val_loss: 0.1552
# Epoch 3/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9566 - loss: 0.1552 - val_accuracy: 0.9643 - val_loss: 0.1435
# Epoch 4/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9577 - loss: 0.1457 - val_accuracy: 0.9619 - val_loss: 0.1416
# Epoch 5/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9626 - loss: 0.1382 - val_accuracy: 0.9627 - val_loss: 0.1410
# Epoch 6/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9586 - loss: 0.1528 - val_accuracy: 0.9619 - val_loss: 0.1405
# Epoch 7/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9633 - loss: 0.1344 - val_accuracy: 0.9619 - val_loss: 0.1405
# Epoch 8/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9586 - loss: 0.1434 - val_accuracy: 0.9610 - val_loss: 0.1417
# Epoch 9/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9641 - loss: 0.1241 - val_accuracy: 0.9619 - val_loss: 0.1401
# Epoch 10/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9654 - loss: 0.1272 - val_accuracy: 0.9610 - val_loss: 0.1399
# Epoch 11/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9616 - loss: 0.1345 - val_accuracy: 0.9610 - val_loss: 0.1402
# Epoch 12/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9571 - loss: 0.1465 - val_accuracy: 0.9610 - val_loss: 0.1408
# Epoch 13/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9637 - loss: 0.1321 - val_accuracy: 0.9619 - val_loss: 0.1400
# Epoch 14/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9622 - loss: 0.1320 - val_accuracy: 0.9619 - val_loss: 0.1392
# Epoch 15/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9617 - loss: 0.1422 - val_accuracy: 0.9627 - val_loss: 0.1403
# Epoch 16/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9569 - loss: 0.1546 - val_accuracy: 0.9627 - val_loss: 0.1407
# Epoch 17/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9628 - loss: 0.1386 - val_accuracy: 0.9627 - val_loss: 0.1403
# Epoch 18/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9678 - loss: 0.1185 - val_accuracy: 0.9627 - val_loss: 0.1401
# Epoch 19/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9559 - loss: 0.1589 - val_accuracy: 0.9627 - val_loss: 0.1423
# Epoch 20/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9574 - loss: 0.1430 - val_accuracy: 0.9619 - val_loss: 0.1402
# Score for fold 4: loss of 0.14020074903964996; compile_metrics of 96.18573784828186%
# Training on fold 5...
# Epoch 1/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9208 - loss: 0.6852 - val_accuracy: 0.9519 - val_loss: 0.1943
# Epoch 2/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9510 - loss: 0.1871 - val_accuracy: 0.9519 - val_loss: 0.1668
# Epoch 3/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9544 - loss: 0.1464 - val_accuracy: 0.9561 - val_loss: 0.1552
# Epoch 4/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9591 - loss: 0.1539 - val_accuracy: 0.9585 - val_loss: 0.1515
# Epoch 5/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9633 - loss: 0.1299 - val_accuracy: 0.9594 - val_loss: 0.1506
# Epoch 6/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9642 - loss: 0.1260 - val_accuracy: 0.9594 - val_loss: 0.1512
# Epoch 7/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9624 - loss: 0.1304 - val_accuracy: 0.9569 - val_loss: 0.1511
# Epoch 8/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9584 - loss: 0.1484 - val_accuracy: 0.9585 - val_loss: 0.1520
# Epoch 9/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9609 - loss: 0.1264 - val_accuracy: 0.9569 - val_loss: 0.1513
# Epoch 10/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9594 - loss: 0.1348 - val_accuracy: 0.9585 - val_loss: 0.1519
# Epoch 11/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9626 - loss: 0.1313 - val_accuracy: 0.9577 - val_loss: 0.1517
# Epoch 12/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9671 - loss: 0.1176 - val_accuracy: 0.9585 - val_loss: 0.1515
# Epoch 13/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9648 - loss: 0.1217 - val_accuracy: 0.9569 - val_loss: 0.1515
# Epoch 14/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9598 - loss: 0.1390 - val_accuracy: 0.9585 - val_loss: 0.1520
# Epoch 15/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9582 - loss: 0.1434 - val_accuracy: 0.9585 - val_loss: 0.1524
# Epoch 16/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9596 - loss: 0.1332 - val_accuracy: 0.9585 - val_loss: 0.1517
# Epoch 17/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9575 - loss: 0.1364 - val_accuracy: 0.9577 - val_loss: 0.1513
# Epoch 18/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9624 - loss: 0.1415 - val_accuracy: 0.9594 - val_loss: 0.1527
# Epoch 19/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9581 - loss: 0.1357 - val_accuracy: 0.9585 - val_loss: 0.1515
# Epoch 20/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9634 - loss: 0.1343 - val_accuracy: 0.9585 - val_loss: 0.1518
# Score for fold 5: loss of 0.15183928608894348; compile_metrics of 95.85406184196472%
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.1177327111363411 - Accuracy: 96.02319598197937%
# > Fold 2 - Loss: 0.12240155041217804 - Accuracy: 95.94034552574158%
# > Fold 3 - Loss: 0.14263683557510376 - Accuracy: 95.93698382377625%
# > Fold 4 - Loss: 0.14020074903964996 - Accuracy: 96.18573784828186%
# > Fold 5 - Loss: 0.15183928608894348 - Accuracy: 95.85406184196472%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 95.98806500434875 (+- 0.11238507195711402)
# > Loss: 0.13496222645044326
# ------------------------------------------------------------------------

# %%
histories_mnli_matched = cross_validate_lstm_model(X_mnli_matched_rnn, features_mnli_matched, y_encoded_mnli_matched)
# Out:
# Training on fold 1...
# Epoch 1/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.7907 - loss: 0.5820 - val_accuracy: 0.9659 - val_loss: 0.1503
# Epoch 2/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9613 - loss: 0.1642 - val_accuracy: 0.9684 - val_loss: 0.1364
# Epoch 3/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9676 - loss: 0.1396 - val_accuracy: 0.9676 - val_loss: 0.1343
# Epoch 4/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9647 - loss: 0.1354 - val_accuracy: 0.9667 - val_loss: 0.1358
# Epoch 5/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9649 - loss: 0.1437 - val_accuracy: 0.9667 - val_loss: 0.1351
# Epoch 6/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9654 - loss: 0.1293 - val_accuracy: 0.9659 - val_loss: 0.1358
# Epoch 7/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9649 - loss: 0.1408 - val_accuracy: 0.9659 - val_loss: 0.1373
# Epoch 8/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9689 - loss: 0.1281 - val_accuracy: 0.9659 - val_loss: 0.1372
# Epoch 9/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9659 - loss: 0.1406 - val_accuracy: 0.9659 - val_loss: 0.1357
# Epoch 10/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9657 - loss: 0.1411 - val_accuracy: 0.9659 - val_loss: 0.1366
# Epoch 11/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9675 - loss: 0.1359 - val_accuracy: 0.9667 - val_loss: 0.1360
# Epoch 12/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9673 - loss: 0.1321 - val_accuracy: 0.9659 - val_loss: 0.1372
# Epoch 13/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9653 - loss: 0.1379 - val_accuracy: 0.9667 - val_loss: 0.1357
# Epoch 14/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9642 - loss: 0.1355 - val_accuracy: 0.9659 - val_loss: 0.1374
# Epoch 15/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9647 - loss: 0.1400 - val_accuracy: 0.9667 - val_loss: 0.1358
# Epoch 16/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9640 - loss: 0.1417 - val_accuracy: 0.9667 - val_loss: 0.1369
# Epoch 17/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9670 - loss: 0.1410 - val_accuracy: 0.9667 - val_loss: 0.1361
# Epoch 18/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9636 - loss: 0.1456 - val_accuracy: 0.9667 - val_loss: 0.1369
# Epoch 19/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9597 - loss: 0.1542 - val_accuracy: 0.9667 - val_loss: 0.1362
# Epoch 20/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9677 - loss: 0.1306 - val_accuracy: 0.9650 - val_loss: 0.1390
# Score for fold 1: loss of 0.13900679349899292; compile_metrics of 96.50170803070068%
# Training on fold 2...
# Epoch 1/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.7720 - loss: 0.6361 - val_accuracy: 0.9633 - val_loss: 0.1649
# Epoch 2/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9641 - loss: 0.1625 - val_accuracy: 0.9633 - val_loss: 0.1509
# Epoch 3/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9714 - loss: 0.1243 - val_accuracy: 0.9624 - val_loss: 0.1450
# Epoch 4/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9670 - loss: 0.1420 - val_accuracy: 0.9633 - val_loss: 0.1451
# Epoch 5/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9643 - loss: 0.1471 - val_accuracy: 0.9641 - val_loss: 0.1451
# Epoch 6/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9670 - loss: 0.1332 - val_accuracy: 0.9641 - val_loss: 0.1457
# Epoch 7/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9649 - loss: 0.1435 - val_accuracy: 0.9650 - val_loss: 0.1437
# Epoch 8/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9706 - loss: 0.1212 - val_accuracy: 0.9633 - val_loss: 0.1442
# Epoch 9/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9655 - loss: 0.1388 - val_accuracy: 0.9650 - val_loss: 0.1436
# Epoch 10/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9661 - loss: 0.1352 - val_accuracy: 0.9650 - val_loss: 0.1442
# Epoch 11/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9635 - loss: 0.1396 - val_accuracy: 0.9641 - val_loss: 0.1446
# Epoch 12/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9657 - loss: 0.1335 - val_accuracy: 0.9650 - val_loss: 0.1432
# Epoch 13/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9710 - loss: 0.1217 - val_accuracy: 0.9633 - val_loss: 0.1443
# Epoch 14/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9676 - loss: 0.1319 - val_accuracy: 0.9650 - val_loss: 0.1435
# Epoch 15/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9696 - loss: 0.1286 - val_accuracy: 0.9641 - val_loss: 0.1445
# Epoch 16/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9691 - loss: 0.1233 - val_accuracy: 0.9633 - val_loss: 0.1440
# Epoch 17/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9640 - loss: 0.1434 - val_accuracy: 0.9650 - val_loss: 0.1441
# Epoch 18/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9651 - loss: 0.1405 - val_accuracy: 0.9633 - val_loss: 0.1448
# Epoch 19/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9700 - loss: 0.1242 - val_accuracy: 0.9650 - val_loss: 0.1427
# Epoch 20/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9663 - loss: 0.1373 - val_accuracy: 0.9633 - val_loss: 0.1446
# Score for fold 2: loss of 0.14459282159805298; compile_metrics of 96.32792472839355%
# Training on fold 3...
# Epoch 1/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - accuracy: 0.9541 - loss: 0.3497 - val_accuracy: 0.9641 - val_loss: 0.1463
# Epoch 2/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9674 - loss: 0.1484 - val_accuracy: 0.9641 - val_loss: 0.1388
# Epoch 3/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9656 - loss: 0.1464 - val_accuracy: 0.9650 - val_loss: 0.1360
# Epoch 4/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9640 - loss: 0.1477 - val_accuracy: 0.9684 - val_loss: 0.1340
# Epoch 5/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9643 - loss: 0.1472 - val_accuracy: 0.9693 - val_loss: 0.1341
# Epoch 6/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9658 - loss: 0.1408 - val_accuracy: 0.9684 - val_loss: 0.1335
# Epoch 7/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9694 - loss: 0.1285 - val_accuracy: 0.9684 - val_loss: 0.1325
# Epoch 8/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9702 - loss: 0.1262 - val_accuracy: 0.9684 - val_loss: 0.1323
# Epoch 9/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9649 - loss: 0.1416 - val_accuracy: 0.9684 - val_loss: 0.1322
# Epoch 10/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9644 - loss: 0.1545 - val_accuracy: 0.9684 - val_loss: 0.1326
# Epoch 11/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9667 - loss: 0.1394 - val_accuracy: 0.9684 - val_loss: 0.1326
# Epoch 12/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9648 - loss: 0.1475 - val_accuracy: 0.9684 - val_loss: 0.1328
# Epoch 13/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9669 - loss: 0.1395 - val_accuracy: 0.9684 - val_loss: 0.1342
# Epoch 14/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9632 - loss: 0.1491 - val_accuracy: 0.9684 - val_loss: 0.1337
# Epoch 15/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9644 - loss: 0.1425 - val_accuracy: 0.9684 - val_loss: 0.1329
# Epoch 16/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9672 - loss: 0.1381 - val_accuracy: 0.9684 - val_loss: 0.1323
# Epoch 17/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9699 - loss: 0.1250 - val_accuracy: 0.9684 - val_loss: 0.1322
# Epoch 18/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9679 - loss: 0.1206 - val_accuracy: 0.9684 - val_loss: 0.1323
# Epoch 19/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9603 - loss: 0.1545 - val_accuracy: 0.9675 - val_loss: 0.1353
# Epoch 20/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9703 - loss: 0.1276 - val_accuracy: 0.9667 - val_loss: 0.1331
# Score for fold 3: loss of 0.13312281668186188; compile_metrics of 96.66951298713684%
# Training on fold 4...
# Epoch 1/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.8878 - loss: 0.4873 - val_accuracy: 0.9650 - val_loss: 0.1474
# Epoch 2/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9657 - loss: 0.1458 - val_accuracy: 0.9650 - val_loss: 0.1350
# Epoch 3/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9656 - loss: 0.1383 - val_accuracy: 0.9658 - val_loss: 0.1335
# Epoch 4/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9657 - loss: 0.1416 - val_accuracy: 0.9658 - val_loss: 0.1309
# Epoch 5/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9636 - loss: 0.1433 - val_accuracy: 0.9658 - val_loss: 0.1321
# Epoch 6/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9674 - loss: 0.1385 - val_accuracy: 0.9658 - val_loss: 0.1307
# Epoch 7/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9647 - loss: 0.1403 - val_accuracy: 0.9658 - val_loss: 0.1310
# Epoch 8/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9688 - loss: 0.1349 - val_accuracy: 0.9650 - val_loss: 0.1302
# Epoch 9/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9693 - loss: 0.1264 - val_accuracy: 0.9658 - val_loss: 0.1306
# Epoch 10/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9635 - loss: 0.1466 - val_accuracy: 0.9650 - val_loss: 0.1321
# Epoch 11/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9702 - loss: 0.1238 - val_accuracy: 0.9667 - val_loss: 0.1310
# Epoch 12/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9638 - loss: 0.1450 - val_accuracy: 0.9658 - val_loss: 0.1306
# Epoch 13/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9671 - loss: 0.1414 - val_accuracy: 0.9650 - val_loss: 0.1315
# Epoch 14/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9662 - loss: 0.1384 - val_accuracy: 0.9667 - val_loss: 0.1310
# Epoch 15/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9723 - loss: 0.1190 - val_accuracy: 0.9650 - val_loss: 0.1298
# Epoch 16/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9641 - loss: 0.1421 - val_accuracy: 0.9667 - val_loss: 0.1301
# Epoch 17/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9686 - loss: 0.1282 - val_accuracy: 0.9667 - val_loss: 0.1306
# Epoch 18/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9640 - loss: 0.1442 - val_accuracy: 0.9658 - val_loss: 0.1302
# Epoch 19/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9644 - loss: 0.1466 - val_accuracy: 0.9658 - val_loss: 0.1301
# Epoch 20/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9702 - loss: 0.1260 - val_accuracy: 0.9667 - val_loss: 0.1310
# Score for fold 4: loss of 0.13096930086612701; compile_metrics of 96.66951298713684%
# Training on fold 5...
# Epoch 1/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.8129 - loss: 0.5734 - val_accuracy: 0.9675 - val_loss: 0.1481
# Epoch 2/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9640 - loss: 0.1653 - val_accuracy: 0.9675 - val_loss: 0.1297
# Epoch 3/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9652 - loss: 0.1508 - val_accuracy: 0.9667 - val_loss: 0.1255
# Epoch 4/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9634 - loss: 0.1461 - val_accuracy: 0.9667 - val_loss: 0.1249
# Epoch 5/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9682 - loss: 0.1355 - val_accuracy: 0.9658 - val_loss: 0.1257
# Epoch 6/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9674 - loss: 0.1327 - val_accuracy: 0.9667 - val_loss: 0.1255
# Epoch 7/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9644 - loss: 0.1444 - val_accuracy: 0.9658 - val_loss: 0.1261
# Epoch 8/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9641 - loss: 0.1514 - val_accuracy: 0.9667 - val_loss: 0.1263
# Epoch 9/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9699 - loss: 0.1293 - val_accuracy: 0.9658 - val_loss: 0.1280
# Epoch 10/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9671 - loss: 0.1407 - val_accuracy: 0.9658 - val_loss: 0.1265
# Epoch 11/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9682 - loss: 0.1356 - val_accuracy: 0.9658 - val_loss: 0.1267
# Epoch 12/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9634 - loss: 0.1365 - val_accuracy: 0.9658 - val_loss: 0.1269
# Epoch 13/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9634 - loss: 0.1419 - val_accuracy: 0.9667 - val_loss: 0.1263
# Epoch 14/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9656 - loss: 0.1420 - val_accuracy: 0.9667 - val_loss: 0.1262
# Epoch 15/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9684 - loss: 0.1334 - val_accuracy: 0.9658 - val_loss: 0.1264
# Epoch 16/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9620 - loss: 0.1500 - val_accuracy: 0.9667 - val_loss: 0.1263
# Epoch 17/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9683 - loss: 0.1303 - val_accuracy: 0.9667 - val_loss: 0.1259
# Epoch 18/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9628 - loss: 0.1477 - val_accuracy: 0.9658 - val_loss: 0.1260
# Epoch 19/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9669 - loss: 0.1304 - val_accuracy: 0.9658 - val_loss: 0.1283
# Epoch 20/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9658 - loss: 0.1450 - val_accuracy: 0.9667 - val_loss: 0.1263
# Score for fold 5: loss of 0.12625813484191895; compile_metrics of 96.66951298713684%
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.13900679349899292 - Accuracy: 96.50170803070068%
# > Fold 2 - Loss: 0.14459282159805298 - Accuracy: 96.32792472839355%
# > Fold 3 - Loss: 0.13312281668186188 - Accuracy: 96.66951298713684%
# > Fold 4 - Loss: 0.13096930086612701 - Accuracy: 96.66951298713684%
# > Fold 5 - Loss: 0.12625813484191895 - Accuracy: 96.66951298713684%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 96.56763434410095 (+- 0.13634130143257447)
# > Loss: 0.13478997349739075
# ------------------------------------------------------------------------

# %%
histories_mnli_mismatched = cross_validate_lstm_model(X_mnli_mismatched_rnn, features_mnli_mismatched, y_encoded_mnli_mismatched)
# Out:
# Training on fold 1...
# Epoch 1/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7676 - loss: 0.7830 - val_accuracy: 0.9645 - val_loss: 0.1743
# Epoch 2/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9611 - loss: 0.1775 - val_accuracy: 0.9645 - val_loss: 0.1468
# Epoch 3/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9676 - loss: 0.1352 - val_accuracy: 0.9645 - val_loss: 0.1409
# Epoch 4/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9721 - loss: 0.1162 - val_accuracy: 0.9645 - val_loss: 0.1375
# Epoch 5/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9656 - loss: 0.1310 - val_accuracy: 0.9645 - val_loss: 0.1389
# Epoch 6/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9616 - loss: 0.1382 - val_accuracy: 0.9645 - val_loss: 0.1373
# Epoch 7/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9656 - loss: 0.1289 - val_accuracy: 0.9653 - val_loss: 0.1359
# Epoch 8/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9677 - loss: 0.1171 - val_accuracy: 0.9653 - val_loss: 0.1366
# Epoch 9/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9660 - loss: 0.1254 - val_accuracy: 0.9645 - val_loss: 0.1367
# Epoch 10/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9640 - loss: 0.1289 - val_accuracy: 0.9653 - val_loss: 0.1362
# Epoch 11/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9660 - loss: 0.1257 - val_accuracy: 0.9653 - val_loss: 0.1361
# Epoch 12/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9674 - loss: 0.1231 - val_accuracy: 0.9645 - val_loss: 0.1340
# Epoch 13/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9648 - loss: 0.1200 - val_accuracy: 0.9662 - val_loss: 0.1354
# Epoch 14/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9675 - loss: 0.1165 - val_accuracy: 0.9645 - val_loss: 0.1345
# Epoch 15/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9659 - loss: 0.1193 - val_accuracy: 0.9645 - val_loss: 0.1344
# Epoch 16/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9702 - loss: 0.1135 - val_accuracy: 0.9653 - val_loss: 0.1348
# Epoch 17/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9695 - loss: 0.1152 - val_accuracy: 0.9653 - val_loss: 0.1352
# Epoch 18/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9627 - loss: 0.1247 - val_accuracy: 0.9653 - val_loss: 0.1375
# Epoch 19/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9688 - loss: 0.1223 - val_accuracy: 0.9653 - val_loss: 0.1353
# Epoch 20/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9671 - loss: 0.1145 - val_accuracy: 0.9653 - val_loss: 0.1347
# Score for fold 1: loss of 0.13474684953689575; compile_metrics of 96.53130173683167%
# Training on fold 2...
# Epoch 1/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7876 - loss: 0.7436 - val_accuracy: 0.9679 - val_loss: 0.1646
# Epoch 2/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9698 - loss: 0.1503 - val_accuracy: 0.9679 - val_loss: 0.1325
# Epoch 3/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9678 - loss: 0.1357 - val_accuracy: 0.9679 - val_loss: 0.1243
# Epoch 4/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9677 - loss: 0.1228 - val_accuracy: 0.9679 - val_loss: 0.1198
# Epoch 5/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9645 - loss: 0.1299 - val_accuracy: 0.9679 - val_loss: 0.1178
# Epoch 6/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9673 - loss: 0.1298 - val_accuracy: 0.9687 - val_loss: 0.1180
# Epoch 7/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9564 - loss: 0.1495 - val_accuracy: 0.9687 - val_loss: 0.1156
# Epoch 8/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9671 - loss: 0.1221 - val_accuracy: 0.9679 - val_loss: 0.1152
# Epoch 9/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9668 - loss: 0.1254 - val_accuracy: 0.9662 - val_loss: 0.1151
# Epoch 10/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9639 - loss: 0.1267 - val_accuracy: 0.9687 - val_loss: 0.1166
# Epoch 11/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9639 - loss: 0.1247 - val_accuracy: 0.9687 - val_loss: 0.1142
# Epoch 12/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9675 - loss: 0.1176 - val_accuracy: 0.9679 - val_loss: 0.1151
# Epoch 13/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9659 - loss: 0.1211 - val_accuracy: 0.9687 - val_loss: 0.1135
# Epoch 14/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9660 - loss: 0.1242 - val_accuracy: 0.9662 - val_loss: 0.1132
# Epoch 15/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9705 - loss: 0.1147 - val_accuracy: 0.9662 - val_loss: 0.1136
# Epoch 16/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9685 - loss: 0.1183 - val_accuracy: 0.9687 - val_loss: 0.1129
# Epoch 17/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9644 - loss: 0.1211 - val_accuracy: 0.9687 - val_loss: 0.1129
# Epoch 18/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9701 - loss: 0.1130 - val_accuracy: 0.9662 - val_loss: 0.1130
# Epoch 19/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9661 - loss: 0.1270 - val_accuracy: 0.9679 - val_loss: 0.1117
# Epoch 20/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9689 - loss: 0.1115 - val_accuracy: 0.9670 - val_loss: 0.1118
# Score for fold 2: loss of 0.11176823079586029; compile_metrics of 96.70050740242004%
# Training on fold 3...
# Epoch 1/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7630 - loss: 0.7612 - val_accuracy: 0.9670 - val_loss: 0.1600
# Epoch 2/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9691 - loss: 0.1461 - val_accuracy: 0.9670 - val_loss: 0.1382
# Epoch 3/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9714 - loss: 0.1213 - val_accuracy: 0.9670 - val_loss: 0.1315
# Epoch 4/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9694 - loss: 0.1219 - val_accuracy: 0.9670 - val_loss: 0.1281
# Epoch 5/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9630 - loss: 0.1357 - val_accuracy: 0.9670 - val_loss: 0.1271
# Epoch 6/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9705 - loss: 0.1214 - val_accuracy: 0.9670 - val_loss: 0.1251
# Epoch 7/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9642 - loss: 0.1343 - val_accuracy: 0.9670 - val_loss: 0.1258
# Epoch 8/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9651 - loss: 0.1235 - val_accuracy: 0.9679 - val_loss: 0.1244
# Epoch 9/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9630 - loss: 0.1273 - val_accuracy: 0.9679 - val_loss: 0.1250
# Epoch 10/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9677 - loss: 0.1171 - val_accuracy: 0.9679 - val_loss: 0.1242
# Epoch 11/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9665 - loss: 0.1267 - val_accuracy: 0.9679 - val_loss: 0.1242
# Epoch 12/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9653 - loss: 0.1241 - val_accuracy: 0.9670 - val_loss: 0.1237
# Epoch 13/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9673 - loss: 0.1250 - val_accuracy: 0.9679 - val_loss: 0.1252
# Epoch 14/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9674 - loss: 0.1165 - val_accuracy: 0.9679 - val_loss: 0.1258
# Epoch 15/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9686 - loss: 0.1160 - val_accuracy: 0.9679 - val_loss: 0.1249
# Epoch 16/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9610 - loss: 0.1203 - val_accuracy: 0.9687 - val_loss: 0.1242
# Epoch 17/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9640 - loss: 0.1191 - val_accuracy: 0.9670 - val_loss: 0.1229
# Epoch 18/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9671 - loss: 0.1149 - val_accuracy: 0.9687 - val_loss: 0.1237
# Epoch 19/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9629 - loss: 0.1302 - val_accuracy: 0.9679 - val_loss: 0.1259
# Epoch 20/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9660 - loss: 0.1225 - val_accuracy: 0.9679 - val_loss: 0.1259
# Score for fold 3: loss of 0.12585672736167908; compile_metrics of 96.78511023521423%
# Training on fold 4...
# Epoch 1/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7492 - loss: 0.7793 - val_accuracy: 0.9662 - val_loss: 0.1743
# Epoch 2/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9658 - loss: 0.1647 - val_accuracy: 0.9670 - val_loss: 0.1364
# Epoch 3/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9641 - loss: 0.1409 - val_accuracy: 0.9679 - val_loss: 0.1274
# Epoch 4/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9635 - loss: 0.1405 - val_accuracy: 0.9679 - val_loss: 0.1237
# Epoch 5/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9696 - loss: 0.1169 - val_accuracy: 0.9662 - val_loss: 0.1219
# Epoch 6/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9628 - loss: 0.1437 - val_accuracy: 0.9645 - val_loss: 0.1214
# Epoch 7/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9629 - loss: 0.1350 - val_accuracy: 0.9645 - val_loss: 0.1208
# Epoch 8/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9620 - loss: 0.1280 - val_accuracy: 0.9662 - val_loss: 0.1206
# Epoch 9/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9672 - loss: 0.1220 - val_accuracy: 0.9662 - val_loss: 0.1205
# Epoch 10/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9645 - loss: 0.1250 - val_accuracy: 0.9653 - val_loss: 0.1207
# Epoch 11/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9697 - loss: 0.1098 - val_accuracy: 0.9653 - val_loss: 0.1210
# Epoch 12/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9691 - loss: 0.1167 - val_accuracy: 0.9653 - val_loss: 0.1201
# Epoch 13/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9662 - loss: 0.1257 - val_accuracy: 0.9653 - val_loss: 0.1202
# Epoch 14/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9664 - loss: 0.1221 - val_accuracy: 0.9645 - val_loss: 0.1207
# Epoch 15/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9703 - loss: 0.1161 - val_accuracy: 0.9662 - val_loss: 0.1205
# Epoch 16/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9622 - loss: 0.1384 - val_accuracy: 0.9653 - val_loss: 0.1195
# Epoch 17/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9662 - loss: 0.1235 - val_accuracy: 0.9653 - val_loss: 0.1196
# Epoch 18/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9644 - loss: 0.1243 - val_accuracy: 0.9653 - val_loss: 0.1202
# Epoch 19/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9640 - loss: 0.1389 - val_accuracy: 0.9645 - val_loss: 0.1198
# Epoch 20/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9651 - loss: 0.1259 - val_accuracy: 0.9645 - val_loss: 0.1195
# Score for fold 4: loss of 0.11947308480739594; compile_metrics of 96.44669890403748%
# Training on fold 5...
# Epoch 1/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8205 - loss: 0.6960 - val_accuracy: 0.9653 - val_loss: 0.1646
# Epoch 2/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9652 - loss: 0.1623 - val_accuracy: 0.9653 - val_loss: 0.1357
# Epoch 3/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9651 - loss: 0.1479 - val_accuracy: 0.9653 - val_loss: 0.1275
# Epoch 4/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9650 - loss: 0.1450 - val_accuracy: 0.9653 - val_loss: 0.1230
# Epoch 5/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9637 - loss: 0.1350 - val_accuracy: 0.9653 - val_loss: 0.1207
# Epoch 6/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9618 - loss: 0.1387 - val_accuracy: 0.9653 - val_loss: 0.1190
# Epoch 7/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9643 - loss: 0.1325 - val_accuracy: 0.9662 - val_loss: 0.1178
# Epoch 8/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9721 - loss: 0.1129 - val_accuracy: 0.9645 - val_loss: 0.1174
# Epoch 9/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9679 - loss: 0.1302 - val_accuracy: 0.9645 - val_loss: 0.1170
# Epoch 10/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9669 - loss: 0.1289 - val_accuracy: 0.9653 - val_loss: 0.1166
# Epoch 11/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9691 - loss: 0.1193 - val_accuracy: 0.9653 - val_loss: 0.1166
# Epoch 12/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9645 - loss: 0.1320 - val_accuracy: 0.9636 - val_loss: 0.1168
# Epoch 13/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9724 - loss: 0.1076 - val_accuracy: 0.9636 - val_loss: 0.1169
# Epoch 14/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9696 - loss: 0.1130 - val_accuracy: 0.9636 - val_loss: 0.1168
# Epoch 15/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9671 - loss: 0.1173 - val_accuracy: 0.9653 - val_loss: 0.1167
# Epoch 16/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9680 - loss: 0.1219 - val_accuracy: 0.9636 - val_loss: 0.1168
# Epoch 17/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9688 - loss: 0.1177 - val_accuracy: 0.9628 - val_loss: 0.1176
# Epoch 18/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9716 - loss: 0.1101 - val_accuracy: 0.9636 - val_loss: 0.1168
# Epoch 19/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9672 - loss: 0.1170 - val_accuracy: 0.9636 - val_loss: 0.1172
# Epoch 20/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9708 - loss: 0.1170 - val_accuracy: 0.9636 - val_loss: 0.1167
# Score for fold 5: loss of 0.1166788786649704; compile_metrics of 96.36209607124329%
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.13474684953689575 - Accuracy: 96.53130173683167%
# > Fold 2 - Loss: 0.11176823079586029 - Accuracy: 96.70050740242004%
# > Fold 3 - Loss: 0.12585672736167908 - Accuracy: 96.78511023521423%
# > Fold 4 - Loss: 0.11947308480739594 - Accuracy: 96.44669890403748%
# > Fold 5 - Loss: 0.1166788786649704 - Accuracy: 96.36209607124329%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 96.56514286994934 (+- 0.15691487899430515)
# > Loss: 0.12170475423336029
# ------------------------------------------------------------------------

# %%
histories_anli_r1 = cross_validate_lstm_model(X_anli_r1_rnn, features_anli_r1, y_encoded_anli_r1)
# Out:
# Training on fold 1...
# Epoch 1/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.2884 - loss: 1.1299 - val_accuracy: 0.5000 - val_loss: 1.0527
# Epoch 2/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4036 - loss: 1.0700 - val_accuracy: 0.6163 - val_loss: 0.9961
# Epoch 3/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5254 - loss: 1.0186 - val_accuracy: 0.6279 - val_loss: 0.9471
# Epoch 4/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6759 - loss: 0.9597 - val_accuracy: 0.6163 - val_loss: 0.8991
# Epoch 5/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6774 - loss: 0.9120 - val_accuracy: 0.6163 - val_loss: 0.8530
# Epoch 6/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6791 - loss: 0.8544 - val_accuracy: 0.6628 - val_loss: 0.8080
# Epoch 7/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6661 - loss: 0.8288 - val_accuracy: 0.6977 - val_loss: 0.7666
# Epoch 8/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7080 - loss: 0.7725 - val_accuracy: 0.6860 - val_loss: 0.7248
# Epoch 9/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7315 - loss: 0.7226 - val_accuracy: 0.6977 - val_loss: 0.6875
# Epoch 10/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7671 - loss: 0.6679 - val_accuracy: 0.7674 - val_loss: 0.6538
# Epoch 11/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7554 - loss: 0.6980 - val_accuracy: 0.7674 - val_loss: 0.6252
# Epoch 12/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7945 - loss: 0.6327 - val_accuracy: 0.7791 - val_loss: 0.5980
# Epoch 13/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7957 - loss: 0.5978 - val_accuracy: 0.7791 - val_loss: 0.5758
# Epoch 14/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7941 - loss: 0.6277 - val_accuracy: 0.7791 - val_loss: 0.5592
# Epoch 15/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7945 - loss: 0.5718 - val_accuracy: 0.7907 - val_loss: 0.5440
# Epoch 16/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8013 - loss: 0.5509 - val_accuracy: 0.8140 - val_loss: 0.5322
# Epoch 17/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8306 - loss: 0.5275 - val_accuracy: 0.7907 - val_loss: 0.5225
# Epoch 18/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8124 - loss: 0.5311 - val_accuracy: 0.7907 - val_loss: 0.5149
# Epoch 19/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8121 - loss: 0.5052 - val_accuracy: 0.8023 - val_loss: 0.5082
# Epoch 20/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7596 - loss: 0.5315 - val_accuracy: 0.8023 - val_loss: 0.5039
# Score for fold 1: loss of 0.5038771629333496; compile_metrics of 80.23256063461304%
# Training on fold 2...
# Epoch 1/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.4835 - loss: 1.0747 - val_accuracy: 0.5647 - val_loss: 1.0512
# Epoch 2/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6264 - loss: 1.0283 - val_accuracy: 0.5412 - val_loss: 1.0001
# Epoch 3/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5815 - loss: 0.9864 - val_accuracy: 0.5882 - val_loss: 0.9531
# Epoch 4/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6608 - loss: 0.9161 - val_accuracy: 0.6235 - val_loss: 0.9071
# Epoch 5/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6731 - loss: 0.8694 - val_accuracy: 0.6235 - val_loss: 0.8630
# Epoch 6/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6811 - loss: 0.8210 - val_accuracy: 0.6353 - val_loss: 0.8210
# Epoch 7/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6847 - loss: 0.8018 - val_accuracy: 0.6353 - val_loss: 0.7803
# Epoch 8/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7150 - loss: 0.7305 - val_accuracy: 0.6706 - val_loss: 0.7426
# Epoch 9/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7283 - loss: 0.7128 - val_accuracy: 0.7412 - val_loss: 0.7088
# Epoch 10/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7478 - loss: 0.6892 - val_accuracy: 0.7529 - val_loss: 0.6798
# Epoch 11/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7605 - loss: 0.6432 - val_accuracy: 0.7529 - val_loss: 0.6560
# Epoch 12/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7774 - loss: 0.6140 - val_accuracy: 0.7765 - val_loss: 0.6353
# Epoch 13/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7903 - loss: 0.5836 - val_accuracy: 0.7882 - val_loss: 0.6174
# Epoch 14/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7637 - loss: 0.6061 - val_accuracy: 0.8000 - val_loss: 0.6038
# Epoch 15/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7723 - loss: 0.5727 - val_accuracy: 0.8118 - val_loss: 0.5926
# Epoch 16/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7847 - loss: 0.5784 - val_accuracy: 0.8118 - val_loss: 0.5840
# Epoch 17/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8088 - loss: 0.5034 - val_accuracy: 0.8118 - val_loss: 0.5763
# Epoch 18/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7778 - loss: 0.5287 - val_accuracy: 0.8118 - val_loss: 0.5695
# Epoch 19/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7759 - loss: 0.5455 - val_accuracy: 0.7882 - val_loss: 0.5696
# Epoch 20/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8106 - loss: 0.5295 - val_accuracy: 0.7882 - val_loss: 0.5658
# Score for fold 2: loss of 0.5658004879951477; compile_metrics of 78.82353067398071%
# Training on fold 3...
# Epoch 1/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.3100 - loss: 1.1010 - val_accuracy: 0.6706 - val_loss: 1.0440
# Epoch 2/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6457 - loss: 1.0231 - val_accuracy: 0.7059 - val_loss: 0.9943
# Epoch 3/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6470 - loss: 0.9876 - val_accuracy: 0.6824 - val_loss: 0.9481
# Epoch 4/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6872 - loss: 0.9389 - val_accuracy: 0.6941 - val_loss: 0.9036
# Epoch 5/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7064 - loss: 0.8718 - val_accuracy: 0.6941 - val_loss: 0.8593
# Epoch 6/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6882 - loss: 0.8475 - val_accuracy: 0.7176 - val_loss: 0.8151
# Epoch 7/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7064 - loss: 0.8061 - val_accuracy: 0.7294 - val_loss: 0.7724
# Epoch 8/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6923 - loss: 0.7740 - val_accuracy: 0.7529 - val_loss: 0.7326
# Epoch 9/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7105 - loss: 0.7275 - val_accuracy: 0.8000 - val_loss: 0.6946
# Epoch 10/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7661 - loss: 0.7056 - val_accuracy: 0.8000 - val_loss: 0.6625
# Epoch 11/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7305 - loss: 0.6902 - val_accuracy: 0.8000 - val_loss: 0.6356
# Epoch 12/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7949 - loss: 0.5999 - val_accuracy: 0.8000 - val_loss: 0.6121
# Epoch 13/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7877 - loss: 0.6089 - val_accuracy: 0.7882 - val_loss: 0.5914
# Epoch 14/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7367 - loss: 0.6280 - val_accuracy: 0.7882 - val_loss: 0.5738
# Epoch 15/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7845 - loss: 0.5546 - val_accuracy: 0.7647 - val_loss: 0.5609
# Epoch 16/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7957 - loss: 0.5585 - val_accuracy: 0.7647 - val_loss: 0.5492
# Epoch 17/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7770 - loss: 0.5589 - val_accuracy: 0.7647 - val_loss: 0.5384
# Epoch 18/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8292 - loss: 0.5391 - val_accuracy: 0.7647 - val_loss: 0.5305
# Epoch 19/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8064 - loss: 0.5160 - val_accuracy: 0.7529 - val_loss: 0.5259
# Epoch 20/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7923 - loss: 0.5488 - val_accuracy: 0.7765 - val_loss: 0.5212
# Score for fold 3: loss of 0.5212428569793701; compile_metrics of 77.64706015586853%
# Training on fold 4...
# Epoch 1/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.3841 - loss: 1.0797 - val_accuracy: 0.4000 - val_loss: 1.0461
# Epoch 2/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5541 - loss: 1.0137 - val_accuracy: 0.6235 - val_loss: 0.9899
# Epoch 3/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6319 - loss: 0.9576 - val_accuracy: 0.6471 - val_loss: 0.9408
# Epoch 4/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6736 - loss: 0.9007 - val_accuracy: 0.6588 - val_loss: 0.8940
# Epoch 5/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7120 - loss: 0.8578 - val_accuracy: 0.6706 - val_loss: 0.8493
# Epoch 6/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6873 - loss: 0.8062 - val_accuracy: 0.6706 - val_loss: 0.8077
# Epoch 7/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7145 - loss: 0.7562 - val_accuracy: 0.6824 - val_loss: 0.7691
# Epoch 8/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6707 - loss: 0.7665 - val_accuracy: 0.6824 - val_loss: 0.7356
# Epoch 9/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7337 - loss: 0.6829 - val_accuracy: 0.7059 - val_loss: 0.7059
# Epoch 10/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7563 - loss: 0.6399 - val_accuracy: 0.7529 - val_loss: 0.6801
# Epoch 11/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7436 - loss: 0.6643 - val_accuracy: 0.7765 - val_loss: 0.6598
# Epoch 12/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7725 - loss: 0.6344 - val_accuracy: 0.8000 - val_loss: 0.6419
# Epoch 13/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7980 - loss: 0.5867 - val_accuracy: 0.8000 - val_loss: 0.6280
# Epoch 14/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8066 - loss: 0.5614 - val_accuracy: 0.7882 - val_loss: 0.6171
# Epoch 15/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8139 - loss: 0.5980 - val_accuracy: 0.7882 - val_loss: 0.6066
# Epoch 16/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8356 - loss: 0.5245 - val_accuracy: 0.8000 - val_loss: 0.5982
# Epoch 17/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8155 - loss: 0.5271 - val_accuracy: 0.7882 - val_loss: 0.5923
# Epoch 18/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8222 - loss: 0.5277 - val_accuracy: 0.7882 - val_loss: 0.5869
# Epoch 19/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8200 - loss: 0.5208 - val_accuracy: 0.7882 - val_loss: 0.5834
# Epoch 20/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8090 - loss: 0.5048 - val_accuracy: 0.7882 - val_loss: 0.5792
# Score for fold 4: loss of 0.5792236328125; compile_metrics of 78.82353067398071%
# Training on fold 5...
# Epoch 1/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.2677 - loss: 1.1113 - val_accuracy: 0.5176 - val_loss: 1.0593
# Epoch 2/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4891 - loss: 1.0498 - val_accuracy: 0.5647 - val_loss: 1.0021
# Epoch 3/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5398 - loss: 1.0108 - val_accuracy: 0.6824 - val_loss: 0.9484
# Epoch 4/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6017 - loss: 0.9563 - val_accuracy: 0.6824 - val_loss: 0.8967
# Epoch 5/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6526 - loss: 0.8988 - val_accuracy: 0.6824 - val_loss: 0.8461
# Epoch 6/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6332 - loss: 0.8578 - val_accuracy: 0.7059 - val_loss: 0.7967
# Epoch 7/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6728 - loss: 0.8178 - val_accuracy: 0.7294 - val_loss: 0.7480
# Epoch 8/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7378 - loss: 0.7479 - val_accuracy: 0.7529 - val_loss: 0.7032
# Epoch 9/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7192 - loss: 0.7448 - val_accuracy: 0.7647 - val_loss: 0.6632
# Epoch 10/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7879 - loss: 0.6503 - val_accuracy: 0.7765 - val_loss: 0.6280
# Epoch 11/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7560 - loss: 0.6801 - val_accuracy: 0.8118 - val_loss: 0.5980
# Epoch 12/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7771 - loss: 0.6213 - val_accuracy: 0.8118 - val_loss: 0.5710
# Epoch 13/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7982 - loss: 0.5988 - val_accuracy: 0.8118 - val_loss: 0.5508
# Epoch 14/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7688 - loss: 0.6169 - val_accuracy: 0.8000 - val_loss: 0.5328
# Epoch 15/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7834 - loss: 0.5592 - val_accuracy: 0.8000 - val_loss: 0.5179
# Epoch 16/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7673 - loss: 0.6051 - val_accuracy: 0.8235 - val_loss: 0.5066
# Epoch 17/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7624 - loss: 0.6119 - val_accuracy: 0.8235 - val_loss: 0.4974
# Epoch 18/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8090 - loss: 0.5577 - val_accuracy: 0.8118 - val_loss: 0.4906
# Epoch 19/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8158 - loss: 0.5270 - val_accuracy: 0.8118 - val_loss: 0.4837
# Epoch 20/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8026 - loss: 0.5259 - val_accuracy: 0.8235 - val_loss: 0.4794
# Score for fold 5: loss of 0.4794273376464844; compile_metrics of 82.35294222831726%
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.5038771629333496 - Accuracy: 80.23256063461304%
# > Fold 2 - Loss: 0.5658004879951477 - Accuracy: 78.82353067398071%
# > Fold 3 - Loss: 0.5212428569793701 - Accuracy: 77.64706015586853%
# > Fold 4 - Loss: 0.5792236328125 - Accuracy: 78.82353067398071%
# > Fold 5 - Loss: 0.4794273376464844 - Accuracy: 82.35294222831726%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 79.57592487335205 (+- 1.6121854157380795)
# > Loss: 0.5299142956733703
# ------------------------------------------------------------------------

# %%
histories_anli_r2 = cross_validate_lstm_model(X_anli_r2_rnn, features_anli_r2, y_encoded_anli_r2)
# Out:
# Training on fold 1...
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.3105 - loss: 1.1085 - val_accuracy: 0.5169 - val_loss: 1.0759
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4708 - loss: 1.0696 - val_accuracy: 0.6629 - val_loss: 1.0307
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5907 - loss: 1.0243 - val_accuracy: 0.6629 - val_loss: 0.9918
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6399 - loss: 0.9884 - val_accuracy: 0.6629 - val_loss: 0.9537
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6433 - loss: 0.9644 - val_accuracy: 0.6742 - val_loss: 0.9132
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6574 - loss: 0.9392 - val_accuracy: 0.6854 - val_loss: 0.8738
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6672 - loss: 0.9136 - val_accuracy: 0.6742 - val_loss: 0.8380
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6543 - loss: 0.9001 - val_accuracy: 0.6966 - val_loss: 0.8022
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6833 - loss: 0.8604 - val_accuracy: 0.6966 - val_loss: 0.7674
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6499 - loss: 0.8675 - val_accuracy: 0.6966 - val_loss: 0.7407
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6799 - loss: 0.8114 - val_accuracy: 0.6966 - val_loss: 0.7158
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7018 - loss: 0.7710 - val_accuracy: 0.6966 - val_loss: 0.6968
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6710 - loss: 0.7685 - val_accuracy: 0.7303 - val_loss: 0.6782
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7048 - loss: 0.7557 - val_accuracy: 0.7303 - val_loss: 0.6629
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6924 - loss: 0.7873 - val_accuracy: 0.7303 - val_loss: 0.6536
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7221 - loss: 0.7551 - val_accuracy: 0.7416 - val_loss: 0.6440
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6886 - loss: 0.7599 - val_accuracy: 0.7528 - val_loss: 0.6370
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7498 - loss: 0.7373 - val_accuracy: 0.7416 - val_loss: 0.6289
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7369 - loss: 0.7092 - val_accuracy: 0.7528 - val_loss: 0.6241
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6773 - loss: 0.7918 - val_accuracy: 0.7865 - val_loss: 0.6181
# Score for fold 1: loss of 0.6180694103240967; compile_metrics of 78.65168452262878%
# Training on fold 2...
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.3167 - loss: 1.1009 - val_accuracy: 0.5730 - val_loss: 1.0724
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4669 - loss: 1.0622 - val_accuracy: 0.5618 - val_loss: 1.0347
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5881 - loss: 1.0219 - val_accuracy: 0.5618 - val_loss: 1.0003
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5604 - loss: 0.9899 - val_accuracy: 0.5730 - val_loss: 0.9671
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5912 - loss: 0.9634 - val_accuracy: 0.6517 - val_loss: 0.9349
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5885 - loss: 0.9286 - val_accuracy: 0.6854 - val_loss: 0.9047
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6773 - loss: 0.8809 - val_accuracy: 0.6854 - val_loss: 0.8727
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6776 - loss: 0.8649 - val_accuracy: 0.6854 - val_loss: 0.8401
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7098 - loss: 0.8053 - val_accuracy: 0.6966 - val_loss: 0.8100
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6842 - loss: 0.8051 - val_accuracy: 0.6854 - val_loss: 0.7862
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7171 - loss: 0.7522 - val_accuracy: 0.6854 - val_loss: 0.7665
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6948 - loss: 0.7528 - val_accuracy: 0.6854 - val_loss: 0.7503
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7035 - loss: 0.7326 - val_accuracy: 0.6854 - val_loss: 0.7373
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7181 - loss: 0.7557 - val_accuracy: 0.6854 - val_loss: 0.7280
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7190 - loss: 0.7210 - val_accuracy: 0.6854 - val_loss: 0.7188
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7318 - loss: 0.7091 - val_accuracy: 0.6966 - val_loss: 0.7117
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6767 - loss: 0.7706 - val_accuracy: 0.7191 - val_loss: 0.7041
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7450 - loss: 0.6847 - val_accuracy: 0.7191 - val_loss: 0.7001
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7461 - loss: 0.7297 - val_accuracy: 0.7191 - val_loss: 0.6956
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7486 - loss: 0.6810 - val_accuracy: 0.7191 - val_loss: 0.6923
# Score for fold 2: loss of 0.6923255324363708; compile_metrics of 71.91011309623718%
# Training on fold 3...
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.4897 - loss: 1.0667 - val_accuracy: 0.5506 - val_loss: 1.0357
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5523 - loss: 1.0407 - val_accuracy: 0.6180 - val_loss: 1.0018
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6149 - loss: 0.9978 - val_accuracy: 0.6180 - val_loss: 0.9699
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6441 - loss: 0.9656 - val_accuracy: 0.6180 - val_loss: 0.9409
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6389 - loss: 0.9443 - val_accuracy: 0.6292 - val_loss: 0.9150
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6503 - loss: 0.9051 - val_accuracy: 0.6292 - val_loss: 0.8872
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6687 - loss: 0.8697 - val_accuracy: 0.6292 - val_loss: 0.8629
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6550 - loss: 0.8565 - val_accuracy: 0.6404 - val_loss: 0.8397
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6111 - loss: 0.8648 - val_accuracy: 0.6517 - val_loss: 0.8203
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6610 - loss: 0.8065 - val_accuracy: 0.6629 - val_loss: 0.8016
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7017 - loss: 0.7747 - val_accuracy: 0.6629 - val_loss: 0.7840
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6695 - loss: 0.8003 - val_accuracy: 0.6629 - val_loss: 0.7736
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6740 - loss: 0.7719 - val_accuracy: 0.6742 - val_loss: 0.7637
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6798 - loss: 0.7541 - val_accuracy: 0.6742 - val_loss: 0.7553
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7431 - loss: 0.7034 - val_accuracy: 0.6742 - val_loss: 0.7487
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7183 - loss: 0.6928 - val_accuracy: 0.7079 - val_loss: 0.7450
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6968 - loss: 0.7340 - val_accuracy: 0.7303 - val_loss: 0.7424
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7205 - loss: 0.7209 - val_accuracy: 0.7191 - val_loss: 0.7437
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7346 - loss: 0.6662 - val_accuracy: 0.7079 - val_loss: 0.7440
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7346 - loss: 0.7144 - val_accuracy: 0.7079 - val_loss: 0.7376
# Score for fold 3: loss of 0.7375814318656921; compile_metrics of 70.78651785850525%
# Training on fold 4...
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.3071 - loss: 1.1161 - val_accuracy: 0.5730 - val_loss: 1.0688
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5327 - loss: 1.0708 - val_accuracy: 0.7079 - val_loss: 1.0307
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6095 - loss: 1.0175 - val_accuracy: 0.7079 - val_loss: 0.9962
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6423 - loss: 0.9774 - val_accuracy: 0.6966 - val_loss: 0.9643
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6206 - loss: 0.9478 - val_accuracy: 0.6966 - val_loss: 0.9348
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6555 - loss: 0.9104 - val_accuracy: 0.6966 - val_loss: 0.9043
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6789 - loss: 0.8655 - val_accuracy: 0.6966 - val_loss: 0.8751
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6668 - loss: 0.8497 - val_accuracy: 0.7079 - val_loss: 0.8470
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6363 - loss: 0.8374 - val_accuracy: 0.6966 - val_loss: 0.8223
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6603 - loss: 0.8209 - val_accuracy: 0.6854 - val_loss: 0.8007
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6575 - loss: 0.7886 - val_accuracy: 0.6966 - val_loss: 0.7840
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7155 - loss: 0.7412 - val_accuracy: 0.6966 - val_loss: 0.7703
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7082 - loss: 0.7145 - val_accuracy: 0.7191 - val_loss: 0.7631
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6865 - loss: 0.7818 - val_accuracy: 0.7640 - val_loss: 0.7518
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7155 - loss: 0.7627 - val_accuracy: 0.7753 - val_loss: 0.7401
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7452 - loss: 0.7207 - val_accuracy: 0.7753 - val_loss: 0.7322
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7235 - loss: 0.7307 - val_accuracy: 0.7753 - val_loss: 0.7233
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7133 - loss: 0.7257 - val_accuracy: 0.7753 - val_loss: 0.7121
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7379 - loss: 0.7250 - val_accuracy: 0.7753 - val_loss: 0.7034
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7325 - loss: 0.7206 - val_accuracy: 0.7753 - val_loss: 0.6926
# Score for fold 4: loss of 0.6925894618034363; compile_metrics of 77.52808928489685%
# Training on fold 5...
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.2881 - loss: 1.1071 - val_accuracy: 0.3371 - val_loss: 1.0797
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3938 - loss: 1.0697 - val_accuracy: 0.5618 - val_loss: 1.0452
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5347 - loss: 1.0364 - val_accuracy: 0.5618 - val_loss: 1.0171
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5973 - loss: 1.0030 - val_accuracy: 0.5618 - val_loss: 0.9899
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6335 - loss: 0.9640 - val_accuracy: 0.5618 - val_loss: 0.9630
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6175 - loss: 0.9433 - val_accuracy: 0.5955 - val_loss: 0.9383
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6830 - loss: 0.8811 - val_accuracy: 0.6067 - val_loss: 0.9126
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6816 - loss: 0.8486 - val_accuracy: 0.6180 - val_loss: 0.8889
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6075 - loss: 0.8693 - val_accuracy: 0.6292 - val_loss: 0.8689
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6557 - loss: 0.8204 - val_accuracy: 0.6404 - val_loss: 0.8510
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6686 - loss: 0.8209 - val_accuracy: 0.6404 - val_loss: 0.8363
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7269 - loss: 0.7459 - val_accuracy: 0.6629 - val_loss: 0.8240
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7005 - loss: 0.7292 - val_accuracy: 0.6517 - val_loss: 0.8173
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7158 - loss: 0.7283 - val_accuracy: 0.6517 - val_loss: 0.8115
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7254 - loss: 0.7311 - val_accuracy: 0.6517 - val_loss: 0.8069
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7275 - loss: 0.7045 - val_accuracy: 0.6517 - val_loss: 0.8031
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7114 - loss: 0.6980 - val_accuracy: 0.6517 - val_loss: 0.8001
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7152 - loss: 0.7009 - val_accuracy: 0.6629 - val_loss: 0.7982
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7699 - loss: 0.6449 - val_accuracy: 0.6742 - val_loss: 0.7972
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7510 - loss: 0.6843 - val_accuracy: 0.6854 - val_loss: 0.7955
# Score for fold 5: loss of 0.7955427169799805; compile_metrics of 68.53932738304138%
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.6180694103240967 - Accuracy: 78.65168452262878%
# > Fold 2 - Loss: 0.6923255324363708 - Accuracy: 71.91011309623718%
# > Fold 3 - Loss: 0.7375814318656921 - Accuracy: 70.78651785850525%
# > Fold 4 - Loss: 0.6925894618034363 - Accuracy: 77.52808928489685%
# > Fold 5 - Loss: 0.7955427169799805 - Accuracy: 68.53932738304138%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 73.48314642906189 (+- 3.9309778682953045)
# > Loss: 0.7072217106819153
# ------------------------------------------------------------------------

# %%
histories_anli_r3 = cross_validate_lstm_model(X_anli_r3_rnn, features_anli_r3, y_encoded_anli_r3)
# Out:
# Training on fold 1...
# Epoch 1/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.5480 - loss: 1.0578 - val_accuracy: 0.5660 - val_loss: 1.0308
# Epoch 2/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6091 - loss: 1.0155 - val_accuracy: 0.5849 - val_loss: 0.9929
# Epoch 3/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6162 - loss: 0.9634 - val_accuracy: 0.5943 - val_loss: 0.9576
# Epoch 4/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5888 - loss: 0.9341 - val_accuracy: 0.6038 - val_loss: 0.9247
# Epoch 5/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6191 - loss: 0.8891 - val_accuracy: 0.6321 - val_loss: 0.8921
# Epoch 6/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6367 - loss: 0.8551 - val_accuracy: 0.6415 - val_loss: 0.8628
# Epoch 7/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6317 - loss: 0.8067 - val_accuracy: 0.6604 - val_loss: 0.8356
# Epoch 8/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6652 - loss: 0.7892 - val_accuracy: 0.7075 - val_loss: 0.8129
# Epoch 9/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7144 - loss: 0.7315 - val_accuracy: 0.6981 - val_loss: 0.7923
# Epoch 10/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6950 - loss: 0.7368 - val_accuracy: 0.7358 - val_loss: 0.7783
# Epoch 11/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6860 - loss: 0.7445 - val_accuracy: 0.7075 - val_loss: 0.7693
# Epoch 12/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7062 - loss: 0.7173 - val_accuracy: 0.6981 - val_loss: 0.7594
# Epoch 13/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7285 - loss: 0.6822 - val_accuracy: 0.6887 - val_loss: 0.7526
# Epoch 14/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7485 - loss: 0.6667 - val_accuracy: 0.6792 - val_loss: 0.7490
# Epoch 15/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7478 - loss: 0.6444 - val_accuracy: 0.6792 - val_loss: 0.7430
# Epoch 16/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7448 - loss: 0.6560 - val_accuracy: 0.6887 - val_loss: 0.7387
# Epoch 17/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7417 - loss: 0.6416 - val_accuracy: 0.6887 - val_loss: 0.7355
# Epoch 18/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7600 - loss: 0.6435 - val_accuracy: 0.6981 - val_loss: 0.7311
# Epoch 19/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7405 - loss: 0.6584 - val_accuracy: 0.6887 - val_loss: 0.7285
# Epoch 20/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7257 - loss: 0.6527 - val_accuracy: 0.6981 - val_loss: 0.7258
# Score for fold 1: loss of 0.7258477210998535; compile_metrics of 69.8113203048706%
# Training on fold 2...
# Epoch 1/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3182 - loss: 1.1087 - val_accuracy: 0.6321 - val_loss: 1.0447
# Epoch 2/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4957 - loss: 1.0413 - val_accuracy: 0.5943 - val_loss: 0.9900
# Epoch 3/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5485 - loss: 1.0001 - val_accuracy: 0.6038 - val_loss: 0.9475
# Epoch 4/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5968 - loss: 0.9585 - val_accuracy: 0.6321 - val_loss: 0.9064
# Epoch 5/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5969 - loss: 0.9183 - val_accuracy: 0.6321 - val_loss: 0.8674
# Epoch 6/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6266 - loss: 0.8744 - val_accuracy: 0.6415 - val_loss: 0.8295
# Epoch 7/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6307 - loss: 0.8521 - val_accuracy: 0.6509 - val_loss: 0.7914
# Epoch 8/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6423 - loss: 0.8231 - val_accuracy: 0.6509 - val_loss: 0.7577
# Epoch 9/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6864 - loss: 0.7442 - val_accuracy: 0.6698 - val_loss: 0.7277
# Epoch 10/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6864 - loss: 0.7483 - val_accuracy: 0.6698 - val_loss: 0.7027
# Epoch 11/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6886 - loss: 0.7387 - val_accuracy: 0.6792 - val_loss: 0.6807
# Epoch 12/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6967 - loss: 0.6892 - val_accuracy: 0.6981 - val_loss: 0.6653
# Epoch 13/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7144 - loss: 0.6826 - val_accuracy: 0.6887 - val_loss: 0.6555
# Epoch 14/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6989 - loss: 0.7085 - val_accuracy: 0.6981 - val_loss: 0.6446
# Epoch 15/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7091 - loss: 0.6852 - val_accuracy: 0.6981 - val_loss: 0.6376
# Epoch 16/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7119 - loss: 0.7087 - val_accuracy: 0.7264 - val_loss: 0.6305
# Epoch 17/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7276 - loss: 0.6750 - val_accuracy: 0.7264 - val_loss: 0.6258
# Epoch 18/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6866 - loss: 0.7356 - val_accuracy: 0.7358 - val_loss: 0.6209
# Epoch 19/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7188 - loss: 0.6814 - val_accuracy: 0.7358 - val_loss: 0.6173
# Epoch 20/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6779 - loss: 0.7271 - val_accuracy: 0.7264 - val_loss: 0.6141
# Score for fold 2: loss of 0.6141375303268433; compile_metrics of 72.64150977134705%
# Training on fold 3...
# Epoch 1/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.4656 - loss: 1.0734 - val_accuracy: 0.5472 - val_loss: 1.0106
# Epoch 2/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5748 - loss: 1.0038 - val_accuracy: 0.6226 - val_loss: 0.9569
# Epoch 3/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5569 - loss: 0.9714 - val_accuracy: 0.6604 - val_loss: 0.9146
# Epoch 4/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6070 - loss: 0.9306 - val_accuracy: 0.6509 - val_loss: 0.8756
# Epoch 5/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6170 - loss: 0.8799 - val_accuracy: 0.6509 - val_loss: 0.8385
# Epoch 6/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6454 - loss: 0.8509 - val_accuracy: 0.6509 - val_loss: 0.8050
# Epoch 7/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6365 - loss: 0.8235 - val_accuracy: 0.6604 - val_loss: 0.7740
# Epoch 8/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6862 - loss: 0.7548 - val_accuracy: 0.6792 - val_loss: 0.7465
# Epoch 9/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6796 - loss: 0.7472 - val_accuracy: 0.6887 - val_loss: 0.7225
# Epoch 10/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6718 - loss: 0.7403 - val_accuracy: 0.6981 - val_loss: 0.7031
# Epoch 11/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6867 - loss: 0.7084 - val_accuracy: 0.6981 - val_loss: 0.6903
# Epoch 12/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6785 - loss: 0.7424 - val_accuracy: 0.7075 - val_loss: 0.6795
# Epoch 13/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7003 - loss: 0.7219 - val_accuracy: 0.6981 - val_loss: 0.6710
# Epoch 14/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7237 - loss: 0.6803 - val_accuracy: 0.7170 - val_loss: 0.6665
# Epoch 15/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7315 - loss: 0.6571 - val_accuracy: 0.7075 - val_loss: 0.6633
# Epoch 16/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7042 - loss: 0.7011 - val_accuracy: 0.7170 - val_loss: 0.6624
# Epoch 17/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7130 - loss: 0.6683 - val_accuracy: 0.7264 - val_loss: 0.6622
# Epoch 18/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6942 - loss: 0.7316 - val_accuracy: 0.7264 - val_loss: 0.6605
# Epoch 19/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7205 - loss: 0.6982 - val_accuracy: 0.7264 - val_loss: 0.6603
# Epoch 20/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7072 - loss: 0.6762 - val_accuracy: 0.7264 - val_loss: 0.6595
# Score for fold 3: loss of 0.6594959497451782; compile_metrics of 72.64150977134705%
# Training on fold 4...
# Epoch 1/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3306 - loss: 1.1033 - val_accuracy: 0.6321 - val_loss: 1.0524
# Epoch 2/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5972 - loss: 1.0443 - val_accuracy: 0.5943 - val_loss: 1.0044
# Epoch 3/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6159 - loss: 1.0104 - val_accuracy: 0.6038 - val_loss: 0.9598
# Epoch 4/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6231 - loss: 0.9573 - val_accuracy: 0.6132 - val_loss: 0.9172
# Epoch 5/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6293 - loss: 0.9312 - val_accuracy: 0.6038 - val_loss: 0.8752
# Epoch 6/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6234 - loss: 0.9044 - val_accuracy: 0.6132 - val_loss: 0.8336
# Epoch 7/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6087 - loss: 0.8693 - val_accuracy: 0.6604 - val_loss: 0.7947
# Epoch 8/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6521 - loss: 0.8343 - val_accuracy: 0.6604 - val_loss: 0.7599
# Epoch 9/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6742 - loss: 0.7750 - val_accuracy: 0.6604 - val_loss: 0.7339
# Epoch 10/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7012 - loss: 0.7335 - val_accuracy: 0.6604 - val_loss: 0.7115
# Epoch 11/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7016 - loss: 0.7193 - val_accuracy: 0.6981 - val_loss: 0.6988
# Epoch 12/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6930 - loss: 0.7246 - val_accuracy: 0.7264 - val_loss: 0.6894
# Epoch 13/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7149 - loss: 0.7149 - val_accuracy: 0.7075 - val_loss: 0.6810
# Epoch 14/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6999 - loss: 0.6873 - val_accuracy: 0.7358 - val_loss: 0.6747
# Epoch 15/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6957 - loss: 0.6770 - val_accuracy: 0.7264 - val_loss: 0.6685
# Epoch 16/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7024 - loss: 0.7029 - val_accuracy: 0.7170 - val_loss: 0.6644
# Epoch 17/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6887 - loss: 0.7135 - val_accuracy: 0.7075 - val_loss: 0.6610
# Epoch 18/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6735 - loss: 0.7458 - val_accuracy: 0.7170 - val_loss: 0.6605
# Epoch 19/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7285 - loss: 0.6435 - val_accuracy: 0.7264 - val_loss: 0.6590
# Epoch 20/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7076 - loss: 0.6924 - val_accuracy: 0.7358 - val_loss: 0.6579
# Score for fold 4: loss of 0.6578643321990967; compile_metrics of 73.58490824699402%
# Training on fold 5...
# Epoch 1/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.4088 - loss: 1.0813 - val_accuracy: 0.5189 - val_loss: 1.0185
# Epoch 2/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5035 - loss: 1.0431 - val_accuracy: 0.5283 - val_loss: 0.9701
# Epoch 3/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5789 - loss: 0.9761 - val_accuracy: 0.5566 - val_loss: 0.9292
# Epoch 4/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6109 - loss: 0.9422 - val_accuracy: 0.5943 - val_loss: 0.8907
# Epoch 5/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6021 - loss: 0.9105 - val_accuracy: 0.6509 - val_loss: 0.8549
# Epoch 6/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6705 - loss: 0.8357 - val_accuracy: 0.6415 - val_loss: 0.8222
# Epoch 7/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6510 - loss: 0.8312 - val_accuracy: 0.6604 - val_loss: 0.8041
# Epoch 8/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6803 - loss: 0.7701 - val_accuracy: 0.6698 - val_loss: 0.7842
# Epoch 9/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6930 - loss: 0.7329 - val_accuracy: 0.6509 - val_loss: 0.7714
# Epoch 10/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6861 - loss: 0.7533 - val_accuracy: 0.6604 - val_loss: 0.7613
# Epoch 11/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7134 - loss: 0.7333 - val_accuracy: 0.6792 - val_loss: 0.7601
# Epoch 12/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7110 - loss: 0.7024 - val_accuracy: 0.6981 - val_loss: 0.7604
# Epoch 13/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7311 - loss: 0.6697 - val_accuracy: 0.6887 - val_loss: 0.7600
# Epoch 14/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7051 - loss: 0.7036 - val_accuracy: 0.6981 - val_loss: 0.7556
# Epoch 15/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7410 - loss: 0.6625 - val_accuracy: 0.6887 - val_loss: 0.7548
# Epoch 16/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7630 - loss: 0.6353 - val_accuracy: 0.6792 - val_loss: 0.7570
# Epoch 17/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7424 - loss: 0.6311 - val_accuracy: 0.7075 - val_loss: 0.7585
# Epoch 18/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7141 - loss: 0.6940 - val_accuracy: 0.6981 - val_loss: 0.7599
# Epoch 19/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7243 - loss: 0.6622 - val_accuracy: 0.6981 - val_loss: 0.7599
# Epoch 20/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7338 - loss: 0.6385 - val_accuracy: 0.7075 - val_loss: 0.7609
# Score for fold 5: loss of 0.7608683109283447; compile_metrics of 70.75471878051758%
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.7258477210998535 - Accuracy: 69.8113203048706%
# > Fold 2 - Loss: 0.6141375303268433 - Accuracy: 72.64150977134705%
# > Fold 3 - Loss: 0.6594959497451782 - Accuracy: 72.64150977134705%
# > Fold 4 - Loss: 0.6578643321990967 - Accuracy: 73.58490824699402%
# > Fold 5 - Loss: 0.7608683109283447 - Accuracy: 70.75471878051758%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 71.88679337501526 (+- 1.386504175877035)
# > Loss: 0.6836427688598633
# ------------------------------------------------------------------------

# %%
X_rnn_all_tasks = np.concatenate([X_snli_rnn, X_mnli_matched_rnn, X_mnli_mismatched_rnn, X_anli_r1_rnn, X_anli_r2_rnn, X_anli_r3_rnn])
features_all_tasks = np.concatenate([features_snli, features_mnli_matched, features_mnli_mismatched, features_anli_r1, features_anli_r2, features_anli_r3])
y_encoded_all_tasks = np.concatenate([y_encoded_snli, y_encoded_mnli_matched, y_encoded_mnli_mismatched, y_encoded_anli_r1, y_encoded_anli_r2, y_encoded_anli_r3])

# Call the cross-validation function
all_histories = cross_validate_lstm_model(X_rnn_all_tasks, features_all_tasks, y_encoded_all_tasks, num_folds=5)
# Out:
# Training on fold 1...
# Epoch 1/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8709 - loss: 0.4975 - val_accuracy: 0.9464 - val_loss: 0.1783
# Epoch 2/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9444 - loss: 0.1929 - val_accuracy: 0.9464 - val_loss: 0.1749
# Epoch 3/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9460 - loss: 0.1806 - val_accuracy: 0.9482 - val_loss: 0.1734
# Epoch 4/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9515 - loss: 0.1736 - val_accuracy: 0.9487 - val_loss: 0.1724
# Epoch 5/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9487 - loss: 0.1760 - val_accuracy: 0.9495 - val_loss: 0.1728
# Epoch 6/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9476 - loss: 0.1786 - val_accuracy: 0.9479 - val_loss: 0.1722
# Epoch 7/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9484 - loss: 0.1783 - val_accuracy: 0.9492 - val_loss: 0.1730
# Epoch 8/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9468 - loss: 0.1821 - val_accuracy: 0.9495 - val_loss: 0.1726
# Epoch 9/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9477 - loss: 0.1766 - val_accuracy: 0.9490 - val_loss: 0.1736
# Epoch 10/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9497 - loss: 0.1713 - val_accuracy: 0.9487 - val_loss: 0.1717
# Epoch 11/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9484 - loss: 0.1703 - val_accuracy: 0.9487 - val_loss: 0.1733
# Epoch 12/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9439 - loss: 0.1879 - val_accuracy: 0.9495 - val_loss: 0.1720
# Epoch 13/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9462 - loss: 0.1793 - val_accuracy: 0.9484 - val_loss: 0.1715
# Epoch 14/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9489 - loss: 0.1737 - val_accuracy: 0.9487 - val_loss: 0.1723
# Epoch 15/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9489 - loss: 0.1761 - val_accuracy: 0.9484 - val_loss: 0.1724
# Epoch 16/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9428 - loss: 0.1870 - val_accuracy: 0.9490 - val_loss: 0.1722
# Epoch 17/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9450 - loss: 0.1805 - val_accuracy: 0.9484 - val_loss: 0.1727
# Epoch 18/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9461 - loss: 0.1779 - val_accuracy: 0.9487 - val_loss: 0.1716
# Epoch 19/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9465 - loss: 0.1772 - val_accuracy: 0.9492 - val_loss: 0.1722
# Epoch 20/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9475 - loss: 0.1811 - val_accuracy: 0.9487 - val_loss: 0.1711
# Score for fold 1: loss of 0.17108914256095886; compile_metrics of 94.86979246139526%
# Training on fold 2...
# Epoch 1/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9223 - loss: 0.4468 - val_accuracy: 0.9451 - val_loss: 0.1753
# Epoch 2/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9407 - loss: 0.1972 - val_accuracy: 0.9469 - val_loss: 0.1702
# Epoch 3/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9452 - loss: 0.1832 - val_accuracy: 0.9479 - val_loss: 0.1687
# Epoch 4/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9468 - loss: 0.1857 - val_accuracy: 0.9482 - val_loss: 0.1687
# Epoch 5/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9469 - loss: 0.1810 - val_accuracy: 0.9466 - val_loss: 0.1685
# Epoch 6/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9481 - loss: 0.1798 - val_accuracy: 0.9477 - val_loss: 0.1673
# Epoch 7/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9484 - loss: 0.1762 - val_accuracy: 0.9477 - val_loss: 0.1675
# Epoch 8/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9464 - loss: 0.1773 - val_accuracy: 0.9479 - val_loss: 0.1687
# Epoch 9/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9464 - loss: 0.1838 - val_accuracy: 0.9477 - val_loss: 0.1681
# Epoch 10/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9438 - loss: 0.1857 - val_accuracy: 0.9479 - val_loss: 0.1687
# Epoch 11/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9484 - loss: 0.1777 - val_accuracy: 0.9474 - val_loss: 0.1674
# Epoch 12/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9468 - loss: 0.1822 - val_accuracy: 0.9474 - val_loss: 0.1674
# Epoch 13/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9472 - loss: 0.1832 - val_accuracy: 0.9477 - val_loss: 0.1672
# Epoch 14/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9447 - loss: 0.1796 - val_accuracy: 0.9479 - val_loss: 0.1682
# Epoch 15/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9476 - loss: 0.1770 - val_accuracy: 0.9487 - val_loss: 0.1677
# Epoch 16/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9452 - loss: 0.1812 - val_accuracy: 0.9479 - val_loss: 0.1671
# Epoch 17/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9509 - loss: 0.1694 - val_accuracy: 0.9474 - val_loss: 0.1687
# Epoch 18/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9461 - loss: 0.1767 - val_accuracy: 0.9479 - val_loss: 0.1673
# Epoch 19/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9483 - loss: 0.1764 - val_accuracy: 0.9487 - val_loss: 0.1667
# Epoch 20/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9420 - loss: 0.1938 - val_accuracy: 0.9484 - val_loss: 0.1677
# Score for fold 2: loss of 0.16769669950008392; compile_metrics of 94.8437511920929%
# Training on fold 3...
# Epoch 1/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8939 - loss: 0.4809 - val_accuracy: 0.9445 - val_loss: 0.1857
# Epoch 2/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9473 - loss: 0.1770 - val_accuracy: 0.9430 - val_loss: 0.1829
# Epoch 3/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9430 - loss: 0.1859 - val_accuracy: 0.9438 - val_loss: 0.1851
# Epoch 4/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9485 - loss: 0.1806 - val_accuracy: 0.9432 - val_loss: 0.1832
# Epoch 5/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9460 - loss: 0.1781 - val_accuracy: 0.9440 - val_loss: 0.1844
# Epoch 6/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9478 - loss: 0.1801 - val_accuracy: 0.9443 - val_loss: 0.1847
# Epoch 7/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9508 - loss: 0.1734 - val_accuracy: 0.9438 - val_loss: 0.1825
# Epoch 8/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9461 - loss: 0.1808 - val_accuracy: 0.9435 - val_loss: 0.1829
# Epoch 9/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9449 - loss: 0.1855 - val_accuracy: 0.9443 - val_loss: 0.1821
# Epoch 10/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9484 - loss: 0.1755 - val_accuracy: 0.9440 - val_loss: 0.1823
# Epoch 11/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9492 - loss: 0.1761 - val_accuracy: 0.9445 - val_loss: 0.1813
# Epoch 12/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9478 - loss: 0.1711 - val_accuracy: 0.9440 - val_loss: 0.1823
# Epoch 13/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9466 - loss: 0.1787 - val_accuracy: 0.9438 - val_loss: 0.1821
# Epoch 14/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9495 - loss: 0.1748 - val_accuracy: 0.9438 - val_loss: 0.1812
# Epoch 15/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9463 - loss: 0.1863 - val_accuracy: 0.9453 - val_loss: 0.1834
# Epoch 16/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9506 - loss: 0.1731 - val_accuracy: 0.9440 - val_loss: 0.1817
# Epoch 17/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9510 - loss: 0.1678 - val_accuracy: 0.9438 - val_loss: 0.1808
# Epoch 18/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9488 - loss: 0.1752 - val_accuracy: 0.9440 - val_loss: 0.1806
# Epoch 19/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9485 - loss: 0.1751 - val_accuracy: 0.9443 - val_loss: 0.1809
# Epoch 20/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9474 - loss: 0.1761 - val_accuracy: 0.9448 - val_loss: 0.1804
# Score for fold 3: loss of 0.1803629994392395; compile_metrics of 94.47916746139526%
# Training on fold 4...
# Epoch 1/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8282 - loss: 0.5282 - val_accuracy: 0.9445 - val_loss: 0.1825
# Epoch 2/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9472 - loss: 0.1785 - val_accuracy: 0.9479 - val_loss: 0.1788
# Epoch 3/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9478 - loss: 0.1781 - val_accuracy: 0.9477 - val_loss: 0.1779
# Epoch 4/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9442 - loss: 0.1930 - val_accuracy: 0.9500 - val_loss: 0.1777
# Epoch 5/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9467 - loss: 0.1794 - val_accuracy: 0.9482 - val_loss: 0.1769
# Epoch 6/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9455 - loss: 0.1877 - val_accuracy: 0.9484 - val_loss: 0.1768
# Epoch 7/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9485 - loss: 0.1773 - val_accuracy: 0.9487 - val_loss: 0.1763
# Epoch 8/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9481 - loss: 0.1796 - val_accuracy: 0.9500 - val_loss: 0.1761
# Epoch 9/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9476 - loss: 0.1725 - val_accuracy: 0.9497 - val_loss: 0.1759
# Epoch 10/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9459 - loss: 0.1788 - val_accuracy: 0.9487 - val_loss: 0.1760
# Epoch 11/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9474 - loss: 0.1775 - val_accuracy: 0.9508 - val_loss: 0.1762
# Epoch 12/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9449 - loss: 0.1838 - val_accuracy: 0.9479 - val_loss: 0.1765
# Epoch 13/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9478 - loss: 0.1730 - val_accuracy: 0.9500 - val_loss: 0.1759
# Epoch 14/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9505 - loss: 0.1644 - val_accuracy: 0.9487 - val_loss: 0.1753
# Epoch 15/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9471 - loss: 0.1799 - val_accuracy: 0.9492 - val_loss: 0.1749
# Epoch 16/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9473 - loss: 0.1785 - val_accuracy: 0.9487 - val_loss: 0.1765
# Epoch 17/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9477 - loss: 0.1790 - val_accuracy: 0.9495 - val_loss: 0.1750
# Epoch 18/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9475 - loss: 0.1738 - val_accuracy: 0.9497 - val_loss: 0.1749
# Epoch 19/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9481 - loss: 0.1738 - val_accuracy: 0.9492 - val_loss: 0.1749
# Epoch 20/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9482 - loss: 0.1715 - val_accuracy: 0.9508 - val_loss: 0.1747
# Score for fold 4: loss of 0.1746681183576584; compile_metrics of 95.07812261581421%
# Training on fold 5...
# Epoch 1/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9033 - loss: 0.4536 - val_accuracy: 0.9484 - val_loss: 0.1878
# Epoch 2/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9427 - loss: 0.1878 - val_accuracy: 0.9487 - val_loss: 0.1823
# Epoch 3/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9478 - loss: 0.1800 - val_accuracy: 0.9476 - val_loss: 0.1836
# Epoch 4/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9473 - loss: 0.1814 - val_accuracy: 0.9489 - val_loss: 0.1819
# Epoch 5/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9440 - loss: 0.1916 - val_accuracy: 0.9487 - val_loss: 0.1825
# Epoch 6/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9467 - loss: 0.1792 - val_accuracy: 0.9487 - val_loss: 0.1814
# Epoch 7/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9474 - loss: 0.1830 - val_accuracy: 0.9471 - val_loss: 0.1810
# Epoch 8/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9476 - loss: 0.1833 - val_accuracy: 0.9495 - val_loss: 0.1798
# Epoch 9/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9466 - loss: 0.1779 - val_accuracy: 0.9479 - val_loss: 0.1795
# Epoch 10/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9469 - loss: 0.1747 - val_accuracy: 0.9471 - val_loss: 0.1796
# Epoch 11/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9471 - loss: 0.1738 - val_accuracy: 0.9484 - val_loss: 0.1799
# Epoch 12/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9481 - loss: 0.1753 - val_accuracy: 0.9476 - val_loss: 0.1789
# Epoch 13/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9473 - loss: 0.1811 - val_accuracy: 0.9469 - val_loss: 0.1798
# Epoch 14/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9478 - loss: 0.1764 - val_accuracy: 0.9466 - val_loss: 0.1789
# Epoch 15/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9465 - loss: 0.1715 - val_accuracy: 0.9469 - val_loss: 0.1789
# Epoch 16/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9463 - loss: 0.1811 - val_accuracy: 0.9471 - val_loss: 0.1784
# Epoch 17/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9484 - loss: 0.1700 - val_accuracy: 0.9476 - val_loss: 0.1779
# Epoch 18/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9498 - loss: 0.1691 - val_accuracy: 0.9484 - val_loss: 0.1784
# Epoch 19/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9440 - loss: 0.1847 - val_accuracy: 0.9466 - val_loss: 0.1792
# Epoch 20/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9466 - loss: 0.1858 - val_accuracy: 0.9479 - val_loss: 0.1775
# Score for fold 5: loss of 0.17750616371631622; compile_metrics of 94.79030966758728%
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.17108914256095886 - Accuracy: 94.86979246139526%
# > Fold 2 - Loss: 0.16769669950008392 - Accuracy: 94.8437511920929%
# > Fold 3 - Loss: 0.1803629994392395 - Accuracy: 94.47916746139526%
# > Fold 4 - Loss: 0.1746681183576584 - Accuracy: 95.07812261581421%
# > Fold 5 - Loss: 0.17750616371631622 - Accuracy: 94.79030966758728%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 94.81222867965698 (+- 0.1930891303225327)
# > Loss: 0.17426462471485138
# ------------------------------------------------------------------------

# %%
# Function to plot k-fold histories
def plot_kfold_histories(histories):
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    
    for fold, history in enumerate(histories, start=1):
        axes[0].plot(history.history['accuracy'], label=f'Train Fold {fold}')
        axes[0].plot(history.history['val_accuracy'], label=f'Val Fold {fold}', linestyle="--")
        axes[1].plot(history.history['loss'], label=f'Train Fold {fold}')
        axes[1].plot(history.history['val_loss'], label=f'Val Fold {fold}', linestyle="--")
    
    axes[0].set_title('Model Accuracy')
    axes[0].set_ylabel('Accuracy')
    axes[0].set_xlabel('Epoch')
    axes[0].legend()
    
    axes[1].set_title('Model Loss')
    axes[1].set_ylabel('Loss')
    axes[1].set_xlabel('Epoch')
    axes[1].legend()
    
    plt.show()
    
    
# Plot the histories
plot_kfold_histories(all_histories)
