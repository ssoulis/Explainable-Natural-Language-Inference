# %%
import pandas as pd

# Load the SNLI test data (including true labels)
snli_test_path = "/kaggle/input/stanford-natural-language-inference-corpus/snli_1.0_test.csv"
snli_test_df = pd.read_csv(snli_test_path)

# Define file paths for SNLI prediction files
snli_predictions_paths = {
    "deberta": "/kaggle/input/deberta-nli/deberta_snli_predictions.csv",
    "roberta": "/kaggle/input/roberta/roberta_snli_predictions.csv",
    "albert": "/kaggle/input/albert/albert_snli_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_snli = "/kaggle/working/combined_snli_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_snli_df = pd.DataFrame(columns=columns)

label_mapping = {'entailment': 0, 'neutral': 1, 'contradiction': 2}

# Load and merge the predictions
for model, path in snli_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_snli_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_snli_df['True_Label'] = snli_test_df['gold_label'].map(label_mapping)

# Convert True_Label to integer type
combined_snli_df['True_Label'] = combined_snli_df['True_Label'].astype('Int64')

# Save the combined DataFrame to CSV
combined_snli_df.to_csv(output_csv_path_snli, index=False)

print(f"Combined SNLI predictions with true labels saved to {output_csv_path_snli}")
# Out:
# Combined SNLI predictions with true labels saved to /kaggle/working/combined_snli_df

# %%
combined_snli_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.034767         0.962592               0.002641
# 1            0.001921         0.319032               0.679047
# 2            0.998783         0.000764               0.000453
# 3            0.001001         0.997708               0.001291
# 4            0.001080         0.301363               0.697557
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.012451         0.927093               0.060457
# 1            0.752766         0.242251               0.004983
# 2            0.000254         0.004494               0.995253
# 3            0.005844         0.990736               0.003419
# 4            0.278348         0.718575               0.003076
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.008653        0.947434              0.043913           1
# 1           0.740332        0.256434              0.003235           0
# 2           0.004677        0.060481              0.934843           2
# 3           0.034056        0.956687              0.009257           1
# 4           0.498761        0.499270              0.001969           0

# %%
# Load the ANLI Round 1 test data (including true labels)
mnli_matched_test_path = "/kaggle/input/nli-dataset-for-sentence-understanding/mnli_validation_matched.csv"
mnli_matched_test_df = pd.read_csv(mnli_matched_test_path)

# Define file paths for ANLI Round 1 prediction files
mnli_matched_predictions_paths = {
    "deberta": "/kaggle/input/validation/deberta_mnli_matched_val_predictions.csv",
    "roberta": "/kaggle/input/validation/roberta_mnli_matched_val_predictions.csv",
    "albert": "/kaggle/input/validation/albert_mnli_matched_val_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_mnli_matched = "/kaggle/working/combined_mnli_matched_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_mnli_matched_df = pd.DataFrame(columns=columns)

# Load and merge the predictions
for model, path in mnli_matched_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_mnli_matched_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_mnli_matched_df['True_Label'] = mnli_matched_test_df['label']

# Save the combined DataFrame to CSV
combined_mnli_matched_df.to_csv(output_csv_path_mnli_matched, index=False)

print(f"Combined MNLI-matched predictions with true labels saved to {output_csv_path_mnli_matched}")
# Out:
# Combined MNLI-matched predictions with true labels saved to /kaggle/working/combined_mnli_matched_df

# %%
combined_mnli_matched_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.005164         0.993364               0.001472
# 1            0.999153         0.000526               0.000321
# 2            0.000989         0.044792               0.954219
# 3            0.994965         0.004808               0.000228
# 4            0.999657         0.000220               0.000123
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.017844         0.950246               0.031909
# 1            0.001413         0.002030               0.996557
# 2            0.954781         0.042249               0.002970
# 3            0.000343         0.003511               0.996146
# 4            0.000079         0.000496               0.999425
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.010844        0.983012              0.006144           1
# 1           0.005388        0.007536              0.987076           2
# 2           0.853862        0.143483              0.002655           0
# 3           0.004128        0.070757              0.925115           2
# 4           0.003864        0.029262              0.966875           2

# %%
# Load the ANLI Round 1 test data (including true labels)
mnli_mismatched_test_path = "/kaggle/input/nli-dataset-for-sentence-understanding/mnli_validation_mismatched.csv"
mnli_mismatched_test_df = pd.read_csv(mnli_mismatched_test_path)

# Define file paths for ANLI Round 1 prediction files
mnli_mismatched_predictions_paths = {
    "deberta": "/kaggle/input/validation/deberta_mnli_mismatched_val_predictions.csv",
    "roberta": "/kaggle/input/validation/roberta_mnli_mismatched_val_predictions.csv",
    "albert": "/kaggle/input/validation/albert_mnli_mismatched_val_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_mnli_mismatched = "/kaggle/working/combined_mnli_mismatched_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_mnli_mismatched_df = pd.DataFrame(columns=columns)

# Load and merge the predictions
for model, path in mnli_mismatched_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_mnli_mismatched_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_mnli_mismatched_df['True_Label'] = mnli_mismatched_test_df['label']

# Save the combined DataFrame to CSV
combined_mnli_mismatched_df.to_csv(output_csv_path_mnli_mismatched, index=False)

print(f"Combined MNLI-mismatched predictions with true labels saved to {output_csv_path_mnli_mismatched}")
# Out:
# Combined MNLI-mismatched predictions with true labels saved to /kaggle/working/combined_mnli_mismatched_df

# %%
combined_mnli_mismatched_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.999667         0.000160               0.000173
# 1            0.998119         0.000962               0.000919
# 2            0.000552         0.004809               0.994639
# 3            0.827653         0.171961               0.000386
# 4            0.000292         0.002875               0.996833
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.000068         0.000402               0.999529
# 1            0.000183         0.001511               0.998306
# 2            0.986062         0.012020               0.001918
# 3            0.000478         0.270953               0.728569
# 4            0.975167         0.021904               0.002929
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.000894        0.003787              0.995318           2
# 1           0.006421        0.010224              0.983355           2
# 2           0.975041        0.023354              0.001605           0
# 3           0.001722        0.796122              0.202156           2
# 4           0.965952        0.032748              0.001300           0

# %%
# Load the ANLI Round 1 test data (including true labels)
anli_r1_test_path = "/kaggle/input/anli-a-large-scale-nli-benchmark-dataset/test_r1.csv"
anli_r1_test_df = pd.read_csv(anli_r1_test_path)

# Define file paths for ANLI Round 1 prediction files
anli_r1_predictions_paths = {
    "deberta": "/kaggle/input/deberta-nli/deberta_anli_r1_predictions.csv",
    "roberta": "/kaggle/input/roberta/roberta_anli_r1_predictions.csv",
    "albert": "/kaggle/input/albert/albert_anli_r1_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_anli_r1 = "/kaggle/working/combined_anli_r1_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_anli_r1_df = pd.DataFrame(columns=columns)

# Load and merge the predictions
for model, path in anli_r1_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_anli_r1_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_anli_r1_df['True_Label'] = anli_r1_test_df['label']

# Save the combined DataFrame to CSV
combined_anli_r1_df.to_csv(output_csv_path_anli_r1, index=False)

print(f"Combined ANLI Round 1 predictions with true labels saved to {output_csv_path_anli_r1}")
# Out:
# Combined ANLI Round 1 predictions with true labels saved to /kaggle/working/combined_anli_r1_df

# %%
combined_anli_r1_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.015388         0.976305               0.008307
# 1            0.224603         0.501549               0.273848
# 2            0.006642         0.976690               0.016669
# 3            0.966494         0.032235               0.001272
# 4            0.880736         0.028293               0.090971
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.996714         0.000376               0.002910
# 1            0.875720         0.000724               0.123556
# 2            0.999484         0.000330               0.000186
# 3            0.000686         0.998181               0.001133
# 4            0.000378         0.000197               0.999425
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.322974        0.667628              0.009398           0
# 1           0.998526        0.000604              0.000869           0
# 2           0.783352        0.212241              0.004407           0
# 3           0.002134        0.989523              0.008343           1
# 4           0.023283        0.013253              0.963464           2

# %%
# Load the ANLI Round 2 test data (including true labels)
anli_r2_test_path = "/kaggle/input/anli-a-large-scale-nli-benchmark-dataset/test_r2.csv"
anli_r2_test_df = pd.read_csv(anli_r2_test_path)

# Define file paths for ANLI Round 2 prediction files
anli_r2_predictions_paths = {
    "deberta": "/kaggle/input/deberta-nli/deberta_anli_r2_predictions.csv",
    "roberta": "/kaggle/input/roberta/roberta_anli_r2_predictions.csv",
    "albert": "/kaggle/input/albert/albert_anli_r2_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_anli_r2 = "/kaggle/working/combined_anli_r2_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_anli_r2_df = pd.DataFrame(columns=columns)

# Load and merge the predictions
for model, path in anli_r2_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_anli_r2_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_anli_r2_df['True_Label'] = anli_r2_test_df['label']

# Save the combined DataFrame to CSV
combined_anli_r2_df.to_csv(output_csv_path_anli_r2, index=False)

print(f"Combined ANLI Round 2 predictions with true labels saved to {output_csv_path_anli_r2}")
# Out:
# Combined ANLI Round 2 predictions with true labels saved to /kaggle/working/combined_anli_r2_df

# %%
combined_anli_r2_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.001309         0.029617               0.969075
# 1            0.724144         0.273676               0.002180
# 2            0.071604         0.917894               0.010503
# 3            0.066162         0.929179               0.004659
# 4            0.906199         0.089873               0.003928
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.999506         0.000264               0.000230
# 1            0.026951         0.054230               0.918819
# 2            0.001282         0.998108               0.000610
# 3            0.007091         0.992694               0.000215
# 4            0.006259         0.989432               0.004309
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.863365        0.133388              0.003246           0
# 1           0.072900        0.904344              0.022756           1
# 2           0.027402        0.972218              0.000380           0
# 3           0.632171        0.365194              0.002635           1
# 4           0.064109        0.234642              0.701249           2

# %%
# Load the ANLI Round 3 test data (including true labels)
anli_r3_test_path = "/kaggle/input/anli-a-large-scale-nli-benchmark-dataset/test_r3.csv"
anli_r3_test_df = pd.read_csv(anli_r3_test_path)

# Define file paths for ANLI Round 2 prediction files
anli_r3_predictions_paths = {
    "deberta": "/kaggle/input/deberta-nli/deberta_anli_r3_predictions.csv",
    "roberta": "/kaggle/input/roberta/roberta_anli_r3_predictions.csv",
    "albert": "/kaggle/input/albert/albert_anli_r3_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_anli_r3 = "/kaggle/working/combined_anli_r3_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_anli_r3_df = pd.DataFrame(columns=columns)

# Load and merge the predictions
for model, path in anli_r3_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_anli_r3_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_anli_r3_df['True_Label'] = anli_r3_test_df['label']

# Save the combined DataFrame to CSV
combined_anli_r3_df.to_csv(output_csv_path_anli_r3, index=False)

print(f"Combined ANLI Round 3 predictions with true labels saved to {output_csv_path_anli_r3}")
# Out:
# Combined ANLI Round 3 predictions with true labels saved to /kaggle/working/combined_anli_r3_df

# %%
combined_anli_r3_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.005921         0.960529               0.033551
# 1            0.009586         0.934714               0.055700
# 2            0.003428         0.976393               0.020179
# 3            0.004633         0.023985               0.971382
# 4            0.017428         0.633695               0.348877
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.022959         0.976533               0.000509
# 1            0.999611         0.000205               0.000185
# 2            0.002020         0.997897               0.000083
# 3            0.974441         0.024459               0.001100
# 4            0.984416         0.011166               0.004419
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.001848        0.998084              0.000067           0
# 1           0.951772        0.048075              0.000153           0
# 2           0.001014        0.998984              0.000002           0
# 3           0.996749        0.000989              0.002262           0
# 4           0.000518        0.128416              0.871066           0

# %%
# Check for missing values
missing_values_anli1 = combined_anli_r1_df.isnull().sum()

missing_values_anli2 = combined_anli_r2_df.isnull().sum()

missing_values_anli3 = combined_anli_r3_df.isnull().sum()

missing_values_snli = combined_snli_df.isnull().sum()

missing_values_mnli_matched = combined_mnli_matched_df.isnull().sum()

missing_values_mnli_mismatched = combined_mnli_mismatched_df.isnull().sum()

# %%
missing_values_anli1
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
missing_values_anli2
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
missing_values_anli3
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
missing_values_snli
# Out:
# Deberta_Entailment         0
# Deberta_Neutral            0
# Deberta_Contradiction      0
# Roberta_Entailment         0
# Roberta_Neutral            0
# Roberta_Contradiction      0
# Albert_Entailment          0
# Albert_Neutral             0
# Albert_Contradiction       0
# True_Label               176
# dtype: int64

# %%
missing_values_mnli_matched
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
missing_values_mnli_mismatched
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
combined_snli_df.dropna(subset=['True_Label'], inplace=True)

# %%
# Verify missing values again after removal
missing_values_snli_after_removal = combined_snli_df.isnull().sum()
print(missing_values_snli_after_removal)
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
combined_snli_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9824 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Deberta_Entailment     9824 non-null   float64
#  1   Deberta_Neutral        9824 non-null   float64
#  2   Deberta_Contradiction  9824 non-null   float64
#  3   Roberta_Entailment     9824 non-null   float64
#  4   Roberta_Neutral        9824 non-null   float64
#  5   Roberta_Contradiction  9824 non-null   float64
#  6   Albert_Entailment      9824 non-null   float64
#  7   Albert_Neutral         9824 non-null   float64
#  8   Albert_Contradiction   9824 non-null   float64
#  9   True_Label             9824 non-null   Int64
# dtypes: Int64(1), float64(9)
# memory usage: 853.8 KB

# %%
combined_snli_df
# Out:
#       Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0               0.034767         0.962592               0.002641
# 1               0.001921         0.319032               0.679047
# 2               0.998783         0.000764               0.000453
# 3               0.001001         0.997708               0.001291
# 4               0.001080         0.301363               0.697557
# ...                  ...              ...                    ...
# 9995            0.998825         0.001033               0.000142
# 9996            0.000704         0.009793               0.989503
# 9997            0.999171         0.000493               0.000336
# 9998            0.000267         0.002178               0.997556
# 9999            0.003641         0.995224               0.001135
#
#       Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0               0.012451         0.927093               0.060457
# 1               0.752766         0.242251               0.004983
# 2               0.000254         0.004494               0.995253
# 3               0.005844         0.990736               0.003419
# 4               0.278348         0.718575               0.003076
# ...                  ...              ...                    ...
# 9995            0.001264         0.028942               0.969794
# 9996            0.780946         0.217053               0.002001
# 9997            0.000054         0.000765               0.999181
# 9998            0.983402         0.015884               0.000714
# 9999            0.000904         0.995495               0.003601
#
#       Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0              0.008653        0.947434              0.043913           1
# 1              0.740332        0.256434              0.003235           0
# 2              0.004677        0.060481              0.934843           2
# 3              0.034056        0.956687              0.009257           1
# 4              0.498761        0.499270              0.001969           0
# ...                 ...             ...                   ...         ...
# 9995           0.006420        0.057240              0.936340           2
# 9996           0.894637        0.104095              0.001267           0
# 9997           0.000838        0.002670              0.996493           2
# 9998           0.984347        0.015223              0.000430           0
# 9999           0.005047        0.990218              0.004735           1
#
# [9824 rows x 10 columns]

# %%
import numpy as np

def calculate_margin(row):
    # Assuming the row only contains the probabilities
    sorted_probs = np.sort(row)  # Sort probabilities in ascending order
    if len(sorted_probs) > 1:
        return sorted_probs[-1] - sorted_probs[-2]  # Difference between the highest and second highest
    else:
        return 0  # This handles the edge case where there is only one probability value

# %%
# Applying to a sample DataFrame with made-up column names
combined_snli_df['confidence_margin_entailment'] = combined_snli_df[['Deberta_Entailment', 'Roberta_Entailment', 'Albert_Entailment']].apply(calculate_margin, axis=1)
combined_snli_df['confidence_margin_neutral'] = combined_snli_df[['Deberta_Neutral', 'Roberta_Neutral', 'Albert_Neutral']].apply(calculate_margin, axis=1)
combined_snli_df['confidence_margin_contradiction'] = combined_snli_df[['Deberta_Contradiction', 'Roberta_Contradiction', 'Albert_Contradiction']].apply(calculate_margin, axis=1)


# Applying to a sample DataFrame with made-up column names
combined_mnli_matched_df['confidence_margin_entailment'] = combined_mnli_matched_df[['Deberta_Entailment', 'Roberta_Entailment', 'Albert_Entailment']].apply(calculate_margin, axis=1)
combined_mnli_matched_df['confidence_margin_neutral'] = combined_mnli_matched_df[['Deberta_Neutral', 'Roberta_Neutral', 'Albert_Neutral']].apply(calculate_margin, axis=1)
combined_mnli_matched_df['confidence_margin_contradiction'] = combined_mnli_matched_df[['Deberta_Contradiction', 'Roberta_Contradiction', 'Albert_Contradiction']].apply(calculate_margin, axis=1)

# Applying to a sample DataFrame with made-up column names
combined_mnli_mismatched_df['confidence_margin_entailment'] = combined_mnli_mismatched_df[['Deberta_Entailment', 'Roberta_Entailment', 'Albert_Entailment']].apply(calculate_margin, axis=1)
combined_mnli_mismatched_df['confidence_margin_neutral'] = combined_mnli_mismatched_df[['Deberta_Neutral', 'Roberta_Neutral', 'Albert_Neutral']].apply(calculate_margin, axis=1)
combined_mnli_mismatched_df['confidence_margin_contradiction'] = combined_mnli_mismatched_df[['Deberta_Contradiction', 'Roberta_Contradiction', 'Albert_Contradiction']].apply(calculate_margin, axis=1)

# Applying to a sample DataFrame with made-up column names
combined_anli_r1_df['confidence_margin_entailment'] = combined_anli_r1_df[['Deberta_Entailment', 'Roberta_Entailment', 'Albert_Entailment']].apply(calculate_margin, axis=1)
combined_anli_r1_df['confidence_margin_neutral'] = combined_anli_r1_df[['Deberta_Neutral', 'Roberta_Neutral', 'Albert_Neutral']].apply(calculate_margin, axis=1)
combined_anli_r1_df['confidence_margin_contradiction'] = combined_anli_r1_df[['Deberta_Contradiction', 'Roberta_Contradiction', 'Albert_Contradiction']].apply(calculate_margin, axis=1)


# Applying to a sample DataFrame with made-up column names
combined_anli_r2_df['confidence_margin_entailment'] = combined_anli_r2_df[['Deberta_Entailment', 'Roberta_Entailment', 'Albert_Entailment']].apply(calculate_margin, axis=1)
combined_anli_r2_df['confidence_margin_neutral'] = combined_anli_r2_df[['Deberta_Neutral', 'Roberta_Neutral', 'Albert_Neutral']].apply(calculate_margin, axis=1)
combined_anli_r2_df['confidence_margin_contradiction'] = combined_anli_r2_df[['Deberta_Contradiction', 'Roberta_Contradiction', 'Albert_Contradiction']].apply(calculate_margin, axis=1)


# Applying to a sample DataFrame with made-up column names
combined_anli_r3_df['confidence_margin_entailment'] = combined_anli_r3_df[['Deberta_Entailment', 'Roberta_Entailment', 'Albert_Entailment']].apply(calculate_margin, axis=1)
combined_anli_r3_df['confidence_margin_neutral'] = combined_anli_r3_df[['Deberta_Neutral', 'Roberta_Neutral', 'Albert_Neutral']].apply(calculate_margin, axis=1)
combined_anli_r3_df['confidence_margin_contradiction'] = combined_anli_r3_df[['Deberta_Contradiction', 'Roberta_Contradiction', 'Albert_Contradiction']].apply(calculate_margin, axis=1)

# %%
combined_anli_r3_df
# Out:
#       Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0               0.005921         0.960529               0.033551
# 1               0.009586         0.934714               0.055700
# 2               0.003428         0.976393               0.020179
# 3               0.004633         0.023985               0.971382
# 4               0.017428         0.633695               0.348877
# ...                  ...              ...                    ...
# 1195            0.150312         0.806051               0.043637
# 1196            0.971834         0.026294               0.001872
# 1197            0.973818         0.025074               0.001109
# 1198            0.341781         0.226539               0.431681
# 1199            0.472737         0.477215               0.050049
#
#       Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0               0.022959         0.976533               0.000509
# 1               0.999611         0.000205               0.000185
# 2               0.002020         0.997897               0.000083
# 3               0.974441         0.024459               0.001100
# 4               0.984416         0.011166               0.004419
# ...                  ...              ...                    ...
# 1195            0.032452         0.068553               0.898994
# 1196            0.009070         0.824654               0.166276
# 1197            0.000352         0.000972               0.998677
# 1198            0.006147         0.073669               0.920184
# 1199            0.000420         0.991832               0.007748
#
#       Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label  \
# 0              0.001848        0.998084              0.000067           0
# 1              0.951772        0.048075              0.000153           0
# 2              0.001014        0.998984              0.000002           0
# 3              0.996749        0.000989              0.002262           0
# 4              0.000518        0.128416              0.871066           0
# ...                 ...             ...                   ...         ...
# 1195           0.122045        0.254093              0.623862           2
# 1196           0.001115        0.003229              0.995656           2
# 1197           0.310862        0.618914              0.070225           2
# 1198           0.054172        0.317935              0.627893           2
# 1199           0.015091        0.121354              0.863554           2
#
#       confidence_margin_entailment  confidence_margin_neutral  \
# 0                         0.017038                   0.021552
# 1                         0.047839                   0.886640
# 2                         0.001408                   0.001087
# 3                         0.022308                   0.000474
# 4                         0.966988                   0.505279
# ...                            ...                        ...
# 1195                      0.028268                   0.551958
# 1196                      0.962764                   0.798360
# 1197                      0.662956                   0.593840
# 1198                      0.287609                   0.091397
# 1199                      0.457646                   0.514617
#
#       confidence_margin_contradiction
# 0                            0.033042
# 1                            0.055515
# 2                            0.020096
# 3                            0.969120
# 4                            0.522189
# ...                               ...
# 1195                         0.275132
# 1196                         0.829379
# 1197                         0.928452
# 1198                         0.292291
# 1199                         0.813506
#
# [1200 rows x 13 columns]

# %%
import matplotlib.pyplot as plt

# Plot histograms for the confidence margins
def plot_confidence_margins(df):
    plt.figure(figsize=(15, 5))
    plt.subplot(1, 3, 1)
    plt.hist(df['confidence_margin_entailment'], bins=50, alpha=0.75, label='Entailment')
    plt.title('Confidence Margin Histogram - Entailment')
    plt.xlabel('Margin')
    plt.ylabel('Frequency')
    
    plt.subplot(1, 3, 2)
    plt.hist(df['confidence_margin_neutral'], bins=50, alpha=0.75, label='Neutral', color='green')
    plt.title('Confidence Margin Histogram - Neutral')
    plt.xlabel('Margin')
    plt.ylabel('Frequency')
    
    plt.subplot(1, 3, 3)
    plt.hist(df['confidence_margin_contradiction'], bins=50, alpha=0.75, label='Contradiction', color='red')
    plt.title('Confidence Margin Histogram - Contradiction')
    plt.xlabel('Margin')
    plt.ylabel('Frequency')
    
    plt.tight_layout()
    plt.show()

plot_confidence_margins(combined_snli_df)

# %%
# Define thresholds based on the distribution
confidence_threshold = 0.8

# Apply threshold and create a new copy of the DataFrame
high_confidence_snli = combined_snli_df[
    (combined_snli_df['confidence_margin_entailment'] >= confidence_threshold) | 
    (combined_snli_df['confidence_margin_neutral'] >= confidence_threshold) |
    (combined_snli_df['confidence_margin_contradiction'] >= confidence_threshold)
].copy()


# Apply threshold and create a new copy of the DataFrame
high_confidence_mnli_matched = combined_mnli_matched_df[
    (combined_mnli_matched_df['confidence_margin_entailment'] >= confidence_threshold) | 
    (combined_mnli_matched_df['confidence_margin_neutral'] >= confidence_threshold) |
    (combined_mnli_matched_df['confidence_margin_contradiction'] >= confidence_threshold)
].copy()

# Apply threshold and create a new copy of the DataFrame
high_confidence_mnli_mismatched = combined_mnli_mismatched_df[
    (combined_mnli_mismatched_df['confidence_margin_entailment'] >= confidence_threshold) | 
    (combined_mnli_mismatched_df['confidence_margin_neutral'] >= confidence_threshold) |
    (combined_mnli_mismatched_df['confidence_margin_contradiction'] >= confidence_threshold)
].copy()

# Filter high confidence samples for ANLI round 1
high_confidence_anli_r1 = combined_anli_r1_df[
    (combined_anli_r1_df['confidence_margin_entailment'] >= confidence_threshold) | 
    (combined_anli_r1_df['confidence_margin_neutral'] >= confidence_threshold) |
    (combined_anli_r1_df['confidence_margin_contradiction'] >= confidence_threshold)
].copy()

# Filter high confidence samples for ANLI round 2
high_confidence_anli_r2 = combined_anli_r2_df[
    (combined_anli_r2_df['confidence_margin_entailment'] >= confidence_threshold) | 
    (combined_anli_r2_df['confidence_margin_neutral'] >= confidence_threshold) |
    (combined_anli_r2_df['confidence_margin_contradiction'] >= confidence_threshold)
].copy()

# Filter high confidence samples for ANLI round 3
high_confidence_anli_r3 = combined_anli_r3_df[
    (combined_anli_r3_df['confidence_margin_entailment'] >= confidence_threshold) | 
    (combined_anli_r3_df['confidence_margin_neutral'] >= confidence_threshold) |
    (combined_anli_r3_df['confidence_margin_contradiction'] >= confidence_threshold)
].copy()

# %%
# Majority vote logic with weights for numeric labels
def majority_vote_with_threshold(row):
    votes = [0, 0, 0]  # Index 0 for entailment, 1 for neutral, 2 for contradiction
    if row['confidence_margin_entailment'] >= confidence_threshold:
        votes[0] += row['confidence_margin_entailment']
    if row['confidence_margin_neutral'] >= confidence_threshold:
        votes[1] += row['confidence_margin_neutral']
    if row['confidence_margin_contradiction'] >= confidence_threshold:
        votes[2] += row['confidence_margin_contradiction']
    
    # Return the index of the highest vote
    return np.argmax(votes)

# Apply the majority vote logic using .loc
high_confidence_snli.loc[:, 'majority_vote'] = high_confidence_snli.apply(majority_vote_with_threshold, axis=1)
# Apply the majority vote logic using .loc
high_confidence_mnli_matched.loc[:, 'majority_vote'] = high_confidence_mnli_matched.apply(majority_vote_with_threshold, axis=1)
# Apply majority vote logic
high_confidence_mnli_mismatched.loc[:, 'majority_vote'] = high_confidence_mnli_mismatched.apply(majority_vote_with_threshold, axis=1)
# Apply majority vote logic
high_confidence_anli_r1.loc[:, 'majority_vote'] = high_confidence_anli_r1.apply(majority_vote_with_threshold, axis=1)
# Apply majority vote logic
high_confidence_anli_r2.loc[:, 'majority_vote'] = high_confidence_anli_r2.apply(majority_vote_with_threshold, axis=1)
# Apply majority vote logic
high_confidence_anli_r3.loc[:, 'majority_vote'] = high_confidence_anli_r3.apply(majority_vote_with_threshold, axis=1)

# %%
high_confidence_anli_r3
# Out:
#       Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 1               0.009586         0.934714               0.055700
# 3               0.004633         0.023985               0.971382
# 4               0.017428         0.633695               0.348877
# 5               0.002461         0.150678               0.846861
# 8               0.131793         0.776056               0.092151
# ...                  ...              ...                    ...
# 1193            0.957103         0.040533               0.002363
# 1194            0.945850         0.052813               0.001337
# 1196            0.971834         0.026294               0.001872
# 1197            0.973818         0.025074               0.001109
# 1199            0.472737         0.477215               0.050049
#
#       Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 1               0.999611         0.000205               0.000185
# 3               0.974441         0.024459               0.001100
# 4               0.984416         0.011166               0.004419
# 5               0.999220         0.000554               0.000227
# 8               0.000384         0.002570               0.997046
# ...                  ...              ...                    ...
# 1193            0.000066         0.000316               0.999618
# 1194            0.000607         0.000853               0.998540
# 1196            0.009070         0.824654               0.166276
# 1197            0.000352         0.000972               0.998677
# 1199            0.000420         0.991832               0.007748
#
#       Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label  \
# 1              0.951772        0.048075              0.000153           0
# 3              0.996749        0.000989              0.002262           0
# 4              0.000518        0.128416              0.871066           0
# 5              0.985221        0.014745              0.000034           0
# 8              0.049409        0.904356              0.046236           0
# ...                 ...             ...                   ...         ...
# 1193           0.009265        0.016116              0.974619           2
# 1194           0.000205        0.000291              0.999504           2
# 1196           0.001115        0.003229              0.995656           2
# 1197           0.310862        0.618914              0.070225           2
# 1199           0.015091        0.121354              0.863554           2
#
#       confidence_margin_entailment  confidence_margin_neutral  \
# 1                         0.047839                   0.886640
# 3                         0.022308                   0.000474
# 4                         0.966988                   0.505279
# 5                         0.013998                   0.135933
# 8                         0.082384                   0.128299
# ...                            ...                        ...
# 1193                      0.947838                   0.024417
# 1194                      0.945243                   0.051960
# 1196                      0.962764                   0.798360
# 1197                      0.662956                   0.593840
# 1199                      0.457646                   0.514617
#
#       confidence_margin_contradiction  majority_vote
# 1                            0.055515              1
# 3                            0.969120              2
# 4                            0.522189              0
# 5                            0.846635              2
# 8                            0.904895              2
# ...                               ...            ...
# 1193                         0.024999              0
# 1194                         0.000965              0
# 1196                         0.829379              0
# 1197                         0.928452              2
# 1199                         0.813506              2
#
# [530 rows x 14 columns]

# %%
high_confidence_mnli_mismatched
# Out:
#       Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0               0.999667         0.000160               0.000173
# 1               0.998119         0.000962               0.000919
# 2               0.000552         0.004809               0.994639
# 3               0.827653         0.171961               0.000386
# 4               0.000292         0.002875               0.996833
# ...                  ...              ...                    ...
# 9824            0.000760         0.013837               0.985402
# 9825            0.000145         0.003906               0.995949
# 9826            0.996226         0.003656               0.000118
# 9828            0.997044         0.001226               0.001730
# 9829            0.999685         0.000112               0.000202
#
#       Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0               0.000068         0.000402               0.999529
# 1               0.000183         0.001511               0.998306
# 2               0.986062         0.012020               0.001918
# 3               0.000478         0.270953               0.728569
# 4               0.975167         0.021904               0.002929
# ...                  ...              ...                    ...
# 9824            0.972984         0.025382               0.001634
# 9825            0.952827         0.045891               0.001281
# 9826            0.000353         0.104717               0.894930
# 9828            0.000364         0.000717               0.998919
# 9829            0.000085         0.000289               0.999626
#
#       Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label  \
# 0              0.000894        0.003787              0.995318           2
# 1              0.006421        0.010224              0.983355           2
# 2              0.975041        0.023354              0.001605           0
# 3              0.001722        0.796122              0.202156           2
# 4              0.965952        0.032748              0.001300           0
# ...                 ...             ...                   ...         ...
# 9824           0.925212        0.069991              0.004798           0
# 9825           0.965645        0.032757              0.001598           0
# 9826           0.004991        0.039946              0.955062           2
# 9828           0.019078        0.039258              0.941663           2
# 9829           0.000420        0.001810              0.997770           2
#
#       confidence_margin_entailment  confidence_margin_neutral  \
# 0                         0.998773                   0.003385
# 1                         0.991698                   0.008714
# 2                         0.011021                   0.011334
# 3                         0.825931                   0.525168
# 4                         0.009215                   0.010844
# ...                            ...                        ...
# 9824                      0.047772                   0.044608
# 9825                      0.012818                   0.013134
# 9826                      0.991234                   0.064771
# 9828                      0.977966                   0.038033
# 9829                      0.999265                   0.001521
#
#       confidence_margin_contradiction  majority_vote
# 0                            0.004211              0
# 1                            0.014951              0
# 2                            0.992721              2
# 3                            0.526413              0
# 4                            0.993904              2
# ...                               ...            ...
# 9824                         0.980605              2
# 9825                         0.994351              2
# 9826                         0.060132              0
# 9828                         0.057256              0
# 9829                         0.001856              0
#
# [5910 rows x 14 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf



# Features and Labels
X_snli = high_confidence_snli.drop(['True_Label','confidence_margin_entailment','confidence_margin_neutral','confidence_margin_contradiction','majority_vote'], axis=1).values
y_snli = high_confidence_snli['True_Label'].values

# Features and Labels
X_mnli_matched = high_confidence_mnli_matched.drop(['True_Label','confidence_margin_entailment','confidence_margin_neutral','confidence_margin_contradiction','majority_vote'], axis=1).values
y_mnli_matched = high_confidence_mnli_matched['True_Label'].values

# Features and Labels
X_mnli_mismatched = high_confidence_mnli_mismatched.drop(['True_Label','confidence_margin_entailment','confidence_margin_neutral','confidence_margin_contradiction','majority_vote'], axis=1).values
y_mnli_mismatched = high_confidence_mnli_mismatched['True_Label'].values

# Features and Labels
X_anli_r1 = high_confidence_anli_r1.drop(['True_Label','confidence_margin_entailment','confidence_margin_neutral','confidence_margin_contradiction','majority_vote'], axis=1).values
y_anli_r1 = high_confidence_anli_r1['True_Label'].values

# Features and Labels
X_anli_r2 = high_confidence_anli_r2.drop(['True_Label','confidence_margin_entailment','confidence_margin_neutral','confidence_margin_contradiction','majority_vote'], axis=1).values
y_anli_r2 = high_confidence_anli_r2['True_Label'].values

# Features and Labels
X_anli_r3 = high_confidence_anli_r3.drop(['True_Label','confidence_margin_entailment','confidence_margin_neutral','confidence_margin_contradiction','majority_vote'], axis=1).values
y_anli_r3 = high_confidence_anli_r3['True_Label'].values
# Out:
# 2024-04-18 19:34:44.649407: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-18 19:34:44.649507: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-18 19:34:44.779879: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Extract only the additional features from each dataset
features_snli = high_confidence_snli[['confidence_margin_entailment', 'confidence_margin_neutral', 'confidence_margin_contradiction']].values
features_mnli_matched = high_confidence_mnli_matched[[ 'confidence_margin_entailment', 'confidence_margin_neutral', 'confidence_margin_contradiction']].values
features_mnli_mismatched = high_confidence_mnli_mismatched[[ 'confidence_margin_entailment', 'confidence_margin_neutral', 'confidence_margin_contradiction']].values
features_anli_r1 = high_confidence_anli_r1[[ 'confidence_margin_entailment', 'confidence_margin_neutral', 'confidence_margin_contradiction']].values
features_anli_r2 = high_confidence_anli_r2[[ 'confidence_margin_entailment', 'confidence_margin_neutral', 'confidence_margin_contradiction']].values
features_anli_r3 = high_confidence_anli_r3[[ 'confidence_margin_entailment', 'confidence_margin_neutral', 'confidence_margin_contradiction']].values

# %%
X_snli
# Out:
# array([[9.9878270e-01, 7.6433434e-04, 4.5297167e-04, ..., 4.6765395e-03,
#         6.0480673e-02, 9.3484277e-01],
#        [5.0442386e-04, 4.3001700e-03, 9.9519530e-01, ..., 9.7817034e-01,
#         2.1051416e-02, 7.7824460e-04],
#        [9.8957914e-01, 5.4418677e-03, 4.9790350e-03, ..., 8.5550435e-02,
#         7.5036585e-02, 8.3941300e-01],
#        ...,
#        [7.0376875e-04, 9.7931010e-03, 9.8950315e-01, ..., 8.9463750e-01,
#         1.0409502e-01, 1.2674012e-03],
#        [9.9917114e-01, 4.9286430e-04, 3.3603658e-04, ..., 8.3751883e-04,
#         2.6697412e-03, 9.9649280e-01],
#        [2.6664520e-04, 2.1777824e-03, 9.9755560e-01, ..., 9.8434700e-01,
#         1.5223468e-02, 4.2961346e-04]])

# %%
features_snli
# Out:
# array([[9.94106161e-01, 5.59870956e-02, 6.04100800e-02],
#        [5.73736000e-03, 5.89017100e-03, 9.94264296e-01],
#        [9.04028705e-01, 1.89172950e-02, 3.66324000e-02],
#        ...,
#        [1.13691360e-01, 1.12957690e-01, 9.87502096e-01],
#        [9.98333621e-01, 1.90469200e-03, 2.68793000e-03],
#        [9.45200000e-04, 6.61004000e-04, 9.96841898e-01]])

# %%
# One-hot encode labels for each dataset using TensorFlow/Keras utility
y_encoded_snli = tf.keras.utils.to_categorical(y_snli)
y_encoded_mnli_matched = tf.keras.utils.to_categorical(y_mnli_matched)
y_encoded_mnli_mismatched = tf.keras.utils.to_categorical(y_mnli_mismatched)
y_encoded_anli_r1 = tf.keras.utils.to_categorical(y_anli_r1)
y_encoded_anli_r2 = tf.keras.utils.to_categorical(y_anli_r2)
y_encoded_anli_r3 = tf.keras.utils.to_categorical(y_anli_r3)

# %%
X_snli_rnn = X_snli.reshape(X_snli.shape[0], 1, X_snli.shape[1])
X_mnli_matched_rnn = X_mnli_matched.reshape(X_mnli_matched.shape[0], 1, X_mnli_matched.shape[1])
X_mnli_mismatched_rnn = X_mnli_mismatched.reshape(X_mnli_mismatched.shape[0], 1, X_mnli_mismatched.shape[1])
X_anli_r1_rnn = X_anli_r1.reshape(X_anli_r1.shape[0], 1, X_anli_r1.shape[1])
X_anli_r2_rnn = X_anli_r2.reshape(X_anli_r2.shape[0], 1, X_anli_r2.shape[1])
X_anli_r3_rnn = X_anli_r3.reshape(X_anli_r3.shape[0], 1, X_anli_r3.shape[1])

# %%
# Reshape feature arrays to match the RNN input shape
features_snli = features_snli.reshape(features_snli.shape[0], 1, features_snli.shape[1])
features_mnli_matched = features_mnli_matched.reshape(features_mnli_matched.shape[0], 1, features_mnli_matched.shape[1])
features_mnli_mismatched = features_mnli_mismatched.reshape(features_mnli_mismatched.shape[0], 1, features_mnli_mismatched.shape[1])
features_anli_r1 = features_anli_r1.reshape(features_anli_r1.shape[0], 1, features_anli_r1.shape[1])
features_anli_r2 = features_anli_r2.reshape(features_anli_r2.shape[0], 1, features_anli_r2.shape[1])
features_anli_r3 = features_anli_r3.reshape(features_anli_r3.shape[0], 1, features_anli_r3.shape[1])

# %%
features_snli.shape
# Out:
# (6032, 1, 3)

# %%
X_snli_rnn
# Out:
# array([[[9.9878270e-01, 7.6433434e-04, 4.5297167e-04, ...,
#          4.6765395e-03, 6.0480673e-02, 9.3484277e-01]],
#
#        [[5.0442386e-04, 4.3001700e-03, 9.9519530e-01, ...,
#          9.7817034e-01, 2.1051416e-02, 7.7824460e-04]],
#
#        [[9.8957914e-01, 5.4418677e-03, 4.9790350e-03, ...,
#          8.5550435e-02, 7.5036585e-02, 8.3941300e-01]],
#
#        ...,
#
#        [[7.0376875e-04, 9.7931010e-03, 9.8950315e-01, ...,
#          8.9463750e-01, 1.0409502e-01, 1.2674012e-03]],
#
#        [[9.9917114e-01, 4.9286430e-04, 3.3603658e-04, ...,
#          8.3751883e-04, 2.6697412e-03, 9.9649280e-01]],
#
#        [[2.6664520e-04, 2.1777824e-03, 9.9755560e-01, ...,
#          9.8434700e-01, 1.5223468e-02, 4.2961346e-04]]])

# %%
X_snli_rnn.shape
# Out:
# (6032, 1, 9)

# %%
from sklearn.model_selection import train_test_split

def prepare_data_splits(X_rnn, features, y_encoded, test_size=0.1, random_state=42):
    # Split the data for the RNN inputs
    X_train_rnn, X_val_rnn, y_train, y_val = train_test_split(
        X_rnn, y_encoded, test_size=test_size, random_state=random_state, stratify=y_encoded)

    # Split the data for the additional features
    features_train, features_val, _, _ = train_test_split(
        features, y_encoded, test_size=test_size, random_state=random_state, stratify=y_encoded)

    return X_train_rnn, X_val_rnn, features_train, features_val, y_train, y_val

# Example for SNLI data
X_train_snli_rnn, X_val_snli_rnn, features_train_snli, features_val_snli, y_train_snli, y_val_snli = prepare_data_splits(X_snli_rnn, features_snli, y_encoded_snli)
# Example for MNLI-m data
X_train_mnli_matched_rnn, X_val_mnli_matched_rnn, features_train_mnli_matched, features_val_mnli_matched, y_train_mnli_matched, y_val_mnli_matched = prepare_data_splits(X_mnli_matched_rnn, features_mnli_matched, y_encoded_mnli_matched)
# Example for MNLI-mm data
X_train_mnli_mismatched_rnn, X_val_mnli_mismatched_rnn, features_train_mnli_mismatched, features_val_mnli_mismatched, y_train_mnli_mismatched, y_val_mnli_mismatched = prepare_data_splits(X_mnli_mismatched_rnn, features_mnli_mismatched, y_encoded_mnli_mismatched)
# Example for ANLI round 1 data
X_train_anli_r1_rnn, X_val_anli_r1_rnn, features_train_anli_r1, features_val_anli_r1, y_train_anli_r1, y_val_anli_r1 = prepare_data_splits(X_anli_r1_rnn, features_anli_r1, y_encoded_anli_r1)
# Example for ANLI round 2 data
X_train_anli_r2_rnn, X_val_anli_r2_rnn, features_train_anli_r2, features_val_anli_r2, y_train_anli_r2, y_val_anli_r2 = prepare_data_splits(X_anli_r2_rnn, features_anli_r2, y_encoded_anli_r2)
# Example for ANLI round 3 data
X_train_anli_r3_rnn, X_val_anli_r3_rnn, features_train_anli_r3, features_val_anli_r3, y_train_anli_r3, y_val_anli_r3 = prepare_data_splits(X_anli_r3_rnn, features_anli_r3, y_encoded_anli_r3)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, Concatenate, Flatten, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping

def build_and_train_bidirectional_lstm_model(X_train_rnn, features_train, y_train, X_val_rnn, features_val, y_val, epochs=20, batch_size=32):
    sequence_input_shape = X_train_rnn.shape[1:]
    features_input_shape = features_train.shape[1:]

    sequence_input = Input(shape=sequence_input_shape, name='sequence_input')
    # Wrap the LSTM in a Bidirectional wrapper
    bi_lstm = Bidirectional(LSTM(64, return_sequences=False))(sequence_input)
    bi_lstm = Dropout(0.5)(bi_lstm)

    features_input = Input(shape=features_input_shape, name='features_input')
    features_layer = Dense(32, activation='relu')(features_input)
    features_layer = Dropout(0.2)(features_layer)
    features_layer = Flatten()(features_layer)

    concatenated = Concatenate()([bi_lstm, features_layer])
    output = Dense(3, activation='softmax')(concatenated)

    model = Model(inputs=[sequence_input, features_input], outputs=output)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    early_stopping = EarlyStopping(monitor='val_loss', patience=3)

    history = model.fit(
        [X_train_rnn, features_train], y_train,
        validation_data=([X_val_rnn, features_val], y_val),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=[early_stopping]
    )

    evaluation = model.evaluate([X_val_rnn, features_val], y_val, verbose=1)
    return model, history, evaluation

# %%
# Training and evaluation for the SNLI data with LSTM
model_snli_lstm, history_snli_lstm, evaluation_snli_lstm = build_and_train_bidirectional_lstm_model(
    X_train_snli_rnn, features_train_snli, y_train_snli, 
    X_val_snli_rnn, features_val_snli, y_val_snli, 
    epochs=20, batch_size=32
)

print("Evaluation on SNLI Validation Data with LSTM:", evaluation_snli_lstm)
print("History keys:", history_snli_lstm.history.keys())
# Out:
# Epoch 1/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8263 - loss: 0.6702 - val_accuracy: 0.9536 - val_loss: 0.1585
# Epoch 2/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9548 - loss: 0.1574 - val_accuracy: 0.9603 - val_loss: 0.1279
# Epoch 3/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9586 - loss: 0.1566 - val_accuracy: 0.9636 - val_loss: 0.1194
# Epoch 4/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9604 - loss: 0.1369 - val_accuracy: 0.9636 - val_loss: 0.1180
# Epoch 5/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9622 - loss: 0.1263 - val_accuracy: 0.9619 - val_loss: 0.1179
# Epoch 6/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9598 - loss: 0.1441 - val_accuracy: 0.9636 - val_loss: 0.1175
# Epoch 7/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9643 - loss: 0.1309 - val_accuracy: 0.9652 - val_loss: 0.1171
# Epoch 8/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9612 - loss: 0.1352 - val_accuracy: 0.9619 - val_loss: 0.1174
# Epoch 9/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9570 - loss: 0.1467 - val_accuracy: 0.9619 - val_loss: 0.1174
# Epoch 10/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9635 - loss: 0.1384 - val_accuracy: 0.9636 - val_loss: 0.1170
# Epoch 11/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9593 - loss: 0.1406 - val_accuracy: 0.9636 - val_loss: 0.1172
# Epoch 12/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9580 - loss: 0.1444 - val_accuracy: 0.9619 - val_loss: 0.1178
# Epoch 13/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9617 - loss: 0.1295 - val_accuracy: 0.9636 - val_loss: 0.1179
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9610 - loss: 0.1071
# Evaluation on SNLI Validation Data with LSTM: [0.11785892397165298, 0.9635761380195618]
# History keys: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Train and evaluate LSTM model on MNLI Matched data
model_mnli_matched_lstm, history_mnli_matched_lstm, evaluation_mnli_matched_lstm = build_and_train_bidirectional_lstm_model(
    X_train_mnli_matched_rnn, features_train_mnli_matched, y_train_mnli_matched,
    X_val_mnli_matched_rnn, features_val_mnli_matched, y_val_mnli_matched,
    epochs=20, batch_size=32
)

print("Evaluation on MNLI Matched Validation Data with LSTM:", evaluation_mnli_matched_lstm)
print("History keys:", history_mnli_matched_lstm.history.keys())
# Out:
# Epoch 1/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8033 - loss: 0.6671 - val_accuracy: 0.9659 - val_loss: 0.1552
# Epoch 2/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9644 - loss: 0.1558 - val_accuracy: 0.9659 - val_loss: 0.1389
# Epoch 3/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9626 - loss: 0.1512 - val_accuracy: 0.9659 - val_loss: 0.1326
# Epoch 4/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9585 - loss: 0.1627 - val_accuracy: 0.9659 - val_loss: 0.1291
# Epoch 5/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9650 - loss: 0.1459 - val_accuracy: 0.9693 - val_loss: 0.1261
# Epoch 6/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9643 - loss: 0.1407 - val_accuracy: 0.9693 - val_loss: 0.1251
# Epoch 7/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9656 - loss: 0.1357 - val_accuracy: 0.9693 - val_loss: 0.1244
# Epoch 8/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9700 - loss: 0.1217 - val_accuracy: 0.9710 - val_loss: 0.1243
# Epoch 9/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9630 - loss: 0.1397 - val_accuracy: 0.9693 - val_loss: 0.1241
# Epoch 10/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9661 - loss: 0.1343 - val_accuracy: 0.9693 - val_loss: 0.1241
# Epoch 11/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9678 - loss: 0.1327 - val_accuracy: 0.9710 - val_loss: 0.1236
# Epoch 12/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9677 - loss: 0.1300 - val_accuracy: 0.9693 - val_loss: 0.1246
# Epoch 13/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9608 - loss: 0.1499 - val_accuracy: 0.9693 - val_loss: 0.1236
# Epoch 14/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9663 - loss: 0.1397 - val_accuracy: 0.9710 - val_loss: 0.1239
# Epoch 15/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9670 - loss: 0.1341 - val_accuracy: 0.9710 - val_loss: 0.1232
# Epoch 16/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9676 - loss: 0.1323 - val_accuracy: 0.9727 - val_loss: 0.1236
# Epoch 17/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9680 - loss: 0.1319 - val_accuracy: 0.9710 - val_loss: 0.1232
# Epoch 18/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9618 - loss: 0.1418 - val_accuracy: 0.9693 - val_loss: 0.1237
# Epoch 19/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9676 - loss: 0.1241 - val_accuracy: 0.9727 - val_loss: 0.1235
# Epoch 20/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9664 - loss: 0.1342 - val_accuracy: 0.9710 - val_loss: 0.1232
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9686 - loss: 0.1436
# Evaluation on MNLI Matched Validation Data with LSTM: [0.12320856004953384, 0.9709897637367249]
# History keys: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Train and evaluate LSTM model on MNLI Mismatched data
model_mnli_mismatched_lstm, history_mnli_mismatched_lstm, evaluation_mnli_mismatched_lstm = build_and_train_bidirectional_lstm_model(
    X_train_mnli_mismatched_rnn, features_train_mnli_mismatched, y_train_mnli_mismatched,
    X_val_mnli_mismatched_rnn, features_val_mnli_mismatched, y_val_mnli_mismatched,
    epochs=20, batch_size=32
)

print("Evaluation on MNLI Mismatched Validation Data with LSTM:", evaluation_mnli_mismatched_lstm)

print("History keys:", history_mnli_mismatched_lstm.history.keys())
# Out:
# Epoch 1/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8567 - loss: 0.6157 - val_accuracy: 0.9628 - val_loss: 0.1618
# Epoch 2/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9666 - loss: 0.1376 - val_accuracy: 0.9628 - val_loss: 0.1513
# Epoch 3/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9684 - loss: 0.1207 - val_accuracy: 0.9628 - val_loss: 0.1489
# Epoch 4/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9693 - loss: 0.1162 - val_accuracy: 0.9628 - val_loss: 0.1486
# Epoch 5/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9643 - loss: 0.1305 - val_accuracy: 0.9628 - val_loss: 0.1489
# Epoch 6/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9674 - loss: 0.1188 - val_accuracy: 0.9645 - val_loss: 0.1491
# Epoch 7/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9643 - loss: 0.1291 - val_accuracy: 0.9645 - val_loss: 0.1496
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9504 - loss: 0.1892
# Evaluation on MNLI Mismatched Validation Data with LSTM: [0.14961394667625427, 0.9644669890403748]
# History keys: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Train and evaluate LSTM model on ANLI Round 1 data
model_anli_r1_lstm, history_anli_r1_lstm, evaluation_anli_r1_lstm = build_and_train_bidirectional_lstm_model(
    X_train_anli_r1_rnn, features_train_anli_r1, y_train_anli_r1,
    X_val_anli_r1_rnn, features_val_anli_r1, y_val_anli_r1,
    epochs=20, batch_size=32
)
print("Evaluation on ANLI Round 1 Validation Data with LSTM:", evaluation_anli_r1_lstm)

print("History keys:", history_anli_r1_lstm.history.keys())
# Out:
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.5680 - loss: 1.0601 - val_accuracy: 0.7209 - val_loss: 0.9809
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7041 - loss: 0.9838 - val_accuracy: 0.7209 - val_loss: 0.9047
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6724 - loss: 0.9199 - val_accuracy: 0.6744 - val_loss: 0.8350
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7304 - loss: 0.8471 - val_accuracy: 0.6512 - val_loss: 0.7688
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7427 - loss: 0.7728 - val_accuracy: 0.6744 - val_loss: 0.7085
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7826 - loss: 0.7169 - val_accuracy: 0.6977 - val_loss: 0.6579
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8168 - loss: 0.6471 - val_accuracy: 0.6977 - val_loss: 0.6152
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8057 - loss: 0.6148 - val_accuracy: 0.7209 - val_loss: 0.5852
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8203 - loss: 0.5784 - val_accuracy: 0.7442 - val_loss: 0.5653
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7865 - loss: 0.5898 - val_accuracy: 0.7442 - val_loss: 0.5485
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8031 - loss: 0.5606 - val_accuracy: 0.7442 - val_loss: 0.5356
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7872 - loss: 0.5276 - val_accuracy: 0.7442 - val_loss: 0.5269
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8196 - loss: 0.5158 - val_accuracy: 0.7442 - val_loss: 0.5243
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8115 - loss: 0.4835 - val_accuracy: 0.7442 - val_loss: 0.5160
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7833 - loss: 0.5196 - val_accuracy: 0.7442 - val_loss: 0.5163
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8460 - loss: 0.4663 - val_accuracy: 0.7442 - val_loss: 0.5118
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8227 - loss: 0.5085 - val_accuracy: 0.7442 - val_loss: 0.5122
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8183 - loss: 0.5170 - val_accuracy: 0.7442 - val_loss: 0.5124
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8242 - loss: 0.4718 - val_accuracy: 0.7442 - val_loss: 0.5132
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7461 - loss: 0.5707
# Evaluation on ANLI Round 1 Validation Data with LSTM: [0.5132185220718384, 0.7441860437393188]
# History keys: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Train and evaluate LSTM model on ANLI Round 2 data
model_anli_r2_lstm, history_anli_r2_lstm, evaluation_anli_r2_lstm = build_and_train_bidirectional_lstm_model(
    X_train_anli_r2_rnn, features_train_anli_r2, y_train_anli_r2,
    X_val_anli_r2_rnn, features_val_anli_r2, y_val_anli_r2,
    epochs=20, batch_size=32
)

print("Evaluation on ANLI Round 2 Validation Data with LSTM:", evaluation_anli_r2_lstm)

print("History keys:", history_anli_r2_lstm.history.keys())
# Out:
# Epoch 1/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.3215 - loss: 1.1017 - val_accuracy: 0.5556 - val_loss: 1.0426
# Epoch 2/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6419 - loss: 1.0209 - val_accuracy: 0.6667 - val_loss: 0.9871
# Epoch 3/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6551 - loss: 0.9693 - val_accuracy: 0.6889 - val_loss: 0.9364
# Epoch 4/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6771 - loss: 0.9230 - val_accuracy: 0.6667 - val_loss: 0.8885
# Epoch 5/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6610 - loss: 0.8833 - val_accuracy: 0.6667 - val_loss: 0.8444
# Epoch 6/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7070 - loss: 0.8067 - val_accuracy: 0.6667 - val_loss: 0.8060
# Epoch 7/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6701 - loss: 0.7948 - val_accuracy: 0.7111 - val_loss: 0.7729
# Epoch 8/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7233 - loss: 0.7720 - val_accuracy: 0.7111 - val_loss: 0.7483
# Epoch 9/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7147 - loss: 0.7323 - val_accuracy: 0.7556 - val_loss: 0.7273
# Epoch 10/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7204 - loss: 0.7099 - val_accuracy: 0.7556 - val_loss: 0.7111
# Epoch 11/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7119 - loss: 0.7338 - val_accuracy: 0.7556 - val_loss: 0.6991
# Epoch 12/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7287 - loss: 0.6870 - val_accuracy: 0.7778 - val_loss: 0.6887
# Epoch 13/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7046 - loss: 0.7453 - val_accuracy: 0.7778 - val_loss: 0.6817
# Epoch 14/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7370 - loss: 0.7127 - val_accuracy: 0.7778 - val_loss: 0.6746
# Epoch 15/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7453 - loss: 0.6839 - val_accuracy: 0.7778 - val_loss: 0.6722
# Epoch 16/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7692 - loss: 0.6675 - val_accuracy: 0.7778 - val_loss: 0.6702
# Epoch 17/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7169 - loss: 0.6960 - val_accuracy: 0.7778 - val_loss: 0.6661
# Epoch 18/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7089 - loss: 0.7080 - val_accuracy: 0.7778 - val_loss: 0.6648
# Epoch 19/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7393 - loss: 0.6682 - val_accuracy: 0.7778 - val_loss: 0.6659
# Epoch 20/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7307 - loss: 0.6822 - val_accuracy: 0.7778 - val_loss: 0.6642
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7789 - loss: 0.6566
# Evaluation on ANLI Round 2 Validation Data with LSTM: [0.6642270088195801, 0.7777777910232544]
# History keys: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Train and evaluate LSTM model on ANLI Round 3 data
model_anli_r3_lstm, history_anli_r3_lstm, evaluation_anli_r3_lstm = build_and_train_bidirectional_lstm_model(
    X_train_anli_r3_rnn, features_train_anli_r3, y_train_anli_r3,
    X_val_anli_r3_rnn, features_val_anli_r3, y_val_anli_r3,
    epochs=20, batch_size=32
)


print("Evaluation on ANLI Round 3 Validation Data with LSTM:", evaluation_anli_r3_lstm)
print("History keys:", history_anli_r3_lstm.history.keys())
# Out:
# Epoch 1/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.4427 - loss: 1.0740 - val_accuracy: 0.6226 - val_loss: 1.0035
# Epoch 2/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5824 - loss: 0.9956 - val_accuracy: 0.6604 - val_loss: 0.9327
# Epoch 3/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6254 - loss: 0.9254 - val_accuracy: 0.6604 - val_loss: 0.8751
# Epoch 4/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6672 - loss: 0.8500 - val_accuracy: 0.6604 - val_loss: 0.8237
# Epoch 5/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6559 - loss: 0.8129 - val_accuracy: 0.6604 - val_loss: 0.7836
# Epoch 6/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6662 - loss: 0.7817 - val_accuracy: 0.6981 - val_loss: 0.7539
# Epoch 7/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6493 - loss: 0.7655 - val_accuracy: 0.6792 - val_loss: 0.7340
# Epoch 8/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7017 - loss: 0.7195 - val_accuracy: 0.6792 - val_loss: 0.7196
# Epoch 9/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7246 - loss: 0.6967 - val_accuracy: 0.6792 - val_loss: 0.7078
# Epoch 10/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7323 - loss: 0.6668 - val_accuracy: 0.6792 - val_loss: 0.6987
# Epoch 11/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7313 - loss: 0.6599 - val_accuracy: 0.6792 - val_loss: 0.6914
# Epoch 12/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7068 - loss: 0.6845 - val_accuracy: 0.6792 - val_loss: 0.6912
# Epoch 13/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7498 - loss: 0.6509 - val_accuracy: 0.6792 - val_loss: 0.6843
# Epoch 14/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7374 - loss: 0.6465 - val_accuracy: 0.6981 - val_loss: 0.6793
# Epoch 15/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7286 - loss: 0.6698 - val_accuracy: 0.6981 - val_loss: 0.6771
# Epoch 16/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7073 - loss: 0.6914 - val_accuracy: 0.6604 - val_loss: 0.6751
# Epoch 17/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7075 - loss: 0.6923 - val_accuracy: 0.6792 - val_loss: 0.6746
# Epoch 18/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7233 - loss: 0.6660 - val_accuracy: 0.6604 - val_loss: 0.6709
# Epoch 19/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7319 - loss: 0.6807 - val_accuracy: 0.6792 - val_loss: 0.6689
# Epoch 20/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7545 - loss: 0.6327 - val_accuracy: 0.6792 - val_loss: 0.6690
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7028 - loss: 0.6263
# Evaluation on ANLI Round 3 Validation Data with LSTM: [0.6690266132354736, 0.6792452931404114]
# History keys: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Combining all datasets for a comprehensive training set
X_rnn_all_tasks = np.concatenate([
    X_snli_rnn, X_mnli_matched_rnn, X_mnli_mismatched_rnn,
    X_anli_r1_rnn, X_anli_r2_rnn, X_anli_r3_rnn
])

features_all_tasks = np.concatenate([
    features_snli, features_mnli_matched, features_mnli_mismatched,
    features_anli_r1, features_anli_r2, features_anli_r3
])

y_encoded_all_tasks = np.concatenate([
    y_encoded_snli, y_encoded_mnli_matched, y_encoded_mnli_mismatched,
    y_encoded_anli_r1, y_encoded_anli_r2, y_encoded_anli_r3
])

# Prepare data splits for combined dataset
X_train_all_rnn, X_val_all_rnn, features_train_all, features_val_all, y_train_all, y_val_all = prepare_data_splits(
    X_rnn_all_tasks, features_all_tasks, y_encoded_all_tasks
)

# Train and evaluate the LSTM model using the combined data from all tasks
model_all, history_all, evaluation_all = build_and_train_bidirectional_lstm_model(
    X_train_all_rnn, features_train_all, y_train_all,
    X_val_all_rnn, features_val_all, y_val_all,
    epochs=20, batch_size=32
)

print("Evaluation on All Tasks Validation Data with LSTM:", evaluation_all)
print("History keys:", history_all.history.keys())
# Out:
# Epoch 1/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9247 - loss: 0.4072 - val_accuracy: 0.9453 - val_loss: 0.1722
# Epoch 2/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9472 - loss: 0.1816 - val_accuracy: 0.9479 - val_loss: 0.1718
# Epoch 3/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9476 - loss: 0.1805 - val_accuracy: 0.9490 - val_loss: 0.1716
# Epoch 4/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9495 - loss: 0.1733 - val_accuracy: 0.9479 - val_loss: 0.1708
# Epoch 5/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9456 - loss: 0.1829 - val_accuracy: 0.9495 - val_loss: 0.1711
# Epoch 6/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9488 - loss: 0.1722 - val_accuracy: 0.9495 - val_loss: 0.1705
# Epoch 7/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9463 - loss: 0.1805 - val_accuracy: 0.9469 - val_loss: 0.1705
# Epoch 8/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9491 - loss: 0.1757 - val_accuracy: 0.9469 - val_loss: 0.1701
# Epoch 9/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9461 - loss: 0.1814 - val_accuracy: 0.9484 - val_loss: 0.1694
# Epoch 10/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9474 - loss: 0.1803 - val_accuracy: 0.9484 - val_loss: 0.1699
# Epoch 11/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9456 - loss: 0.1853 - val_accuracy: 0.9479 - val_loss: 0.1699
# Epoch 12/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9466 - loss: 0.1778 - val_accuracy: 0.9484 - val_loss: 0.1696
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9474 - loss: 0.1615
# Evaluation on All Tasks Validation Data with LSTM: [0.16962195932865143, 0.948437511920929]
# History keys: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# After training the model
model_all.save('biLSTM_feature_ensemble.h5')  # Saves the model in HDF5 format
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 2
#       1 # After training the model
# ----> 2 model_all.save('biLSTM_feature_ensemble.h5')  # Saves the model in HDF5 format
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:123, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     120     filtered_tb = _process_traceback_frames(e.__traceback__)
#     121     # To get the full stack trace, call:
#     122     # `keras.config.disable_traceback_filtering()`
# --> 123     raise e.with_traceback(filtered_tb) from None
#     124 finally:
#     125     del filtered_tb
#
# File /opt/conda/lib/python3.10/site-packages/h5py/_hl/group.py:183, in Group.create_dataset(self, name, shape, dtype, data, **kwds)
#     180         parent_path, name = name.rsplit(b'/', 1)
#     181         group = self.require_group(parent_path)
# --> 183 dsid = dataset.make_new_dset(group, shape, dtype, data, name, **kwds)
#     184 dset = dataset.Dataset(dsid)
#     185 return dset
#
# File /opt/conda/lib/python3.10/site-packages/h5py/_hl/dataset.py:163, in make_new_dset(parent, shape, dtype, data, name, chunks, compression, shuffle, fletcher32, maxshape, compression_opts, fillvalue, scaleoffset, track_times, external, track_order, dcpl, dapl, efile_prefix, virtual_prefix, allow_unknown_filter, rdcc_nslots, rdcc_nbytes, rdcc_w0)
#     160 else:
#     161     sid = h5s.create_simple(shape, maxshape)
# --> 163 dset_id = h5d.create(parent.id, name, tid, sid, dcpl=dcpl, dapl=dapl)
#     165 if (data is not None) and (not isinstance(data, Empty)):
#     166     dset_id.write(h5s.ALL, h5s.ALL, data)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5d.pyx:137, in h5py.h5d.create()
#
# ValueError: Unable to synchronously create dataset (name already exists)

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    plt.show()

plot_training_history(history_snli_lstm)

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    plt.show()

plot_training_history(history_mnli_matched_lstm)

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    plt.show()

plot_training_history(history_mnli_mismatched_lstm)

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    plt.show()

plot_training_history(history_anli_r1_lstm)

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    plt.show()

plot_training_history(history_anli_r2_lstm)

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    plt.show()

plot_training_history(history_anli_r3_lstm)

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    plt.show()

plot_training_history(history_all)

# %%
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, Concatenate, Flatten, Bidirectional
from tensorflow.keras.models import Model
from sklearn.model_selection import StratifiedKFold


# Function to build the Bidirectional LSTM model
def create_bidirectional_lstm_model(sequence_input_shape, features_input_shape):
    sequence_input = Input(shape=sequence_input_shape, name='sequence_input')
    bi_lstm = Bidirectional(LSTM(64, return_sequences=False))(sequence_input)
    bi_lstm = Dropout(0.5)(bi_lstm)

    features_input = Input(shape=features_input_shape, name='features_input')
    features = Dense(32, activation='relu')(features_input)
    features = Dropout(0.2)(features)
    features = Flatten()(features)

    concatenated = Concatenate()([bi_lstm, features])
    final_output = Dense(3, activation='softmax')(concatenated)

    model = Model(inputs=[sequence_input, features_input], outputs=final_output)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model



def cross_validate_bidirectional_lstm_model(X_rnn, features, y_encoded, num_folds=5):
    # Convert labels to single integers for stratified split
    y_single = np.argmax(y_encoded, axis=1)
    kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)
    fold_no = 1
    acc_per_fold = []
    loss_per_fold = []
    histories = []  # List to store history for each fold

    for train, test in kfold.split(X_rnn, y_single):
        X_train_rnn, X_test_rnn = X_rnn[train], X_rnn[test]
        features_train, features_test = features[train], features[test]
        y_train, y_test = y_encoded[train], y_encoded[test]

        model = create_bidirectional_lstm_model(X_train_rnn.shape[1:], features_train.shape[1:])

        print(f'Training on fold {fold_no}...')
        history = model.fit([X_train_rnn, features_train], y_train, epochs=20, batch_size=32, verbose=1, validation_data=([X_test_rnn, features_test], y_test))
        histories.append(history)

        scores = model.evaluate([X_test_rnn, features_test], y_test, verbose=0)
        print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
        acc_per_fold.append(scores[1] * 100)
        loss_per_fold.append(scores[0])

        fold_no += 1

    print('------------------------------------------------------------------------')
    print('Score per fold')
    for i in range(0, len(acc_per_fold)):
        print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
    print('------------------------------------------------------------------------')
    print('Average scores for all folds:')
    print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
    print(f'> Loss: {np.mean(loss_per_fold)}')
    print('------------------------------------------------------------------------')
    
    return histories

# %%
histories_snli = cross_validate_bidirectional_lstm_model(X_snli_rnn, features_snli, y_encoded_snli)
# Out:
# Training on fold 1...
# Epoch 1/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9033 - loss: 0.6453 - val_accuracy: 0.9544 - val_loss: 0.1598
# Epoch 2/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9517 - loss: 0.1686 - val_accuracy: 0.9569 - val_loss: 0.1285
# Epoch 3/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9562 - loss: 0.1469 - val_accuracy: 0.9635 - val_loss: 0.1181
# Epoch 4/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9576 - loss: 0.1524 - val_accuracy: 0.9635 - val_loss: 0.1161
# Epoch 5/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9638 - loss: 0.1265 - val_accuracy: 0.9660 - val_loss: 0.1167
# Epoch 6/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9610 - loss: 0.1495 - val_accuracy: 0.9635 - val_loss: 0.1155
# Epoch 7/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9605 - loss: 0.1432 - val_accuracy: 0.9644 - val_loss: 0.1160
# Epoch 8/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9627 - loss: 0.1319 - val_accuracy: 0.9611 - val_loss: 0.1182
# Epoch 9/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9627 - loss: 0.1336 - val_accuracy: 0.9619 - val_loss: 0.1160
# Epoch 10/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9565 - loss: 0.1517 - val_accuracy: 0.9644 - val_loss: 0.1161
# Epoch 11/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9590 - loss: 0.1462 - val_accuracy: 0.9652 - val_loss: 0.1170
# Epoch 12/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9624 - loss: 0.1389 - val_accuracy: 0.9619 - val_loss: 0.1163
# Epoch 13/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9673 - loss: 0.1223 - val_accuracy: 0.9644 - val_loss: 0.1178
# Epoch 14/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9554 - loss: 0.1479 - val_accuracy: 0.9644 - val_loss: 0.1171
# Epoch 15/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9642 - loss: 0.1398 - val_accuracy: 0.9627 - val_loss: 0.1160
# Epoch 16/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9631 - loss: 0.1406 - val_accuracy: 0.9635 - val_loss: 0.1173
# Epoch 17/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9622 - loss: 0.1359 - val_accuracy: 0.9619 - val_loss: 0.1181
# Epoch 18/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9633 - loss: 0.1382 - val_accuracy: 0.9619 - val_loss: 0.1175
# Epoch 19/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9596 - loss: 0.1394 - val_accuracy: 0.9644 - val_loss: 0.1190
# Epoch 20/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9614 - loss: 0.1443 - val_accuracy: 0.9635 - val_loss: 0.1174
# Score for fold 1: loss of 0.11736833304166794; compile_metrics of 96.35459780693054%
# Training on fold 2...
# Epoch 1/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8384 - loss: 0.6587 - val_accuracy: 0.9544 - val_loss: 0.1653
# Epoch 2/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9531 - loss: 0.1645 - val_accuracy: 0.9544 - val_loss: 0.1368
# Epoch 3/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9504 - loss: 0.1707 - val_accuracy: 0.9644 - val_loss: 0.1269
# Epoch 4/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9648 - loss: 0.1359 - val_accuracy: 0.9619 - val_loss: 0.1239
# Epoch 5/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9637 - loss: 0.1263 - val_accuracy: 0.9611 - val_loss: 0.1236
# Epoch 6/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9624 - loss: 0.1384 - val_accuracy: 0.9602 - val_loss: 0.1234
# Epoch 7/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9607 - loss: 0.1366 - val_accuracy: 0.9611 - val_loss: 0.1225
# Epoch 8/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9569 - loss: 0.1472 - val_accuracy: 0.9611 - val_loss: 0.1231
# Epoch 9/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9616 - loss: 0.1353 - val_accuracy: 0.9602 - val_loss: 0.1228
# Epoch 10/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9624 - loss: 0.1416 - val_accuracy: 0.9611 - val_loss: 0.1233
# Epoch 11/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9592 - loss: 0.1437 - val_accuracy: 0.9602 - val_loss: 0.1234
# Epoch 12/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9623 - loss: 0.1468 - val_accuracy: 0.9602 - val_loss: 0.1229
# Epoch 13/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9615 - loss: 0.1501 - val_accuracy: 0.9627 - val_loss: 0.1220
# Epoch 14/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9654 - loss: 0.1274 - val_accuracy: 0.9602 - val_loss: 0.1227
# Epoch 15/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9646 - loss: 0.1296 - val_accuracy: 0.9611 - val_loss: 0.1222
# Epoch 16/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9635 - loss: 0.1250 - val_accuracy: 0.9602 - val_loss: 0.1229
# Epoch 17/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9630 - loss: 0.1315 - val_accuracy: 0.9635 - val_loss: 0.1221
# Epoch 18/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9623 - loss: 0.1345 - val_accuracy: 0.9627 - val_loss: 0.1219
# Epoch 19/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9631 - loss: 0.1360 - val_accuracy: 0.9619 - val_loss: 0.1220
# Epoch 20/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9598 - loss: 0.1426 - val_accuracy: 0.9619 - val_loss: 0.1219
# Score for fold 2: loss of 0.1219397485256195; compile_metrics of 96.18889689445496%
# Training on fold 3...
# Epoch 1/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8439 - loss: 0.6367 - val_accuracy: 0.9527 - val_loss: 0.1758
# Epoch 2/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9502 - loss: 0.1691 - val_accuracy: 0.9536 - val_loss: 0.1510
# Epoch 3/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9622 - loss: 0.1361 - val_accuracy: 0.9627 - val_loss: 0.1440
# Epoch 4/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9606 - loss: 0.1431 - val_accuracy: 0.9619 - val_loss: 0.1427
# Epoch 5/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9622 - loss: 0.1313 - val_accuracy: 0.9619 - val_loss: 0.1430
# Epoch 6/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9610 - loss: 0.1396 - val_accuracy: 0.9594 - val_loss: 0.1455
# Epoch 7/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9634 - loss: 0.1340 - val_accuracy: 0.9602 - val_loss: 0.1440
# Epoch 8/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9576 - loss: 0.1456 - val_accuracy: 0.9619 - val_loss: 0.1442
# Epoch 9/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9657 - loss: 0.1252 - val_accuracy: 0.9602 - val_loss: 0.1429
# Epoch 10/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9662 - loss: 0.1293 - val_accuracy: 0.9594 - val_loss: 0.1430
# Epoch 11/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9556 - loss: 0.1382 - val_accuracy: 0.9610 - val_loss: 0.1426
# Epoch 12/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9622 - loss: 0.1383 - val_accuracy: 0.9643 - val_loss: 0.1427
# Epoch 13/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9602 - loss: 0.1350 - val_accuracy: 0.9602 - val_loss: 0.1428
# Epoch 14/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9674 - loss: 0.1182 - val_accuracy: 0.9594 - val_loss: 0.1429
# Epoch 15/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9633 - loss: 0.1274 - val_accuracy: 0.9585 - val_loss: 0.1422
# Epoch 16/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9602 - loss: 0.1372 - val_accuracy: 0.9594 - val_loss: 0.1423
# Epoch 17/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9611 - loss: 0.1338 - val_accuracy: 0.9602 - val_loss: 0.1422
# Epoch 18/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9672 - loss: 0.1247 - val_accuracy: 0.9594 - val_loss: 0.1424
# Epoch 19/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9623 - loss: 0.1242 - val_accuracy: 0.9585 - val_loss: 0.1430
# Epoch 20/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9673 - loss: 0.1245 - val_accuracy: 0.9610 - val_loss: 0.1419
# Score for fold 3: loss of 0.14190968871116638; compile_metrics of 96.10282182693481%
# Training on fold 4...
# Epoch 1/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8342 - loss: 0.6387 - val_accuracy: 0.9536 - val_loss: 0.1742
# Epoch 2/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9571 - loss: 0.1552 - val_accuracy: 0.9585 - val_loss: 0.1500
# Epoch 3/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9605 - loss: 0.1399 - val_accuracy: 0.9635 - val_loss: 0.1420
# Epoch 4/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9621 - loss: 0.1352 - val_accuracy: 0.9619 - val_loss: 0.1429
# Epoch 5/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9675 - loss: 0.1098 - val_accuracy: 0.9610 - val_loss: 0.1402
# Epoch 6/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9611 - loss: 0.1395 - val_accuracy: 0.9619 - val_loss: 0.1410
# Epoch 7/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9566 - loss: 0.1450 - val_accuracy: 0.9619 - val_loss: 0.1413
# Epoch 8/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9620 - loss: 0.1401 - val_accuracy: 0.9610 - val_loss: 0.1398
# Epoch 9/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9616 - loss: 0.1303 - val_accuracy: 0.9627 - val_loss: 0.1401
# Epoch 10/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9599 - loss: 0.1334 - val_accuracy: 0.9619 - val_loss: 0.1399
# Epoch 11/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9567 - loss: 0.1528 - val_accuracy: 0.9627 - val_loss: 0.1413
# Epoch 12/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9593 - loss: 0.1512 - val_accuracy: 0.9627 - val_loss: 0.1405
# Epoch 13/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9652 - loss: 0.1266 - val_accuracy: 0.9610 - val_loss: 0.1391
# Epoch 14/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9660 - loss: 0.1257 - val_accuracy: 0.9619 - val_loss: 0.1390
# Epoch 15/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9651 - loss: 0.1184 - val_accuracy: 0.9627 - val_loss: 0.1395
# Epoch 16/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9634 - loss: 0.1299 - val_accuracy: 0.9619 - val_loss: 0.1402
# Epoch 17/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9580 - loss: 0.1444 - val_accuracy: 0.9619 - val_loss: 0.1394
# Epoch 18/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9671 - loss: 0.1229 - val_accuracy: 0.9619 - val_loss: 0.1388
# Epoch 19/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9631 - loss: 0.1340 - val_accuracy: 0.9619 - val_loss: 0.1410
# Epoch 20/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9602 - loss: 0.1455 - val_accuracy: 0.9627 - val_loss: 0.1413
# Score for fold 4: loss of 0.14132294058799744; compile_metrics of 96.2686538696289%
# Training on fold 5...
# Epoch 1/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8216 - loss: 0.6810 - val_accuracy: 0.9519 - val_loss: 0.1813
# Epoch 2/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9541 - loss: 0.1637 - val_accuracy: 0.9544 - val_loss: 0.1582
# Epoch 3/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9606 - loss: 0.1404 - val_accuracy: 0.9594 - val_loss: 0.1515
# Epoch 4/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9637 - loss: 0.1263 - val_accuracy: 0.9594 - val_loss: 0.1514
# Epoch 5/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9596 - loss: 0.1480 - val_accuracy: 0.9594 - val_loss: 0.1513
# Epoch 6/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9633 - loss: 0.1378 - val_accuracy: 0.9594 - val_loss: 0.1516
# Epoch 7/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9678 - loss: 0.1145 - val_accuracy: 0.9561 - val_loss: 0.1512
# Epoch 8/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9649 - loss: 0.1261 - val_accuracy: 0.9585 - val_loss: 0.1527
# Epoch 9/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9587 - loss: 0.1508 - val_accuracy: 0.9585 - val_loss: 0.1537
# Epoch 10/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9636 - loss: 0.1240 - val_accuracy: 0.9561 - val_loss: 0.1517
# Epoch 11/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9634 - loss: 0.1312 - val_accuracy: 0.9569 - val_loss: 0.1517
# Epoch 12/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9597 - loss: 0.1404 - val_accuracy: 0.9585 - val_loss: 0.1537
# Epoch 13/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9663 - loss: 0.1249 - val_accuracy: 0.9569 - val_loss: 0.1519
# Epoch 14/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9596 - loss: 0.1455 - val_accuracy: 0.9585 - val_loss: 0.1518
# Epoch 15/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9662 - loss: 0.1213 - val_accuracy: 0.9569 - val_loss: 0.1514
# Epoch 16/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9656 - loss: 0.1276 - val_accuracy: 0.9594 - val_loss: 0.1527
# Epoch 17/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9634 - loss: 0.1202 - val_accuracy: 0.9569 - val_loss: 0.1514
# Epoch 18/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9624 - loss: 0.1271 - val_accuracy: 0.9585 - val_loss: 0.1518
# Epoch 19/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9621 - loss: 0.1269 - val_accuracy: 0.9569 - val_loss: 0.1518
# Epoch 20/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9574 - loss: 0.1419 - val_accuracy: 0.9552 - val_loss: 0.1516
# Score for fold 5: loss of 0.15162700414657593; compile_metrics of 95.52238583564758%
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.11736833304166794 - Accuracy: 96.35459780693054%
# > Fold 2 - Loss: 0.1219397485256195 - Accuracy: 96.18889689445496%
# > Fold 3 - Loss: 0.14190968871116638 - Accuracy: 96.10282182693481%
# > Fold 4 - Loss: 0.14132294058799744 - Accuracy: 96.2686538696289%
# > Fold 5 - Loss: 0.15162700414657593 - Accuracy: 95.52238583564758%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 96.08747124671936 (+- 0.29462792337194943)
# > Loss: 0.13483354300260544
# ------------------------------------------------------------------------

# %%
histories_mnli_matched = cross_validate_bidirectional_lstm_model(X_mnli_matched_rnn, features_mnli_matched, y_encoded_mnli_matched)
# Out:
# Training on fold 1...
# Epoch 1/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8479 - loss: 0.6655 - val_accuracy: 0.9659 - val_loss: 0.1566
# Epoch 2/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9655 - loss: 0.1535 - val_accuracy: 0.9659 - val_loss: 0.1401
# Epoch 3/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9649 - loss: 0.1386 - val_accuracy: 0.9659 - val_loss: 0.1365
# Epoch 4/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9688 - loss: 0.1231 - val_accuracy: 0.9676 - val_loss: 0.1355
# Epoch 5/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9669 - loss: 0.1323 - val_accuracy: 0.9676 - val_loss: 0.1351
# Epoch 6/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9699 - loss: 0.1276 - val_accuracy: 0.9667 - val_loss: 0.1358
# Epoch 7/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9660 - loss: 0.1366 - val_accuracy: 0.9667 - val_loss: 0.1364
# Epoch 8/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9715 - loss: 0.1224 - val_accuracy: 0.9659 - val_loss: 0.1357
# Epoch 9/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9692 - loss: 0.1200 - val_accuracy: 0.9659 - val_loss: 0.1367
# Epoch 10/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9678 - loss: 0.1320 - val_accuracy: 0.9667 - val_loss: 0.1361
# Epoch 11/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9678 - loss: 0.1312 - val_accuracy: 0.9667 - val_loss: 0.1356
# Epoch 12/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9665 - loss: 0.1289 - val_accuracy: 0.9667 - val_loss: 0.1365
# Epoch 13/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9620 - loss: 0.1449 - val_accuracy: 0.9667 - val_loss: 0.1364
# Epoch 14/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9623 - loss: 0.1472 - val_accuracy: 0.9676 - val_loss: 0.1362
# Epoch 15/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9691 - loss: 0.1317 - val_accuracy: 0.9667 - val_loss: 0.1357
# Epoch 16/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9705 - loss: 0.1203 - val_accuracy: 0.9676 - val_loss: 0.1348
# Epoch 17/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9689 - loss: 0.1297 - val_accuracy: 0.9667 - val_loss: 0.1366
# Epoch 18/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9707 - loss: 0.1182 - val_accuracy: 0.9650 - val_loss: 0.1361
# Epoch 19/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9674 - loss: 0.1269 - val_accuracy: 0.9667 - val_loss: 0.1356
# Epoch 20/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9656 - loss: 0.1326 - val_accuracy: 0.9667 - val_loss: 0.1342
# Score for fold 1: loss of 0.13421855866909027; compile_metrics of 96.67235612869263%
# Training on fold 2...
# Epoch 1/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7879 - loss: 0.7012 - val_accuracy: 0.9633 - val_loss: 0.1648
# Epoch 2/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9679 - loss: 0.1433 - val_accuracy: 0.9633 - val_loss: 0.1511
# Epoch 3/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9657 - loss: 0.1386 - val_accuracy: 0.9633 - val_loss: 0.1465
# Epoch 4/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9661 - loss: 0.1328 - val_accuracy: 0.9624 - val_loss: 0.1447
# Epoch 5/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9627 - loss: 0.1509 - val_accuracy: 0.9641 - val_loss: 0.1454
# Epoch 6/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9658 - loss: 0.1400 - val_accuracy: 0.9633 - val_loss: 0.1441
# Epoch 7/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9670 - loss: 0.1230 - val_accuracy: 0.9650 - val_loss: 0.1426
# Epoch 8/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9690 - loss: 0.1241 - val_accuracy: 0.9650 - val_loss: 0.1424
# Epoch 9/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9648 - loss: 0.1361 - val_accuracy: 0.9641 - val_loss: 0.1444
# Epoch 10/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9652 - loss: 0.1488 - val_accuracy: 0.9658 - val_loss: 0.1426
# Epoch 11/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9679 - loss: 0.1212 - val_accuracy: 0.9641 - val_loss: 0.1429
# Epoch 12/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9646 - loss: 0.1342 - val_accuracy: 0.9650 - val_loss: 0.1428
# Epoch 13/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9704 - loss: 0.1183 - val_accuracy: 0.9641 - val_loss: 0.1419
# Epoch 14/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9614 - loss: 0.1478 - val_accuracy: 0.9641 - val_loss: 0.1425
# Epoch 15/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9674 - loss: 0.1282 - val_accuracy: 0.9650 - val_loss: 0.1415
# Epoch 16/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9668 - loss: 0.1293 - val_accuracy: 0.9650 - val_loss: 0.1411
# Epoch 17/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9638 - loss: 0.1399 - val_accuracy: 0.9641 - val_loss: 0.1419
# Epoch 18/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9638 - loss: 0.1390 - val_accuracy: 0.9650 - val_loss: 0.1430
# Epoch 19/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9680 - loss: 0.1235 - val_accuracy: 0.9658 - val_loss: 0.1407
# Epoch 20/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9675 - loss: 0.1275 - val_accuracy: 0.9650 - val_loss: 0.1416
# Score for fold 2: loss of 0.14159750938415527; compile_metrics of 96.49872183799744%
# Training on fold 3...
# Epoch 1/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8332 - loss: 0.6879 - val_accuracy: 0.9641 - val_loss: 0.1575
# Epoch 2/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9679 - loss: 0.1470 - val_accuracy: 0.9641 - val_loss: 0.1434
# Epoch 3/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9655 - loss: 0.1376 - val_accuracy: 0.9641 - val_loss: 0.1385
# Epoch 4/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9661 - loss: 0.1356 - val_accuracy: 0.9641 - val_loss: 0.1364
# Epoch 5/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9616 - loss: 0.1575 - val_accuracy: 0.9650 - val_loss: 0.1360
# Epoch 6/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9639 - loss: 0.1411 - val_accuracy: 0.9675 - val_loss: 0.1329
# Epoch 7/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9632 - loss: 0.1513 - val_accuracy: 0.9684 - val_loss: 0.1330
# Epoch 8/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9661 - loss: 0.1406 - val_accuracy: 0.9684 - val_loss: 0.1340
# Epoch 9/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9714 - loss: 0.1176 - val_accuracy: 0.9684 - val_loss: 0.1322
# Epoch 10/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9648 - loss: 0.1388 - val_accuracy: 0.9684 - val_loss: 0.1315
# Epoch 11/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9714 - loss: 0.1184 - val_accuracy: 0.9684 - val_loss: 0.1316
# Epoch 12/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9706 - loss: 0.1258 - val_accuracy: 0.9684 - val_loss: 0.1320
# Epoch 13/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9646 - loss: 0.1366 - val_accuracy: 0.9684 - val_loss: 0.1324
# Epoch 14/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9726 - loss: 0.1155 - val_accuracy: 0.9684 - val_loss: 0.1319
# Epoch 15/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9649 - loss: 0.1331 - val_accuracy: 0.9684 - val_loss: 0.1325
# Epoch 16/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9657 - loss: 0.1363 - val_accuracy: 0.9684 - val_loss: 0.1318
# Epoch 17/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9637 - loss: 0.1505 - val_accuracy: 0.9684 - val_loss: 0.1322
# Epoch 18/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9678 - loss: 0.1269 - val_accuracy: 0.9675 - val_loss: 0.1327
# Epoch 19/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9672 - loss: 0.1342 - val_accuracy: 0.9684 - val_loss: 0.1314
# Epoch 20/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9702 - loss: 0.1203 - val_accuracy: 0.9693 - val_loss: 0.1313
# Score for fold 3: loss of 0.13133347034454346; compile_metrics of 96.92570567131042%
# Training on fold 4...
# Epoch 1/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8758 - loss: 0.6493 - val_accuracy: 0.9650 - val_loss: 0.1565
# Epoch 2/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9669 - loss: 0.1479 - val_accuracy: 0.9658 - val_loss: 0.1408
# Epoch 3/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9672 - loss: 0.1375 - val_accuracy: 0.9658 - val_loss: 0.1363
# Epoch 4/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9632 - loss: 0.1421 - val_accuracy: 0.9658 - val_loss: 0.1337
# Epoch 5/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9643 - loss: 0.1401 - val_accuracy: 0.9650 - val_loss: 0.1313
# Epoch 6/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9685 - loss: 0.1375 - val_accuracy: 0.9667 - val_loss: 0.1305
# Epoch 7/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9683 - loss: 0.1335 - val_accuracy: 0.9667 - val_loss: 0.1297
# Epoch 8/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9654 - loss: 0.1403 - val_accuracy: 0.9667 - val_loss: 0.1317
# Epoch 9/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9692 - loss: 0.1210 - val_accuracy: 0.9667 - val_loss: 0.1293
# Epoch 10/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9648 - loss: 0.1317 - val_accuracy: 0.9667 - val_loss: 0.1294
# Epoch 11/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9581 - loss: 0.1566 - val_accuracy: 0.9667 - val_loss: 0.1296
# Epoch 12/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9709 - loss: 0.1179 - val_accuracy: 0.9658 - val_loss: 0.1296
# Epoch 13/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9631 - loss: 0.1476 - val_accuracy: 0.9667 - val_loss: 0.1292
# Epoch 14/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9623 - loss: 0.1508 - val_accuracy: 0.9658 - val_loss: 0.1292
# Epoch 15/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9704 - loss: 0.1200 - val_accuracy: 0.9667 - val_loss: 0.1295
# Epoch 16/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9710 - loss: 0.1160 - val_accuracy: 0.9658 - val_loss: 0.1291
# Epoch 17/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9664 - loss: 0.1354 - val_accuracy: 0.9658 - val_loss: 0.1294
# Epoch 18/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9646 - loss: 0.1381 - val_accuracy: 0.9675 - val_loss: 0.1288
# Epoch 19/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9673 - loss: 0.1303 - val_accuracy: 0.9675 - val_loss: 0.1290
# Epoch 20/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9691 - loss: 0.1307 - val_accuracy: 0.9667 - val_loss: 0.1288
# Score for fold 4: loss of 0.12878422439098358; compile_metrics of 96.66951298713684%
# Training on fold 5...
# Epoch 1/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9088 - loss: 0.6409 - val_accuracy: 0.9675 - val_loss: 0.1514
# Epoch 2/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9707 - loss: 0.1345 - val_accuracy: 0.9675 - val_loss: 0.1312
# Epoch 3/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9647 - loss: 0.1480 - val_accuracy: 0.9675 - val_loss: 0.1249
# Epoch 4/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9658 - loss: 0.1398 - val_accuracy: 0.9684 - val_loss: 0.1233
# Epoch 5/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9667 - loss: 0.1347 - val_accuracy: 0.9658 - val_loss: 0.1240
# Epoch 6/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9676 - loss: 0.1347 - val_accuracy: 0.9667 - val_loss: 0.1231
# Epoch 7/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9687 - loss: 0.1339 - val_accuracy: 0.9658 - val_loss: 0.1234
# Epoch 8/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9648 - loss: 0.1433 - val_accuracy: 0.9658 - val_loss: 0.1239
# Epoch 9/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9645 - loss: 0.1393 - val_accuracy: 0.9667 - val_loss: 0.1243
# Epoch 10/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9630 - loss: 0.1496 - val_accuracy: 0.9658 - val_loss: 0.1242
# Epoch 11/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9641 - loss: 0.1455 - val_accuracy: 0.9667 - val_loss: 0.1241
# Epoch 12/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9651 - loss: 0.1467 - val_accuracy: 0.9667 - val_loss: 0.1240
# Epoch 13/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9666 - loss: 0.1306 - val_accuracy: 0.9667 - val_loss: 0.1248
# Epoch 14/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9676 - loss: 0.1300 - val_accuracy: 0.9667 - val_loss: 0.1259
# Epoch 15/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9707 - loss: 0.1224 - val_accuracy: 0.9675 - val_loss: 0.1244
# Epoch 16/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9646 - loss: 0.1407 - val_accuracy: 0.9658 - val_loss: 0.1238
# Epoch 17/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9636 - loss: 0.1443 - val_accuracy: 0.9658 - val_loss: 0.1245
# Epoch 18/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9649 - loss: 0.1339 - val_accuracy: 0.9658 - val_loss: 0.1239
# Epoch 19/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9652 - loss: 0.1361 - val_accuracy: 0.9667 - val_loss: 0.1242
# Epoch 20/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9685 - loss: 0.1317 - val_accuracy: 0.9658 - val_loss: 0.1239
# Score for fold 5: loss of 0.12387607246637344; compile_metrics of 96.58411741256714%
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.13421855866909027 - Accuracy: 96.67235612869263%
# > Fold 2 - Loss: 0.14159750938415527 - Accuracy: 96.49872183799744%
# > Fold 3 - Loss: 0.13133347034454346 - Accuracy: 96.92570567131042%
# > Fold 4 - Loss: 0.12878422439098358 - Accuracy: 96.66951298713684%
# > Fold 5 - Loss: 0.12387607246637344 - Accuracy: 96.58411741256714%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 96.6700828075409 (+- 0.14290078528962352)
# > Loss: 0.1319619670510292
# ------------------------------------------------------------------------

# %%
histories_mnli_mismatched = cross_validate_bidirectional_lstm_model(X_mnli_mismatched_rnn, features_mnli_mismatched, y_encoded_mnli_mismatched)
# Out:
# Training on fold 1...
# Epoch 1/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8914 - loss: 0.6256 - val_accuracy: 0.9645 - val_loss: 0.1571
# Epoch 2/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9675 - loss: 0.1441 - val_accuracy: 0.9645 - val_loss: 0.1417
# Epoch 3/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9683 - loss: 0.1259 - val_accuracy: 0.9645 - val_loss: 0.1385
# Epoch 4/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9686 - loss: 0.1245 - val_accuracy: 0.9645 - val_loss: 0.1362
# Epoch 5/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9665 - loss: 0.1224 - val_accuracy: 0.9653 - val_loss: 0.1348
# Epoch 6/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9674 - loss: 0.1113 - val_accuracy: 0.9645 - val_loss: 0.1349
# Epoch 7/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9685 - loss: 0.1176 - val_accuracy: 0.9645 - val_loss: 0.1346
# Epoch 8/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9655 - loss: 0.1163 - val_accuracy: 0.9636 - val_loss: 0.1342
# Epoch 9/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9651 - loss: 0.1234 - val_accuracy: 0.9645 - val_loss: 0.1357
# Epoch 10/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9639 - loss: 0.1363 - val_accuracy: 0.9645 - val_loss: 0.1358
# Epoch 11/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9690 - loss: 0.1046 - val_accuracy: 0.9636 - val_loss: 0.1342
# Epoch 12/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9620 - loss: 0.1302 - val_accuracy: 0.9645 - val_loss: 0.1353
# Epoch 13/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9672 - loss: 0.1199 - val_accuracy: 0.9636 - val_loss: 0.1341
# Epoch 14/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9675 - loss: 0.1175 - val_accuracy: 0.9645 - val_loss: 0.1341
# Epoch 15/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9707 - loss: 0.1105 - val_accuracy: 0.9628 - val_loss: 0.1338
# Epoch 16/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9698 - loss: 0.1086 - val_accuracy: 0.9628 - val_loss: 0.1330
# Epoch 17/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9640 - loss: 0.1234 - val_accuracy: 0.9645 - val_loss: 0.1357
# Epoch 18/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9659 - loss: 0.1209 - val_accuracy: 0.9628 - val_loss: 0.1342
# Epoch 19/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9683 - loss: 0.1104 - val_accuracy: 0.9628 - val_loss: 0.1328
# Epoch 20/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9664 - loss: 0.1184 - val_accuracy: 0.9619 - val_loss: 0.1322
# Score for fold 1: loss of 0.13223864138126373; compile_metrics of 96.19289636611938%
# Training on fold 2...
# Epoch 1/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8269 - loss: 0.6785 - val_accuracy: 0.9679 - val_loss: 0.1441
# Epoch 2/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9671 - loss: 0.1474 - val_accuracy: 0.9679 - val_loss: 0.1257
# Epoch 3/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9704 - loss: 0.1250 - val_accuracy: 0.9679 - val_loss: 0.1190
# Epoch 4/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9665 - loss: 0.1300 - val_accuracy: 0.9679 - val_loss: 0.1154
# Epoch 5/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9681 - loss: 0.1159 - val_accuracy: 0.9679 - val_loss: 0.1152
# Epoch 6/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9685 - loss: 0.1186 - val_accuracy: 0.9662 - val_loss: 0.1129
# Epoch 7/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9669 - loss: 0.1280 - val_accuracy: 0.9687 - val_loss: 0.1121
# Epoch 8/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9704 - loss: 0.1155 - val_accuracy: 0.9662 - val_loss: 0.1122
# Epoch 9/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9623 - loss: 0.1365 - val_accuracy: 0.9687 - val_loss: 0.1117
# Epoch 10/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9642 - loss: 0.1217 - val_accuracy: 0.9679 - val_loss: 0.1118
# Epoch 11/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9666 - loss: 0.1194 - val_accuracy: 0.9695 - val_loss: 0.1115
# Epoch 12/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9689 - loss: 0.1173 - val_accuracy: 0.9662 - val_loss: 0.1137
# Epoch 13/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9656 - loss: 0.1243 - val_accuracy: 0.9679 - val_loss: 0.1124
# Epoch 14/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9658 - loss: 0.1241 - val_accuracy: 0.9679 - val_loss: 0.1115
# Epoch 15/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9629 - loss: 0.1268 - val_accuracy: 0.9679 - val_loss: 0.1109
# Epoch 16/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9689 - loss: 0.1141 - val_accuracy: 0.9679 - val_loss: 0.1122
# Epoch 17/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9619 - loss: 0.1302 - val_accuracy: 0.9687 - val_loss: 0.1110
# Epoch 18/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9658 - loss: 0.1316 - val_accuracy: 0.9695 - val_loss: 0.1103
# Epoch 19/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9663 - loss: 0.1141 - val_accuracy: 0.9662 - val_loss: 0.1111
# Epoch 20/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9672 - loss: 0.1175 - val_accuracy: 0.9695 - val_loss: 0.1101
# Score for fold 2: loss of 0.11012154817581177; compile_metrics of 96.95431590080261%
# Training on fold 3...
# Epoch 1/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9101 - loss: 0.6236 - val_accuracy: 0.9670 - val_loss: 0.1490
# Epoch 2/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9648 - loss: 0.1495 - val_accuracy: 0.9670 - val_loss: 0.1348
# Epoch 3/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9622 - loss: 0.1475 - val_accuracy: 0.9670 - val_loss: 0.1289
# Epoch 4/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9701 - loss: 0.1137 - val_accuracy: 0.9662 - val_loss: 0.1245
# Epoch 5/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9650 - loss: 0.1223 - val_accuracy: 0.9679 - val_loss: 0.1264
# Epoch 6/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9680 - loss: 0.1196 - val_accuracy: 0.9679 - val_loss: 0.1224
# Epoch 7/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9630 - loss: 0.1217 - val_accuracy: 0.9679 - val_loss: 0.1223
# Epoch 8/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9660 - loss: 0.1282 - val_accuracy: 0.9679 - val_loss: 0.1228
# Epoch 9/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9670 - loss: 0.1192 - val_accuracy: 0.9679 - val_loss: 0.1252
# Epoch 10/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9621 - loss: 0.1292 - val_accuracy: 0.9679 - val_loss: 0.1239
# Epoch 11/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9698 - loss: 0.1165 - val_accuracy: 0.9670 - val_loss: 0.1226
# Epoch 12/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9677 - loss: 0.1139 - val_accuracy: 0.9670 - val_loss: 0.1227
# Epoch 13/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9731 - loss: 0.0964 - val_accuracy: 0.9662 - val_loss: 0.1226
# Epoch 14/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9666 - loss: 0.1220 - val_accuracy: 0.9670 - val_loss: 0.1223
# Epoch 15/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9680 - loss: 0.1105 - val_accuracy: 0.9670 - val_loss: 0.1217
# Epoch 16/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9630 - loss: 0.1244 - val_accuracy: 0.9687 - val_loss: 0.1239
# Epoch 17/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9667 - loss: 0.1192 - val_accuracy: 0.9670 - val_loss: 0.1223
# Epoch 18/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9608 - loss: 0.1271 - val_accuracy: 0.9679 - val_loss: 0.1225
# Epoch 19/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9675 - loss: 0.1133 - val_accuracy: 0.9679 - val_loss: 0.1242
# Epoch 20/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9626 - loss: 0.1300 - val_accuracy: 0.9687 - val_loss: 0.1239
# Score for fold 3: loss of 0.12388017773628235; compile_metrics of 96.86971306800842%
# Training on fold 4...
# Epoch 1/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7936 - loss: 0.7171 - val_accuracy: 0.9679 - val_loss: 0.1486
# Epoch 2/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9715 - loss: 0.1313 - val_accuracy: 0.9687 - val_loss: 0.1285
# Epoch 3/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9676 - loss: 0.1305 - val_accuracy: 0.9687 - val_loss: 0.1230
# Epoch 4/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9687 - loss: 0.1174 - val_accuracy: 0.9662 - val_loss: 0.1203
# Epoch 5/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9680 - loss: 0.1190 - val_accuracy: 0.9662 - val_loss: 0.1195
# Epoch 6/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9663 - loss: 0.1237 - val_accuracy: 0.9653 - val_loss: 0.1191
# Epoch 7/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9683 - loss: 0.1215 - val_accuracy: 0.9662 - val_loss: 0.1189
# Epoch 8/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9652 - loss: 0.1287 - val_accuracy: 0.9653 - val_loss: 0.1188
# Epoch 9/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9662 - loss: 0.1285 - val_accuracy: 0.9645 - val_loss: 0.1200
# Epoch 10/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9657 - loss: 0.1341 - val_accuracy: 0.9653 - val_loss: 0.1187
# Epoch 11/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9638 - loss: 0.1211 - val_accuracy: 0.9645 - val_loss: 0.1196
# Epoch 12/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9668 - loss: 0.1228 - val_accuracy: 0.9645 - val_loss: 0.1187
# Epoch 13/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9647 - loss: 0.1237 - val_accuracy: 0.9653 - val_loss: 0.1188
# Epoch 14/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9637 - loss: 0.1238 - val_accuracy: 0.9645 - val_loss: 0.1194
# Epoch 15/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9729 - loss: 0.0989 - val_accuracy: 0.9653 - val_loss: 0.1205
# Epoch 16/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9649 - loss: 0.1244 - val_accuracy: 0.9653 - val_loss: 0.1190
# Epoch 17/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9677 - loss: 0.1197 - val_accuracy: 0.9645 - val_loss: 0.1195
# Epoch 18/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9638 - loss: 0.1177 - val_accuracy: 0.9645 - val_loss: 0.1185
# Epoch 19/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9676 - loss: 0.1194 - val_accuracy: 0.9653 - val_loss: 0.1205
# Epoch 20/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9672 - loss: 0.1158 - val_accuracy: 0.9653 - val_loss: 0.1192
# Score for fold 4: loss of 0.11920151859521866; compile_metrics of 96.53130173683167%
# Training on fold 5...
# Epoch 1/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8154 - loss: 0.6838 - val_accuracy: 0.9653 - val_loss: 0.1525
# Epoch 2/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9683 - loss: 0.1385 - val_accuracy: 0.9653 - val_loss: 0.1323
# Epoch 3/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9707 - loss: 0.1215 - val_accuracy: 0.9653 - val_loss: 0.1247
# Epoch 4/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9699 - loss: 0.1222 - val_accuracy: 0.9662 - val_loss: 0.1208
# Epoch 5/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9657 - loss: 0.1285 - val_accuracy: 0.9679 - val_loss: 0.1190
# Epoch 6/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9645 - loss: 0.1284 - val_accuracy: 0.9653 - val_loss: 0.1184
# Epoch 7/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9667 - loss: 0.1233 - val_accuracy: 0.9636 - val_loss: 0.1181
# Epoch 8/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9681 - loss: 0.1240 - val_accuracy: 0.9636 - val_loss: 0.1179
# Epoch 9/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9680 - loss: 0.1213 - val_accuracy: 0.9636 - val_loss: 0.1184
# Epoch 10/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9674 - loss: 0.1167 - val_accuracy: 0.9636 - val_loss: 0.1180
# Epoch 11/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9713 - loss: 0.1064 - val_accuracy: 0.9636 - val_loss: 0.1187
# Epoch 12/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9683 - loss: 0.1098 - val_accuracy: 0.9636 - val_loss: 0.1181
# Epoch 13/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9721 - loss: 0.1082 - val_accuracy: 0.9653 - val_loss: 0.1211
# Epoch 14/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9735 - loss: 0.1045 - val_accuracy: 0.9636 - val_loss: 0.1187
# Epoch 15/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9668 - loss: 0.1197 - val_accuracy: 0.9636 - val_loss: 0.1184
# Epoch 16/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9711 - loss: 0.1088 - val_accuracy: 0.9636 - val_loss: 0.1177
# Epoch 17/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9685 - loss: 0.1116 - val_accuracy: 0.9636 - val_loss: 0.1188
# Epoch 18/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9692 - loss: 0.1114 - val_accuracy: 0.9636 - val_loss: 0.1192
# Epoch 19/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9674 - loss: 0.1160 - val_accuracy: 0.9636 - val_loss: 0.1181
# Epoch 20/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9685 - loss: 0.1116 - val_accuracy: 0.9636 - val_loss: 0.1179
# Score for fold 5: loss of 0.11786875873804092; compile_metrics of 96.36209607124329%
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.13223864138126373 - Accuracy: 96.19289636611938%
# > Fold 2 - Loss: 0.11012154817581177 - Accuracy: 96.95431590080261%
# > Fold 3 - Loss: 0.12388017773628235 - Accuracy: 96.86971306800842%
# > Fold 4 - Loss: 0.11920151859521866 - Accuracy: 96.53130173683167%
# > Fold 5 - Loss: 0.11786875873804092 - Accuracy: 96.36209607124329%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 96.58206462860107 (+- 0.2911108408421174)
# > Loss: 0.12066212892532349
# ------------------------------------------------------------------------

# %%
histories_anli_r1 = cross_validate_bidirectional_lstm_model(X_anli_r1_rnn, features_anli_r1, y_encoded_anli_r1)
# Out:
# Training on fold 1...
# Epoch 1/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.2671 - loss: 1.1170 - val_accuracy: 0.7093 - val_loss: 1.0580
# Epoch 2/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6063 - loss: 1.0367 - val_accuracy: 0.6628 - val_loss: 0.9782
# Epoch 3/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7431 - loss: 0.9556 - val_accuracy: 0.6860 - val_loss: 0.9078
# Epoch 4/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6862 - loss: 0.8918 - val_accuracy: 0.6977 - val_loss: 0.8420
# Epoch 5/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7146 - loss: 0.8364 - val_accuracy: 0.6977 - val_loss: 0.7814
# Epoch 6/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6757 - loss: 0.7916 - val_accuracy: 0.6977 - val_loss: 0.7255
# Epoch 7/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7184 - loss: 0.7194 - val_accuracy: 0.7093 - val_loss: 0.6737
# Epoch 8/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7313 - loss: 0.6908 - val_accuracy: 0.7791 - val_loss: 0.6356
# Epoch 9/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7434 - loss: 0.6487 - val_accuracy: 0.7791 - val_loss: 0.6023
# Epoch 10/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7870 - loss: 0.6288 - val_accuracy: 0.7907 - val_loss: 0.5764
# Epoch 11/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8109 - loss: 0.5631 - val_accuracy: 0.8023 - val_loss: 0.5544
# Epoch 12/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8179 - loss: 0.5269 - val_accuracy: 0.8023 - val_loss: 0.5381
# Epoch 13/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7838 - loss: 0.5468 - val_accuracy: 0.8140 - val_loss: 0.5258
# Epoch 14/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7865 - loss: 0.5469 - val_accuracy: 0.8023 - val_loss: 0.5160
# Epoch 15/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8055 - loss: 0.5419 - val_accuracy: 0.8023 - val_loss: 0.5114
# Epoch 16/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8129 - loss: 0.4972 - val_accuracy: 0.8023 - val_loss: 0.5054
# Epoch 17/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8186 - loss: 0.5143 - val_accuracy: 0.8023 - val_loss: 0.4997
# Epoch 18/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8135 - loss: 0.5201 - val_accuracy: 0.8023 - val_loss: 0.4984
# Epoch 19/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8134 - loss: 0.5240 - val_accuracy: 0.8023 - val_loss: 0.4953
# Epoch 20/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7951 - loss: 0.5719 - val_accuracy: 0.8140 - val_loss: 0.4912
# Score for fold 1: loss of 0.4912198483943939; compile_metrics of 81.39534592628479%
# Training on fold 2...
# Epoch 1/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.4357 - loss: 1.0591 - val_accuracy: 0.5176 - val_loss: 1.0085
# Epoch 2/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5558 - loss: 0.9879 - val_accuracy: 0.6353 - val_loss: 0.9439
# Epoch 3/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6386 - loss: 0.9209 - val_accuracy: 0.6471 - val_loss: 0.8832
# Epoch 4/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6719 - loss: 0.8680 - val_accuracy: 0.6471 - val_loss: 0.8264
# Epoch 5/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6768 - loss: 0.8039 - val_accuracy: 0.6471 - val_loss: 0.7729
# Epoch 6/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7100 - loss: 0.7520 - val_accuracy: 0.6824 - val_loss: 0.7240
# Epoch 7/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7308 - loss: 0.6965 - val_accuracy: 0.7647 - val_loss: 0.6848
# Epoch 8/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7600 - loss: 0.6401 - val_accuracy: 0.7765 - val_loss: 0.6512
# Epoch 9/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7613 - loss: 0.6353 - val_accuracy: 0.7765 - val_loss: 0.6259
# Epoch 10/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7894 - loss: 0.5950 - val_accuracy: 0.7765 - val_loss: 0.6080
# Epoch 11/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7714 - loss: 0.5602 - val_accuracy: 0.7765 - val_loss: 0.5925
# Epoch 12/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7942 - loss: 0.5482 - val_accuracy: 0.7765 - val_loss: 0.5807
# Epoch 13/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7798 - loss: 0.5308 - val_accuracy: 0.8118 - val_loss: 0.5718
# Epoch 14/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7933 - loss: 0.5497 - val_accuracy: 0.8000 - val_loss: 0.5666
# Epoch 15/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8270 - loss: 0.4931 - val_accuracy: 0.8000 - val_loss: 0.5614
# Epoch 16/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7954 - loss: 0.5164 - val_accuracy: 0.8000 - val_loss: 0.5582
# Epoch 17/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7840 - loss: 0.5483 - val_accuracy: 0.8000 - val_loss: 0.5539
# Epoch 18/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8089 - loss: 0.4528 - val_accuracy: 0.8000 - val_loss: 0.5529
# Epoch 19/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8241 - loss: 0.5154 - val_accuracy: 0.8000 - val_loss: 0.5482
# Epoch 20/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7863 - loss: 0.5191 - val_accuracy: 0.8000 - val_loss: 0.5475
# Score for fold 2: loss of 0.547548234462738; compile_metrics of 80.0000011920929%
# Training on fold 3...
# Epoch 1/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.4240 - loss: 1.0846 - val_accuracy: 0.6588 - val_loss: 1.0288
# Epoch 2/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5837 - loss: 1.0170 - val_accuracy: 0.6706 - val_loss: 0.9694
# Epoch 3/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6368 - loss: 0.9485 - val_accuracy: 0.6471 - val_loss: 0.9143
# Epoch 4/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6235 - loss: 0.9066 - val_accuracy: 0.6941 - val_loss: 0.8580
# Epoch 5/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6789 - loss: 0.8447 - val_accuracy: 0.6941 - val_loss: 0.8021
# Epoch 6/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7288 - loss: 0.7590 - val_accuracy: 0.7882 - val_loss: 0.7479
# Epoch 7/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7418 - loss: 0.7267 - val_accuracy: 0.8000 - val_loss: 0.6971
# Epoch 8/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7687 - loss: 0.6855 - val_accuracy: 0.7882 - val_loss: 0.6523
# Epoch 9/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7760 - loss: 0.6574 - val_accuracy: 0.7765 - val_loss: 0.6162
# Epoch 10/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8026 - loss: 0.6241 - val_accuracy: 0.7882 - val_loss: 0.5883
# Epoch 11/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7950 - loss: 0.5829 - val_accuracy: 0.7765 - val_loss: 0.5647
# Epoch 12/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8100 - loss: 0.5160 - val_accuracy: 0.7882 - val_loss: 0.5456
# Epoch 13/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7928 - loss: 0.5229 - val_accuracy: 0.7765 - val_loss: 0.5330
# Epoch 14/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8201 - loss: 0.5088 - val_accuracy: 0.7882 - val_loss: 0.5227
# Epoch 15/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8186 - loss: 0.5455 - val_accuracy: 0.7765 - val_loss: 0.5157
# Epoch 16/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8496 - loss: 0.5133 - val_accuracy: 0.7882 - val_loss: 0.5114
# Epoch 17/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8452 - loss: 0.4814 - val_accuracy: 0.7882 - val_loss: 0.5081
# Epoch 18/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8009 - loss: 0.5071 - val_accuracy: 0.7882 - val_loss: 0.5046
# Epoch 19/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7844 - loss: 0.5434 - val_accuracy: 0.8000 - val_loss: 0.5043
# Epoch 20/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7840 - loss: 0.5247 - val_accuracy: 0.7882 - val_loss: 0.5039
# Score for fold 3: loss of 0.5039251446723938; compile_metrics of 78.82353067398071%
# Training on fold 4...
# Epoch 1/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.5206 - loss: 1.0415 - val_accuracy: 0.6353 - val_loss: 0.9954
# Epoch 2/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6445 - loss: 0.9802 - val_accuracy: 0.6588 - val_loss: 0.9389
# Epoch 3/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6548 - loss: 0.9076 - val_accuracy: 0.6588 - val_loss: 0.8853
# Epoch 4/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6603 - loss: 0.8555 - val_accuracy: 0.6706 - val_loss: 0.8335
# Epoch 5/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6958 - loss: 0.7985 - val_accuracy: 0.7059 - val_loss: 0.7831
# Epoch 6/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7187 - loss: 0.7348 - val_accuracy: 0.6941 - val_loss: 0.7370
# Epoch 7/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7281 - loss: 0.6844 - val_accuracy: 0.7176 - val_loss: 0.6976
# Epoch 8/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7563 - loss: 0.6510 - val_accuracy: 0.7765 - val_loss: 0.6656
# Epoch 9/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7514 - loss: 0.6270 - val_accuracy: 0.7882 - val_loss: 0.6387
# Epoch 10/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7885 - loss: 0.5715 - val_accuracy: 0.8235 - val_loss: 0.6188
# Epoch 11/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7902 - loss: 0.5983 - val_accuracy: 0.8000 - val_loss: 0.6053
# Epoch 12/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8060 - loss: 0.5678 - val_accuracy: 0.8118 - val_loss: 0.5943
# Epoch 13/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8206 - loss: 0.5256 - val_accuracy: 0.7882 - val_loss: 0.5857
# Epoch 14/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7691 - loss: 0.5595 - val_accuracy: 0.7882 - val_loss: 0.5814
# Epoch 15/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7872 - loss: 0.5360 - val_accuracy: 0.7882 - val_loss: 0.5764
# Epoch 16/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8473 - loss: 0.4722 - val_accuracy: 0.7882 - val_loss: 0.5733
# Epoch 17/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7968 - loss: 0.5221 - val_accuracy: 0.7882 - val_loss: 0.5720
# Epoch 18/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8103 - loss: 0.5316 - val_accuracy: 0.7882 - val_loss: 0.5699
# Epoch 19/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8269 - loss: 0.4460 - val_accuracy: 0.7882 - val_loss: 0.5692
# Epoch 20/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8269 - loss: 0.4493 - val_accuracy: 0.7882 - val_loss: 0.5713
# Score for fold 4: loss of 0.5712835788726807; compile_metrics of 78.82353067398071%
# Training on fold 5...
# Epoch 1/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.4422 - loss: 1.0538 - val_accuracy: 0.4353 - val_loss: 0.9979
# Epoch 2/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6041 - loss: 0.9752 - val_accuracy: 0.6471 - val_loss: 0.9324
# Epoch 3/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6227 - loss: 0.9417 - val_accuracy: 0.6471 - val_loss: 0.8712
# Epoch 4/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7005 - loss: 0.8594 - val_accuracy: 0.6588 - val_loss: 0.8105
# Epoch 5/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7112 - loss: 0.8072 - val_accuracy: 0.7647 - val_loss: 0.7493
# Epoch 6/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7547 - loss: 0.7493 - val_accuracy: 0.7882 - val_loss: 0.6904
# Epoch 7/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7856 - loss: 0.6961 - val_accuracy: 0.8353 - val_loss: 0.6391
# Epoch 8/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7732 - loss: 0.6625 - val_accuracy: 0.8235 - val_loss: 0.5952
# Epoch 9/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7583 - loss: 0.6494 - val_accuracy: 0.8235 - val_loss: 0.5608
# Epoch 10/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7806 - loss: 0.6387 - val_accuracy: 0.8118 - val_loss: 0.5333
# Epoch 11/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7982 - loss: 0.5675 - val_accuracy: 0.8118 - val_loss: 0.5139
# Epoch 12/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7962 - loss: 0.5662 - val_accuracy: 0.8118 - val_loss: 0.4979
# Epoch 13/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8048 - loss: 0.5113 - val_accuracy: 0.8118 - val_loss: 0.4867
# Epoch 14/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7956 - loss: 0.4956 - val_accuracy: 0.8118 - val_loss: 0.4787
# Epoch 15/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8342 - loss: 0.4792 - val_accuracy: 0.8118 - val_loss: 0.4734
# Epoch 16/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8358 - loss: 0.4979 - val_accuracy: 0.8235 - val_loss: 0.4693
# Epoch 17/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7739 - loss: 0.5246 - val_accuracy: 0.8235 - val_loss: 0.4669
# Epoch 18/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8418 - loss: 0.4571 - val_accuracy: 0.8235 - val_loss: 0.4651
# Epoch 19/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8227 - loss: 0.5236 - val_accuracy: 0.8235 - val_loss: 0.4640
# Epoch 20/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7800 - loss: 0.5435 - val_accuracy: 0.8235 - val_loss: 0.4631
# Score for fold 5: loss of 0.4630790054798126; compile_metrics of 82.35294222831726%
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.4912198483943939 - Accuracy: 81.39534592628479%
# > Fold 2 - Loss: 0.547548234462738 - Accuracy: 80.0000011920929%
# > Fold 3 - Loss: 0.5039251446723938 - Accuracy: 78.82353067398071%
# > Fold 4 - Loss: 0.5712835788726807 - Accuracy: 78.82353067398071%
# > Fold 5 - Loss: 0.4630790054798126 - Accuracy: 82.35294222831726%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 80.27907013893127 (+- 1.404427771137592)
# > Loss: 0.5154111623764038
# ------------------------------------------------------------------------

# %%
histories_anli_r2 = cross_validate_bidirectional_lstm_model(X_anli_r2_rnn, features_anli_r2, y_encoded_anli_r2)
# Out:
# Training on fold 1...
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.4311 - loss: 1.0858 - val_accuracy: 0.5506 - val_loss: 1.0164
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5278 - loss: 1.0299 - val_accuracy: 0.6517 - val_loss: 0.9617
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5760 - loss: 0.9795 - val_accuracy: 0.6742 - val_loss: 0.9156
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6181 - loss: 0.9500 - val_accuracy: 0.6854 - val_loss: 0.8732
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5997 - loss: 0.9302 - val_accuracy: 0.6742 - val_loss: 0.8306
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6423 - loss: 0.8958 - val_accuracy: 0.6742 - val_loss: 0.7881
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6764 - loss: 0.8502 - val_accuracy: 0.6854 - val_loss: 0.7499
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6787 - loss: 0.8191 - val_accuracy: 0.7191 - val_loss: 0.7202
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6912 - loss: 0.7992 - val_accuracy: 0.7303 - val_loss: 0.6934
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7189 - loss: 0.7596 - val_accuracy: 0.7416 - val_loss: 0.6738
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6998 - loss: 0.7745 - val_accuracy: 0.7303 - val_loss: 0.6576
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7144 - loss: 0.7477 - val_accuracy: 0.7528 - val_loss: 0.6417
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7166 - loss: 0.7538 - val_accuracy: 0.7640 - val_loss: 0.6286
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7040 - loss: 0.7266 - val_accuracy: 0.7640 - val_loss: 0.6181
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7117 - loss: 0.7247 - val_accuracy: 0.7865 - val_loss: 0.6121
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7065 - loss: 0.7302 - val_accuracy: 0.7865 - val_loss: 0.6039
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7107 - loss: 0.7487 - val_accuracy: 0.7865 - val_loss: 0.5992
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7454 - loss: 0.7035 - val_accuracy: 0.7865 - val_loss: 0.5923
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7297 - loss: 0.7211 - val_accuracy: 0.7753 - val_loss: 0.5934
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7288 - loss: 0.6875 - val_accuracy: 0.7753 - val_loss: 0.5895
# Score for fold 1: loss of 0.5894808769226074; compile_metrics of 77.52808928489685%
# Training on fold 2...
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.2867 - loss: 1.1171 - val_accuracy: 0.6966 - val_loss: 1.0458
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6269 - loss: 1.0292 - val_accuracy: 0.7191 - val_loss: 0.9905
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6766 - loss: 0.9770 - val_accuracy: 0.6742 - val_loss: 0.9442
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6551 - loss: 0.9368 - val_accuracy: 0.6629 - val_loss: 0.9029
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6500 - loss: 0.8922 - val_accuracy: 0.6629 - val_loss: 0.8638
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6708 - loss: 0.8500 - val_accuracy: 0.6742 - val_loss: 0.8268
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6825 - loss: 0.8132 - val_accuracy: 0.6742 - val_loss: 0.7978
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6418 - loss: 0.8126 - val_accuracy: 0.6854 - val_loss: 0.7699
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6891 - loss: 0.7611 - val_accuracy: 0.6742 - val_loss: 0.7476
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6984 - loss: 0.7512 - val_accuracy: 0.6966 - val_loss: 0.7284
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7154 - loss: 0.7420 - val_accuracy: 0.7191 - val_loss: 0.7154
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7084 - loss: 0.7488 - val_accuracy: 0.7303 - val_loss: 0.7035
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7447 - loss: 0.7081 - val_accuracy: 0.7303 - val_loss: 0.6969
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7192 - loss: 0.7406 - val_accuracy: 0.7303 - val_loss: 0.6954
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7270 - loss: 0.7155 - val_accuracy: 0.7416 - val_loss: 0.6897
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7310 - loss: 0.6948 - val_accuracy: 0.7416 - val_loss: 0.6837
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7331 - loss: 0.7115 - val_accuracy: 0.7416 - val_loss: 0.6805
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7501 - loss: 0.6297 - val_accuracy: 0.7416 - val_loss: 0.6777
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7435 - loss: 0.6791 - val_accuracy: 0.7416 - val_loss: 0.6763
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7204 - loss: 0.6837 - val_accuracy: 0.7416 - val_loss: 0.6761
# Score for fold 2: loss of 0.6760776042938232; compile_metrics of 74.15730357170105%
# Training on fold 3...
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.2891 - loss: 1.1189 - val_accuracy: 0.4944 - val_loss: 1.0662
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5866 - loss: 1.0507 - val_accuracy: 0.6180 - val_loss: 1.0106
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6033 - loss: 1.0053 - val_accuracy: 0.6180 - val_loss: 0.9675
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6576 - loss: 0.9396 - val_accuracy: 0.6629 - val_loss: 0.9257
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6477 - loss: 0.9153 - val_accuracy: 0.6742 - val_loss: 0.8870
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6647 - loss: 0.8430 - val_accuracy: 0.6742 - val_loss: 0.8535
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6785 - loss: 0.8325 - val_accuracy: 0.6742 - val_loss: 0.8214
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6982 - loss: 0.7850 - val_accuracy: 0.6966 - val_loss: 0.7987
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6879 - loss: 0.7512 - val_accuracy: 0.6966 - val_loss: 0.7828
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7049 - loss: 0.7427 - val_accuracy: 0.7079 - val_loss: 0.7697
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7000 - loss: 0.7530 - val_accuracy: 0.7303 - val_loss: 0.7592
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7598 - loss: 0.6860 - val_accuracy: 0.7079 - val_loss: 0.7501
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7350 - loss: 0.7041 - val_accuracy: 0.7079 - val_loss: 0.7428
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7437 - loss: 0.6824 - val_accuracy: 0.7191 - val_loss: 0.7356
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7439 - loss: 0.6867 - val_accuracy: 0.7191 - val_loss: 0.7348
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7171 - loss: 0.6979 - val_accuracy: 0.7191 - val_loss: 0.7380
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7542 - loss: 0.6553 - val_accuracy: 0.7191 - val_loss: 0.7391
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7287 - loss: 0.6715 - val_accuracy: 0.7191 - val_loss: 0.7346
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7512 - loss: 0.6352 - val_accuracy: 0.7191 - val_loss: 0.7350
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7705 - loss: 0.6236 - val_accuracy: 0.7191 - val_loss: 0.7349
# Score for fold 3: loss of 0.7348883152008057; compile_metrics of 71.91011309623718%
# Training on fold 4...
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.4018 - loss: 1.0948 - val_accuracy: 0.5169 - val_loss: 1.0536
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5650 - loss: 1.0352 - val_accuracy: 0.6292 - val_loss: 1.0064
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6728 - loss: 0.9798 - val_accuracy: 0.6742 - val_loss: 0.9633
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6390 - loss: 0.9491 - val_accuracy: 0.6854 - val_loss: 0.9228
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6578 - loss: 0.8980 - val_accuracy: 0.6854 - val_loss: 0.8807
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6530 - loss: 0.8758 - val_accuracy: 0.6854 - val_loss: 0.8409
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6635 - loss: 0.8322 - val_accuracy: 0.7079 - val_loss: 0.8065
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7091 - loss: 0.7658 - val_accuracy: 0.7079 - val_loss: 0.7776
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6883 - loss: 0.7688 - val_accuracy: 0.7079 - val_loss: 0.7570
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7189 - loss: 0.7232 - val_accuracy: 0.7303 - val_loss: 0.7383
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7190 - loss: 0.7239 - val_accuracy: 0.7978 - val_loss: 0.7237
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7426 - loss: 0.7073 - val_accuracy: 0.7640 - val_loss: 0.7112
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7146 - loss: 0.7251 - val_accuracy: 0.7865 - val_loss: 0.7084
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7389 - loss: 0.7040 - val_accuracy: 0.7753 - val_loss: 0.7035
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7302 - loss: 0.7385 - val_accuracy: 0.7753 - val_loss: 0.6923
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7096 - loss: 0.7239 - val_accuracy: 0.7753 - val_loss: 0.6814
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7260 - loss: 0.7246 - val_accuracy: 0.7753 - val_loss: 0.6736
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7518 - loss: 0.6707 - val_accuracy: 0.7753 - val_loss: 0.6693
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7408 - loss: 0.6700 - val_accuracy: 0.7753 - val_loss: 0.6672
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7275 - loss: 0.6940 - val_accuracy: 0.7753 - val_loss: 0.6605
# Score for fold 4: loss of 0.6605170369148254; compile_metrics of 77.52808928489685%
# Training on fold 5...
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.3394 - loss: 1.0915 - val_accuracy: 0.5506 - val_loss: 1.0449
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6008 - loss: 1.0308 - val_accuracy: 0.5506 - val_loss: 1.0028
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6296 - loss: 0.9759 - val_accuracy: 0.5506 - val_loss: 0.9640
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6409 - loss: 0.9292 - val_accuracy: 0.5955 - val_loss: 0.9281
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6658 - loss: 0.8955 - val_accuracy: 0.5955 - val_loss: 0.8966
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6734 - loss: 0.8425 - val_accuracy: 0.5955 - val_loss: 0.8703
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7158 - loss: 0.7842 - val_accuracy: 0.5955 - val_loss: 0.8474
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7158 - loss: 0.7530 - val_accuracy: 0.6180 - val_loss: 0.8289
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7113 - loss: 0.7515 - val_accuracy: 0.6629 - val_loss: 0.8171
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7278 - loss: 0.7307 - val_accuracy: 0.6404 - val_loss: 0.8095
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7281 - loss: 0.7117 - val_accuracy: 0.6517 - val_loss: 0.8051
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7470 - loss: 0.6858 - val_accuracy: 0.6742 - val_loss: 0.8021
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7299 - loss: 0.7277 - val_accuracy: 0.6742 - val_loss: 0.8005
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7375 - loss: 0.6965 - val_accuracy: 0.6854 - val_loss: 0.7999
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7587 - loss: 0.6560 - val_accuracy: 0.6742 - val_loss: 0.7999
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7207 - loss: 0.7239 - val_accuracy: 0.6854 - val_loss: 0.7997
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7524 - loss: 0.6625 - val_accuracy: 0.6854 - val_loss: 0.8008
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7692 - loss: 0.6446 - val_accuracy: 0.6854 - val_loss: 0.8001
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7253 - loss: 0.7098 - val_accuracy: 0.6854 - val_loss: 0.7996
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7670 - loss: 0.6470 - val_accuracy: 0.6854 - val_loss: 0.8002
# Score for fold 5: loss of 0.8001944422721863; compile_metrics of 68.53932738304138%
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.5894808769226074 - Accuracy: 77.52808928489685%
# > Fold 2 - Loss: 0.6760776042938232 - Accuracy: 74.15730357170105%
# > Fold 3 - Loss: 0.7348883152008057 - Accuracy: 71.91011309623718%
# > Fold 4 - Loss: 0.6605170369148254 - Accuracy: 77.52808928489685%
# > Fold 5 - Loss: 0.8001944422721863 - Accuracy: 68.53932738304138%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 73.93258452415466 (+- 3.437540425545032)
# > Loss: 0.6922316551208496
# ------------------------------------------------------------------------

# %%
histories_anli_r3 = cross_validate_bidirectional_lstm_model(X_anli_r3_rnn, features_anli_r3, y_encoded_anli_r3)
# Out:
# Training on fold 1...
# Epoch 1/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.3674 - loss: 1.1012 - val_accuracy: 0.7075 - val_loss: 1.0392
# Epoch 2/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6416 - loss: 1.0201 - val_accuracy: 0.6887 - val_loss: 0.9778
# Epoch 3/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6511 - loss: 0.9494 - val_accuracy: 0.6792 - val_loss: 0.9204
# Epoch 4/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6598 - loss: 0.8933 - val_accuracy: 0.6981 - val_loss: 0.8728
# Epoch 5/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6518 - loss: 0.8500 - val_accuracy: 0.7075 - val_loss: 0.8291
# Epoch 6/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6920 - loss: 0.7887 - val_accuracy: 0.7264 - val_loss: 0.7929
# Epoch 7/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6542 - loss: 0.7665 - val_accuracy: 0.7264 - val_loss: 0.7689
# Epoch 8/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6958 - loss: 0.7108 - val_accuracy: 0.7264 - val_loss: 0.7506
# Epoch 9/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7034 - loss: 0.7172 - val_accuracy: 0.7358 - val_loss: 0.7395
# Epoch 10/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7215 - loss: 0.7121 - val_accuracy: 0.7075 - val_loss: 0.7325
# Epoch 11/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7316 - loss: 0.6607 - val_accuracy: 0.7170 - val_loss: 0.7284
# Epoch 12/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7377 - loss: 0.6878 - val_accuracy: 0.7170 - val_loss: 0.7253
# Epoch 13/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7270 - loss: 0.6719 - val_accuracy: 0.6887 - val_loss: 0.7237
# Epoch 14/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7319 - loss: 0.6832 - val_accuracy: 0.6887 - val_loss: 0.7200
# Epoch 15/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7467 - loss: 0.6693 - val_accuracy: 0.6887 - val_loss: 0.7184
# Epoch 16/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7401 - loss: 0.6504 - val_accuracy: 0.6698 - val_loss: 0.7167
# Epoch 17/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7393 - loss: 0.6390 - val_accuracy: 0.6698 - val_loss: 0.7158
# Epoch 18/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7346 - loss: 0.6958 - val_accuracy: 0.6792 - val_loss: 0.7153
# Epoch 19/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7491 - loss: 0.6616 - val_accuracy: 0.6698 - val_loss: 0.7136
# Epoch 20/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7462 - loss: 0.6626 - val_accuracy: 0.6981 - val_loss: 0.7131
# Score for fold 1: loss of 0.7130861878395081; compile_metrics of 69.8113203048706%
# Training on fold 2...
# Epoch 1/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.4563 - loss: 1.0497 - val_accuracy: 0.6698 - val_loss: 0.9800
# Epoch 2/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6005 - loss: 0.9828 - val_accuracy: 0.6604 - val_loss: 0.9185
# Epoch 3/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5989 - loss: 0.9230 - val_accuracy: 0.6604 - val_loss: 0.8666
# Epoch 4/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6550 - loss: 0.8515 - val_accuracy: 0.6698 - val_loss: 0.8191
# Epoch 5/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6805 - loss: 0.8105 - val_accuracy: 0.6792 - val_loss: 0.7765
# Epoch 6/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6925 - loss: 0.7557 - val_accuracy: 0.6887 - val_loss: 0.7350
# Epoch 7/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6541 - loss: 0.7810 - val_accuracy: 0.6887 - val_loss: 0.7053
# Epoch 8/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6748 - loss: 0.7541 - val_accuracy: 0.6792 - val_loss: 0.6802
# Epoch 9/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6629 - loss: 0.7708 - val_accuracy: 0.6981 - val_loss: 0.6593
# Epoch 10/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6851 - loss: 0.7137 - val_accuracy: 0.6887 - val_loss: 0.6443
# Epoch 11/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7262 - loss: 0.6974 - val_accuracy: 0.6981 - val_loss: 0.6307
# Epoch 12/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7217 - loss: 0.7034 - val_accuracy: 0.7075 - val_loss: 0.6192
# Epoch 13/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7116 - loss: 0.6736 - val_accuracy: 0.7075 - val_loss: 0.6146
# Epoch 14/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7069 - loss: 0.6656 - val_accuracy: 0.6981 - val_loss: 0.6122
# Epoch 15/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7289 - loss: 0.6748 - val_accuracy: 0.7170 - val_loss: 0.6086
# Epoch 16/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7412 - loss: 0.6718 - val_accuracy: 0.7264 - val_loss: 0.6048
# Epoch 17/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7052 - loss: 0.7075 - val_accuracy: 0.7264 - val_loss: 0.6016
# Epoch 18/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7365 - loss: 0.6867 - val_accuracy: 0.7358 - val_loss: 0.5972
# Epoch 19/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6962 - loss: 0.6625 - val_accuracy: 0.7358 - val_loss: 0.5973
# Epoch 20/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7243 - loss: 0.6717 - val_accuracy: 0.7358 - val_loss: 0.5946
# Score for fold 2: loss of 0.5946409702301025; compile_metrics of 73.58490824699402%
# Training on fold 3...
# Epoch 1/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.6354 - loss: 1.0252 - val_accuracy: 0.5755 - val_loss: 0.9792
# Epoch 2/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6052 - loss: 0.9790 - val_accuracy: 0.6038 - val_loss: 0.9251
# Epoch 3/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6516 - loss: 0.9110 - val_accuracy: 0.6226 - val_loss: 0.8737
# Epoch 4/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6406 - loss: 0.8693 - val_accuracy: 0.6509 - val_loss: 0.8260
# Epoch 5/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6602 - loss: 0.8240 - val_accuracy: 0.6698 - val_loss: 0.7817
# Epoch 6/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7010 - loss: 0.7626 - val_accuracy: 0.6698 - val_loss: 0.7434
# Epoch 7/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6924 - loss: 0.7197 - val_accuracy: 0.6698 - val_loss: 0.7134
# Epoch 8/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7202 - loss: 0.6938 - val_accuracy: 0.6698 - val_loss: 0.6955
# Epoch 9/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7196 - loss: 0.6974 - val_accuracy: 0.6887 - val_loss: 0.6797
# Epoch 10/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7167 - loss: 0.7353 - val_accuracy: 0.6887 - val_loss: 0.6706
# Epoch 11/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7107 - loss: 0.6884 - val_accuracy: 0.7075 - val_loss: 0.6635
# Epoch 12/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6905 - loss: 0.7038 - val_accuracy: 0.6981 - val_loss: 0.6598
# Epoch 13/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7504 - loss: 0.6638 - val_accuracy: 0.7170 - val_loss: 0.6566
# Epoch 14/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7275 - loss: 0.6616 - val_accuracy: 0.7170 - val_loss: 0.6558
# Epoch 15/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7263 - loss: 0.6700 - val_accuracy: 0.7170 - val_loss: 0.6533
# Epoch 16/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7309 - loss: 0.6673 - val_accuracy: 0.7358 - val_loss: 0.6549
# Epoch 17/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7760 - loss: 0.5949 - val_accuracy: 0.6981 - val_loss: 0.6588
# Epoch 18/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6882 - loss: 0.7119 - val_accuracy: 0.7453 - val_loss: 0.6574
# Epoch 19/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7409 - loss: 0.6457 - val_accuracy: 0.7170 - val_loss: 0.6599
# Epoch 20/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7434 - loss: 0.6299 - val_accuracy: 0.7264 - val_loss: 0.6588
# Score for fold 3: loss of 0.6587774157524109; compile_metrics of 72.64150977134705%
# Training on fold 4...
# Epoch 1/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.3730 - loss: 1.0931 - val_accuracy: 0.5189 - val_loss: 1.0347
# Epoch 2/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5342 - loss: 1.0292 - val_accuracy: 0.5943 - val_loss: 0.9715
# Epoch 3/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5966 - loss: 0.9721 - val_accuracy: 0.6038 - val_loss: 0.9124
# Epoch 4/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6108 - loss: 0.9136 - val_accuracy: 0.6509 - val_loss: 0.8572
# Epoch 5/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6804 - loss: 0.8521 - val_accuracy: 0.6509 - val_loss: 0.8035
# Epoch 6/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6838 - loss: 0.7970 - val_accuracy: 0.6604 - val_loss: 0.7579
# Epoch 7/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6684 - loss: 0.7769 - val_accuracy: 0.6792 - val_loss: 0.7242
# Epoch 8/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6965 - loss: 0.7216 - val_accuracy: 0.7170 - val_loss: 0.7010
# Epoch 9/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7019 - loss: 0.7149 - val_accuracy: 0.7170 - val_loss: 0.6850
# Epoch 10/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7106 - loss: 0.7144 - val_accuracy: 0.7264 - val_loss: 0.6748
# Epoch 11/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6673 - loss: 0.7519 - val_accuracy: 0.7358 - val_loss: 0.6681
# Epoch 12/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7275 - loss: 0.6602 - val_accuracy: 0.7453 - val_loss: 0.6626
# Epoch 13/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7171 - loss: 0.6674 - val_accuracy: 0.7358 - val_loss: 0.6568
# Epoch 14/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7460 - loss: 0.6308 - val_accuracy: 0.7358 - val_loss: 0.6529
# Epoch 15/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7197 - loss: 0.6610 - val_accuracy: 0.7358 - val_loss: 0.6519
# Epoch 16/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7293 - loss: 0.6636 - val_accuracy: 0.7358 - val_loss: 0.6489
# Epoch 17/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7328 - loss: 0.6572 - val_accuracy: 0.7170 - val_loss: 0.6456
# Epoch 18/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7534 - loss: 0.6322 - val_accuracy: 0.7264 - val_loss: 0.6465
# Epoch 19/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7257 - loss: 0.6529 - val_accuracy: 0.7264 - val_loss: 0.6443
# Epoch 20/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7518 - loss: 0.6513 - val_accuracy: 0.7264 - val_loss: 0.6450
# Score for fold 4: loss of 0.6450185775756836; compile_metrics of 72.64150977134705%
# Training on fold 5...
# Epoch 1/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.2842 - loss: 1.1056 - val_accuracy: 0.5660 - val_loss: 1.0462
# Epoch 2/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6015 - loss: 1.0305 - val_accuracy: 0.5943 - val_loss: 0.9782
# Epoch 3/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6549 - loss: 0.9627 - val_accuracy: 0.6415 - val_loss: 0.9172
# Epoch 4/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6831 - loss: 0.8926 - val_accuracy: 0.6415 - val_loss: 0.8647
# Epoch 5/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6685 - loss: 0.8441 - val_accuracy: 0.6415 - val_loss: 0.8235
# Epoch 6/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6707 - loss: 0.7961 - val_accuracy: 0.6509 - val_loss: 0.7945
# Epoch 7/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7134 - loss: 0.7480 - val_accuracy: 0.6698 - val_loss: 0.7782
# Epoch 8/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7331 - loss: 0.7109 - val_accuracy: 0.6698 - val_loss: 0.7699
# Epoch 9/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7173 - loss: 0.6750 - val_accuracy: 0.6887 - val_loss: 0.7664
# Epoch 10/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6778 - loss: 0.7064 - val_accuracy: 0.6887 - val_loss: 0.7660
# Epoch 11/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7189 - loss: 0.6779 - val_accuracy: 0.6887 - val_loss: 0.7667
# Epoch 12/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7326 - loss: 0.6994 - val_accuracy: 0.6887 - val_loss: 0.7696
# Epoch 13/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7348 - loss: 0.6519 - val_accuracy: 0.7075 - val_loss: 0.7693
# Epoch 14/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7063 - loss: 0.6919 - val_accuracy: 0.7075 - val_loss: 0.7683
# Epoch 15/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6869 - loss: 0.6885 - val_accuracy: 0.6981 - val_loss: 0.7682
# Epoch 16/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7253 - loss: 0.6391 - val_accuracy: 0.6887 - val_loss: 0.7707
# Epoch 17/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7407 - loss: 0.6455 - val_accuracy: 0.7075 - val_loss: 0.7668
# Epoch 18/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7521 - loss: 0.6175 - val_accuracy: 0.6981 - val_loss: 0.7679
# Epoch 19/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7265 - loss: 0.6627 - val_accuracy: 0.7075 - val_loss: 0.7688
# Epoch 20/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7490 - loss: 0.6303 - val_accuracy: 0.7075 - val_loss: 0.7651
# Score for fold 5: loss of 0.7651262283325195; compile_metrics of 70.75471878051758%
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.7130861878395081 - Accuracy: 69.8113203048706%
# > Fold 2 - Loss: 0.5946409702301025 - Accuracy: 73.58490824699402%
# > Fold 3 - Loss: 0.6587774157524109 - Accuracy: 72.64150977134705%
# > Fold 4 - Loss: 0.6450185775756836 - Accuracy: 72.64150977134705%
# > Fold 5 - Loss: 0.7651262283325195 - Accuracy: 70.75471878051758%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 71.88679337501526 (+- 1.386504175877035)
# > Loss: 0.6753298759460449
# ------------------------------------------------------------------------

# %%
X_rnn_all_tasks = np.concatenate([X_snli_rnn, X_mnli_matched_rnn, X_mnli_mismatched_rnn, X_anli_r1_rnn, X_anli_r2_rnn, X_anli_r3_rnn])
features_all_tasks = np.concatenate([features_snli, features_mnli_matched, features_mnli_mismatched, features_anli_r1, features_anli_r2, features_anli_r3])
y_encoded_all_tasks = np.concatenate([y_encoded_snli, y_encoded_mnli_matched, y_encoded_mnli_mismatched, y_encoded_anli_r1, y_encoded_anli_r2, y_encoded_anli_r3])

# Call the cross-validation function
all_histories = cross_validate_bidirectional_lstm_model(X_rnn_all_tasks, features_all_tasks, y_encoded_all_tasks, num_folds=5)
# Out:
# Training on fold 1...
# Epoch 1/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.8653 - loss: 0.4673 - val_accuracy: 0.9474 - val_loss: 0.1750
# Epoch 2/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9456 - loss: 0.1852 - val_accuracy: 0.9479 - val_loss: 0.1725
# Epoch 3/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9467 - loss: 0.1796 - val_accuracy: 0.9482 - val_loss: 0.1722
# Epoch 4/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9501 - loss: 0.1711 - val_accuracy: 0.9497 - val_loss: 0.1721
# Epoch 5/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9500 - loss: 0.1698 - val_accuracy: 0.9487 - val_loss: 0.1727
# Epoch 6/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9518 - loss: 0.1692 - val_accuracy: 0.9474 - val_loss: 0.1726
# Epoch 7/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9467 - loss: 0.1829 - val_accuracy: 0.9490 - val_loss: 0.1721
# Epoch 8/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9441 - loss: 0.1910 - val_accuracy: 0.9482 - val_loss: 0.1721
# Epoch 9/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9450 - loss: 0.1827 - val_accuracy: 0.9482 - val_loss: 0.1721
# Epoch 10/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9493 - loss: 0.1711 - val_accuracy: 0.9484 - val_loss: 0.1718
# Epoch 11/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9458 - loss: 0.1865 - val_accuracy: 0.9474 - val_loss: 0.1741
# Epoch 12/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9462 - loss: 0.1796 - val_accuracy: 0.9482 - val_loss: 0.1722
# Epoch 13/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9500 - loss: 0.1687 - val_accuracy: 0.9487 - val_loss: 0.1727
# Epoch 14/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9479 - loss: 0.1716 - val_accuracy: 0.9482 - val_loss: 0.1719
# Epoch 15/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9455 - loss: 0.1828 - val_accuracy: 0.9490 - val_loss: 0.1729
# Epoch 16/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9506 - loss: 0.1694 - val_accuracy: 0.9487 - val_loss: 0.1721
# Epoch 17/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9517 - loss: 0.1649 - val_accuracy: 0.9482 - val_loss: 0.1716
# Epoch 18/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9464 - loss: 0.1838 - val_accuracy: 0.9484 - val_loss: 0.1721
# Epoch 19/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9472 - loss: 0.1726 - val_accuracy: 0.9479 - val_loss: 0.1721
# Epoch 20/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9481 - loss: 0.1768 - val_accuracy: 0.9484 - val_loss: 0.1720
# Score for fold 1: loss of 0.17201295495033264; compile_metrics of 94.8437511920929%
# Training on fold 2...
# Epoch 1/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9249 - loss: 0.4152 - val_accuracy: 0.9469 - val_loss: 0.1723
# Epoch 2/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9473 - loss: 0.1828 - val_accuracy: 0.9456 - val_loss: 0.1707
# Epoch 3/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9488 - loss: 0.1774 - val_accuracy: 0.9495 - val_loss: 0.1692
# Epoch 4/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9482 - loss: 0.1786 - val_accuracy: 0.9469 - val_loss: 0.1687
# Epoch 5/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9461 - loss: 0.1861 - val_accuracy: 0.9484 - val_loss: 0.1679
# Epoch 6/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9499 - loss: 0.1739 - val_accuracy: 0.9471 - val_loss: 0.1691
# Epoch 7/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9455 - loss: 0.1889 - val_accuracy: 0.9482 - val_loss: 0.1680
# Epoch 8/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9493 - loss: 0.1790 - val_accuracy: 0.9482 - val_loss: 0.1680
# Epoch 9/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9464 - loss: 0.1831 - val_accuracy: 0.9479 - val_loss: 0.1666
# Epoch 10/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9499 - loss: 0.1770 - val_accuracy: 0.9474 - val_loss: 0.1670
# Epoch 11/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9479 - loss: 0.1791 - val_accuracy: 0.9482 - val_loss: 0.1676
# Epoch 12/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9453 - loss: 0.1864 - val_accuracy: 0.9477 - val_loss: 0.1674
# Epoch 13/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9421 - loss: 0.1897 - val_accuracy: 0.9474 - val_loss: 0.1673
# Epoch 14/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9512 - loss: 0.1666 - val_accuracy: 0.9477 - val_loss: 0.1667
# Epoch 15/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9483 - loss: 0.1730 - val_accuracy: 0.9482 - val_loss: 0.1668
# Epoch 16/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9494 - loss: 0.1733 - val_accuracy: 0.9461 - val_loss: 0.1679
# Epoch 17/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9497 - loss: 0.1733 - val_accuracy: 0.9474 - val_loss: 0.1669
# Epoch 18/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9459 - loss: 0.1839 - val_accuracy: 0.9479 - val_loss: 0.1664
# Epoch 19/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9490 - loss: 0.1757 - val_accuracy: 0.9479 - val_loss: 0.1660
# Epoch 20/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9451 - loss: 0.1780 - val_accuracy: 0.9474 - val_loss: 0.1661
# Score for fold 2: loss of 0.1661105453968048; compile_metrics of 94.73958611488342%
# Training on fold 3...
# Epoch 1/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.8680 - loss: 0.4731 - val_accuracy: 0.9438 - val_loss: 0.1840
# Epoch 2/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9471 - loss: 0.1765 - val_accuracy: 0.9427 - val_loss: 0.1843
# Epoch 3/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9507 - loss: 0.1653 - val_accuracy: 0.9435 - val_loss: 0.1829
# Epoch 4/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9448 - loss: 0.1830 - val_accuracy: 0.9443 - val_loss: 0.1846
# Epoch 5/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9454 - loss: 0.1810 - val_accuracy: 0.9451 - val_loss: 0.1827
# Epoch 6/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9500 - loss: 0.1677 - val_accuracy: 0.9438 - val_loss: 0.1838
# Epoch 7/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9468 - loss: 0.1802 - val_accuracy: 0.9445 - val_loss: 0.1822
# Epoch 8/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9466 - loss: 0.1781 - val_accuracy: 0.9438 - val_loss: 0.1829
# Epoch 9/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9459 - loss: 0.1811 - val_accuracy: 0.9445 - val_loss: 0.1835
# Epoch 10/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9509 - loss: 0.1698 - val_accuracy: 0.9461 - val_loss: 0.1822
# Epoch 11/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9492 - loss: 0.1754 - val_accuracy: 0.9443 - val_loss: 0.1822
# Epoch 12/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9460 - loss: 0.1802 - val_accuracy: 0.9445 - val_loss: 0.1826
# Epoch 13/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9484 - loss: 0.1716 - val_accuracy: 0.9440 - val_loss: 0.1813
# Epoch 14/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9468 - loss: 0.1811 - val_accuracy: 0.9445 - val_loss: 0.1819
# Epoch 15/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9489 - loss: 0.1703 - val_accuracy: 0.9432 - val_loss: 0.1815
# Epoch 16/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9480 - loss: 0.1739 - val_accuracy: 0.9432 - val_loss: 0.1812
# Epoch 17/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9463 - loss: 0.1769 - val_accuracy: 0.9443 - val_loss: 0.1817
# Epoch 18/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9525 - loss: 0.1670 - val_accuracy: 0.9445 - val_loss: 0.1809
# Epoch 19/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9490 - loss: 0.1680 - val_accuracy: 0.9435 - val_loss: 0.1811
# Epoch 20/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9453 - loss: 0.1840 - val_accuracy: 0.9445 - val_loss: 0.1822
# Score for fold 3: loss of 0.1822149008512497; compile_metrics of 94.4531261920929%
# Training on fold 4...
# Epoch 1/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9032 - loss: 0.4290 - val_accuracy: 0.9464 - val_loss: 0.1802
# Epoch 2/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9449 - loss: 0.1883 - val_accuracy: 0.9477 - val_loss: 0.1774
# Epoch 3/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9478 - loss: 0.1824 - val_accuracy: 0.9479 - val_loss: 0.1766
# Epoch 4/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9443 - loss: 0.1871 - val_accuracy: 0.9477 - val_loss: 0.1776
# Epoch 5/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9464 - loss: 0.1802 - val_accuracy: 0.9479 - val_loss: 0.1758
# Epoch 6/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9492 - loss: 0.1747 - val_accuracy: 0.9497 - val_loss: 0.1759
# Epoch 7/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9488 - loss: 0.1734 - val_accuracy: 0.9492 - val_loss: 0.1764
# Epoch 8/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9474 - loss: 0.1744 - val_accuracy: 0.9497 - val_loss: 0.1755
# Epoch 9/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9466 - loss: 0.1807 - val_accuracy: 0.9497 - val_loss: 0.1769
# Epoch 10/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9501 - loss: 0.1756 - val_accuracy: 0.9482 - val_loss: 0.1756
# Epoch 11/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9486 - loss: 0.1733 - val_accuracy: 0.9505 - val_loss: 0.1753
# Epoch 12/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9487 - loss: 0.1752 - val_accuracy: 0.9487 - val_loss: 0.1751
# Epoch 13/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9463 - loss: 0.1775 - val_accuracy: 0.9482 - val_loss: 0.1757
# Epoch 14/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9435 - loss: 0.1916 - val_accuracy: 0.9487 - val_loss: 0.1769
# Epoch 15/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9472 - loss: 0.1794 - val_accuracy: 0.9484 - val_loss: 0.1749
# Epoch 16/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9465 - loss: 0.1777 - val_accuracy: 0.9497 - val_loss: 0.1748
# Epoch 17/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9480 - loss: 0.1720 - val_accuracy: 0.9508 - val_loss: 0.1753
# Epoch 18/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9487 - loss: 0.1814 - val_accuracy: 0.9505 - val_loss: 0.1768
# Epoch 19/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9480 - loss: 0.1805 - val_accuracy: 0.9497 - val_loss: 0.1752
# Epoch 20/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9461 - loss: 0.1799 - val_accuracy: 0.9500 - val_loss: 0.1748
# Score for fold 4: loss of 0.17484290897846222; compile_metrics of 94.9999988079071%
# Training on fold 5...
# Epoch 1/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9191 - loss: 0.4221 - val_accuracy: 0.9492 - val_loss: 0.1829
# Epoch 2/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9507 - loss: 0.1752 - val_accuracy: 0.9492 - val_loss: 0.1818
# Epoch 3/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9450 - loss: 0.1807 - val_accuracy: 0.9502 - val_loss: 0.1816
# Epoch 4/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9441 - loss: 0.1836 - val_accuracy: 0.9479 - val_loss: 0.1827
# Epoch 5/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9443 - loss: 0.1850 - val_accuracy: 0.9479 - val_loss: 0.1812
# Epoch 6/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9494 - loss: 0.1742 - val_accuracy: 0.9482 - val_loss: 0.1810
# Epoch 7/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9476 - loss: 0.1772 - val_accuracy: 0.9489 - val_loss: 0.1794
# Epoch 8/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9450 - loss: 0.1786 - val_accuracy: 0.9476 - val_loss: 0.1801
# Epoch 9/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9456 - loss: 0.1748 - val_accuracy: 0.9479 - val_loss: 0.1796
# Epoch 10/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9455 - loss: 0.1808 - val_accuracy: 0.9479 - val_loss: 0.1820
# Epoch 11/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9463 - loss: 0.1842 - val_accuracy: 0.9479 - val_loss: 0.1787
# Epoch 12/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9492 - loss: 0.1754 - val_accuracy: 0.9476 - val_loss: 0.1792
# Epoch 13/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9496 - loss: 0.1711 - val_accuracy: 0.9484 - val_loss: 0.1788
# Epoch 14/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9480 - loss: 0.1701 - val_accuracy: 0.9474 - val_loss: 0.1783
# Epoch 15/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9475 - loss: 0.1744 - val_accuracy: 0.9482 - val_loss: 0.1790
# Epoch 16/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9529 - loss: 0.1663 - val_accuracy: 0.9474 - val_loss: 0.1788
# Epoch 17/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9457 - loss: 0.1719 - val_accuracy: 0.9476 - val_loss: 0.1772
# Epoch 18/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9524 - loss: 0.1671 - val_accuracy: 0.9474 - val_loss: 0.1781
# Epoch 19/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9451 - loss: 0.1813 - val_accuracy: 0.9482 - val_loss: 0.1772
# Epoch 20/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9493 - loss: 0.1711 - val_accuracy: 0.9474 - val_loss: 0.1773
# Score for fold 5: loss of 0.17728492617607117; compile_metrics of 94.73821520805359%
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.17201295495033264 - Accuracy: 94.8437511920929%
# > Fold 2 - Loss: 0.1661105453968048 - Accuracy: 94.73958611488342%
# > Fold 3 - Loss: 0.1822149008512497 - Accuracy: 94.4531261920929%
# > Fold 4 - Loss: 0.17484290897846222 - Accuracy: 94.9999988079071%
# > Fold 5 - Loss: 0.17728492617607117 - Accuracy: 94.73821520805359%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 94.75493550300598 (+- 0.17863274177479777)
# > Loss: 0.1744932472705841
# ------------------------------------------------------------------------

# %%
# Function to plot k-fold histories
def plot_kfold_histories(histories):
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    
    for fold, history in enumerate(histories, start=1):
        axes[0].plot(history.history['accuracy'], label=f'Train Fold {fold}')
        axes[0].plot(history.history['val_accuracy'], label=f'Val Fold {fold}', linestyle="--")
        axes[1].plot(history.history['loss'], label=f'Train Fold {fold}')
        axes[1].plot(history.history['val_loss'], label=f'Val Fold {fold}', linestyle="--")
    
    axes[0].set_title('Model Accuracy')
    axes[0].set_ylabel('Accuracy')
    axes[0].set_xlabel('Epoch')
    axes[0].legend()
    
    axes[1].set_title('Model Loss')
    axes[1].set_ylabel('Loss')
    axes[1].set_xlabel('Epoch')
    axes[1].legend()
    
    plt.show()
    
    
# Plot the histories
plot_kfold_histories(all_histories)
