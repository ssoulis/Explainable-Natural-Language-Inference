# %%
import pandas as pd

# Load the SNLI test data (including true labels)
snli_test_path = "/kaggle/input/stanford-natural-language-inference-corpus/snli_1.0_test.csv"
snli_test_df = pd.read_csv(snli_test_path)

# Define file paths for SNLI prediction files
snli_predictions_paths = {
    "deberta": "/kaggle/input/deberta-nli/deberta_snli_predictions.csv",
    "roberta": "/kaggle/input/roberta/roberta_snli_predictions.csv",
    "albert": "/kaggle/input/albert/albert_snli_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_snli = "/kaggle/working/combined_snli_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_snli_df = pd.DataFrame(columns=columns)

label_mapping = {'entailment': 0, 'neutral': 1, 'contradiction': 2}

# Load and merge the predictions
for model, path in snli_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_snli_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_snli_df['True_Label'] = snli_test_df['gold_label'].map(label_mapping)

# Convert True_Label to integer type
combined_snli_df['True_Label'] = combined_snli_df['True_Label'].astype('Int64')

# Save the combined DataFrame to CSV
combined_snli_df.to_csv(output_csv_path_snli, index=False)

print(f"Combined SNLI predictions with true labels saved to {output_csv_path_snli}")
# Out:
# Combined SNLI predictions with true labels saved to /kaggle/working/combined_snli_df

# %%
combined_snli_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.034767         0.962592               0.002641
# 1            0.001921         0.319032               0.679047
# 2            0.998783         0.000764               0.000453
# 3            0.001001         0.997708               0.001291
# 4            0.001080         0.301363               0.697557
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.012451         0.927093               0.060457
# 1            0.752766         0.242251               0.004983
# 2            0.000254         0.004494               0.995253
# 3            0.005844         0.990736               0.003419
# 4            0.278348         0.718575               0.003076
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.008653        0.947434              0.043913           1
# 1           0.740332        0.256434              0.003235           0
# 2           0.004677        0.060481              0.934843           2
# 3           0.034056        0.956687              0.009257           1
# 4           0.498761        0.499270              0.001969           0

# %%
# Load the ANLI Round 1 test data (including true labels)
mnli_matched_test_path = "/kaggle/input/nli-dataset-for-sentence-understanding/mnli_validation_matched.csv"
mnli_matched_test_df = pd.read_csv(mnli_matched_test_path)

# Define file paths for ANLI Round 1 prediction files
mnli_matched_predictions_paths = {
    "deberta": "/kaggle/input/validation/deberta_mnli_matched_val_predictions.csv",
    "roberta": "/kaggle/input/validation/roberta_mnli_matched_val_predictions.csv",
    "albert": "/kaggle/input/validation/albert_mnli_matched_val_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_mnli_matched = "/kaggle/working/combined_mnli_matched_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_mnli_matched_df = pd.DataFrame(columns=columns)

# Load and merge the predictions
for model, path in mnli_matched_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_mnli_matched_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_mnli_matched_df['True_Label'] = mnli_matched_test_df['label']

# Save the combined DataFrame to CSV
combined_mnli_matched_df.to_csv(output_csv_path_mnli_matched, index=False)

print(f"Combined MNLI-matched predictions with true labels saved to {output_csv_path_mnli_matched}")
# Out:
# Combined MNLI-matched predictions with true labels saved to /kaggle/working/combined_mnli_matched_df

# %%
combined_mnli_matched_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.005164         0.993364               0.001472
# 1            0.999153         0.000526               0.000321
# 2            0.000989         0.044792               0.954219
# 3            0.994965         0.004808               0.000228
# 4            0.999657         0.000220               0.000123
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.017844         0.950246               0.031909
# 1            0.001413         0.002030               0.996557
# 2            0.954781         0.042249               0.002970
# 3            0.000343         0.003511               0.996146
# 4            0.000079         0.000496               0.999425
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.010844        0.983012              0.006144           1
# 1           0.005388        0.007536              0.987076           2
# 2           0.853862        0.143483              0.002655           0
# 3           0.004128        0.070757              0.925115           2
# 4           0.003864        0.029262              0.966875           2

# %%
# Load the ANLI Round 1 test data (including true labels)
mnli_mismatched_test_path = "/kaggle/input/nli-dataset-for-sentence-understanding/mnli_validation_mismatched.csv"
mnli_mismatched_test_df = pd.read_csv(mnli_mismatched_test_path)

# Define file paths for ANLI Round 1 prediction files
mnli_mismatched_predictions_paths = {
    "deberta": "/kaggle/input/validation/deberta_mnli_mismatched_val_predictions.csv",
    "roberta": "/kaggle/input/validation/roberta_mnli_mismatched_val_predictions.csv",
    "albert": "/kaggle/input/validation/albert_mnli_mismatched_val_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_mnli_mismatched = "/kaggle/working/combined_mnli_mismatched_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_mnli_mismatched_df = pd.DataFrame(columns=columns)

# Load and merge the predictions
for model, path in mnli_mismatched_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_mnli_mismatched_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_mnli_mismatched_df['True_Label'] = mnli_mismatched_test_df['label']

# Save the combined DataFrame to CSV
combined_mnli_mismatched_df.to_csv(output_csv_path_mnli_mismatched, index=False)

print(f"Combined MNLI-mismatched predictions with true labels saved to {output_csv_path_mnli_mismatched}")
# Out:
# Combined MNLI-mismatched predictions with true labels saved to /kaggle/working/combined_mnli_mismatched_df

# %%
combined_mnli_mismatched_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.999667         0.000160               0.000173
# 1            0.998119         0.000962               0.000919
# 2            0.000552         0.004809               0.994639
# 3            0.827653         0.171961               0.000386
# 4            0.000292         0.002875               0.996833
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.000068         0.000402               0.999529
# 1            0.000183         0.001511               0.998306
# 2            0.986062         0.012020               0.001918
# 3            0.000478         0.270953               0.728569
# 4            0.975167         0.021904               0.002929
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.000894        0.003787              0.995318           2
# 1           0.006421        0.010224              0.983355           2
# 2           0.975041        0.023354              0.001605           0
# 3           0.001722        0.796122              0.202156           2
# 4           0.965952        0.032748              0.001300           0

# %%
# Load the ANLI Round 1 test data (including true labels)
anli_r1_test_path = "/kaggle/input/anli-a-large-scale-nli-benchmark-dataset/test_r1.csv"
anli_r1_test_df = pd.read_csv(anli_r1_test_path)

# Define file paths for ANLI Round 1 prediction files
anli_r1_predictions_paths = {
    "deberta": "/kaggle/input/deberta-nli/deberta_anli_r1_predictions.csv",
    "roberta": "/kaggle/input/roberta/roberta_anli_r1_predictions.csv",
    "albert": "/kaggle/input/albert/albert_anli_r1_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_anli_r1 = "/kaggle/working/combined_anli_r1_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_anli_r1_df = pd.DataFrame(columns=columns)

# Load and merge the predictions
for model, path in anli_r1_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_anli_r1_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_anli_r1_df['True_Label'] = anli_r1_test_df['label']

# Save the combined DataFrame to CSV
combined_anli_r1_df.to_csv(output_csv_path_anli_r1, index=False)

print(f"Combined ANLI Round 1 predictions with true labels saved to {output_csv_path_anli_r1}")
# Out:
# Combined ANLI Round 1 predictions with true labels saved to /kaggle/working/combined_anli_r1_df

# %%
combined_anli_r1_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.015388         0.976305               0.008307
# 1            0.224603         0.501549               0.273848
# 2            0.006642         0.976690               0.016669
# 3            0.966494         0.032235               0.001272
# 4            0.880736         0.028293               0.090971
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.996714         0.000376               0.002910
# 1            0.875720         0.000724               0.123556
# 2            0.999484         0.000330               0.000186
# 3            0.000686         0.998181               0.001133
# 4            0.000378         0.000197               0.999425
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.322974        0.667628              0.009398           0
# 1           0.998526        0.000604              0.000869           0
# 2           0.783352        0.212241              0.004407           0
# 3           0.002134        0.989523              0.008343           1
# 4           0.023283        0.013253              0.963464           2

# %%
# Load the ANLI Round 2 test data (including true labels)
anli_r2_test_path = "/kaggle/input/anli-a-large-scale-nli-benchmark-dataset/test_r2.csv"
anli_r2_test_df = pd.read_csv(anli_r2_test_path)

# Define file paths for ANLI Round 2 prediction files
anli_r2_predictions_paths = {
    "deberta": "/kaggle/input/deberta-nli/deberta_anli_r2_predictions.csv",
    "roberta": "/kaggle/input/roberta/roberta_anli_r2_predictions.csv",
    "albert": "/kaggle/input/albert/albert_anli_r2_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_anli_r2 = "/kaggle/working/combined_anli_r2_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_anli_r2_df = pd.DataFrame(columns=columns)

# Load and merge the predictions
for model, path in anli_r2_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_anli_r2_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_anli_r2_df['True_Label'] = anli_r2_test_df['label']

# Save the combined DataFrame to CSV
combined_anli_r2_df.to_csv(output_csv_path_anli_r2, index=False)

print(f"Combined ANLI Round 2 predictions with true labels saved to {output_csv_path_anli_r2}")
# Out:
# Combined ANLI Round 2 predictions with true labels saved to /kaggle/working/combined_anli_r2_df

# %%
combined_anli_r2_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.001309         0.029617               0.969075
# 1            0.724144         0.273676               0.002180
# 2            0.071604         0.917894               0.010503
# 3            0.066162         0.929179               0.004659
# 4            0.906199         0.089873               0.003928
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.999506         0.000264               0.000230
# 1            0.026951         0.054230               0.918819
# 2            0.001282         0.998108               0.000610
# 3            0.007091         0.992694               0.000215
# 4            0.006259         0.989432               0.004309
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.863365        0.133388              0.003246           0
# 1           0.072900        0.904344              0.022756           1
# 2           0.027402        0.972218              0.000380           0
# 3           0.632171        0.365194              0.002635           1
# 4           0.064109        0.234642              0.701249           2

# %%
# Load the ANLI Round 3 test data (including true labels)
anli_r3_test_path = "/kaggle/input/anli-a-large-scale-nli-benchmark-dataset/test_r3.csv"
anli_r3_test_df = pd.read_csv(anli_r3_test_path)

# Define file paths for ANLI Round 2 prediction files
anli_r3_predictions_paths = {
    "deberta": "/kaggle/input/deberta-nli/deberta_anli_r3_predictions.csv",
    "roberta": "/kaggle/input/roberta/roberta_anli_r3_predictions.csv",
    "albert": "/kaggle/input/albert/albert_anli_r3_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_anli_r3 = "/kaggle/working/combined_anli_r3_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_anli_r3_df = pd.DataFrame(columns=columns)

# Load and merge the predictions
for model, path in anli_r3_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_anli_r3_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_anli_r3_df['True_Label'] = anli_r3_test_df['label']

# Save the combined DataFrame to CSV
combined_anli_r3_df.to_csv(output_csv_path_anli_r3, index=False)

print(f"Combined ANLI Round 3 predictions with true labels saved to {output_csv_path_anli_r3}")
# Out:
# Combined ANLI Round 3 predictions with true labels saved to /kaggle/working/combined_anli_r3_df

# %%
combined_anli_r3_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.005921         0.960529               0.033551
# 1            0.009586         0.934714               0.055700
# 2            0.003428         0.976393               0.020179
# 3            0.004633         0.023985               0.971382
# 4            0.017428         0.633695               0.348877
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.022959         0.976533               0.000509
# 1            0.999611         0.000205               0.000185
# 2            0.002020         0.997897               0.000083
# 3            0.974441         0.024459               0.001100
# 4            0.984416         0.011166               0.004419
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.001848        0.998084              0.000067           0
# 1           0.951772        0.048075              0.000153           0
# 2           0.001014        0.998984              0.000002           0
# 3           0.996749        0.000989              0.002262           0
# 4           0.000518        0.128416              0.871066           0

# %%
# Check for missing values
missing_values_anli1 = combined_anli_r1_df.isnull().sum()

missing_values_anli2 = combined_anli_r2_df.isnull().sum()

missing_values_anli3 = combined_anli_r3_df.isnull().sum()

missing_values_snli = combined_snli_df.isnull().sum()

missing_values_mnli_matched = combined_mnli_matched_df.isnull().sum()

missing_values_mnli_mismatched = combined_mnli_mismatched_df.isnull().sum()

# %%
missing_values_anli1
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
missing_values_anli2
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
missing_values_anli3
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
missing_values_snli
# Out:
# Deberta_Entailment         0
# Deberta_Neutral            0
# Deberta_Contradiction      0
# Roberta_Entailment         0
# Roberta_Neutral            0
# Roberta_Contradiction      0
# Albert_Entailment          0
# Albert_Neutral             0
# Albert_Contradiction       0
# True_Label               176
# dtype: int64

# %%
missing_values_mnli_matched
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
missing_values_mnli_mismatched
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
combined_snli_df.dropna(subset=['True_Label'], inplace=True)

# %%
# Verify missing values again after removal
missing_values_snli_after_removal = combined_snli_df.isnull().sum()
print(missing_values_snli_after_removal)
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
combined_snli_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9824 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Deberta_Entailment     9824 non-null   float64
#  1   Deberta_Neutral        9824 non-null   float64
#  2   Deberta_Contradiction  9824 non-null   float64
#  3   Roberta_Entailment     9824 non-null   float64
#  4   Roberta_Neutral        9824 non-null   float64
#  5   Roberta_Contradiction  9824 non-null   float64
#  6   Albert_Entailment      9824 non-null   float64
#  7   Albert_Neutral         9824 non-null   float64
#  8   Albert_Contradiction   9824 non-null   float64
#  9   True_Label             9824 non-null   Int64
# dtypes: Int64(1), float64(9)
# memory usage: 853.8 KB

# %%
combined_snli_df
# Out:
#       Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0               0.034767         0.962592               0.002641
# 1               0.001921         0.319032               0.679047
# 2               0.998783         0.000764               0.000453
# 3               0.001001         0.997708               0.001291
# 4               0.001080         0.301363               0.697557
# ...                  ...              ...                    ...
# 9995            0.998825         0.001033               0.000142
# 9996            0.000704         0.009793               0.989503
# 9997            0.999171         0.000493               0.000336
# 9998            0.000267         0.002178               0.997556
# 9999            0.003641         0.995224               0.001135
#
#       Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0               0.012451         0.927093               0.060457
# 1               0.752766         0.242251               0.004983
# 2               0.000254         0.004494               0.995253
# 3               0.005844         0.990736               0.003419
# 4               0.278348         0.718575               0.003076
# ...                  ...              ...                    ...
# 9995            0.001264         0.028942               0.969794
# 9996            0.780946         0.217053               0.002001
# 9997            0.000054         0.000765               0.999181
# 9998            0.983402         0.015884               0.000714
# 9999            0.000904         0.995495               0.003601
#
#       Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0              0.008653        0.947434              0.043913           1
# 1              0.740332        0.256434              0.003235           0
# 2              0.004677        0.060481              0.934843           2
# 3              0.034056        0.956687              0.009257           1
# 4              0.498761        0.499270              0.001969           0
# ...                 ...             ...                   ...         ...
# 9995           0.006420        0.057240              0.936340           2
# 9996           0.894637        0.104095              0.001267           0
# 9997           0.000838        0.002670              0.996493           2
# 9998           0.984347        0.015223              0.000430           0
# 9999           0.005047        0.990218              0.004735           1
#
# [9824 rows x 10 columns]

# %%
import numpy as np

def calculate_margin(row):
    # Assuming the row only contains the probabilities
    sorted_probs = np.sort(row)  # Sort probabilities in ascending order
    if len(sorted_probs) > 1:
        return sorted_probs[-1] - sorted_probs[-2]  # Difference between the highest and second highest
    else:
        return 0  # This handles the edge case where there is only one probability value

# %%
# Applying to a sample DataFrame with made-up column names
combined_snli_df['confidence_margin_entailment'] = combined_snli_df[['Deberta_Entailment', 'Roberta_Entailment', 'Albert_Entailment']].apply(calculate_margin, axis=1)
combined_snli_df['confidence_margin_neutral'] = combined_snli_df[['Deberta_Neutral', 'Roberta_Neutral', 'Albert_Neutral']].apply(calculate_margin, axis=1)
combined_snli_df['confidence_margin_contradiction'] = combined_snli_df[['Deberta_Contradiction', 'Roberta_Contradiction', 'Albert_Contradiction']].apply(calculate_margin, axis=1)


# Applying to a sample DataFrame with made-up column names
combined_mnli_matched_df['confidence_margin_entailment'] = combined_mnli_matched_df[['Deberta_Entailment', 'Roberta_Entailment', 'Albert_Entailment']].apply(calculate_margin, axis=1)
combined_mnli_matched_df['confidence_margin_neutral'] = combined_mnli_matched_df[['Deberta_Neutral', 'Roberta_Neutral', 'Albert_Neutral']].apply(calculate_margin, axis=1)
combined_mnli_matched_df['confidence_margin_contradiction'] = combined_mnli_matched_df[['Deberta_Contradiction', 'Roberta_Contradiction', 'Albert_Contradiction']].apply(calculate_margin, axis=1)

# Applying to a sample DataFrame with made-up column names
combined_mnli_mismatched_df['confidence_margin_entailment'] = combined_mnli_mismatched_df[['Deberta_Entailment', 'Roberta_Entailment', 'Albert_Entailment']].apply(calculate_margin, axis=1)
combined_mnli_mismatched_df['confidence_margin_neutral'] = combined_mnli_mismatched_df[['Deberta_Neutral', 'Roberta_Neutral', 'Albert_Neutral']].apply(calculate_margin, axis=1)
combined_mnli_mismatched_df['confidence_margin_contradiction'] = combined_mnli_mismatched_df[['Deberta_Contradiction', 'Roberta_Contradiction', 'Albert_Contradiction']].apply(calculate_margin, axis=1)

# Applying to a sample DataFrame with made-up column names
combined_anli_r1_df['confidence_margin_entailment'] = combined_anli_r1_df[['Deberta_Entailment', 'Roberta_Entailment', 'Albert_Entailment']].apply(calculate_margin, axis=1)
combined_anli_r1_df['confidence_margin_neutral'] = combined_anli_r1_df[['Deberta_Neutral', 'Roberta_Neutral', 'Albert_Neutral']].apply(calculate_margin, axis=1)
combined_anli_r1_df['confidence_margin_contradiction'] = combined_anli_r1_df[['Deberta_Contradiction', 'Roberta_Contradiction', 'Albert_Contradiction']].apply(calculate_margin, axis=1)


# Applying to a sample DataFrame with made-up column names
combined_anli_r2_df['confidence_margin_entailment'] = combined_anli_r2_df[['Deberta_Entailment', 'Roberta_Entailment', 'Albert_Entailment']].apply(calculate_margin, axis=1)
combined_anli_r2_df['confidence_margin_neutral'] = combined_anli_r2_df[['Deberta_Neutral', 'Roberta_Neutral', 'Albert_Neutral']].apply(calculate_margin, axis=1)
combined_anli_r2_df['confidence_margin_contradiction'] = combined_anli_r2_df[['Deberta_Contradiction', 'Roberta_Contradiction', 'Albert_Contradiction']].apply(calculate_margin, axis=1)


# Applying to a sample DataFrame with made-up column names
combined_anli_r3_df['confidence_margin_entailment'] = combined_anli_r3_df[['Deberta_Entailment', 'Roberta_Entailment', 'Albert_Entailment']].apply(calculate_margin, axis=1)
combined_anli_r3_df['confidence_margin_neutral'] = combined_anli_r3_df[['Deberta_Neutral', 'Roberta_Neutral', 'Albert_Neutral']].apply(calculate_margin, axis=1)
combined_anli_r3_df['confidence_margin_contradiction'] = combined_anli_r3_df[['Deberta_Contradiction', 'Roberta_Contradiction', 'Albert_Contradiction']].apply(calculate_margin, axis=1)

# %%
combined_anli_r3_df
# Out:
#       Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0               0.005921         0.960529               0.033551
# 1               0.009586         0.934714               0.055700
# 2               0.003428         0.976393               0.020179
# 3               0.004633         0.023985               0.971382
# 4               0.017428         0.633695               0.348877
# ...                  ...              ...                    ...
# 1195            0.150312         0.806051               0.043637
# 1196            0.971834         0.026294               0.001872
# 1197            0.973818         0.025074               0.001109
# 1198            0.341781         0.226539               0.431681
# 1199            0.472737         0.477215               0.050049
#
#       Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0               0.022959         0.976533               0.000509
# 1               0.999611         0.000205               0.000185
# 2               0.002020         0.997897               0.000083
# 3               0.974441         0.024459               0.001100
# 4               0.984416         0.011166               0.004419
# ...                  ...              ...                    ...
# 1195            0.032452         0.068553               0.898994
# 1196            0.009070         0.824654               0.166276
# 1197            0.000352         0.000972               0.998677
# 1198            0.006147         0.073669               0.920184
# 1199            0.000420         0.991832               0.007748
#
#       Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label  \
# 0              0.001848        0.998084              0.000067           0
# 1              0.951772        0.048075              0.000153           0
# 2              0.001014        0.998984              0.000002           0
# 3              0.996749        0.000989              0.002262           0
# 4              0.000518        0.128416              0.871066           0
# ...                 ...             ...                   ...         ...
# 1195           0.122045        0.254093              0.623862           2
# 1196           0.001115        0.003229              0.995656           2
# 1197           0.310862        0.618914              0.070225           2
# 1198           0.054172        0.317935              0.627893           2
# 1199           0.015091        0.121354              0.863554           2
#
#       confidence_margin_entailment  confidence_margin_neutral  \
# 0                         0.017038                   0.021552
# 1                         0.047839                   0.886640
# 2                         0.001408                   0.001087
# 3                         0.022308                   0.000474
# 4                         0.966988                   0.505279
# ...                            ...                        ...
# 1195                      0.028268                   0.551958
# 1196                      0.962764                   0.798360
# 1197                      0.662956                   0.593840
# 1198                      0.287609                   0.091397
# 1199                      0.457646                   0.514617
#
#       confidence_margin_contradiction
# 0                            0.033042
# 1                            0.055515
# 2                            0.020096
# 3                            0.969120
# 4                            0.522189
# ...                               ...
# 1195                         0.275132
# 1196                         0.829379
# 1197                         0.928452
# 1198                         0.292291
# 1199                         0.813506
#
# [1200 rows x 13 columns]

# %%
import matplotlib.pyplot as plt

# Plot histograms for the confidence margins
def plot_confidence_margins(df):
    plt.figure(figsize=(15, 5))
    plt.subplot(1, 3, 1)
    plt.hist(df['confidence_margin_entailment'], bins=50, alpha=0.75, label='Entailment')
    plt.title('Confidence Margin Histogram - Entailment')
    plt.xlabel('Margin')
    plt.ylabel('Frequency')
    
    plt.subplot(1, 3, 2)
    plt.hist(df['confidence_margin_neutral'], bins=50, alpha=0.75, label='Neutral', color='green')
    plt.title('Confidence Margin Histogram - Neutral')
    plt.xlabel('Margin')
    plt.ylabel('Frequency')
    
    plt.subplot(1, 3, 3)
    plt.hist(df['confidence_margin_contradiction'], bins=50, alpha=0.75, label='Contradiction', color='red')
    plt.title('Confidence Margin Histogram - Contradiction')
    plt.xlabel('Margin')
    plt.ylabel('Frequency')
    
    plt.tight_layout()
    plt.show()

plot_confidence_margins(combined_snli_df)

# %%
# Define thresholds based on the distribution
confidence_threshold = 0.8

# Apply threshold and create a new copy of the DataFrame
high_confidence_snli = combined_snli_df[
    (combined_snli_df['confidence_margin_entailment'] >= confidence_threshold) | 
    (combined_snli_df['confidence_margin_neutral'] >= confidence_threshold) |
    (combined_snli_df['confidence_margin_contradiction'] >= confidence_threshold)
].copy()


# Apply threshold and create a new copy of the DataFrame
high_confidence_mnli_matched = combined_mnli_matched_df[
    (combined_mnli_matched_df['confidence_margin_entailment'] >= confidence_threshold) | 
    (combined_mnli_matched_df['confidence_margin_neutral'] >= confidence_threshold) |
    (combined_mnli_matched_df['confidence_margin_contradiction'] >= confidence_threshold)
].copy()

# Apply threshold and create a new copy of the DataFrame
high_confidence_mnli_mismatched = combined_mnli_mismatched_df[
    (combined_mnli_mismatched_df['confidence_margin_entailment'] >= confidence_threshold) | 
    (combined_mnli_mismatched_df['confidence_margin_neutral'] >= confidence_threshold) |
    (combined_mnli_mismatched_df['confidence_margin_contradiction'] >= confidence_threshold)
].copy()

# Filter high confidence samples for ANLI round 1
high_confidence_anli_r1 = combined_anli_r1_df[
    (combined_anli_r1_df['confidence_margin_entailment'] >= confidence_threshold) | 
    (combined_anli_r1_df['confidence_margin_neutral'] >= confidence_threshold) |
    (combined_anli_r1_df['confidence_margin_contradiction'] >= confidence_threshold)
].copy()

# Filter high confidence samples for ANLI round 2
high_confidence_anli_r2 = combined_anli_r2_df[
    (combined_anli_r2_df['confidence_margin_entailment'] >= confidence_threshold) | 
    (combined_anli_r2_df['confidence_margin_neutral'] >= confidence_threshold) |
    (combined_anli_r2_df['confidence_margin_contradiction'] >= confidence_threshold)
].copy()

# Filter high confidence samples for ANLI round 3
high_confidence_anli_r3 = combined_anli_r3_df[
    (combined_anli_r3_df['confidence_margin_entailment'] >= confidence_threshold) | 
    (combined_anli_r3_df['confidence_margin_neutral'] >= confidence_threshold) |
    (combined_anli_r3_df['confidence_margin_contradiction'] >= confidence_threshold)
].copy()

# %%
# Majority vote logic with weights for numeric labels
def majority_vote_with_threshold(row):
    votes = [0, 0, 0]  # Index 0 for entailment, 1 for neutral, 2 for contradiction
    if row['confidence_margin_entailment'] >= confidence_threshold:
        votes[0] += row['confidence_margin_entailment']
    if row['confidence_margin_neutral'] >= confidence_threshold:
        votes[1] += row['confidence_margin_neutral']
    if row['confidence_margin_contradiction'] >= confidence_threshold:
        votes[2] += row['confidence_margin_contradiction']
    
    # Return the index of the highest vote
    return np.argmax(votes)

# Apply the majority vote logic using .loc
high_confidence_snli.loc[:, 'majority_vote'] = high_confidence_snli.apply(majority_vote_with_threshold, axis=1)
# Apply the majority vote logic using .loc
high_confidence_mnli_matched.loc[:, 'majority_vote'] = high_confidence_mnli_matched.apply(majority_vote_with_threshold, axis=1)
# Apply majority vote logic
high_confidence_mnli_mismatched.loc[:, 'majority_vote'] = high_confidence_mnli_mismatched.apply(majority_vote_with_threshold, axis=1)
# Apply majority vote logic
high_confidence_anli_r1.loc[:, 'majority_vote'] = high_confidence_anli_r1.apply(majority_vote_with_threshold, axis=1)
# Apply majority vote logic
high_confidence_anli_r2.loc[:, 'majority_vote'] = high_confidence_anli_r2.apply(majority_vote_with_threshold, axis=1)
# Apply majority vote logic
high_confidence_anli_r3.loc[:, 'majority_vote'] = high_confidence_anli_r3.apply(majority_vote_with_threshold, axis=1)

# %%
high_confidence_anli_r3
# Out:
#       Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 1               0.009586         0.934714               0.055700
# 3               0.004633         0.023985               0.971382
# 4               0.017428         0.633695               0.348877
# 5               0.002461         0.150678               0.846861
# 8               0.131793         0.776056               0.092151
# ...                  ...              ...                    ...
# 1193            0.957103         0.040533               0.002363
# 1194            0.945850         0.052813               0.001337
# 1196            0.971834         0.026294               0.001872
# 1197            0.973818         0.025074               0.001109
# 1199            0.472737         0.477215               0.050049
#
#       Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 1               0.999611         0.000205               0.000185
# 3               0.974441         0.024459               0.001100
# 4               0.984416         0.011166               0.004419
# 5               0.999220         0.000554               0.000227
# 8               0.000384         0.002570               0.997046
# ...                  ...              ...                    ...
# 1193            0.000066         0.000316               0.999618
# 1194            0.000607         0.000853               0.998540
# 1196            0.009070         0.824654               0.166276
# 1197            0.000352         0.000972               0.998677
# 1199            0.000420         0.991832               0.007748
#
#       Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label  \
# 1              0.951772        0.048075              0.000153           0
# 3              0.996749        0.000989              0.002262           0
# 4              0.000518        0.128416              0.871066           0
# 5              0.985221        0.014745              0.000034           0
# 8              0.049409        0.904356              0.046236           0
# ...                 ...             ...                   ...         ...
# 1193           0.009265        0.016116              0.974619           2
# 1194           0.000205        0.000291              0.999504           2
# 1196           0.001115        0.003229              0.995656           2
# 1197           0.310862        0.618914              0.070225           2
# 1199           0.015091        0.121354              0.863554           2
#
#       confidence_margin_entailment  confidence_margin_neutral  \
# 1                         0.047839                   0.886640
# 3                         0.022308                   0.000474
# 4                         0.966988                   0.505279
# 5                         0.013998                   0.135933
# 8                         0.082384                   0.128299
# ...                            ...                        ...
# 1193                      0.947838                   0.024417
# 1194                      0.945243                   0.051960
# 1196                      0.962764                   0.798360
# 1197                      0.662956                   0.593840
# 1199                      0.457646                   0.514617
#
#       confidence_margin_contradiction  majority_vote
# 1                            0.055515              1
# 3                            0.969120              2
# 4                            0.522189              0
# 5                            0.846635              2
# 8                            0.904895              2
# ...                               ...            ...
# 1193                         0.024999              0
# 1194                         0.000965              0
# 1196                         0.829379              0
# 1197                         0.928452              2
# 1199                         0.813506              2
#
# [530 rows x 14 columns]

# %%
high_confidence_mnli_mismatched
# Out:
#       Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0               0.999667         0.000160               0.000173
# 1               0.998119         0.000962               0.000919
# 2               0.000552         0.004809               0.994639
# 3               0.827653         0.171961               0.000386
# 4               0.000292         0.002875               0.996833
# ...                  ...              ...                    ...
# 9824            0.000760         0.013837               0.985402
# 9825            0.000145         0.003906               0.995949
# 9826            0.996226         0.003656               0.000118
# 9828            0.997044         0.001226               0.001730
# 9829            0.999685         0.000112               0.000202
#
#       Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0               0.000068         0.000402               0.999529
# 1               0.000183         0.001511               0.998306
# 2               0.986062         0.012020               0.001918
# 3               0.000478         0.270953               0.728569
# 4               0.975167         0.021904               0.002929
# ...                  ...              ...                    ...
# 9824            0.972984         0.025382               0.001634
# 9825            0.952827         0.045891               0.001281
# 9826            0.000353         0.104717               0.894930
# 9828            0.000364         0.000717               0.998919
# 9829            0.000085         0.000289               0.999626
#
#       Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label  \
# 0              0.000894        0.003787              0.995318           2
# 1              0.006421        0.010224              0.983355           2
# 2              0.975041        0.023354              0.001605           0
# 3              0.001722        0.796122              0.202156           2
# 4              0.965952        0.032748              0.001300           0
# ...                 ...             ...                   ...         ...
# 9824           0.925212        0.069991              0.004798           0
# 9825           0.965645        0.032757              0.001598           0
# 9826           0.004991        0.039946              0.955062           2
# 9828           0.019078        0.039258              0.941663           2
# 9829           0.000420        0.001810              0.997770           2
#
#       confidence_margin_entailment  confidence_margin_neutral  \
# 0                         0.998773                   0.003385
# 1                         0.991698                   0.008714
# 2                         0.011021                   0.011334
# 3                         0.825931                   0.525168
# 4                         0.009215                   0.010844
# ...                            ...                        ...
# 9824                      0.047772                   0.044608
# 9825                      0.012818                   0.013134
# 9826                      0.991234                   0.064771
# 9828                      0.977966                   0.038033
# 9829                      0.999265                   0.001521
#
#       confidence_margin_contradiction  majority_vote
# 0                            0.004211              0
# 1                            0.014951              0
# 2                            0.992721              2
# 3                            0.526413              0
# 4                            0.993904              2
# ...                               ...            ...
# 9824                         0.980605              2
# 9825                         0.994351              2
# 9826                         0.060132              0
# 9828                         0.057256              0
# 9829                         0.001856              0
#
# [5910 rows x 14 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf



# Features and Labels
X_snli = high_confidence_snli.drop(['True_Label','confidence_margin_entailment','confidence_margin_neutral','confidence_margin_contradiction','majority_vote'], axis=1).values
y_snli = high_confidence_snli['True_Label'].values

# Features and Labels
X_mnli_matched = high_confidence_mnli_matched.drop(['True_Label','confidence_margin_entailment','confidence_margin_neutral','confidence_margin_contradiction','majority_vote'], axis=1).values
y_mnli_matched = high_confidence_mnli_matched['True_Label'].values

# Features and Labels
X_mnli_mismatched = high_confidence_mnli_mismatched.drop(['True_Label','confidence_margin_entailment','confidence_margin_neutral','confidence_margin_contradiction','majority_vote'], axis=1).values
y_mnli_mismatched = high_confidence_mnli_mismatched['True_Label'].values

# Features and Labels
X_anli_r1 = high_confidence_anli_r1.drop(['True_Label','confidence_margin_entailment','confidence_margin_neutral','confidence_margin_contradiction','majority_vote'], axis=1).values
y_anli_r1 = high_confidence_anli_r1['True_Label'].values

# Features and Labels
X_anli_r2 = high_confidence_anli_r2.drop(['True_Label','confidence_margin_entailment','confidence_margin_neutral','confidence_margin_contradiction','majority_vote'], axis=1).values
y_anli_r2 = high_confidence_anli_r2['True_Label'].values

# Features and Labels
X_anli_r3 = high_confidence_anli_r3.drop(['True_Label','confidence_margin_entailment','confidence_margin_neutral','confidence_margin_contradiction','majority_vote'], axis=1).values
y_anli_r3 = high_confidence_anli_r3['True_Label'].values

# %%
# Extract only the additional features from each dataset
features_snli = high_confidence_snli[['confidence_margin_entailment', 'confidence_margin_neutral', 'confidence_margin_contradiction']].values
features_mnli_matched = high_confidence_mnli_matched[[ 'confidence_margin_entailment', 'confidence_margin_neutral', 'confidence_margin_contradiction']].values
features_mnli_mismatched = high_confidence_mnli_mismatched[[ 'confidence_margin_entailment', 'confidence_margin_neutral', 'confidence_margin_contradiction']].values
features_anli_r1 = high_confidence_anli_r1[[ 'confidence_margin_entailment', 'confidence_margin_neutral', 'confidence_margin_contradiction']].values
features_anli_r2 = high_confidence_anli_r2[[ 'confidence_margin_entailment', 'confidence_margin_neutral', 'confidence_margin_contradiction']].values
features_anli_r3 = high_confidence_anli_r3[[ 'confidence_margin_entailment', 'confidence_margin_neutral', 'confidence_margin_contradiction']].values

# %%
X_snli
# Out:
# array([[9.9878270e-01, 7.6433434e-04, 4.5297167e-04, ..., 4.6765395e-03,
#         6.0480673e-02, 9.3484277e-01],
#        [5.0442386e-04, 4.3001700e-03, 9.9519530e-01, ..., 9.7817034e-01,
#         2.1051416e-02, 7.7824460e-04],
#        [9.8957914e-01, 5.4418677e-03, 4.9790350e-03, ..., 8.5550435e-02,
#         7.5036585e-02, 8.3941300e-01],
#        ...,
#        [7.0376875e-04, 9.7931010e-03, 9.8950315e-01, ..., 8.9463750e-01,
#         1.0409502e-01, 1.2674012e-03],
#        [9.9917114e-01, 4.9286430e-04, 3.3603658e-04, ..., 8.3751883e-04,
#         2.6697412e-03, 9.9649280e-01],
#        [2.6664520e-04, 2.1777824e-03, 9.9755560e-01, ..., 9.8434700e-01,
#         1.5223468e-02, 4.2961346e-04]])

# %%
features_snli
# Out:
# array([[9.94106161e-01, 5.59870956e-02, 6.04100800e-02],
#        [5.73736000e-03, 5.89017100e-03, 9.94264296e-01],
#        [9.04028705e-01, 1.89172950e-02, 3.66324000e-02],
#        ...,
#        [1.13691360e-01, 1.12957690e-01, 9.87502096e-01],
#        [9.98333621e-01, 1.90469200e-03, 2.68793000e-03],
#        [9.45200000e-04, 6.61004000e-04, 9.96841898e-01]])

# %%
# One-hot encode labels for each dataset using TensorFlow/Keras utility
y_encoded_snli = tf.keras.utils.to_categorical(y_snli)
y_encoded_mnli_matched = tf.keras.utils.to_categorical(y_mnli_matched)
y_encoded_mnli_mismatched = tf.keras.utils.to_categorical(y_mnli_mismatched)
y_encoded_anli_r1 = tf.keras.utils.to_categorical(y_anli_r1)
y_encoded_anli_r2 = tf.keras.utils.to_categorical(y_anli_r2)
y_encoded_anli_r3 = tf.keras.utils.to_categorical(y_anli_r3)

# %%
X_snli_rnn = X_snli.reshape(X_snli.shape[0], 1, X_snli.shape[1])
X_mnli_matched_rnn = X_mnli_matched.reshape(X_mnli_matched.shape[0], 1, X_mnli_matched.shape[1])
X_mnli_mismatched_rnn = X_mnli_mismatched.reshape(X_mnli_mismatched.shape[0], 1, X_mnli_mismatched.shape[1])
X_anli_r1_rnn = X_anli_r1.reshape(X_anli_r1.shape[0], 1, X_anli_r1.shape[1])
X_anli_r2_rnn = X_anli_r2.reshape(X_anli_r2.shape[0], 1, X_anli_r2.shape[1])
X_anli_r3_rnn = X_anli_r3.reshape(X_anli_r3.shape[0], 1, X_anli_r3.shape[1])

# %%
# Reshape feature arrays to match the RNN input shape
features_snli = features_snli.reshape(features_snli.shape[0], 1, features_snli.shape[1])
features_mnli_matched = features_mnli_matched.reshape(features_mnli_matched.shape[0], 1, features_mnli_matched.shape[1])
features_mnli_mismatched = features_mnli_mismatched.reshape(features_mnli_mismatched.shape[0], 1, features_mnli_mismatched.shape[1])
features_anli_r1 = features_anli_r1.reshape(features_anli_r1.shape[0], 1, features_anli_r1.shape[1])
features_anli_r2 = features_anli_r2.reshape(features_anli_r2.shape[0], 1, features_anli_r2.shape[1])
features_anli_r3 = features_anli_r3.reshape(features_anli_r3.shape[0], 1, features_anli_r3.shape[1])

# %%
features_snli.shape
# Out:
# (6032, 1, 3)

# %%
X_snli_rnn
# Out:
# array([[[9.9878270e-01, 7.6433434e-04, 4.5297167e-04, ...,
#          4.6765395e-03, 6.0480673e-02, 9.3484277e-01]],
#
#        [[5.0442386e-04, 4.3001700e-03, 9.9519530e-01, ...,
#          9.7817034e-01, 2.1051416e-02, 7.7824460e-04]],
#
#        [[9.8957914e-01, 5.4418677e-03, 4.9790350e-03, ...,
#          8.5550435e-02, 7.5036585e-02, 8.3941300e-01]],
#
#        ...,
#
#        [[7.0376875e-04, 9.7931010e-03, 9.8950315e-01, ...,
#          8.9463750e-01, 1.0409502e-01, 1.2674012e-03]],
#
#        [[9.9917114e-01, 4.9286430e-04, 3.3603658e-04, ...,
#          8.3751883e-04, 2.6697412e-03, 9.9649280e-01]],
#
#        [[2.6664520e-04, 2.1777824e-03, 9.9755560e-01, ...,
#          9.8434700e-01, 1.5223468e-02, 4.2961346e-04]]])

# %%
X_snli_rnn.shape
# Out:
# (6032, 1, 9)

# %%
from sklearn.model_selection import train_test_split

def prepare_data_splits(X_rnn, features, y_encoded, test_size=0.1, random_state=42):
    # Split the data for the RNN inputs
    X_train_rnn, X_val_rnn, y_train, y_val = train_test_split(
        X_rnn, y_encoded, test_size=test_size, random_state=random_state, stratify=y_encoded)

    # Split the data for the additional features
    features_train, features_val, _, _ = train_test_split(
        features, y_encoded, test_size=test_size, random_state=random_state, stratify=y_encoded)

    return X_train_rnn, X_val_rnn, features_train, features_val, y_train, y_val

# Example for SNLI data
X_train_snli_rnn, X_val_snli_rnn, features_train_snli, features_val_snli, y_train_snli, y_val_snli = prepare_data_splits(X_snli_rnn, features_snli, y_encoded_snli)
# Example for MNLI-m data
X_train_mnli_matched_rnn, X_val_mnli_matched_rnn, features_train_mnli_matched, features_val_mnli_matched, y_train_mnli_matched, y_val_mnli_matched = prepare_data_splits(X_mnli_matched_rnn, features_mnli_matched, y_encoded_mnli_matched)
# Example for MNLI-mm data
X_train_mnli_mismatched_rnn, X_val_mnli_mismatched_rnn, features_train_mnli_mismatched, features_val_mnli_mismatched, y_train_mnli_mismatched, y_val_mnli_mismatched = prepare_data_splits(X_mnli_mismatched_rnn, features_mnli_mismatched, y_encoded_mnli_mismatched)
# Example for ANLI round 1 data
X_train_anli_r1_rnn, X_val_anli_r1_rnn, features_train_anli_r1, features_val_anli_r1, y_train_anli_r1, y_val_anli_r1 = prepare_data_splits(X_anli_r1_rnn, features_anli_r1, y_encoded_anli_r1)
# Example for ANLI round 2 data
X_train_anli_r2_rnn, X_val_anli_r2_rnn, features_train_anli_r2, features_val_anli_r2, y_train_anli_r2, y_val_anli_r2 = prepare_data_splits(X_anli_r2_rnn, features_anli_r2, y_encoded_anli_r2)
# Example for ANLI round 3 data
X_train_anli_r3_rnn, X_val_anli_r3_rnn, features_train_anli_r3, features_val_anli_r3, y_train_anli_r3, y_val_anli_r3 = prepare_data_splits(X_anli_r3_rnn, features_anli_r3, y_encoded_anli_r3)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, SimpleRNN, Dense, Dropout, Concatenate
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Flatten


def build_and_train_model(X_train_rnn, features_train, y_train, X_val_rnn, features_val, y_val, epochs=20, batch_size=32):
    sequence_input_shape = X_train_rnn.shape[1:]
    features_input_shape = features_train.shape[1:]

    sequence_input = Input(shape=sequence_input_shape, name='sequence_input')
    rnn = SimpleRNN(64, return_sequences=False)(sequence_input)
    rnn = Dropout(0.5)(rnn)

    features_input = Input(shape=features_input_shape, name='features_input')
    features = Dense(32, activation='relu')(features_input)
    features = Dropout(0.2)(features)
    features = Flatten()(features)  # Ensure the features tensor is flattened

    concatenated = Concatenate()([rnn, features])
    output = Dense(3, activation='softmax')(concatenated)

    model = Model(inputs=[sequence_input, features_input], outputs=output)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    early_stopping = EarlyStopping(monitor='val_loss', patience=3)

    history = model.fit(
        [X_train_rnn, features_train], y_train,
        validation_data=([X_val_rnn, features_val], y_val),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=[early_stopping]
    )

    evaluation = model.evaluate([X_val_rnn, features_val], y_val, verbose=1)
    return model, history, evaluation

# %%
# Let's train and evaluate the model using the SNLI data we prepared earlier
model_snli, history_snli, evaluation_snli = build_and_train_model(
    X_train_snli_rnn, features_train_snli, y_train_snli, 
    X_val_snli_rnn, features_val_snli, y_val_snli, 
    epochs=20, batch_size=32
)

print("Evaluation on SNLI Validation Data:", evaluation_snli)
print("History keys:", history_snli.history.keys())
# Out:
# Epoch 1/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.8238 - loss: 0.5221 - val_accuracy: 0.9536 - val_loss: 0.1468
# Epoch 2/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9561 - loss: 0.1629 - val_accuracy: 0.9619 - val_loss: 0.1251
# Epoch 3/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9608 - loss: 0.1457 - val_accuracy: 0.9652 - val_loss: 0.1188
# Epoch 4/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9625 - loss: 0.1408 - val_accuracy: 0.9636 - val_loss: 0.1175
# Epoch 5/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9586 - loss: 0.1527 - val_accuracy: 0.9636 - val_loss: 0.1172
# Epoch 6/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9572 - loss: 0.1589 - val_accuracy: 0.9636 - val_loss: 0.1164
# Epoch 7/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9625 - loss: 0.1411 - val_accuracy: 0.9619 - val_loss: 0.1182
# Epoch 8/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9556 - loss: 0.1550 - val_accuracy: 0.9619 - val_loss: 0.1165
# Epoch 9/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9563 - loss: 0.1507 - val_accuracy: 0.9652 - val_loss: 0.1176
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9628 - loss: 0.1063
# Evaluation on SNLI Validation Data: [0.11760400235652924, 0.9652317762374878]
# History keys: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Let's train and evaluate the model using the mnli_matched data we prepared earlier
model_mnli_matched, history_mnli_matched, evaluation_mnli_matched = build_and_train_model(
    X_train_mnli_matched_rnn, features_train_mnli_matched, y_train_mnli_matched, 
    X_val_mnli_matched_rnn, features_val_mnli_matched, y_val_mnli_matched, 
    epochs=20, batch_size=32
)

print("Evaluation on MNLI-m Validation Data:", evaluation_mnli_matched)
print("History keys:", history_mnli_matched.history.keys())
# Out:
# Epoch 1/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.8443 - loss: 0.5147 - val_accuracy: 0.9659 - val_loss: 0.1490
# Epoch 2/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9659 - loss: 0.1539 - val_accuracy: 0.9659 - val_loss: 0.1331
# Epoch 3/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9644 - loss: 0.1365 - val_accuracy: 0.9659 - val_loss: 0.1271
# Epoch 4/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9620 - loss: 0.1482 - val_accuracy: 0.9693 - val_loss: 0.1249
# Epoch 5/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9654 - loss: 0.1518 - val_accuracy: 0.9693 - val_loss: 0.1244
# Epoch 6/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9653 - loss: 0.1440 - val_accuracy: 0.9710 - val_loss: 0.1234
# Epoch 7/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9718 - loss: 0.1233 - val_accuracy: 0.9727 - val_loss: 0.1234
# Epoch 8/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9596 - loss: 0.1611 - val_accuracy: 0.9710 - val_loss: 0.1237
# Epoch 9/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9655 - loss: 0.1389 - val_accuracy: 0.9710 - val_loss: 0.1233
# Epoch 10/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9666 - loss: 0.1361 - val_accuracy: 0.9710 - val_loss: 0.1242
# Epoch 11/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9682 - loss: 0.1251 - val_accuracy: 0.9710 - val_loss: 0.1237
# Epoch 12/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9648 - loss: 0.1336 - val_accuracy: 0.9710 - val_loss: 0.1229
# Epoch 13/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9676 - loss: 0.1310 - val_accuracy: 0.9710 - val_loss: 0.1229
# Epoch 14/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9695 - loss: 0.1272 - val_accuracy: 0.9744 - val_loss: 0.1232
# Epoch 15/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9625 - loss: 0.1496 - val_accuracy: 0.9710 - val_loss: 0.1235
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9686 - loss: 0.1440
# Evaluation on MNLI-m Validation Data: [0.12348829954862595, 0.9709897637367249]
# History keys: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Let's train and evaluate the model using the mnli_mismatched data we prepared earlier
model_mnli_mismatched, history_mnli_mismatched, evaluation_mnli_mismatched = build_and_train_model(
    X_train_mnli_mismatched_rnn, features_train_mnli_mismatched, y_train_mnli_mismatched, 
    X_val_mnli_mismatched_rnn, features_val_mnli_mismatched, y_val_mnli_mismatched, 
    epochs=20, batch_size=32
)

print("Evaluation on MNLI-mm Validation Data:", evaluation_mnli_mismatched)
print("History keys:", history_mnli_mismatched.history.keys())
# Out:
# Epoch 1/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.8132 - loss: 0.5546 - val_accuracy: 0.9628 - val_loss: 0.1622
# Epoch 2/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9643 - loss: 0.1533 - val_accuracy: 0.9628 - val_loss: 0.1541
# Epoch 3/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9700 - loss: 0.1247 - val_accuracy: 0.9628 - val_loss: 0.1508
# Epoch 4/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9645 - loss: 0.1367 - val_accuracy: 0.9645 - val_loss: 0.1503
# Epoch 5/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9656 - loss: 0.1195 - val_accuracy: 0.9628 - val_loss: 0.1489
# Epoch 6/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9632 - loss: 0.1280 - val_accuracy: 0.9628 - val_loss: 0.1509
# Epoch 7/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9668 - loss: 0.1217 - val_accuracy: 0.9645 - val_loss: 0.1535
# Epoch 8/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9630 - loss: 0.1390 - val_accuracy: 0.9628 - val_loss: 0.1524
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9448 - loss: 0.1925
# Evaluation on MNLI-mm Validation Data: [0.1523924469947815, 0.962774932384491]
# History keys: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Let's train and evaluate the model using the ANLI round 1 data we prepared earlier
model_anli_r1, history_anli_r1, evaluation_anli_r1 = build_and_train_model(
    X_train_anli_r1_rnn, features_train_anli_r1, y_train_anli_r1, 
    X_val_anli_r1_rnn, features_val_anli_r1, y_val_anli_r1, 
    epochs=20, batch_size=32
)

print("Evaluation on ANLI round 1 Validation Data:", evaluation_anli_r1)
print("History keys:", history_anli_r1.history.keys())
# Out:
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 418ms/step - accuracy: 0.4712 - loss: 0.9978 - val_accuracy: 0.6744 - val_loss: 0.9052
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6634 - loss: 0.8491 - val_accuracy: 0.6977 - val_loss: 0.8032
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7368 - loss: 0.7862 - val_accuracy: 0.6977 - val_loss: 0.7286
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7470 - loss: 0.7098 - val_accuracy: 0.7442 - val_loss: 0.6717
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7829 - loss: 0.6390 - val_accuracy: 0.7442 - val_loss: 0.6341
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8099 - loss: 0.6054 - val_accuracy: 0.7442 - val_loss: 0.6073
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8028 - loss: 0.5418 - val_accuracy: 0.7442 - val_loss: 0.5893
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7635 - loss: 0.5945 - val_accuracy: 0.7442 - val_loss: 0.5741
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8211 - loss: 0.5388 - val_accuracy: 0.7442 - val_loss: 0.5641
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8136 - loss: 0.5167 - val_accuracy: 0.7442 - val_loss: 0.5591
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7910 - loss: 0.5547 - val_accuracy: 0.7442 - val_loss: 0.5472
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7690 - loss: 0.5342 - val_accuracy: 0.7442 - val_loss: 0.5428
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7947 - loss: 0.5152 - val_accuracy: 0.7442 - val_loss: 0.5414
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7730 - loss: 0.5606 - val_accuracy: 0.7442 - val_loss: 0.5393
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8139 - loss: 0.5594 - val_accuracy: 0.7442 - val_loss: 0.5391
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8172 - loss: 0.4902 - val_accuracy: 0.7442 - val_loss: 0.5355
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7945 - loss: 0.5647 - val_accuracy: 0.7442 - val_loss: 0.5314
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8068 - loss: 0.5189 - val_accuracy: 0.7442 - val_loss: 0.5308
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7898 - loss: 0.5361 - val_accuracy: 0.7442 - val_loss: 0.5369
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8167 - loss: 0.5141 - val_accuracy: 0.7442 - val_loss: 0.5359
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7461 - loss: 0.5945
# Evaluation on ANLI round 1 Validation Data: [0.5359214544296265, 0.7441860437393188]
# History keys: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Let's train and evaluate the model using the ANLI round 2 data we prepared earlier
model_anli_r2, history_anli_r2, evaluation_anli_r2 = build_and_train_model(
    X_train_anli_r2_rnn, features_train_anli_r2, y_train_anli_r2, 
    X_val_anli_r2_rnn, features_val_anli_r2, y_val_anli_r2, 
    epochs=20, batch_size=32
)

print("Evaluation on ANLI round 2 Validation Data:", evaluation_anli_r2)
print("History keys:", history_anli_r2.history.keys())
# Out:
# Epoch 1/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 313ms/step - accuracy: 0.3077 - loss: 1.1610 - val_accuracy: 0.6222 - val_loss: 0.9902
# Epoch 2/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5165 - loss: 1.0050 - val_accuracy: 0.6000 - val_loss: 0.9021
# Epoch 3/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5485 - loss: 0.9584 - val_accuracy: 0.6000 - val_loss: 0.8402
# Epoch 4/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6132 - loss: 0.9074 - val_accuracy: 0.6222 - val_loss: 0.7974
# Epoch 5/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6417 - loss: 0.8534 - val_accuracy: 0.6889 - val_loss: 0.7651
# Epoch 6/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6738 - loss: 0.7959 - val_accuracy: 0.6889 - val_loss: 0.7411
# Epoch 7/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6767 - loss: 0.7700 - val_accuracy: 0.7333 - val_loss: 0.7208
# Epoch 8/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6856 - loss: 0.7880 - val_accuracy: 0.7333 - val_loss: 0.7077
# Epoch 9/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6640 - loss: 0.8097 - val_accuracy: 0.7556 - val_loss: 0.6978
# Epoch 10/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7093 - loss: 0.7320 - val_accuracy: 0.7778 - val_loss: 0.6891
# Epoch 11/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7086 - loss: 0.7064 - val_accuracy: 0.7778 - val_loss: 0.6829
# Epoch 12/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6931 - loss: 0.7316 - val_accuracy: 0.7778 - val_loss: 0.6774
# Epoch 13/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6784 - loss: 0.7714 - val_accuracy: 0.7778 - val_loss: 0.6728
# Epoch 14/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6875 - loss: 0.7821 - val_accuracy: 0.7778 - val_loss: 0.6692
# Epoch 15/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7385 - loss: 0.7296 - val_accuracy: 0.7778 - val_loss: 0.6673
# Epoch 16/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7220 - loss: 0.6768 - val_accuracy: 0.7778 - val_loss: 0.6653
# Epoch 17/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7464 - loss: 0.6832 - val_accuracy: 0.7778 - val_loss: 0.6649
# Epoch 18/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7250 - loss: 0.7055 - val_accuracy: 0.7778 - val_loss: 0.6661
# Epoch 19/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7027 - loss: 0.7054 - val_accuracy: 0.7778 - val_loss: 0.6640
# Epoch 20/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7406 - loss: 0.6714 - val_accuracy: 0.7778 - val_loss: 0.6624
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7789 - loss: 0.6517
# Evaluation on ANLI round 2 Validation Data: [0.662442684173584, 0.7777777910232544]
# History keys: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Let's train and evaluate the model using the ANLI round 3 data we prepared earlier
model_anli_r3, history_anli_r3, evaluation_anli_r3 = build_and_train_model(
    X_train_anli_r3_rnn, features_train_anli_r3, y_train_anli_r3, 
    X_val_anli_r3_rnn, features_val_anli_r3, y_val_anli_r3, 
    epochs=20, batch_size=32
)

print("Evaluation on ANLI round 3 Validation Data:", evaluation_anli_r3)
print("History keys:", history_anli_r3.history.keys())
# Out:
# Epoch 1/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 9s 336ms/step - accuracy: 0.4676 - loss: 0.9864 - val_accuracy: 0.6604 - val_loss: 0.8393
# Epoch 2/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6357 - loss: 0.8579 - val_accuracy: 0.6981 - val_loss: 0.7725
# Epoch 3/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6692 - loss: 0.7913 - val_accuracy: 0.6981 - val_loss: 0.7423
# Epoch 4/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6716 - loss: 0.7545 - val_accuracy: 0.6981 - val_loss: 0.7233
# Epoch 5/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7389 - loss: 0.6708 - val_accuracy: 0.6981 - val_loss: 0.7086
# Epoch 6/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6656 - loss: 0.7610 - val_accuracy: 0.6981 - val_loss: 0.7020
# Epoch 7/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7053 - loss: 0.7042 - val_accuracy: 0.7170 - val_loss: 0.6946
# Epoch 8/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7150 - loss: 0.6712 - val_accuracy: 0.7170 - val_loss: 0.6890
# Epoch 9/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6912 - loss: 0.7307 - val_accuracy: 0.7170 - val_loss: 0.6846
# Epoch 10/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7357 - loss: 0.6849 - val_accuracy: 0.7170 - val_loss: 0.6815
# Epoch 11/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6933 - loss: 0.7262 - val_accuracy: 0.6981 - val_loss: 0.6782
# Epoch 12/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7466 - loss: 0.6425 - val_accuracy: 0.6604 - val_loss: 0.6801
# Epoch 13/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7474 - loss: 0.6309 - val_accuracy: 0.6792 - val_loss: 0.6771
# Epoch 14/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7022 - loss: 0.7415 - val_accuracy: 0.6604 - val_loss: 0.6776
# Epoch 15/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7234 - loss: 0.6866 - val_accuracy: 0.6604 - val_loss: 0.6730
# Epoch 16/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7278 - loss: 0.6661 - val_accuracy: 0.6604 - val_loss: 0.6703
# Epoch 17/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7434 - loss: 0.6520 - val_accuracy: 0.6792 - val_loss: 0.6725
# Epoch 18/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7209 - loss: 0.6731 - val_accuracy: 0.6604 - val_loss: 0.6711
# Epoch 19/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7403 - loss: 0.6706 - val_accuracy: 0.6604 - val_loss: 0.6683
# Epoch 20/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6991 - loss: 0.7469 - val_accuracy: 0.6604 - val_loss: 0.6694
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6903 - loss: 0.6255
# Evaluation on ANLI round 3 Validation Data: [0.66937255859375, 0.6603773832321167]
# History keys: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
X_rnn_all_tasks = np.concatenate([X_snli_rnn, X_mnli_matched_rnn, X_mnli_mismatched_rnn, X_anli_r1_rnn, X_anli_r2_rnn, X_anli_r3_rnn])
features_all_tasks = np.concatenate([features_snli, features_mnli_matched, features_mnli_mismatched, features_anli_r1, features_anli_r2, features_anli_r3])
y_encoded_all_tasks = np.concatenate([y_encoded_snli, y_encoded_mnli_matched, y_encoded_mnli_mismatched, y_encoded_anli_r1, y_encoded_anli_r2, y_encoded_anli_r3])


# Example for SNLI data
X_train_all_rnn, X_val_all_rnn, features_train_all, features_val_all, y_train_all, y_val_all = prepare_data_splits(X_rnn_all_tasks, features_all_tasks, y_encoded_all_tasks)

# Let's train and evaluate the model using the ANLI round 3 data we prepared earlier
model_all, history_all, evaluation_all = build_and_train_model(
    X_train_all_rnn, features_train_all, y_train_all, 
    X_val_all_rnn, features_val_all, y_val_all, 
    epochs=20, batch_size=32
)

print("Evaluation on All Tasks Validation Data:", evaluation_all)
print("History keys:", history_all.history.keys())
# Out:
# Epoch 1/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.8805 - loss: 0.3828 - val_accuracy: 0.9448 - val_loss: 0.1740
# Epoch 2/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9457 - loss: 0.1857 - val_accuracy: 0.9438 - val_loss: 0.1743
# Epoch 3/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9482 - loss: 0.1800 - val_accuracy: 0.9464 - val_loss: 0.1732
# Epoch 4/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9470 - loss: 0.1807 - val_accuracy: 0.9495 - val_loss: 0.1722
# Epoch 5/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9508 - loss: 0.1746 - val_accuracy: 0.9495 - val_loss: 0.1722
# Epoch 6/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9439 - loss: 0.1924 - val_accuracy: 0.9495 - val_loss: 0.1713
# Epoch 7/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9477 - loss: 0.1842 - val_accuracy: 0.9495 - val_loss: 0.1716
# Epoch 8/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9477 - loss: 0.1802 - val_accuracy: 0.9495 - val_loss: 0.1715
# Epoch 9/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9468 - loss: 0.1854 - val_accuracy: 0.9484 - val_loss: 0.1712
# Epoch 10/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9465 - loss: 0.1791 - val_accuracy: 0.9479 - val_loss: 0.1711
# Epoch 11/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9467 - loss: 0.1837 - val_accuracy: 0.9474 - val_loss: 0.1724
# Epoch 12/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9478 - loss: 0.1784 - val_accuracy: 0.9484 - val_loss: 0.1707
# Epoch 13/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9450 - loss: 0.1870 - val_accuracy: 0.9490 - val_loss: 0.1709
# Epoch 14/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9466 - loss: 0.1819 - val_accuracy: 0.9484 - val_loss: 0.1714
# Epoch 15/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9456 - loss: 0.1768 - val_accuracy: 0.9484 - val_loss: 0.1711
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9493 - loss: 0.1623
# Evaluation on All Tasks Validation Data: [0.17112495005130768, 0.948437511920929]
# History keys: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# After training the model
model_all.save('RNN_feature_ensemble.h5')  # Saves the model in HDF5 format

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    plt.show()

plot_training_history(history_snli)

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    plt.show()

plot_training_history(history_mnli_matched)

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    plt.show()

plot_training_history(history_mnli_mismatched)

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    plt.show()

plot_training_history(history_anli_r1)

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    plt.show()

plot_training_history(history_anli_r2)

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    plt.show()

plot_training_history(history_anli_r3)

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    plt.show()

plot_training_history(history_all)

# %%
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.layers import Input, SimpleRNN, Dense, Dropout, Concatenate, Flatten
from tensorflow.keras.models import Model
import numpy as np
import matplotlib.pyplot as plt

# Function to build the RNN model
def create_rnn_model(sequence_input_shape, features_input_shape):
    sequence_input = Input(shape=sequence_input_shape, name='sequence_input')
    rnn = SimpleRNN(64, return_sequences=False)(sequence_input)
    rnn = Dropout(0.5)(rnn)

    features_input = Input(shape=features_input_shape, name='features_input')
    features = Dense(32, activation='relu')(features_input)
    features = Dropout(0.2)(features)
    features = Flatten()(features)

    concatenated = Concatenate()([rnn, features])
    final_output = Dense(3, activation='softmax')(concatenated)

    model = Model(inputs=[sequence_input, features_input], outputs=final_output)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

def cross_validate_rnn_model(X_rnn, features, y_encoded, num_folds=5):
    # Convert labels to single integers for stratified split
    y_single = np.argmax(y_encoded, axis=1)
    kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)
    fold_no = 1
    acc_per_fold = []
    loss_per_fold = []
    histories = []  # List to store history for each fold

    for train, test in kfold.split(X_rnn, y_single):
        X_train_rnn, X_test_rnn = X_rnn[train], X_rnn[test]
        features_train, features_test = features[train], features[test]
        y_train, y_test = y_encoded[train], y_encoded[test]

        model = create_rnn_model(X_train_rnn.shape[1:], features_train.shape[1:])

        print(f'Training on fold {fold_no}...')
        history = model.fit([X_train_rnn, features_train], y_train, epochs=20, batch_size=32, verbose=1, validation_data=([X_test_rnn, features_test], y_test))
        histories.append(history)

        scores = model.evaluate([X_test_rnn, features_test], y_test, verbose=0)
        print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
        acc_per_fold.append(scores[1] * 100)
        loss_per_fold.append(scores[0])

        fold_no += 1

    print('------------------------------------------------------------------------')
    print('Score per fold')
    for i in range(0, len(acc_per_fold)):
        print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
    print('------------------------------------------------------------------------')
    print('Average scores for all folds:')
    print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
    print(f'> Loss: {np.mean(loss_per_fold)}')
    print('------------------------------------------------------------------------')
    
    return histories

# %%
# Call the cross-validation function
snli_histories = cross_validate_rnn_model(X_snli_rnn, features_snli, y_encoded_snli, num_folds=5)
# Out:
# Training on fold 1...
# Epoch 1/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - accuracy: 0.7427 - loss: 0.6551 - val_accuracy: 0.9544 - val_loss: 0.1590
# Epoch 2/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9580 - loss: 0.1699 - val_accuracy: 0.9635 - val_loss: 0.1267
# Epoch 3/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9593 - loss: 0.1453 - val_accuracy: 0.9669 - val_loss: 0.1201
# Epoch 4/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9625 - loss: 0.1395 - val_accuracy: 0.9660 - val_loss: 0.1168
# Epoch 5/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9612 - loss: 0.1439 - val_accuracy: 0.9660 - val_loss: 0.1170
# Epoch 6/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9622 - loss: 0.1406 - val_accuracy: 0.9644 - val_loss: 0.1168
# Epoch 7/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9658 - loss: 0.1345 - val_accuracy: 0.9644 - val_loss: 0.1168
# Epoch 8/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9649 - loss: 0.1367 - val_accuracy: 0.9635 - val_loss: 0.1166
# Epoch 9/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9608 - loss: 0.1377 - val_accuracy: 0.9644 - val_loss: 0.1179
# Epoch 10/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9601 - loss: 0.1432 - val_accuracy: 0.9644 - val_loss: 0.1170
# Epoch 11/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9562 - loss: 0.1498 - val_accuracy: 0.9635 - val_loss: 0.1170
# Epoch 12/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9589 - loss: 0.1441 - val_accuracy: 0.9627 - val_loss: 0.1172
# Epoch 13/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9548 - loss: 0.1585 - val_accuracy: 0.9635 - val_loss: 0.1170
# Epoch 14/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9665 - loss: 0.1257 - val_accuracy: 0.9594 - val_loss: 0.1187
# Epoch 15/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9554 - loss: 0.1591 - val_accuracy: 0.9644 - val_loss: 0.1176
# Epoch 16/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9622 - loss: 0.1417 - val_accuracy: 0.9635 - val_loss: 0.1174
# Epoch 17/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9579 - loss: 0.1429 - val_accuracy: 0.9619 - val_loss: 0.1183
# Epoch 18/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9634 - loss: 0.1347 - val_accuracy: 0.9635 - val_loss: 0.1182
# Epoch 19/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9591 - loss: 0.1428 - val_accuracy: 0.9619 - val_loss: 0.1189
# Epoch 20/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9575 - loss: 0.1457 - val_accuracy: 0.9627 - val_loss: 0.1200
# Score for fold 1: loss of 0.11997145414352417; compile_metrics of 96.27174735069275%
# Training on fold 2...
# Epoch 1/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.8419 - loss: 0.5496 - val_accuracy: 0.9544 - val_loss: 0.1585
# Epoch 2/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9536 - loss: 0.1714 - val_accuracy: 0.9602 - val_loss: 0.1308
# Epoch 3/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9575 - loss: 0.1581 - val_accuracy: 0.9635 - val_loss: 0.1240
# Epoch 4/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9586 - loss: 0.1506 - val_accuracy: 0.9627 - val_loss: 0.1231
# Epoch 5/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9591 - loss: 0.1495 - val_accuracy: 0.9635 - val_loss: 0.1222
# Epoch 6/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9590 - loss: 0.1514 - val_accuracy: 0.9619 - val_loss: 0.1222
# Epoch 7/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9598 - loss: 0.1415 - val_accuracy: 0.9602 - val_loss: 0.1225
# Epoch 8/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9633 - loss: 0.1383 - val_accuracy: 0.9619 - val_loss: 0.1219
# Epoch 9/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9597 - loss: 0.1529 - val_accuracy: 0.9619 - val_loss: 0.1226
# Epoch 10/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9629 - loss: 0.1393 - val_accuracy: 0.9619 - val_loss: 0.1219
# Epoch 11/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9598 - loss: 0.1443 - val_accuracy: 0.9644 - val_loss: 0.1223
# Epoch 12/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9608 - loss: 0.1396 - val_accuracy: 0.9611 - val_loss: 0.1238
# Epoch 13/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9631 - loss: 0.1385 - val_accuracy: 0.9627 - val_loss: 0.1219
# Epoch 14/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9624 - loss: 0.1404 - val_accuracy: 0.9627 - val_loss: 0.1223
# Epoch 15/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9570 - loss: 0.1487 - val_accuracy: 0.9611 - val_loss: 0.1219
# Epoch 16/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9657 - loss: 0.1281 - val_accuracy: 0.9594 - val_loss: 0.1237
# Epoch 17/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9598 - loss: 0.1406 - val_accuracy: 0.9627 - val_loss: 0.1219
# Epoch 18/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9526 - loss: 0.1547 - val_accuracy: 0.9611 - val_loss: 0.1216
# Epoch 19/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9620 - loss: 0.1264 - val_accuracy: 0.9602 - val_loss: 0.1221
# Epoch 20/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9613 - loss: 0.1372 - val_accuracy: 0.9611 - val_loss: 0.1217
# Score for fold 2: loss of 0.12167054414749146; compile_metrics of 96.10604643821716%
# Training on fold 3...
# Epoch 1/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - accuracy: 0.7128 - loss: 0.6683 - val_accuracy: 0.9527 - val_loss: 0.1706
# Epoch 2/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9587 - loss: 0.1557 - val_accuracy: 0.9602 - val_loss: 0.1484
# Epoch 3/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9594 - loss: 0.1468 - val_accuracy: 0.9602 - val_loss: 0.1448
# Epoch 4/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9613 - loss: 0.1297 - val_accuracy: 0.9635 - val_loss: 0.1439
# Epoch 5/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9563 - loss: 0.1468 - val_accuracy: 0.9627 - val_loss: 0.1443
# Epoch 6/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9616 - loss: 0.1396 - val_accuracy: 0.9627 - val_loss: 0.1438
# Epoch 7/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9609 - loss: 0.1340 - val_accuracy: 0.9594 - val_loss: 0.1460
# Epoch 8/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9625 - loss: 0.1421 - val_accuracy: 0.9619 - val_loss: 0.1441
# Epoch 9/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9585 - loss: 0.1401 - val_accuracy: 0.9585 - val_loss: 0.1444
# Epoch 10/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9632 - loss: 0.1348 - val_accuracy: 0.9627 - val_loss: 0.1433
# Epoch 11/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9624 - loss: 0.1402 - val_accuracy: 0.9602 - val_loss: 0.1439
# Epoch 12/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9612 - loss: 0.1345 - val_accuracy: 0.9627 - val_loss: 0.1433
# Epoch 13/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9626 - loss: 0.1354 - val_accuracy: 0.9594 - val_loss: 0.1432
# Epoch 14/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9649 - loss: 0.1345 - val_accuracy: 0.9619 - val_loss: 0.1430
# Epoch 15/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9599 - loss: 0.1369 - val_accuracy: 0.9594 - val_loss: 0.1440
# Epoch 16/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9624 - loss: 0.1290 - val_accuracy: 0.9585 - val_loss: 0.1439
# Epoch 17/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9615 - loss: 0.1278 - val_accuracy: 0.9610 - val_loss: 0.1433
# Epoch 18/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9529 - loss: 0.1588 - val_accuracy: 0.9594 - val_loss: 0.1437
# Epoch 19/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9532 - loss: 0.1549 - val_accuracy: 0.9610 - val_loss: 0.1433
# Epoch 20/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9595 - loss: 0.1401 - val_accuracy: 0.9602 - val_loss: 0.1431
# Score for fold 3: loss of 0.14310376346111298; compile_metrics of 96.01989984512329%
# Training on fold 4...
# Epoch 1/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - accuracy: 0.8422 - loss: 0.4962 - val_accuracy: 0.9585 - val_loss: 0.1585
# Epoch 2/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9553 - loss: 0.1609 - val_accuracy: 0.9635 - val_loss: 0.1433
# Epoch 3/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9580 - loss: 0.1439 - val_accuracy: 0.9627 - val_loss: 0.1417
# Epoch 4/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9673 - loss: 0.1294 - val_accuracy: 0.9619 - val_loss: 0.1398
# Epoch 5/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9634 - loss: 0.1444 - val_accuracy: 0.9619 - val_loss: 0.1399
# Epoch 6/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9613 - loss: 0.1372 - val_accuracy: 0.9627 - val_loss: 0.1419
# Epoch 7/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9637 - loss: 0.1397 - val_accuracy: 0.9619 - val_loss: 0.1401
# Epoch 8/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9595 - loss: 0.1458 - val_accuracy: 0.9610 - val_loss: 0.1410
# Epoch 9/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9616 - loss: 0.1385 - val_accuracy: 0.9610 - val_loss: 0.1407
# Epoch 10/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9575 - loss: 0.1346 - val_accuracy: 0.9610 - val_loss: 0.1396
# Epoch 11/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9648 - loss: 0.1303 - val_accuracy: 0.9610 - val_loss: 0.1390
# Epoch 12/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9603 - loss: 0.1448 - val_accuracy: 0.9619 - val_loss: 0.1402
# Epoch 13/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9662 - loss: 0.1194 - val_accuracy: 0.9610 - val_loss: 0.1393
# Epoch 14/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9583 - loss: 0.1444 - val_accuracy: 0.9619 - val_loss: 0.1418
# Epoch 15/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9638 - loss: 0.1341 - val_accuracy: 0.9627 - val_loss: 0.1400
# Epoch 16/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9652 - loss: 0.1225 - val_accuracy: 0.9610 - val_loss: 0.1388
# Epoch 17/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9606 - loss: 0.1376 - val_accuracy: 0.9635 - val_loss: 0.1400
# Epoch 18/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9587 - loss: 0.1461 - val_accuracy: 0.9627 - val_loss: 0.1414
# Epoch 19/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9619 - loss: 0.1350 - val_accuracy: 0.9619 - val_loss: 0.1408
# Epoch 20/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9649 - loss: 0.1258 - val_accuracy: 0.9627 - val_loss: 0.1394
# Score for fold 4: loss of 0.13939319550991058; compile_metrics of 96.2686538696289%
# Training on fold 5...
# Epoch 1/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - accuracy: 0.7938 - loss: 0.5868 - val_accuracy: 0.9519 - val_loss: 0.1724
# Epoch 2/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9545 - loss: 0.1650 - val_accuracy: 0.9577 - val_loss: 0.1529
# Epoch 3/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9635 - loss: 0.1417 - val_accuracy: 0.9602 - val_loss: 0.1506
# Epoch 4/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9583 - loss: 0.1531 - val_accuracy: 0.9602 - val_loss: 0.1504
# Epoch 5/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9665 - loss: 0.1279 - val_accuracy: 0.9594 - val_loss: 0.1501
# Epoch 6/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9620 - loss: 0.1316 - val_accuracy: 0.9602 - val_loss: 0.1526
# Epoch 7/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9615 - loss: 0.1300 - val_accuracy: 0.9594 - val_loss: 0.1503
# Epoch 8/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9577 - loss: 0.1516 - val_accuracy: 0.9594 - val_loss: 0.1510
# Epoch 9/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9630 - loss: 0.1290 - val_accuracy: 0.9585 - val_loss: 0.1519
# Epoch 10/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9590 - loss: 0.1471 - val_accuracy: 0.9585 - val_loss: 0.1511
# Epoch 11/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9624 - loss: 0.1318 - val_accuracy: 0.9585 - val_loss: 0.1509
# Epoch 12/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9660 - loss: 0.1246 - val_accuracy: 0.9594 - val_loss: 0.1519
# Epoch 13/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9628 - loss: 0.1334 - val_accuracy: 0.9585 - val_loss: 0.1510
# Epoch 14/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9631 - loss: 0.1345 - val_accuracy: 0.9585 - val_loss: 0.1517
# Epoch 15/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9632 - loss: 0.1324 - val_accuracy: 0.9577 - val_loss: 0.1516
# Epoch 16/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9658 - loss: 0.1197 - val_accuracy: 0.9577 - val_loss: 0.1511
# Epoch 17/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9624 - loss: 0.1353 - val_accuracy: 0.9577 - val_loss: 0.1510
# Epoch 18/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9594 - loss: 0.1289 - val_accuracy: 0.9585 - val_loss: 0.1515
# Epoch 19/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9659 - loss: 0.1188 - val_accuracy: 0.9585 - val_loss: 0.1516
# Epoch 20/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9636 - loss: 0.1322 - val_accuracy: 0.9585 - val_loss: 0.1523
# Score for fold 5: loss of 0.15232501924037933; compile_metrics of 95.85406184196472%
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.11997145414352417 - Accuracy: 96.27174735069275%
# > Fold 2 - Loss: 0.12167054414749146 - Accuracy: 96.10604643821716%
# > Fold 3 - Loss: 0.14310376346111298 - Accuracy: 96.01989984512329%
# > Fold 4 - Loss: 0.13939319550991058 - Accuracy: 96.2686538696289%
# > Fold 5 - Loss: 0.15232501924037933 - Accuracy: 95.85406184196472%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 96.10408186912537 (+- 0.15798490037796106)
# > Loss: 0.13529279530048371
# ------------------------------------------------------------------------

# %%
# Call the cross-validation function
mnli_matched_histories = cross_validate_rnn_model(X_mnli_matched_rnn, features_mnli_matched, y_encoded_mnli_matched, num_folds=5)
# Out:
# Training on fold 1...
# Epoch 1/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.7907 - loss: 0.5820 - val_accuracy: 0.9659 - val_loss: 0.1503
# Epoch 2/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9613 - loss: 0.1642 - val_accuracy: 0.9684 - val_loss: 0.1364
# Epoch 3/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9676 - loss: 0.1396 - val_accuracy: 0.9676 - val_loss: 0.1343
# Epoch 4/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9647 - loss: 0.1354 - val_accuracy: 0.9667 - val_loss: 0.1358
# Epoch 5/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9649 - loss: 0.1437 - val_accuracy: 0.9667 - val_loss: 0.1351
# Epoch 6/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9654 - loss: 0.1293 - val_accuracy: 0.9659 - val_loss: 0.1358
# Epoch 7/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9649 - loss: 0.1408 - val_accuracy: 0.9659 - val_loss: 0.1373
# Epoch 8/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9689 - loss: 0.1281 - val_accuracy: 0.9659 - val_loss: 0.1372
# Epoch 9/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9659 - loss: 0.1406 - val_accuracy: 0.9659 - val_loss: 0.1357
# Epoch 10/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9657 - loss: 0.1411 - val_accuracy: 0.9659 - val_loss: 0.1366
# Epoch 11/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9675 - loss: 0.1359 - val_accuracy: 0.9667 - val_loss: 0.1360
# Epoch 12/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9673 - loss: 0.1321 - val_accuracy: 0.9659 - val_loss: 0.1372
# Epoch 13/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9653 - loss: 0.1379 - val_accuracy: 0.9667 - val_loss: 0.1357
# Epoch 14/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9642 - loss: 0.1355 - val_accuracy: 0.9659 - val_loss: 0.1374
# Epoch 15/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9647 - loss: 0.1400 - val_accuracy: 0.9667 - val_loss: 0.1358
# Epoch 16/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9640 - loss: 0.1417 - val_accuracy: 0.9667 - val_loss: 0.1369
# Epoch 17/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9670 - loss: 0.1410 - val_accuracy: 0.9667 - val_loss: 0.1361
# Epoch 18/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9636 - loss: 0.1456 - val_accuracy: 0.9667 - val_loss: 0.1369
# Epoch 19/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9597 - loss: 0.1542 - val_accuracy: 0.9667 - val_loss: 0.1362
# Epoch 20/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9677 - loss: 0.1306 - val_accuracy: 0.9650 - val_loss: 0.1390
# Score for fold 1: loss of 0.13900679349899292; compile_metrics of 96.50170803070068%
# Training on fold 2...
# Epoch 1/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.7720 - loss: 0.6361 - val_accuracy: 0.9633 - val_loss: 0.1649
# Epoch 2/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9641 - loss: 0.1625 - val_accuracy: 0.9633 - val_loss: 0.1509
# Epoch 3/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9714 - loss: 0.1243 - val_accuracy: 0.9624 - val_loss: 0.1450
# Epoch 4/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9670 - loss: 0.1420 - val_accuracy: 0.9633 - val_loss: 0.1451
# Epoch 5/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9643 - loss: 0.1471 - val_accuracy: 0.9641 - val_loss: 0.1451
# Epoch 6/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9670 - loss: 0.1332 - val_accuracy: 0.9641 - val_loss: 0.1457
# Epoch 7/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9649 - loss: 0.1435 - val_accuracy: 0.9650 - val_loss: 0.1437
# Epoch 8/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9706 - loss: 0.1212 - val_accuracy: 0.9633 - val_loss: 0.1442
# Epoch 9/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9655 - loss: 0.1388 - val_accuracy: 0.9650 - val_loss: 0.1436
# Epoch 10/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9661 - loss: 0.1352 - val_accuracy: 0.9650 - val_loss: 0.1442
# Epoch 11/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9635 - loss: 0.1396 - val_accuracy: 0.9641 - val_loss: 0.1446
# Epoch 12/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9657 - loss: 0.1335 - val_accuracy: 0.9650 - val_loss: 0.1432
# Epoch 13/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9710 - loss: 0.1217 - val_accuracy: 0.9633 - val_loss: 0.1443
# Epoch 14/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9676 - loss: 0.1319 - val_accuracy: 0.9650 - val_loss: 0.1435
# Epoch 15/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9696 - loss: 0.1286 - val_accuracy: 0.9641 - val_loss: 0.1445
# Epoch 16/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9691 - loss: 0.1233 - val_accuracy: 0.9633 - val_loss: 0.1440
# Epoch 17/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9640 - loss: 0.1434 - val_accuracy: 0.9650 - val_loss: 0.1441
# Epoch 18/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9651 - loss: 0.1405 - val_accuracy: 0.9633 - val_loss: 0.1448
# Epoch 19/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9700 - loss: 0.1242 - val_accuracy: 0.9650 - val_loss: 0.1427
# Epoch 20/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9663 - loss: 0.1373 - val_accuracy: 0.9633 - val_loss: 0.1446
# Score for fold 2: loss of 0.14459282159805298; compile_metrics of 96.32792472839355%
# Training on fold 3...
# Epoch 1/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - accuracy: 0.9541 - loss: 0.3497 - val_accuracy: 0.9641 - val_loss: 0.1463
# Epoch 2/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9674 - loss: 0.1484 - val_accuracy: 0.9641 - val_loss: 0.1388
# Epoch 3/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9656 - loss: 0.1464 - val_accuracy: 0.9650 - val_loss: 0.1360
# Epoch 4/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9640 - loss: 0.1477 - val_accuracy: 0.9684 - val_loss: 0.1340
# Epoch 5/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9643 - loss: 0.1472 - val_accuracy: 0.9693 - val_loss: 0.1341
# Epoch 6/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9658 - loss: 0.1408 - val_accuracy: 0.9684 - val_loss: 0.1335
# Epoch 7/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9694 - loss: 0.1285 - val_accuracy: 0.9684 - val_loss: 0.1325
# Epoch 8/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9702 - loss: 0.1262 - val_accuracy: 0.9684 - val_loss: 0.1323
# Epoch 9/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9649 - loss: 0.1416 - val_accuracy: 0.9684 - val_loss: 0.1322
# Epoch 10/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9644 - loss: 0.1545 - val_accuracy: 0.9684 - val_loss: 0.1326
# Epoch 11/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9667 - loss: 0.1394 - val_accuracy: 0.9684 - val_loss: 0.1326
# Epoch 12/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9648 - loss: 0.1475 - val_accuracy: 0.9684 - val_loss: 0.1328
# Epoch 13/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9669 - loss: 0.1395 - val_accuracy: 0.9684 - val_loss: 0.1342
# Epoch 14/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9632 - loss: 0.1491 - val_accuracy: 0.9684 - val_loss: 0.1337
# Epoch 15/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9644 - loss: 0.1425 - val_accuracy: 0.9684 - val_loss: 0.1329
# Epoch 16/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9672 - loss: 0.1381 - val_accuracy: 0.9684 - val_loss: 0.1323
# Epoch 17/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9699 - loss: 0.1250 - val_accuracy: 0.9684 - val_loss: 0.1322
# Epoch 18/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9679 - loss: 0.1206 - val_accuracy: 0.9684 - val_loss: 0.1323
# Epoch 19/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9603 - loss: 0.1545 - val_accuracy: 0.9675 - val_loss: 0.1353
# Epoch 20/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9703 - loss: 0.1276 - val_accuracy: 0.9667 - val_loss: 0.1331
# Score for fold 3: loss of 0.13312281668186188; compile_metrics of 96.66951298713684%
# Training on fold 4...
# Epoch 1/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.8878 - loss: 0.4873 - val_accuracy: 0.9650 - val_loss: 0.1474
# Epoch 2/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9657 - loss: 0.1458 - val_accuracy: 0.9650 - val_loss: 0.1350
# Epoch 3/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9656 - loss: 0.1383 - val_accuracy: 0.9658 - val_loss: 0.1335
# Epoch 4/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9657 - loss: 0.1416 - val_accuracy: 0.9658 - val_loss: 0.1309
# Epoch 5/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9636 - loss: 0.1433 - val_accuracy: 0.9658 - val_loss: 0.1321
# Epoch 6/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9674 - loss: 0.1385 - val_accuracy: 0.9658 - val_loss: 0.1307
# Epoch 7/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9647 - loss: 0.1403 - val_accuracy: 0.9658 - val_loss: 0.1310
# Epoch 8/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9688 - loss: 0.1349 - val_accuracy: 0.9650 - val_loss: 0.1302
# Epoch 9/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9693 - loss: 0.1264 - val_accuracy: 0.9658 - val_loss: 0.1306
# Epoch 10/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9635 - loss: 0.1466 - val_accuracy: 0.9650 - val_loss: 0.1321
# Epoch 11/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9702 - loss: 0.1238 - val_accuracy: 0.9667 - val_loss: 0.1310
# Epoch 12/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9638 - loss: 0.1450 - val_accuracy: 0.9658 - val_loss: 0.1306
# Epoch 13/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9671 - loss: 0.1414 - val_accuracy: 0.9650 - val_loss: 0.1315
# Epoch 14/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9662 - loss: 0.1384 - val_accuracy: 0.9667 - val_loss: 0.1310
# Epoch 15/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9723 - loss: 0.1190 - val_accuracy: 0.9650 - val_loss: 0.1298
# Epoch 16/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9641 - loss: 0.1421 - val_accuracy: 0.9667 - val_loss: 0.1301
# Epoch 17/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9686 - loss: 0.1282 - val_accuracy: 0.9667 - val_loss: 0.1306
# Epoch 18/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9640 - loss: 0.1442 - val_accuracy: 0.9658 - val_loss: 0.1302
# Epoch 19/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9644 - loss: 0.1466 - val_accuracy: 0.9658 - val_loss: 0.1301
# Epoch 20/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9702 - loss: 0.1260 - val_accuracy: 0.9667 - val_loss: 0.1310
# Score for fold 4: loss of 0.13096930086612701; compile_metrics of 96.66951298713684%
# Training on fold 5...
# Epoch 1/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.8129 - loss: 0.5734 - val_accuracy: 0.9675 - val_loss: 0.1481
# Epoch 2/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9640 - loss: 0.1653 - val_accuracy: 0.9675 - val_loss: 0.1297
# Epoch 3/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9652 - loss: 0.1508 - val_accuracy: 0.9667 - val_loss: 0.1255
# Epoch 4/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9634 - loss: 0.1461 - val_accuracy: 0.9667 - val_loss: 0.1249
# Epoch 5/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9682 - loss: 0.1355 - val_accuracy: 0.9658 - val_loss: 0.1257
# Epoch 6/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9674 - loss: 0.1327 - val_accuracy: 0.9667 - val_loss: 0.1255
# Epoch 7/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9644 - loss: 0.1444 - val_accuracy: 0.9658 - val_loss: 0.1261
# Epoch 8/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9641 - loss: 0.1514 - val_accuracy: 0.9667 - val_loss: 0.1263
# Epoch 9/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9699 - loss: 0.1293 - val_accuracy: 0.9658 - val_loss: 0.1280
# Epoch 10/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9671 - loss: 0.1407 - val_accuracy: 0.9658 - val_loss: 0.1265
# Epoch 11/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9682 - loss: 0.1356 - val_accuracy: 0.9658 - val_loss: 0.1267
# Epoch 12/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9634 - loss: 0.1365 - val_accuracy: 0.9658 - val_loss: 0.1269
# Epoch 13/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9634 - loss: 0.1419 - val_accuracy: 0.9667 - val_loss: 0.1263
# Epoch 14/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9656 - loss: 0.1420 - val_accuracy: 0.9667 - val_loss: 0.1262
# Epoch 15/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9684 - loss: 0.1334 - val_accuracy: 0.9658 - val_loss: 0.1264
# Epoch 16/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9620 - loss: 0.1500 - val_accuracy: 0.9667 - val_loss: 0.1263
# Epoch 17/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9683 - loss: 0.1303 - val_accuracy: 0.9667 - val_loss: 0.1259
# Epoch 18/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9628 - loss: 0.1477 - val_accuracy: 0.9658 - val_loss: 0.1260
# Epoch 19/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9669 - loss: 0.1304 - val_accuracy: 0.9658 - val_loss: 0.1283
# Epoch 20/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9658 - loss: 0.1450 - val_accuracy: 0.9667 - val_loss: 0.1263
# Score for fold 5: loss of 0.12625813484191895; compile_metrics of 96.66951298713684%
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.13900679349899292 - Accuracy: 96.50170803070068%
# > Fold 2 - Loss: 0.14459282159805298 - Accuracy: 96.32792472839355%
# > Fold 3 - Loss: 0.13312281668186188 - Accuracy: 96.66951298713684%
# > Fold 4 - Loss: 0.13096930086612701 - Accuracy: 96.66951298713684%
# > Fold 5 - Loss: 0.12625813484191895 - Accuracy: 96.66951298713684%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 96.56763434410095 (+- 0.13634130143257447)
# > Loss: 0.13478997349739075
# ------------------------------------------------------------------------

# %%
# Call the cross-validation function
mnli_mismatched_histories = cross_validate_rnn_model(X_mnli_mismatched_rnn, features_mnli_mismatched, y_encoded_mnli_mismatched, num_folds=5)
# Out:
# Training on fold 1...
# Epoch 1/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.7979 - loss: 0.6017 - val_accuracy: 0.9645 - val_loss: 0.1531
# Epoch 2/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9650 - loss: 0.1555 - val_accuracy: 0.9645 - val_loss: 0.1396
# Epoch 3/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9668 - loss: 0.1266 - val_accuracy: 0.9636 - val_loss: 0.1363
# Epoch 4/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9681 - loss: 0.1216 - val_accuracy: 0.9653 - val_loss: 0.1352
# Epoch 5/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9664 - loss: 0.1185 - val_accuracy: 0.9636 - val_loss: 0.1346
# Epoch 6/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9619 - loss: 0.1348 - val_accuracy: 0.9636 - val_loss: 0.1355
# Epoch 7/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9631 - loss: 0.1313 - val_accuracy: 0.9619 - val_loss: 0.1345
# Epoch 8/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9660 - loss: 0.1180 - val_accuracy: 0.9636 - val_loss: 0.1370
# Epoch 9/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9630 - loss: 0.1272 - val_accuracy: 0.9645 - val_loss: 0.1383
# Epoch 10/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9647 - loss: 0.1305 - val_accuracy: 0.9636 - val_loss: 0.1375
# Epoch 11/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9599 - loss: 0.1319 - val_accuracy: 0.9645 - val_loss: 0.1384
# Epoch 12/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9692 - loss: 0.1105 - val_accuracy: 0.9628 - val_loss: 0.1359
# Epoch 13/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9669 - loss: 0.1204 - val_accuracy: 0.9619 - val_loss: 0.1345
# Epoch 14/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9612 - loss: 0.1236 - val_accuracy: 0.9628 - val_loss: 0.1366
# Epoch 15/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9708 - loss: 0.1141 - val_accuracy: 0.9619 - val_loss: 0.1354
# Epoch 16/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9648 - loss: 0.1245 - val_accuracy: 0.9628 - val_loss: 0.1360
# Epoch 17/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9603 - loss: 0.1309 - val_accuracy: 0.9645 - val_loss: 0.1382
# Epoch 18/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9659 - loss: 0.1143 - val_accuracy: 0.9628 - val_loss: 0.1360
# Epoch 19/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9715 - loss: 0.1066 - val_accuracy: 0.9628 - val_loss: 0.1337
# Epoch 20/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9683 - loss: 0.1181 - val_accuracy: 0.9628 - val_loss: 0.1351
# Score for fold 1: loss of 0.1351037174463272; compile_metrics of 96.2774932384491%
# Training on fold 2...
# Epoch 1/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - accuracy: 0.8256 - loss: 0.5722 - val_accuracy: 0.9687 - val_loss: 0.1406
# Epoch 2/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9640 - loss: 0.1610 - val_accuracy: 0.9679 - val_loss: 0.1205
# Epoch 3/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9660 - loss: 0.1377 - val_accuracy: 0.9704 - val_loss: 0.1146
# Epoch 4/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9637 - loss: 0.1373 - val_accuracy: 0.9704 - val_loss: 0.1134
# Epoch 5/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9675 - loss: 0.1262 - val_accuracy: 0.9679 - val_loss: 0.1133
# Epoch 6/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9608 - loss: 0.1404 - val_accuracy: 0.9729 - val_loss: 0.1117
# Epoch 7/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9693 - loss: 0.1177 - val_accuracy: 0.9712 - val_loss: 0.1112
# Epoch 8/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9651 - loss: 0.1285 - val_accuracy: 0.9721 - val_loss: 0.1116
# Epoch 9/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9608 - loss: 0.1365 - val_accuracy: 0.9738 - val_loss: 0.1119
# Epoch 10/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9635 - loss: 0.1281 - val_accuracy: 0.9729 - val_loss: 0.1115
# Epoch 11/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9659 - loss: 0.1262 - val_accuracy: 0.9704 - val_loss: 0.1111
# Epoch 12/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9657 - loss: 0.1350 - val_accuracy: 0.9721 - val_loss: 0.1118
# Epoch 13/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9625 - loss: 0.1385 - val_accuracy: 0.9721 - val_loss: 0.1108
# Epoch 14/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9699 - loss: 0.1123 - val_accuracy: 0.9670 - val_loss: 0.1112
# Epoch 15/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9652 - loss: 0.1241 - val_accuracy: 0.9687 - val_loss: 0.1114
# Epoch 16/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9647 - loss: 0.1186 - val_accuracy: 0.9670 - val_loss: 0.1132
# Epoch 17/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9630 - loss: 0.1335 - val_accuracy: 0.9712 - val_loss: 0.1108
# Epoch 18/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9649 - loss: 0.1283 - val_accuracy: 0.9712 - val_loss: 0.1107
# Epoch 19/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9662 - loss: 0.1237 - val_accuracy: 0.9695 - val_loss: 0.1117
# Epoch 20/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9668 - loss: 0.1215 - val_accuracy: 0.9704 - val_loss: 0.1107
# Score for fold 2: loss of 0.11069915443658829; compile_metrics of 97.0389187335968%
# Training on fold 3...
# Epoch 1/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - accuracy: 0.7986 - loss: 0.5775 - val_accuracy: 0.9670 - val_loss: 0.1487
# Epoch 2/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9663 - loss: 0.1481 - val_accuracy: 0.9670 - val_loss: 0.1320
# Epoch 3/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9702 - loss: 0.1232 - val_accuracy: 0.9670 - val_loss: 0.1297
# Epoch 4/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9683 - loss: 0.1149 - val_accuracy: 0.9653 - val_loss: 0.1287
# Epoch 5/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9648 - loss: 0.1290 - val_accuracy: 0.9636 - val_loss: 0.1278
# Epoch 6/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9690 - loss: 0.1174 - val_accuracy: 0.9679 - val_loss: 0.1249
# Epoch 7/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9630 - loss: 0.1340 - val_accuracy: 0.9645 - val_loss: 0.1273
# Epoch 8/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9662 - loss: 0.1248 - val_accuracy: 0.9679 - val_loss: 0.1253
# Epoch 9/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9662 - loss: 0.1202 - val_accuracy: 0.9645 - val_loss: 0.1265
# Epoch 10/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9646 - loss: 0.1293 - val_accuracy: 0.9670 - val_loss: 0.1244
# Epoch 11/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9623 - loss: 0.1281 - val_accuracy: 0.9653 - val_loss: 0.1261
# Epoch 12/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9660 - loss: 0.1351 - val_accuracy: 0.9679 - val_loss: 0.1242
# Epoch 13/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9630 - loss: 0.1346 - val_accuracy: 0.9679 - val_loss: 0.1258
# Epoch 14/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9666 - loss: 0.1250 - val_accuracy: 0.9662 - val_loss: 0.1237
# Epoch 15/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9639 - loss: 0.1306 - val_accuracy: 0.9679 - val_loss: 0.1264
# Epoch 16/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9652 - loss: 0.1200 - val_accuracy: 0.9687 - val_loss: 0.1255
# Epoch 17/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9658 - loss: 0.1367 - val_accuracy: 0.9687 - val_loss: 0.1271
# Epoch 18/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9592 - loss: 0.1441 - val_accuracy: 0.9670 - val_loss: 0.1251
# Epoch 19/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9669 - loss: 0.1159 - val_accuracy: 0.9645 - val_loss: 0.1250
# Epoch 20/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9621 - loss: 0.1312 - val_accuracy: 0.9687 - val_loss: 0.1253
# Score for fold 3: loss of 0.12529125809669495; compile_metrics of 96.86971306800842%
# Training on fold 4...
# Epoch 1/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - accuracy: 0.9136 - loss: 0.4191 - val_accuracy: 0.9670 - val_loss: 0.1386
# Epoch 2/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9681 - loss: 0.1367 - val_accuracy: 0.9679 - val_loss: 0.1244
# Epoch 3/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9692 - loss: 0.1206 - val_accuracy: 0.9670 - val_loss: 0.1214
# Epoch 4/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9660 - loss: 0.1335 - val_accuracy: 0.9662 - val_loss: 0.1209
# Epoch 5/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9710 - loss: 0.1248 - val_accuracy: 0.9653 - val_loss: 0.1207
# Epoch 6/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9642 - loss: 0.1280 - val_accuracy: 0.9653 - val_loss: 0.1232
# Epoch 7/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9710 - loss: 0.1182 - val_accuracy: 0.9645 - val_loss: 0.1205
# Epoch 8/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9673 - loss: 0.1227 - val_accuracy: 0.9645 - val_loss: 0.1211
# Epoch 9/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9673 - loss: 0.1170 - val_accuracy: 0.9645 - val_loss: 0.1212
# Epoch 10/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9703 - loss: 0.1184 - val_accuracy: 0.9645 - val_loss: 0.1208
# Epoch 11/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9658 - loss: 0.1210 - val_accuracy: 0.9645 - val_loss: 0.1211
# Epoch 12/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9666 - loss: 0.1184 - val_accuracy: 0.9645 - val_loss: 0.1212
# Epoch 13/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9662 - loss: 0.1230 - val_accuracy: 0.9636 - val_loss: 0.1210
# Epoch 14/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9597 - loss: 0.1437 - val_accuracy: 0.9645 - val_loss: 0.1216
# Epoch 15/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9645 - loss: 0.1301 - val_accuracy: 0.9636 - val_loss: 0.1220
# Epoch 16/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9687 - loss: 0.1243 - val_accuracy: 0.9645 - val_loss: 0.1220
# Epoch 17/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9660 - loss: 0.1360 - val_accuracy: 0.9653 - val_loss: 0.1221
# Epoch 18/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9641 - loss: 0.1295 - val_accuracy: 0.9636 - val_loss: 0.1221
# Epoch 19/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9639 - loss: 0.1305 - val_accuracy: 0.9662 - val_loss: 0.1228
# Epoch 20/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9652 - loss: 0.1215 - val_accuracy: 0.9662 - val_loss: 0.1230
# Score for fold 4: loss of 0.12296168506145477; compile_metrics of 96.61590456962585%
# Training on fold 5...
# Epoch 1/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - accuracy: 0.8976 - loss: 0.4787 - val_accuracy: 0.9645 - val_loss: 0.1415
# Epoch 2/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9636 - loss: 0.1500 - val_accuracy: 0.9653 - val_loss: 0.1262
# Epoch 3/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9643 - loss: 0.1439 - val_accuracy: 0.9679 - val_loss: 0.1208
# Epoch 4/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9651 - loss: 0.1334 - val_accuracy: 0.9653 - val_loss: 0.1196
# Epoch 5/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9640 - loss: 0.1351 - val_accuracy: 0.9645 - val_loss: 0.1190
# Epoch 6/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9703 - loss: 0.1192 - val_accuracy: 0.9636 - val_loss: 0.1192
# Epoch 7/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9681 - loss: 0.1219 - val_accuracy: 0.9636 - val_loss: 0.1185
# Epoch 8/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9640 - loss: 0.1340 - val_accuracy: 0.9645 - val_loss: 0.1189
# Epoch 9/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9644 - loss: 0.1234 - val_accuracy: 0.9636 - val_loss: 0.1187
# Epoch 10/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9688 - loss: 0.1211 - val_accuracy: 0.9636 - val_loss: 0.1188
# Epoch 11/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9618 - loss: 0.1320 - val_accuracy: 0.9645 - val_loss: 0.1190
# Epoch 12/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9658 - loss: 0.1232 - val_accuracy: 0.9636 - val_loss: 0.1205
# Epoch 13/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9646 - loss: 0.1258 - val_accuracy: 0.9636 - val_loss: 0.1191
# Epoch 14/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9676 - loss: 0.1245 - val_accuracy: 0.9636 - val_loss: 0.1194
# Epoch 15/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9651 - loss: 0.1207 - val_accuracy: 0.9636 - val_loss: 0.1204
# Epoch 16/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9658 - loss: 0.1302 - val_accuracy: 0.9636 - val_loss: 0.1200
# Epoch 17/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9705 - loss: 0.1180 - val_accuracy: 0.9636 - val_loss: 0.1194
# Epoch 18/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9688 - loss: 0.1165 - val_accuracy: 0.9636 - val_loss: 0.1219
# Epoch 19/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9602 - loss: 0.1332 - val_accuracy: 0.9636 - val_loss: 0.1200
# Epoch 20/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9640 - loss: 0.1251 - val_accuracy: 0.9636 - val_loss: 0.1201
# Score for fold 5: loss of 0.12005835771560669; compile_metrics of 96.36209607124329%
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.1351037174463272 - Accuracy: 96.2774932384491%
# > Fold 2 - Loss: 0.11069915443658829 - Accuracy: 97.0389187335968%
# > Fold 3 - Loss: 0.12529125809669495 - Accuracy: 96.86971306800842%
# > Fold 4 - Loss: 0.12296168506145477 - Accuracy: 96.61590456962585%
# > Fold 5 - Loss: 0.12005835771560669 - Accuracy: 96.36209607124329%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 96.63282513618469 (+- 0.2901272795956743)
# > Loss: 0.12282283455133439
# ------------------------------------------------------------------------

# %%
# Call the cross-validation function
anli_r1_histories = cross_validate_rnn_model(X_anli_r1_rnn, features_anli_r1, y_encoded_anli_r1, num_folds=5)
# Out:
# Training on fold 1...
# Epoch 1/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 403ms/step - accuracy: 0.4279 - loss: 1.1078 - val_accuracy: 0.6860 - val_loss: 0.8888
# Epoch 2/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6231 - loss: 0.9081 - val_accuracy: 0.6860 - val_loss: 0.7793
# Epoch 3/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6686 - loss: 0.8158 - val_accuracy: 0.7558 - val_loss: 0.6991
# Epoch 4/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7267 - loss: 0.7208 - val_accuracy: 0.7558 - val_loss: 0.6432
# Epoch 5/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7702 - loss: 0.6607 - val_accuracy: 0.7791 - val_loss: 0.6035
# Epoch 6/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7960 - loss: 0.5851 - val_accuracy: 0.7674 - val_loss: 0.5728
# Epoch 7/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7940 - loss: 0.6125 - val_accuracy: 0.7674 - val_loss: 0.5526
# Epoch 8/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7309 - loss: 0.6319 - val_accuracy: 0.7907 - val_loss: 0.5387
# Epoch 9/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7754 - loss: 0.5959 - val_accuracy: 0.7907 - val_loss: 0.5286
# Epoch 10/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7752 - loss: 0.5500 - val_accuracy: 0.7907 - val_loss: 0.5211
# Epoch 11/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7652 - loss: 0.6194 - val_accuracy: 0.8023 - val_loss: 0.5124
# Epoch 12/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8057 - loss: 0.5233 - val_accuracy: 0.8023 - val_loss: 0.5085
# Epoch 13/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8069 - loss: 0.5206 - val_accuracy: 0.8023 - val_loss: 0.5045
# Epoch 14/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7888 - loss: 0.5528 - val_accuracy: 0.8023 - val_loss: 0.5009
# Epoch 15/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7980 - loss: 0.5806 - val_accuracy: 0.7907 - val_loss: 0.4972
# Epoch 16/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7980 - loss: 0.4956 - val_accuracy: 0.7907 - val_loss: 0.4958
# Epoch 17/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7726 - loss: 0.5629 - val_accuracy: 0.7907 - val_loss: 0.4942
# Epoch 18/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7787 - loss: 0.5821 - val_accuracy: 0.7907 - val_loss: 0.4955
# Epoch 19/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7987 - loss: 0.5497 - val_accuracy: 0.8023 - val_loss: 0.4911
# Epoch 20/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8263 - loss: 0.4881 - val_accuracy: 0.8023 - val_loss: 0.4898
# Score for fold 1: loss of 0.4898100197315216; compile_metrics of 80.23256063461304%
# Training on fold 2...
# Epoch 1/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 9s 446ms/step - accuracy: 0.3658 - loss: 1.1254 - val_accuracy: 0.6588 - val_loss: 0.9849
# Epoch 2/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5665 - loss: 0.9632 - val_accuracy: 0.7882 - val_loss: 0.8495
# Epoch 3/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7046 - loss: 0.8414 - val_accuracy: 0.7882 - val_loss: 0.7558
# Epoch 4/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7203 - loss: 0.7555 - val_accuracy: 0.7765 - val_loss: 0.6937
# Epoch 5/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7733 - loss: 0.6760 - val_accuracy: 0.7765 - val_loss: 0.6521
# Epoch 6/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7873 - loss: 0.6179 - val_accuracy: 0.7882 - val_loss: 0.6237
# Epoch 7/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7801 - loss: 0.5874 - val_accuracy: 0.8000 - val_loss: 0.6046
# Epoch 8/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7853 - loss: 0.5823 - val_accuracy: 0.8235 - val_loss: 0.5924
# Epoch 9/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8072 - loss: 0.5706 - val_accuracy: 0.8118 - val_loss: 0.5813
# Epoch 10/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8291 - loss: 0.5512 - val_accuracy: 0.8118 - val_loss: 0.5720
# Epoch 11/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7868 - loss: 0.5412 - val_accuracy: 0.8118 - val_loss: 0.5652
# Epoch 12/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7999 - loss: 0.5313 - val_accuracy: 0.8118 - val_loss: 0.5626
# Epoch 13/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8016 - loss: 0.5225 - val_accuracy: 0.8000 - val_loss: 0.5602
# Epoch 14/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8560 - loss: 0.4637 - val_accuracy: 0.8000 - val_loss: 0.5587
# Epoch 15/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7847 - loss: 0.5422 - val_accuracy: 0.8000 - val_loss: 0.5539
# Epoch 16/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8171 - loss: 0.4988 - val_accuracy: 0.8000 - val_loss: 0.5516
# Epoch 17/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8090 - loss: 0.5489 - val_accuracy: 0.8000 - val_loss: 0.5493
# Epoch 18/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8112 - loss: 0.4785 - val_accuracy: 0.8000 - val_loss: 0.5468
# Epoch 19/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8114 - loss: 0.4999 - val_accuracy: 0.8000 - val_loss: 0.5442
# Epoch 20/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7774 - loss: 0.5499 - val_accuracy: 0.8000 - val_loss: 0.5487
# Score for fold 2: loss of 0.548690915107727; compile_metrics of 80.0000011920929%
# Training on fold 3...
# Epoch 1/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 401ms/step - accuracy: 0.2329 - loss: 1.3001 - val_accuracy: 0.5176 - val_loss: 1.0795
# Epoch 2/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.4253 - loss: 1.0970 - val_accuracy: 0.7176 - val_loss: 0.9255
# Epoch 3/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5714 - loss: 0.9403 - val_accuracy: 0.8000 - val_loss: 0.8184
# Epoch 4/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6540 - loss: 0.8440 - val_accuracy: 0.7765 - val_loss: 0.7427
# Epoch 5/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7500 - loss: 0.7719 - val_accuracy: 0.7765 - val_loss: 0.6892
# Epoch 6/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7482 - loss: 0.6747 - val_accuracy: 0.7647 - val_loss: 0.6465
# Epoch 7/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8051 - loss: 0.6614 - val_accuracy: 0.7647 - val_loss: 0.6150
# Epoch 8/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7692 - loss: 0.6522 - val_accuracy: 0.7647 - val_loss: 0.5920
# Epoch 9/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7969 - loss: 0.6037 - val_accuracy: 0.7765 - val_loss: 0.5749
# Epoch 10/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7892 - loss: 0.6037 - val_accuracy: 0.7765 - val_loss: 0.5616
# Epoch 11/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8087 - loss: 0.5859 - val_accuracy: 0.7647 - val_loss: 0.5494
# Epoch 12/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8021 - loss: 0.5560 - val_accuracy: 0.7765 - val_loss: 0.5423
# Epoch 13/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8071 - loss: 0.5481 - val_accuracy: 0.7882 - val_loss: 0.5354
# Epoch 14/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7738 - loss: 0.5392 - val_accuracy: 0.7765 - val_loss: 0.5303
# Epoch 15/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7588 - loss: 0.5963 - val_accuracy: 0.7882 - val_loss: 0.5272
# Epoch 16/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7816 - loss: 0.5435 - val_accuracy: 0.7882 - val_loss: 0.5230
# Epoch 17/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7840 - loss: 0.5939 - val_accuracy: 0.8000 - val_loss: 0.5211
# Epoch 18/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8216 - loss: 0.5409 - val_accuracy: 0.8000 - val_loss: 0.5192
# Epoch 19/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8123 - loss: 0.5370 - val_accuracy: 0.8000 - val_loss: 0.5154
# Epoch 20/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8269 - loss: 0.4948 - val_accuracy: 0.8000 - val_loss: 0.5138
# Score for fold 3: loss of 0.5138072967529297; compile_metrics of 80.0000011920929%
# Training on fold 4...
# Epoch 1/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 408ms/step - accuracy: 0.2951 - loss: 1.1371 - val_accuracy: 0.6353 - val_loss: 0.9761
# Epoch 2/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5495 - loss: 0.9720 - val_accuracy: 0.6941 - val_loss: 0.8542
# Epoch 3/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6924 - loss: 0.8316 - val_accuracy: 0.7176 - val_loss: 0.7732
# Epoch 4/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6794 - loss: 0.7619 - val_accuracy: 0.7059 - val_loss: 0.7196
# Epoch 5/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7193 - loss: 0.6908 - val_accuracy: 0.7059 - val_loss: 0.6815
# Epoch 6/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7448 - loss: 0.6506 - val_accuracy: 0.7647 - val_loss: 0.6523
# Epoch 7/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7726 - loss: 0.6084 - val_accuracy: 0.7765 - val_loss: 0.6311
# Epoch 8/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7877 - loss: 0.6363 - val_accuracy: 0.7765 - val_loss: 0.6154
# Epoch 9/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8118 - loss: 0.5874 - val_accuracy: 0.7882 - val_loss: 0.6042
# Epoch 10/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8068 - loss: 0.5703 - val_accuracy: 0.7882 - val_loss: 0.5931
# Epoch 11/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8173 - loss: 0.5333 - val_accuracy: 0.7882 - val_loss: 0.5857
# Epoch 12/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8238 - loss: 0.4986 - val_accuracy: 0.7765 - val_loss: 0.5804
# Epoch 13/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7934 - loss: 0.5517 - val_accuracy: 0.7765 - val_loss: 0.5756
# Epoch 14/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8136 - loss: 0.5182 - val_accuracy: 0.7882 - val_loss: 0.5729
# Epoch 15/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8405 - loss: 0.4734 - val_accuracy: 0.7765 - val_loss: 0.5712
# Epoch 16/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7666 - loss: 0.5360 - val_accuracy: 0.7882 - val_loss: 0.5697
# Epoch 17/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8187 - loss: 0.4884 - val_accuracy: 0.7882 - val_loss: 0.5676
# Epoch 18/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8058 - loss: 0.5043 - val_accuracy: 0.7882 - val_loss: 0.5653
# Epoch 19/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7969 - loss: 0.5766 - val_accuracy: 0.8000 - val_loss: 0.5663
# Epoch 20/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8258 - loss: 0.5216 - val_accuracy: 0.8000 - val_loss: 0.5658
# Score for fold 4: loss of 0.565816342830658; compile_metrics of 80.0000011920929%
# Training on fold 5...
# Epoch 1/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 401ms/step - accuracy: 0.5695 - loss: 0.9858 - val_accuracy: 0.7294 - val_loss: 0.8460
# Epoch 2/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7024 - loss: 0.8373 - val_accuracy: 0.7294 - val_loss: 0.7554
# Epoch 3/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7048 - loss: 0.7828 - val_accuracy: 0.7294 - val_loss: 0.6893
# Epoch 4/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7216 - loss: 0.6936 - val_accuracy: 0.7294 - val_loss: 0.6431
# Epoch 5/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6859 - loss: 0.7183 - val_accuracy: 0.7529 - val_loss: 0.6082
# Epoch 6/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7641 - loss: 0.6685 - val_accuracy: 0.7882 - val_loss: 0.5808
# Epoch 7/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7403 - loss: 0.6465 - val_accuracy: 0.8118 - val_loss: 0.5589
# Epoch 8/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7805 - loss: 0.5844 - val_accuracy: 0.8000 - val_loss: 0.5428
# Epoch 9/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7539 - loss: 0.5939 - val_accuracy: 0.7765 - val_loss: 0.5297
# Epoch 10/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7785 - loss: 0.6039 - val_accuracy: 0.7882 - val_loss: 0.5168
# Epoch 11/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7807 - loss: 0.5949 - val_accuracy: 0.7882 - val_loss: 0.5081
# Epoch 12/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7602 - loss: 0.5973 - val_accuracy: 0.8000 - val_loss: 0.5004
# Epoch 13/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7563 - loss: 0.6028 - val_accuracy: 0.8118 - val_loss: 0.4937
# Epoch 14/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7575 - loss: 0.5896 - val_accuracy: 0.8118 - val_loss: 0.4883
# Epoch 15/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7948 - loss: 0.5370 - val_accuracy: 0.8235 - val_loss: 0.4834
# Epoch 16/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8008 - loss: 0.5443 - val_accuracy: 0.8353 - val_loss: 0.4814
# Epoch 17/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7794 - loss: 0.5661 - val_accuracy: 0.8235 - val_loss: 0.4788
# Epoch 18/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7821 - loss: 0.5345 - val_accuracy: 0.8235 - val_loss: 0.4758
# Epoch 19/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8059 - loss: 0.5166 - val_accuracy: 0.8235 - val_loss: 0.4758
# Epoch 20/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8184 - loss: 0.5014 - val_accuracy: 0.8000 - val_loss: 0.4748
# Score for fold 5: loss of 0.47482991218566895; compile_metrics of 80.0000011920929%
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.4898100197315216 - Accuracy: 80.23256063461304%
# > Fold 2 - Loss: 0.548690915107727 - Accuracy: 80.0000011920929%
# > Fold 3 - Loss: 0.5138072967529297 - Accuracy: 80.0000011920929%
# > Fold 4 - Loss: 0.565816342830658 - Accuracy: 80.0000011920929%
# > Fold 5 - Loss: 0.47482991218566895 - Accuracy: 80.0000011920929%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 80.04651308059692 (+- 0.09302377700805664)
# > Loss: 0.518590897321701
# ------------------------------------------------------------------------

# %%
# Call the cross-validation function
anli_r2_histories = cross_validate_rnn_model(X_anli_r2_rnn, features_anli_r2, y_encoded_anli_r2, num_folds=5)
# Out:
# Training on fold 1...
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 333ms/step - accuracy: 0.2832 - loss: 1.2198 - val_accuracy: 0.4157 - val_loss: 1.1238
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4139 - loss: 1.1207 - val_accuracy: 0.5730 - val_loss: 1.0045
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5105 - loss: 1.0256 - val_accuracy: 0.6966 - val_loss: 0.9173
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5724 - loss: 0.9537 - val_accuracy: 0.6966 - val_loss: 0.8511
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6137 - loss: 0.9352 - val_accuracy: 0.7079 - val_loss: 0.8034
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6599 - loss: 0.9014 - val_accuracy: 0.7079 - val_loss: 0.7632
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6197 - loss: 0.8695 - val_accuracy: 0.6966 - val_loss: 0.7319
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6728 - loss: 0.8279 - val_accuracy: 0.7303 - val_loss: 0.7072
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6396 - loss: 0.8425 - val_accuracy: 0.7303 - val_loss: 0.6843
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6887 - loss: 0.7955 - val_accuracy: 0.7528 - val_loss: 0.6676
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7131 - loss: 0.7670 - val_accuracy: 0.7416 - val_loss: 0.6542
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6739 - loss: 0.7936 - val_accuracy: 0.7416 - val_loss: 0.6411
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7113 - loss: 0.7236 - val_accuracy: 0.7753 - val_loss: 0.6319
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7365 - loss: 0.7533 - val_accuracy: 0.7640 - val_loss: 0.6250
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6813 - loss: 0.7386 - val_accuracy: 0.7640 - val_loss: 0.6183
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7239 - loss: 0.7203 - val_accuracy: 0.7865 - val_loss: 0.6108
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7371 - loss: 0.6946 - val_accuracy: 0.7753 - val_loss: 0.6063
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7347 - loss: 0.7240 - val_accuracy: 0.7753 - val_loss: 0.6055
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7124 - loss: 0.7278 - val_accuracy: 0.7865 - val_loss: 0.6043
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7048 - loss: 0.7595 - val_accuracy: 0.7865 - val_loss: 0.6010
# Score for fold 1: loss of 0.6010212898254395; compile_metrics of 78.65168452262878%
# Training on fold 2...
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 292ms/step - accuracy: 0.4620 - loss: 1.0446 - val_accuracy: 0.6966 - val_loss: 0.9246
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5759 - loss: 0.9627 - val_accuracy: 0.6966 - val_loss: 0.8597
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6086 - loss: 0.9057 - val_accuracy: 0.6966 - val_loss: 0.8161
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6460 - loss: 0.8695 - val_accuracy: 0.6966 - val_loss: 0.7855
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6969 - loss: 0.7842 - val_accuracy: 0.6854 - val_loss: 0.7587
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6928 - loss: 0.7630 - val_accuracy: 0.6854 - val_loss: 0.7376
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7013 - loss: 0.7528 - val_accuracy: 0.6966 - val_loss: 0.7220
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6506 - loss: 0.8161 - val_accuracy: 0.7303 - val_loss: 0.7104
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6739 - loss: 0.7494 - val_accuracy: 0.7191 - val_loss: 0.7050
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7398 - loss: 0.7156 - val_accuracy: 0.7191 - val_loss: 0.6964
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6964 - loss: 0.7352 - val_accuracy: 0.7303 - val_loss: 0.6903
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7387 - loss: 0.6902 - val_accuracy: 0.7416 - val_loss: 0.6874
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7238 - loss: 0.7128 - val_accuracy: 0.7416 - val_loss: 0.6860
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7034 - loss: 0.7187 - val_accuracy: 0.7528 - val_loss: 0.6848
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6394 - loss: 0.8127 - val_accuracy: 0.7303 - val_loss: 0.6856
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7176 - loss: 0.7248 - val_accuracy: 0.7303 - val_loss: 0.6831
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7239 - loss: 0.7026 - val_accuracy: 0.7303 - val_loss: 0.6783
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6852 - loss: 0.7364 - val_accuracy: 0.7303 - val_loss: 0.6715
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7473 - loss: 0.6838 - val_accuracy: 0.7416 - val_loss: 0.6713
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7057 - loss: 0.6852 - val_accuracy: 0.7416 - val_loss: 0.6696
# Score for fold 2: loss of 0.6696227192878723; compile_metrics of 74.15730357170105%
# Training on fold 3...
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 292ms/step - accuracy: 0.2940 - loss: 1.1959 - val_accuracy: 0.3708 - val_loss: 1.0239
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4474 - loss: 1.0594 - val_accuracy: 0.6629 - val_loss: 0.9404
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5747 - loss: 0.9506 - val_accuracy: 0.6742 - val_loss: 0.8809
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6162 - loss: 0.8733 - val_accuracy: 0.7079 - val_loss: 0.8397
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6448 - loss: 0.8431 - val_accuracy: 0.7079 - val_loss: 0.8084
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6780 - loss: 0.8030 - val_accuracy: 0.7191 - val_loss: 0.7844
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6586 - loss: 0.8306 - val_accuracy: 0.7079 - val_loss: 0.7691
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7119 - loss: 0.7601 - val_accuracy: 0.7079 - val_loss: 0.7569
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7071 - loss: 0.7528 - val_accuracy: 0.6966 - val_loss: 0.7509
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6916 - loss: 0.7602 - val_accuracy: 0.7191 - val_loss: 0.7462
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7255 - loss: 0.6985 - val_accuracy: 0.6966 - val_loss: 0.7451
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7426 - loss: 0.7092 - val_accuracy: 0.6966 - val_loss: 0.7396
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6767 - loss: 0.7790 - val_accuracy: 0.6966 - val_loss: 0.7355
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7142 - loss: 0.7070 - val_accuracy: 0.7191 - val_loss: 0.7323
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7342 - loss: 0.7119 - val_accuracy: 0.7079 - val_loss: 0.7325
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7272 - loss: 0.6974 - val_accuracy: 0.7079 - val_loss: 0.7353
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7453 - loss: 0.6767 - val_accuracy: 0.7079 - val_loss: 0.7379
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7016 - loss: 0.7279 - val_accuracy: 0.7191 - val_loss: 0.7404
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7218 - loss: 0.7071 - val_accuracy: 0.7079 - val_loss: 0.7352
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7468 - loss: 0.6801 - val_accuracy: 0.7079 - val_loss: 0.7306
# Score for fold 3: loss of 0.7305676937103271; compile_metrics of 70.78651785850525%
# Training on fold 4...
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 297ms/step - accuracy: 0.3251 - loss: 1.1314 - val_accuracy: 0.6517 - val_loss: 0.9567
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5904 - loss: 0.9119 - val_accuracy: 0.6966 - val_loss: 0.8734
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5685 - loss: 0.8899 - val_accuracy: 0.6966 - val_loss: 0.8210
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6667 - loss: 0.8075 - val_accuracy: 0.6966 - val_loss: 0.7840
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6718 - loss: 0.8049 - val_accuracy: 0.6966 - val_loss: 0.7565
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6707 - loss: 0.7710 - val_accuracy: 0.7191 - val_loss: 0.7374
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6735 - loss: 0.7858 - val_accuracy: 0.7753 - val_loss: 0.7265
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6683 - loss: 0.7769 - val_accuracy: 0.7865 - val_loss: 0.7127
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7238 - loss: 0.6978 - val_accuracy: 0.7865 - val_loss: 0.7058
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7150 - loss: 0.7545 - val_accuracy: 0.7865 - val_loss: 0.6991
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6836 - loss: 0.7600 - val_accuracy: 0.7865 - val_loss: 0.6922
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6926 - loss: 0.7726 - val_accuracy: 0.7753 - val_loss: 0.6901
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6601 - loss: 0.7657 - val_accuracy: 0.7753 - val_loss: 0.6851
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7445 - loss: 0.6914 - val_accuracy: 0.7865 - val_loss: 0.6742
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7008 - loss: 0.7456 - val_accuracy: 0.7753 - val_loss: 0.6709
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7018 - loss: 0.7661 - val_accuracy: 0.7753 - val_loss: 0.6672
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7230 - loss: 0.6732 - val_accuracy: 0.7753 - val_loss: 0.6662
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7384 - loss: 0.7082 - val_accuracy: 0.7753 - val_loss: 0.6650
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7059 - loss: 0.7257 - val_accuracy: 0.7753 - val_loss: 0.6689
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7144 - loss: 0.7102 - val_accuracy: 0.7753 - val_loss: 0.6700
# Score for fold 4: loss of 0.6699957847595215; compile_metrics of 77.52808928489685%
# Training on fold 5...
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 295ms/step - accuracy: 0.3973 - loss: 1.0857 - val_accuracy: 0.6292 - val_loss: 0.9726
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4967 - loss: 1.0096 - val_accuracy: 0.6404 - val_loss: 0.9066
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5876 - loss: 0.9377 - val_accuracy: 0.6404 - val_loss: 0.8627
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6633 - loss: 0.8538 - val_accuracy: 0.6404 - val_loss: 0.8331
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6587 - loss: 0.8021 - val_accuracy: 0.6404 - val_loss: 0.8166
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7019 - loss: 0.7360 - val_accuracy: 0.6404 - val_loss: 0.8056
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7179 - loss: 0.7260 - val_accuracy: 0.6517 - val_loss: 0.7991
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7330 - loss: 0.7258 - val_accuracy: 0.6517 - val_loss: 0.7950
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7181 - loss: 0.7020 - val_accuracy: 0.6629 - val_loss: 0.7916
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7065 - loss: 0.7145 - val_accuracy: 0.6854 - val_loss: 0.7890
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7522 - loss: 0.6660 - val_accuracy: 0.6854 - val_loss: 0.7886
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7131 - loss: 0.7479 - val_accuracy: 0.6854 - val_loss: 0.7885
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7304 - loss: 0.6756 - val_accuracy: 0.6854 - val_loss: 0.7884
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7550 - loss: 0.6879 - val_accuracy: 0.6854 - val_loss: 0.7894
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7381 - loss: 0.7120 - val_accuracy: 0.6854 - val_loss: 0.7881
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7410 - loss: 0.6718 - val_accuracy: 0.6854 - val_loss: 0.7865
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7432 - loss: 0.6312 - val_accuracy: 0.6854 - val_loss: 0.7870
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7375 - loss: 0.6689 - val_accuracy: 0.6742 - val_loss: 0.7889
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7821 - loss: 0.6139 - val_accuracy: 0.6854 - val_loss: 0.7892
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7353 - loss: 0.6938 - val_accuracy: 0.6854 - val_loss: 0.7916
# Score for fold 5: loss of 0.7916039824485779; compile_metrics of 68.53932738304138%
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.6010212898254395 - Accuracy: 78.65168452262878%
# > Fold 2 - Loss: 0.6696227192878723 - Accuracy: 74.15730357170105%
# > Fold 3 - Loss: 0.7305676937103271 - Accuracy: 70.78651785850525%
# > Fold 4 - Loss: 0.6699957847595215 - Accuracy: 77.52808928489685%
# > Fold 5 - Loss: 0.7916039824485779 - Accuracy: 68.53932738304138%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 73.93258452415466 (+- 3.853129013810157)
# > Loss: 0.6925622940063476
# ------------------------------------------------------------------------

# %%
# Call the cross-validation function
anli_r3_histories = cross_validate_rnn_model(X_anli_r3_rnn, features_anli_r3, y_encoded_anli_r3, num_folds=5)
# Out:
# Training on fold 1...
# Epoch 1/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 282ms/step - accuracy: 0.3658 - loss: 1.0946 - val_accuracy: 0.6509 - val_loss: 0.9459
# Epoch 2/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5659 - loss: 0.9537 - val_accuracy: 0.6698 - val_loss: 0.8670
# Epoch 3/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6250 - loss: 0.8492 - val_accuracy: 0.6887 - val_loss: 0.8152
# Epoch 4/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6731 - loss: 0.8128 - val_accuracy: 0.7358 - val_loss: 0.7862
# Epoch 5/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6846 - loss: 0.7899 - val_accuracy: 0.7453 - val_loss: 0.7684
# Epoch 6/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6997 - loss: 0.7461 - val_accuracy: 0.7547 - val_loss: 0.7552
# Epoch 7/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6716 - loss: 0.7386 - val_accuracy: 0.7264 - val_loss: 0.7472
# Epoch 8/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6904 - loss: 0.7190 - val_accuracy: 0.6887 - val_loss: 0.7404
# Epoch 9/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7325 - loss: 0.7094 - val_accuracy: 0.6981 - val_loss: 0.7348
# Epoch 10/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7540 - loss: 0.7015 - val_accuracy: 0.6981 - val_loss: 0.7313
# Epoch 11/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6851 - loss: 0.7290 - val_accuracy: 0.6981 - val_loss: 0.7288
# Epoch 12/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7405 - loss: 0.6804 - val_accuracy: 0.6981 - val_loss: 0.7301
# Epoch 13/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7299 - loss: 0.6800 - val_accuracy: 0.6981 - val_loss: 0.7270
# Epoch 14/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7357 - loss: 0.6397 - val_accuracy: 0.7075 - val_loss: 0.7264
# Epoch 15/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7093 - loss: 0.7062 - val_accuracy: 0.6887 - val_loss: 0.7224
# Epoch 16/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7237 - loss: 0.6985 - val_accuracy: 0.6887 - val_loss: 0.7215
# Epoch 17/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7226 - loss: 0.6712 - val_accuracy: 0.7075 - val_loss: 0.7215
# Epoch 18/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7324 - loss: 0.6586 - val_accuracy: 0.7075 - val_loss: 0.7224
# Epoch 19/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7243 - loss: 0.6735 - val_accuracy: 0.6981 - val_loss: 0.7219
# Epoch 20/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7294 - loss: 0.6472 - val_accuracy: 0.6981 - val_loss: 0.7229
# Score for fold 1: loss of 0.7229290008544922; compile_metrics of 69.8113203048706%
# Training on fold 2...
# Epoch 1/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 246ms/step - accuracy: 0.4903 - loss: 1.0070 - val_accuracy: 0.6415 - val_loss: 0.8932
# Epoch 2/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6114 - loss: 0.9196 - val_accuracy: 0.6792 - val_loss: 0.8141
# Epoch 3/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6468 - loss: 0.8491 - val_accuracy: 0.6792 - val_loss: 0.7574
# Epoch 4/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5981 - loss: 0.8598 - val_accuracy: 0.7075 - val_loss: 0.7132
# Epoch 5/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6825 - loss: 0.7471 - val_accuracy: 0.6981 - val_loss: 0.6836
# Epoch 6/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7067 - loss: 0.7191 - val_accuracy: 0.7170 - val_loss: 0.6589
# Epoch 7/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6513 - loss: 0.7537 - val_accuracy: 0.7264 - val_loss: 0.6464
# Epoch 8/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6757 - loss: 0.7531 - val_accuracy: 0.7264 - val_loss: 0.6328
# Epoch 9/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7106 - loss: 0.7201 - val_accuracy: 0.7358 - val_loss: 0.6242
# Epoch 10/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7261 - loss: 0.6869 - val_accuracy: 0.7264 - val_loss: 0.6172
# Epoch 11/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7277 - loss: 0.6720 - val_accuracy: 0.7453 - val_loss: 0.6126
# Epoch 12/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7159 - loss: 0.6961 - val_accuracy: 0.7358 - val_loss: 0.6108
# Epoch 13/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6713 - loss: 0.7185 - val_accuracy: 0.7453 - val_loss: 0.6033
# Epoch 14/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7310 - loss: 0.6998 - val_accuracy: 0.7453 - val_loss: 0.6022
# Epoch 15/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6843 - loss: 0.7047 - val_accuracy: 0.7453 - val_loss: 0.5995
# Epoch 16/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6850 - loss: 0.7366 - val_accuracy: 0.7547 - val_loss: 0.5989
# Epoch 17/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7228 - loss: 0.6647 - val_accuracy: 0.7453 - val_loss: 0.6014
# Epoch 18/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7146 - loss: 0.6852 - val_accuracy: 0.7547 - val_loss: 0.6002
# Epoch 19/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6959 - loss: 0.7010 - val_accuracy: 0.7547 - val_loss: 0.5983
# Epoch 20/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7486 - loss: 0.6270 - val_accuracy: 0.7547 - val_loss: 0.5946
# Score for fold 2: loss of 0.5945808291435242; compile_metrics of 75.47169923782349%
# Training on fold 3...
# Epoch 1/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 0.4206 - loss: 1.1106 - val_accuracy: 0.6887 - val_loss: 0.9416
# Epoch 2/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5747 - loss: 0.9581 - val_accuracy: 0.6887 - val_loss: 0.8502
# Epoch 3/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6661 - loss: 0.8375 - val_accuracy: 0.6887 - val_loss: 0.7913
# Epoch 4/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6520 - loss: 0.8446 - val_accuracy: 0.7075 - val_loss: 0.7510
# Epoch 5/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6481 - loss: 0.8244 - val_accuracy: 0.7170 - val_loss: 0.7199
# Epoch 6/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6899 - loss: 0.7581 - val_accuracy: 0.7170 - val_loss: 0.6992
# Epoch 7/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7029 - loss: 0.7283 - val_accuracy: 0.7170 - val_loss: 0.6843
# Epoch 8/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6886 - loss: 0.7017 - val_accuracy: 0.7170 - val_loss: 0.6790
# Epoch 9/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7126 - loss: 0.7089 - val_accuracy: 0.7170 - val_loss: 0.6744
# Epoch 10/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6907 - loss: 0.7053 - val_accuracy: 0.7170 - val_loss: 0.6690
# Epoch 11/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7070 - loss: 0.7424 - val_accuracy: 0.7170 - val_loss: 0.6626
# Epoch 12/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7153 - loss: 0.6753 - val_accuracy: 0.7264 - val_loss: 0.6604
# Epoch 13/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7172 - loss: 0.6780 - val_accuracy: 0.7264 - val_loss: 0.6605
# Epoch 14/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7321 - loss: 0.6650 - val_accuracy: 0.7264 - val_loss: 0.6581
# Epoch 15/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7175 - loss: 0.6757 - val_accuracy: 0.7170 - val_loss: 0.6563
# Epoch 16/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7367 - loss: 0.6641 - val_accuracy: 0.7170 - val_loss: 0.6550
# Epoch 17/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7287 - loss: 0.6550 - val_accuracy: 0.7264 - val_loss: 0.6516
# Epoch 18/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6939 - loss: 0.6973 - val_accuracy: 0.7358 - val_loss: 0.6504
# Epoch 19/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7378 - loss: 0.6390 - val_accuracy: 0.7170 - val_loss: 0.6508
# Epoch 20/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7442 - loss: 0.6533 - val_accuracy: 0.7264 - val_loss: 0.6525
# Score for fold 3: loss of 0.652488112449646; compile_metrics of 72.64150977134705%
# Training on fold 4...
# Epoch 1/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 254ms/step - accuracy: 0.5447 - loss: 0.9877 - val_accuracy: 0.6604 - val_loss: 0.8402
# Epoch 2/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6442 - loss: 0.8897 - val_accuracy: 0.6792 - val_loss: 0.7714
# Epoch 3/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6414 - loss: 0.8571 - val_accuracy: 0.7075 - val_loss: 0.7287
# Epoch 4/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6657 - loss: 0.8108 - val_accuracy: 0.7170 - val_loss: 0.7004
# Epoch 5/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6826 - loss: 0.7751 - val_accuracy: 0.7170 - val_loss: 0.6812
# Epoch 6/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7181 - loss: 0.6975 - val_accuracy: 0.7264 - val_loss: 0.6680
# Epoch 7/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6718 - loss: 0.7803 - val_accuracy: 0.7453 - val_loss: 0.6641
# Epoch 8/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6874 - loss: 0.7082 - val_accuracy: 0.7547 - val_loss: 0.6581
# Epoch 9/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7022 - loss: 0.6854 - val_accuracy: 0.7547 - val_loss: 0.6555
# Epoch 10/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6869 - loss: 0.6939 - val_accuracy: 0.7642 - val_loss: 0.6511
# Epoch 11/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7384 - loss: 0.6657 - val_accuracy: 0.7264 - val_loss: 0.6455
# Epoch 12/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7164 - loss: 0.6936 - val_accuracy: 0.7547 - val_loss: 0.6443
# Epoch 13/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7180 - loss: 0.6786 - val_accuracy: 0.7453 - val_loss: 0.6452
# Epoch 14/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7407 - loss: 0.6462 - val_accuracy: 0.7453 - val_loss: 0.6462
# Epoch 15/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7151 - loss: 0.6800 - val_accuracy: 0.7453 - val_loss: 0.6447
# Epoch 16/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7075 - loss: 0.6920 - val_accuracy: 0.7453 - val_loss: 0.6432
# Epoch 17/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6985 - loss: 0.6845 - val_accuracy: 0.7453 - val_loss: 0.6429
# Epoch 18/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7108 - loss: 0.6733 - val_accuracy: 0.7264 - val_loss: 0.6416
# Epoch 19/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7202 - loss: 0.6785 - val_accuracy: 0.7453 - val_loss: 0.6464
# Epoch 20/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7181 - loss: 0.6755 - val_accuracy: 0.7358 - val_loss: 0.6514
# Score for fold 4: loss of 0.6513978242874146; compile_metrics of 73.58490824699402%
# Training on fold 5...
# Epoch 1/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 0.4309 - loss: 1.0617 - val_accuracy: 0.5000 - val_loss: 0.9755
# Epoch 2/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5524 - loss: 0.9655 - val_accuracy: 0.6132 - val_loss: 0.8907
# Epoch 3/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6439 - loss: 0.8455 - val_accuracy: 0.6132 - val_loss: 0.8467
# Epoch 4/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6791 - loss: 0.7952 - val_accuracy: 0.6321 - val_loss: 0.8247
# Epoch 5/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6903 - loss: 0.7674 - val_accuracy: 0.6321 - val_loss: 0.8099
# Epoch 6/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6691 - loss: 0.7734 - val_accuracy: 0.6604 - val_loss: 0.8005
# Epoch 7/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6772 - loss: 0.7495 - val_accuracy: 0.6792 - val_loss: 0.7950
# Epoch 8/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7391 - loss: 0.7106 - val_accuracy: 0.6698 - val_loss: 0.7908
# Epoch 9/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7051 - loss: 0.7063 - val_accuracy: 0.6981 - val_loss: 0.7924
# Epoch 10/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7252 - loss: 0.6937 - val_accuracy: 0.6887 - val_loss: 0.7867
# Epoch 11/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7392 - loss: 0.6275 - val_accuracy: 0.6887 - val_loss: 0.7815
# Epoch 12/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7240 - loss: 0.6546 - val_accuracy: 0.6792 - val_loss: 0.7796
# Epoch 13/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7529 - loss: 0.6493 - val_accuracy: 0.6792 - val_loss: 0.7796
# Epoch 14/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6677 - loss: 0.7275 - val_accuracy: 0.6887 - val_loss: 0.7776
# Epoch 15/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7140 - loss: 0.6836 - val_accuracy: 0.6981 - val_loss: 0.7748
# Epoch 16/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7389 - loss: 0.6327 - val_accuracy: 0.6887 - val_loss: 0.7764
# Epoch 17/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7231 - loss: 0.6956 - val_accuracy: 0.6981 - val_loss: 0.7739
# Epoch 18/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7011 - loss: 0.6758 - val_accuracy: 0.6981 - val_loss: 0.7710
# Epoch 19/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7408 - loss: 0.6231 - val_accuracy: 0.7075 - val_loss: 0.7652
# Epoch 20/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7118 - loss: 0.6971 - val_accuracy: 0.7075 - val_loss: 0.7643
# Score for fold 5: loss of 0.7643257975578308; compile_metrics of 70.75471878051758%
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.7229290008544922 - Accuracy: 69.8113203048706%
# > Fold 2 - Loss: 0.5945808291435242 - Accuracy: 75.47169923782349%
# > Fold 3 - Loss: 0.652488112449646 - Accuracy: 72.64150977134705%
# > Fold 4 - Loss: 0.6513978242874146 - Accuracy: 73.58490824699402%
# > Fold 5 - Loss: 0.7643257975578308 - Accuracy: 70.75471878051758%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 72.45283126831055 (+- 2.0145435151267495)
# > Loss: 0.6771443128585816
# ------------------------------------------------------------------------

# %%
X_rnn_all_tasks = np.concatenate([X_snli_rnn, X_mnli_matched_rnn, X_mnli_mismatched_rnn, X_anli_r1_rnn, X_anli_r2_rnn, X_anli_r3_rnn])
features_all_tasks = np.concatenate([features_snli, features_mnli_matched, features_mnli_mismatched, features_anli_r1, features_anli_r2, features_anli_r3])
y_encoded_all_tasks = np.concatenate([y_encoded_snli, y_encoded_mnli_matched, y_encoded_mnli_mismatched, y_encoded_anli_r1, y_encoded_anli_r2, y_encoded_anli_r3])

# Call the cross-validation function
all_histories = cross_validate_rnn_model(X_rnn_all_tasks, features_all_tasks, y_encoded_all_tasks, num_folds=5)
# Out:
# Training on fold 1...
# Epoch 1/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.8810 - loss: 0.3726 - val_accuracy: 0.9474 - val_loss: 0.1742
# Epoch 2/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9442 - loss: 0.1928 - val_accuracy: 0.9477 - val_loss: 0.1723
# Epoch 3/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9443 - loss: 0.1907 - val_accuracy: 0.9490 - val_loss: 0.1732
# Epoch 4/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9481 - loss: 0.1799 - val_accuracy: 0.9497 - val_loss: 0.1725
# Epoch 5/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9478 - loss: 0.1806 - val_accuracy: 0.9490 - val_loss: 0.1723
# Epoch 6/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9475 - loss: 0.1769 - val_accuracy: 0.9497 - val_loss: 0.1727
# Epoch 7/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9493 - loss: 0.1751 - val_accuracy: 0.9479 - val_loss: 0.1729
# Epoch 8/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9486 - loss: 0.1797 - val_accuracy: 0.9497 - val_loss: 0.1725
# Epoch 9/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9452 - loss: 0.1886 - val_accuracy: 0.9487 - val_loss: 0.1729
# Epoch 10/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9451 - loss: 0.1829 - val_accuracy: 0.9487 - val_loss: 0.1724
# Epoch 11/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9503 - loss: 0.1720 - val_accuracy: 0.9487 - val_loss: 0.1720
# Epoch 12/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9448 - loss: 0.1846 - val_accuracy: 0.9487 - val_loss: 0.1721
# Epoch 13/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9466 - loss: 0.1837 - val_accuracy: 0.9490 - val_loss: 0.1721
# Epoch 14/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9438 - loss: 0.1873 - val_accuracy: 0.9492 - val_loss: 0.1727
# Epoch 15/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9496 - loss: 0.1769 - val_accuracy: 0.9497 - val_loss: 0.1723
# Epoch 16/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9513 - loss: 0.1695 - val_accuracy: 0.9487 - val_loss: 0.1728
# Epoch 17/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9459 - loss: 0.1770 - val_accuracy: 0.9487 - val_loss: 0.1716
# Epoch 18/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9482 - loss: 0.1781 - val_accuracy: 0.9492 - val_loss: 0.1714
# Epoch 19/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9438 - loss: 0.1856 - val_accuracy: 0.9487 - val_loss: 0.1729
# Epoch 20/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9481 - loss: 0.1738 - val_accuracy: 0.9484 - val_loss: 0.1718
# Score for fold 1: loss of 0.17183974385261536; compile_metrics of 94.8437511920929%
# Training on fold 2...
# Epoch 1/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.8507 - loss: 0.4413 - val_accuracy: 0.9464 - val_loss: 0.1719
# Epoch 2/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9488 - loss: 0.1798 - val_accuracy: 0.9474 - val_loss: 0.1697
# Epoch 3/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9459 - loss: 0.1863 - val_accuracy: 0.9482 - val_loss: 0.1693
# Epoch 4/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9447 - loss: 0.1880 - val_accuracy: 0.9487 - val_loss: 0.1695
# Epoch 5/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9464 - loss: 0.1886 - val_accuracy: 0.9471 - val_loss: 0.1683
# Epoch 6/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9477 - loss: 0.1858 - val_accuracy: 0.9469 - val_loss: 0.1679
# Epoch 7/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9490 - loss: 0.1819 - val_accuracy: 0.9477 - val_loss: 0.1681
# Epoch 8/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9453 - loss: 0.1887 - val_accuracy: 0.9469 - val_loss: 0.1691
# Epoch 9/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9474 - loss: 0.1793 - val_accuracy: 0.9482 - val_loss: 0.1684
# Epoch 10/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9510 - loss: 0.1765 - val_accuracy: 0.9477 - val_loss: 0.1689
# Epoch 11/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9471 - loss: 0.1838 - val_accuracy: 0.9471 - val_loss: 0.1684
# Epoch 12/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9480 - loss: 0.1756 - val_accuracy: 0.9484 - val_loss: 0.1675
# Epoch 13/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9502 - loss: 0.1719 - val_accuracy: 0.9482 - val_loss: 0.1674
# Epoch 14/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9454 - loss: 0.1912 - val_accuracy: 0.9479 - val_loss: 0.1677
# Epoch 15/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9496 - loss: 0.1744 - val_accuracy: 0.9477 - val_loss: 0.1682
# Epoch 16/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9471 - loss: 0.1787 - val_accuracy: 0.9471 - val_loss: 0.1686
# Epoch 17/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9472 - loss: 0.1818 - val_accuracy: 0.9477 - val_loss: 0.1681
# Epoch 18/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9477 - loss: 0.1773 - val_accuracy: 0.9487 - val_loss: 0.1666
# Epoch 19/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9495 - loss: 0.1742 - val_accuracy: 0.9482 - val_loss: 0.1678
# Epoch 20/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9493 - loss: 0.1735 - val_accuracy: 0.9474 - val_loss: 0.1683
# Score for fold 2: loss of 0.16828805208206177; compile_metrics of 94.73958611488342%
# Training on fold 3...
# Epoch 1/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9292 - loss: 0.3211 - val_accuracy: 0.9438 - val_loss: 0.1845
# Epoch 2/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9482 - loss: 0.1827 - val_accuracy: 0.9435 - val_loss: 0.1846
# Epoch 3/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9498 - loss: 0.1816 - val_accuracy: 0.9438 - val_loss: 0.1841
# Epoch 4/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9466 - loss: 0.1797 - val_accuracy: 0.9440 - val_loss: 0.1834
# Epoch 5/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9486 - loss: 0.1822 - val_accuracy: 0.9440 - val_loss: 0.1833
# Epoch 6/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9472 - loss: 0.1780 - val_accuracy: 0.9438 - val_loss: 0.1838
# Epoch 7/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9485 - loss: 0.1820 - val_accuracy: 0.9458 - val_loss: 0.1841
# Epoch 8/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9470 - loss: 0.1813 - val_accuracy: 0.9440 - val_loss: 0.1835
# Epoch 9/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9513 - loss: 0.1723 - val_accuracy: 0.9443 - val_loss: 0.1822
# Epoch 10/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9481 - loss: 0.1809 - val_accuracy: 0.9445 - val_loss: 0.1828
# Epoch 11/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9477 - loss: 0.1759 - val_accuracy: 0.9445 - val_loss: 0.1841
# Epoch 12/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9491 - loss: 0.1752 - val_accuracy: 0.9443 - val_loss: 0.1829
# Epoch 13/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9444 - loss: 0.1841 - val_accuracy: 0.9445 - val_loss: 0.1834
# Epoch 14/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9456 - loss: 0.1805 - val_accuracy: 0.9440 - val_loss: 0.1819
# Epoch 15/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9493 - loss: 0.1723 - val_accuracy: 0.9456 - val_loss: 0.1839
# Epoch 16/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9466 - loss: 0.1841 - val_accuracy: 0.9440 - val_loss: 0.1820
# Epoch 17/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9498 - loss: 0.1724 - val_accuracy: 0.9422 - val_loss: 0.1831
# Epoch 18/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9487 - loss: 0.1745 - val_accuracy: 0.9430 - val_loss: 0.1825
# Epoch 19/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9502 - loss: 0.1693 - val_accuracy: 0.9456 - val_loss: 0.1827
# Epoch 20/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9471 - loss: 0.1827 - val_accuracy: 0.9445 - val_loss: 0.1807
# Score for fold 3: loss of 0.18065506219863892; compile_metrics of 94.4531261920929%
# Training on fold 4...
# Epoch 1/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.8770 - loss: 0.3829 - val_accuracy: 0.9482 - val_loss: 0.1808
# Epoch 2/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9463 - loss: 0.1791 - val_accuracy: 0.9497 - val_loss: 0.1776
# Epoch 3/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9482 - loss: 0.1820 - val_accuracy: 0.9492 - val_loss: 0.1777
# Epoch 4/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9479 - loss: 0.1810 - val_accuracy: 0.9487 - val_loss: 0.1772
# Epoch 5/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9491 - loss: 0.1723 - val_accuracy: 0.9495 - val_loss: 0.1775
# Epoch 6/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9460 - loss: 0.1859 - val_accuracy: 0.9479 - val_loss: 0.1783
# Epoch 7/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9469 - loss: 0.1780 - val_accuracy: 0.9497 - val_loss: 0.1769
# Epoch 8/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9467 - loss: 0.1744 - val_accuracy: 0.9497 - val_loss: 0.1769
# Epoch 9/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9470 - loss: 0.1840 - val_accuracy: 0.9490 - val_loss: 0.1766
# Epoch 10/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9479 - loss: 0.1701 - val_accuracy: 0.9495 - val_loss: 0.1768
# Epoch 11/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9488 - loss: 0.1779 - val_accuracy: 0.9495 - val_loss: 0.1769
# Epoch 12/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9477 - loss: 0.1744 - val_accuracy: 0.9500 - val_loss: 0.1766
# Epoch 13/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9495 - loss: 0.1720 - val_accuracy: 0.9497 - val_loss: 0.1771
# Epoch 14/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9444 - loss: 0.1866 - val_accuracy: 0.9500 - val_loss: 0.1769
# Epoch 15/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9474 - loss: 0.1744 - val_accuracy: 0.9503 - val_loss: 0.1766
# Epoch 16/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9455 - loss: 0.1814 - val_accuracy: 0.9497 - val_loss: 0.1761
# Epoch 17/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9494 - loss: 0.1747 - val_accuracy: 0.9500 - val_loss: 0.1766
# Epoch 18/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9484 - loss: 0.1736 - val_accuracy: 0.9490 - val_loss: 0.1763
# Epoch 19/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9492 - loss: 0.1800 - val_accuracy: 0.9497 - val_loss: 0.1764
# Epoch 20/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9506 - loss: 0.1685 - val_accuracy: 0.9497 - val_loss: 0.1765
# Score for fold 4: loss of 0.17650042474269867; compile_metrics of 94.97395753860474%
# Training on fold 5...
# Epoch 1/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8561 - loss: 0.4085 - val_accuracy: 0.9495 - val_loss: 0.1826
# Epoch 2/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9464 - loss: 0.1845 - val_accuracy: 0.9502 - val_loss: 0.1822
# Epoch 3/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9493 - loss: 0.1793 - val_accuracy: 0.9489 - val_loss: 0.1815
# Epoch 4/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9427 - loss: 0.1947 - val_accuracy: 0.9482 - val_loss: 0.1828
# Epoch 5/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9458 - loss: 0.1839 - val_accuracy: 0.9495 - val_loss: 0.1811
# Epoch 6/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9451 - loss: 0.1837 - val_accuracy: 0.9500 - val_loss: 0.1812
# Epoch 7/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9453 - loss: 0.1847 - val_accuracy: 0.9487 - val_loss: 0.1803
# Epoch 8/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9484 - loss: 0.1776 - val_accuracy: 0.9479 - val_loss: 0.1811
# Epoch 9/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9469 - loss: 0.1820 - val_accuracy: 0.9482 - val_loss: 0.1800
# Epoch 10/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9469 - loss: 0.1793 - val_accuracy: 0.9482 - val_loss: 0.1805
# Epoch 11/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9474 - loss: 0.1796 - val_accuracy: 0.9476 - val_loss: 0.1803
# Epoch 12/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9468 - loss: 0.1836 - val_accuracy: 0.9482 - val_loss: 0.1797
# Epoch 13/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9491 - loss: 0.1753 - val_accuracy: 0.9484 - val_loss: 0.1789
# Epoch 14/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9452 - loss: 0.1829 - val_accuracy: 0.9482 - val_loss: 0.1806
# Epoch 15/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9473 - loss: 0.1781 - val_accuracy: 0.9482 - val_loss: 0.1793
# Epoch 16/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9489 - loss: 0.1783 - val_accuracy: 0.9479 - val_loss: 0.1807
# Epoch 17/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9481 - loss: 0.1744 - val_accuracy: 0.9482 - val_loss: 0.1790
# Epoch 18/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9443 - loss: 0.1835 - val_accuracy: 0.9489 - val_loss: 0.1812
# Epoch 19/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9422 - loss: 0.1982 - val_accuracy: 0.9500 - val_loss: 0.1792
# Epoch 20/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9469 - loss: 0.1814 - val_accuracy: 0.9476 - val_loss: 0.1792
# Score for fold 5: loss of 0.17919088900089264; compile_metrics of 94.76426243782043%
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.17183974385261536 - Accuracy: 94.8437511920929%
# > Fold 2 - Loss: 0.16828805208206177 - Accuracy: 94.73958611488342%
# > Fold 3 - Loss: 0.18065506219863892 - Accuracy: 94.4531261920929%
# > Fold 4 - Loss: 0.17650042474269867 - Accuracy: 94.97395753860474%
# > Fold 5 - Loss: 0.17919088900089264 - Accuracy: 94.76426243782043%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 94.75493669509888 (+- 0.17162187173044233)
# > Loss: 0.17529483437538146
# ------------------------------------------------------------------------

# %%
# Function to plot k-fold histories
def plot_kfold_histories(histories):
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    
    for fold, history in enumerate(histories, start=1):
        axes[0].plot(history.history['accuracy'], label=f'Train Fold {fold}')
        axes[0].plot(history.history['val_accuracy'], label=f'Val Fold {fold}', linestyle="--")
        axes[1].plot(history.history['loss'], label=f'Train Fold {fold}')
        axes[1].plot(history.history['val_loss'], label=f'Val Fold {fold}', linestyle="--")
    
    axes[0].set_title('Model Accuracy')
    axes[0].set_ylabel('Accuracy')
    axes[0].set_xlabel('Epoch')
    axes[0].legend()
    
    axes[1].set_title('Model Loss')
    axes[1].set_ylabel('Loss')
    axes[1].set_xlabel('Epoch')
    axes[1].legend()
    
    plt.show()
    
    
# Plot the histories
plot_kfold_histories(all_histories)
