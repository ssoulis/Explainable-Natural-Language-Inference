# %%
import pandas as pd

# Load the SNLI test data (including true labels)
snli_test_path = "/kaggle/input/stanford-natural-language-inference-corpus/snli_1.0_test.csv"
snli_test_df = pd.read_csv(snli_test_path)

# Define file paths for SNLI prediction files
snli_predictions_paths = {
    "deberta": "/kaggle/input/deberta-nli/deberta_snli_predictions.csv",
    "roberta": "/kaggle/input/roberta/roberta_snli_predictions.csv",
    "albert": "/kaggle/input/albert/albert_snli_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_snli = "/kaggle/working/combined_snli_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_snli_df = pd.DataFrame(columns=columns)

label_mapping = {'entailment': 0, 'neutral': 1, 'contradiction': 2}

# Load and merge the predictions
for model, path in snli_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_snli_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_snli_df['True_Label'] = snli_test_df['gold_label'].map(label_mapping)

# Convert True_Label to integer type
combined_snli_df['True_Label'] = combined_snli_df['True_Label'].astype('Int64')

# Save the combined DataFrame to CSV
combined_snli_df.to_csv(output_csv_path_snli, index=False)

print(f"Combined SNLI predictions with true labels saved to {output_csv_path_snli}")
# Out:
# Combined SNLI predictions with true labels saved to /kaggle/working/combined_snli_df

# %%
combined_snli_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.034767         0.962592               0.002641
# 1            0.001921         0.319032               0.679047
# 2            0.998783         0.000764               0.000453
# 3            0.001001         0.997708               0.001291
# 4            0.001080         0.301363               0.697557
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.012451         0.927093               0.060457
# 1            0.752766         0.242251               0.004983
# 2            0.000254         0.004494               0.995253
# 3            0.005844         0.990736               0.003419
# 4            0.278348         0.718575               0.003076
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.008653        0.947434              0.043913           1
# 1           0.740332        0.256434              0.003235           0
# 2           0.004677        0.060481              0.934843           2
# 3           0.034056        0.956687              0.009257           1
# 4           0.498761        0.499270              0.001969           0

# %%
# Load the ANLI Round 1 test data (including true labels)
mnli_matched_test_path = "/kaggle/input/nli-dataset-for-sentence-understanding/mnli_validation_matched.csv"
mnli_matched_test_df = pd.read_csv(mnli_matched_test_path)

# Define file paths for ANLI Round 1 prediction files
mnli_matched_predictions_paths = {
    "deberta": "/kaggle/input/validation/deberta_mnli_matched_val_predictions.csv",
    "roberta": "/kaggle/input/validation/roberta_mnli_matched_val_predictions.csv",
    "albert": "/kaggle/input/validation/albert_mnli_matched_val_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_mnli_matched = "/kaggle/working/combined_mnli_matched_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_mnli_matched_df = pd.DataFrame(columns=columns)

# Load and merge the predictions
for model, path in mnli_matched_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_mnli_matched_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_mnli_matched_df['True_Label'] = mnli_matched_test_df['label']

# Save the combined DataFrame to CSV
combined_mnli_matched_df.to_csv(output_csv_path_mnli_matched, index=False)

print(f"Combined MNLI-matched predictions with true labels saved to {output_csv_path_mnli_matched}")
# Out:
# Combined MNLI-matched predictions with true labels saved to /kaggle/working/combined_mnli_matched_df

# %%
combined_mnli_matched_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.005164         0.993364               0.001472
# 1            0.999153         0.000526               0.000321
# 2            0.000989         0.044792               0.954219
# 3            0.994965         0.004808               0.000228
# 4            0.999657         0.000220               0.000123
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.017844         0.950246               0.031909
# 1            0.001413         0.002030               0.996557
# 2            0.954781         0.042249               0.002970
# 3            0.000343         0.003511               0.996146
# 4            0.000079         0.000496               0.999425
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.010844        0.983012              0.006144           1
# 1           0.005388        0.007536              0.987076           2
# 2           0.853862        0.143483              0.002655           0
# 3           0.004128        0.070757              0.925115           2
# 4           0.003864        0.029262              0.966875           2

# %%
# Load the ANLI Round 1 test data (including true labels)
mnli_mismatched_test_path = "/kaggle/input/nli-dataset-for-sentence-understanding/mnli_validation_mismatched.csv"
mnli_mismatched_test_df = pd.read_csv(mnli_mismatched_test_path)

# Define file paths for ANLI Round 1 prediction files
mnli_mismatched_predictions_paths = {
    "deberta": "/kaggle/input/validation/deberta_mnli_mismatched_val_predictions.csv",
    "roberta": "/kaggle/input/validation/roberta_mnli_mismatched_val_predictions.csv",
    "albert": "/kaggle/input/validation/albert_mnli_mismatched_val_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_mnli_mismatched = "/kaggle/working/combined_mnli_mismatched_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_mnli_mismatched_df = pd.DataFrame(columns=columns)

# Load and merge the predictions
for model, path in mnli_mismatched_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_mnli_mismatched_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_mnli_mismatched_df['True_Label'] = mnli_mismatched_test_df['label']

# Save the combined DataFrame to CSV
combined_mnli_mismatched_df.to_csv(output_csv_path_mnli_mismatched, index=False)

print(f"Combined MNLI-mismatched predictions with true labels saved to {output_csv_path_mnli_mismatched}")
# Out:
# Combined MNLI-mismatched predictions with true labels saved to /kaggle/working/combined_mnli_mismatched_df

# %%
combined_mnli_mismatched_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.999667         0.000160               0.000173
# 1            0.998119         0.000962               0.000919
# 2            0.000552         0.004809               0.994639
# 3            0.827653         0.171961               0.000386
# 4            0.000292         0.002875               0.996833
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.000068         0.000402               0.999529
# 1            0.000183         0.001511               0.998306
# 2            0.986062         0.012020               0.001918
# 3            0.000478         0.270953               0.728569
# 4            0.975167         0.021904               0.002929
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.000894        0.003787              0.995318           2
# 1           0.006421        0.010224              0.983355           2
# 2           0.975041        0.023354              0.001605           0
# 3           0.001722        0.796122              0.202156           2
# 4           0.965952        0.032748              0.001300           0

# %%
# Load the ANLI Round 1 test data (including true labels)
anli_r1_test_path = "/kaggle/input/anli-a-large-scale-nli-benchmark-dataset/test_r1.csv"
anli_r1_test_df = pd.read_csv(anli_r1_test_path)

# Define file paths for ANLI Round 1 prediction files
anli_r1_predictions_paths = {
    "deberta": "/kaggle/input/deberta-nli/deberta_anli_r1_predictions.csv",
    "roberta": "/kaggle/input/roberta/roberta_anli_r1_predictions.csv",
    "albert": "/kaggle/input/albert/albert_anli_r1_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_anli_r1 = "/kaggle/working/combined_anli_r1_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_anli_r1_df = pd.DataFrame(columns=columns)

# Load and merge the predictions
for model, path in anli_r1_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_anli_r1_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_anli_r1_df['True_Label'] = anli_r1_test_df['label']

# Save the combined DataFrame to CSV
combined_anli_r1_df.to_csv(output_csv_path_anli_r1, index=False)

print(f"Combined ANLI Round 1 predictions with true labels saved to {output_csv_path_anli_r1}")
# Out:
# Combined ANLI Round 1 predictions with true labels saved to /kaggle/working/combined_anli_r1_df

# %%
combined_anli_r1_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.015388         0.976305               0.008307
# 1            0.224603         0.501549               0.273848
# 2            0.006642         0.976690               0.016669
# 3            0.966494         0.032235               0.001272
# 4            0.880736         0.028293               0.090971
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.996714         0.000376               0.002910
# 1            0.875720         0.000724               0.123556
# 2            0.999484         0.000330               0.000186
# 3            0.000686         0.998181               0.001133
# 4            0.000378         0.000197               0.999425
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.322974        0.667628              0.009398           0
# 1           0.998526        0.000604              0.000869           0
# 2           0.783352        0.212241              0.004407           0
# 3           0.002134        0.989523              0.008343           1
# 4           0.023283        0.013253              0.963464           2

# %%
# Load the ANLI Round 2 test data (including true labels)
anli_r2_test_path = "/kaggle/input/anli-a-large-scale-nli-benchmark-dataset/test_r2.csv"
anli_r2_test_df = pd.read_csv(anli_r2_test_path)

# Define file paths for ANLI Round 2 prediction files
anli_r2_predictions_paths = {
    "deberta": "/kaggle/input/deberta-nli/deberta_anli_r2_predictions.csv",
    "roberta": "/kaggle/input/roberta/roberta_anli_r2_predictions.csv",
    "albert": "/kaggle/input/albert/albert_anli_r2_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_anli_r2 = "/kaggle/working/combined_anli_r2_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_anli_r2_df = pd.DataFrame(columns=columns)

# Load and merge the predictions
for model, path in anli_r2_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_anli_r2_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_anli_r2_df['True_Label'] = anli_r2_test_df['label']

# Save the combined DataFrame to CSV
combined_anli_r2_df.to_csv(output_csv_path_anli_r2, index=False)

print(f"Combined ANLI Round 2 predictions with true labels saved to {output_csv_path_anli_r2}")
# Out:
# Combined ANLI Round 2 predictions with true labels saved to /kaggle/working/combined_anli_r2_df

# %%
combined_anli_r2_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.001309         0.029617               0.969075
# 1            0.724144         0.273676               0.002180
# 2            0.071604         0.917894               0.010503
# 3            0.066162         0.929179               0.004659
# 4            0.906199         0.089873               0.003928
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.999506         0.000264               0.000230
# 1            0.026951         0.054230               0.918819
# 2            0.001282         0.998108               0.000610
# 3            0.007091         0.992694               0.000215
# 4            0.006259         0.989432               0.004309
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.863365        0.133388              0.003246           0
# 1           0.072900        0.904344              0.022756           1
# 2           0.027402        0.972218              0.000380           0
# 3           0.632171        0.365194              0.002635           1
# 4           0.064109        0.234642              0.701249           2

# %%
# Load the ANLI Round 3 test data (including true labels)
anli_r3_test_path = "/kaggle/input/anli-a-large-scale-nli-benchmark-dataset/test_r3.csv"
anli_r3_test_df = pd.read_csv(anli_r3_test_path)

# Define file paths for ANLI Round 2 prediction files
anli_r3_predictions_paths = {
    "deberta": "/kaggle/input/deberta-nli/deberta_anli_r3_predictions.csv",
    "roberta": "/kaggle/input/roberta/roberta_anli_r3_predictions.csv",
    "albert": "/kaggle/input/albert/albert_anli_r3_predictions.csv",
}

# Specify where you want to save the combined predictions CSV file
output_csv_path_anli_r3 = "/kaggle/working/combined_anli_r3_df"

# Define the column names, placing True_Label at the end
columns = [
    'Deberta_Entailment', 'Deberta_Neutral', 'Deberta_Contradiction',
    'Roberta_Entailment', 'Roberta_Neutral', 'Roberta_Contradiction',
    'Albert_Entailment', 'Albert_Neutral', 'Albert_Contradiction',
    'True_Label'  # Ensuring True_Label is the last column
]

# Initialize the DataFrame with specified columns
combined_anli_r3_df = pd.DataFrame(columns=columns)

# Load and merge the predictions
for model, path in anli_r3_predictions_paths.items():
    predictions_df = pd.read_csv(path)
    for label in ['Entailment', 'Neutral', 'Contradiction']:
        combined_anli_r3_df[f"{model.capitalize()}_{label}"] = predictions_df[label]

# Assign the true labels to the True_Label column, now positioned at the end
combined_anli_r3_df['True_Label'] = anli_r3_test_df['label']

# Save the combined DataFrame to CSV
combined_anli_r3_df.to_csv(output_csv_path_anli_r3, index=False)

print(f"Combined ANLI Round 3 predictions with true labels saved to {output_csv_path_anli_r3}")
# Out:
# Combined ANLI Round 3 predictions with true labels saved to /kaggle/working/combined_anli_r3_df

# %%
combined_anli_r3_df.head()
# Out:
#    Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0            0.005921         0.960529               0.033551
# 1            0.009586         0.934714               0.055700
# 2            0.003428         0.976393               0.020179
# 3            0.004633         0.023985               0.971382
# 4            0.017428         0.633695               0.348877
#
#    Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0            0.022959         0.976533               0.000509
# 1            0.999611         0.000205               0.000185
# 2            0.002020         0.997897               0.000083
# 3            0.974441         0.024459               0.001100
# 4            0.984416         0.011166               0.004419
#
#    Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0           0.001848        0.998084              0.000067           0
# 1           0.951772        0.048075              0.000153           0
# 2           0.001014        0.998984              0.000002           0
# 3           0.996749        0.000989              0.002262           0
# 4           0.000518        0.128416              0.871066           0

# %%
# Check for missing values
missing_values_anli1 = combined_anli_r1_df.isnull().sum()

missing_values_anli2 = combined_anli_r2_df.isnull().sum()

missing_values_anli3 = combined_anli_r3_df.isnull().sum()

missing_values_snli = combined_snli_df.isnull().sum()

missing_values_mnli_matched = combined_mnli_matched_df.isnull().sum()

missing_values_mnli_mismatched = combined_mnli_mismatched_df.isnull().sum()

# %%
missing_values_anli1
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
missing_values_anli2
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
missing_values_anli3
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
missing_values_snli
# Out:
# Deberta_Entailment         0
# Deberta_Neutral            0
# Deberta_Contradiction      0
# Roberta_Entailment         0
# Roberta_Neutral            0
# Roberta_Contradiction      0
# Albert_Entailment          0
# Albert_Neutral             0
# Albert_Contradiction       0
# True_Label               176
# dtype: int64

# %%
missing_values_mnli_matched
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
missing_values_mnli_mismatched
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
combined_snli_df.dropna(subset=['True_Label'], inplace=True)

# %%
# Verify missing values again after removal
missing_values_snli_after_removal = combined_snli_df.isnull().sum()
print(missing_values_snli_after_removal)
# Out:
# Deberta_Entailment       0
# Deberta_Neutral          0
# Deberta_Contradiction    0
# Roberta_Entailment       0
# Roberta_Neutral          0
# Roberta_Contradiction    0
# Albert_Entailment        0
# Albert_Neutral           0
# Albert_Contradiction     0
# True_Label               0
# dtype: int64

# %%
combined_snli_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9824 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Deberta_Entailment     9824 non-null   float64
#  1   Deberta_Neutral        9824 non-null   float64
#  2   Deberta_Contradiction  9824 non-null   float64
#  3   Roberta_Entailment     9824 non-null   float64
#  4   Roberta_Neutral        9824 non-null   float64
#  5   Roberta_Contradiction  9824 non-null   float64
#  6   Albert_Entailment      9824 non-null   float64
#  7   Albert_Neutral         9824 non-null   float64
#  8   Albert_Contradiction   9824 non-null   float64
#  9   True_Label             9824 non-null   Int64
# dtypes: Int64(1), float64(9)
# memory usage: 853.8 KB

# %%
combined_snli_df
# Out:
#       Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0               0.034767         0.962592               0.002641
# 1               0.001921         0.319032               0.679047
# 2               0.998783         0.000764               0.000453
# 3               0.001001         0.997708               0.001291
# 4               0.001080         0.301363               0.697557
# ...                  ...              ...                    ...
# 9995            0.998825         0.001033               0.000142
# 9996            0.000704         0.009793               0.989503
# 9997            0.999171         0.000493               0.000336
# 9998            0.000267         0.002178               0.997556
# 9999            0.003641         0.995224               0.001135
#
#       Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0               0.012451         0.927093               0.060457
# 1               0.752766         0.242251               0.004983
# 2               0.000254         0.004494               0.995253
# 3               0.005844         0.990736               0.003419
# 4               0.278348         0.718575               0.003076
# ...                  ...              ...                    ...
# 9995            0.001264         0.028942               0.969794
# 9996            0.780946         0.217053               0.002001
# 9997            0.000054         0.000765               0.999181
# 9998            0.983402         0.015884               0.000714
# 9999            0.000904         0.995495               0.003601
#
#       Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label
# 0              0.008653        0.947434              0.043913           1
# 1              0.740332        0.256434              0.003235           0
# 2              0.004677        0.060481              0.934843           2
# 3              0.034056        0.956687              0.009257           1
# 4              0.498761        0.499270              0.001969           0
# ...                 ...             ...                   ...         ...
# 9995           0.006420        0.057240              0.936340           2
# 9996           0.894637        0.104095              0.001267           0
# 9997           0.000838        0.002670              0.996493           2
# 9998           0.984347        0.015223              0.000430           0
# 9999           0.005047        0.990218              0.004735           1
#
# [9824 rows x 10 columns]

# %%
import numpy as np

def calculate_margin(row):
    # Assuming the row only contains the probabilities
    sorted_probs = np.sort(row)  # Sort probabilities in ascending order
    if len(sorted_probs) > 1:
        return sorted_probs[-1] - sorted_probs[-2]  # Difference between the highest and second highest
    else:
        return 0  # This handles the edge case where there is only one probability value

# %%
# Applying to a sample DataFrame with made-up column names
combined_snli_df['confidence_margin_entailment'] = combined_snli_df[['Deberta_Entailment', 'Roberta_Entailment', 'Albert_Entailment']].apply(calculate_margin, axis=1)
combined_snli_df['confidence_margin_neutral'] = combined_snli_df[['Deberta_Neutral', 'Roberta_Neutral', 'Albert_Neutral']].apply(calculate_margin, axis=1)
combined_snli_df['confidence_margin_contradiction'] = combined_snli_df[['Deberta_Contradiction', 'Roberta_Contradiction', 'Albert_Contradiction']].apply(calculate_margin, axis=1)


# Applying to a sample DataFrame with made-up column names
combined_mnli_matched_df['confidence_margin_entailment'] = combined_mnli_matched_df[['Deberta_Entailment', 'Roberta_Entailment', 'Albert_Entailment']].apply(calculate_margin, axis=1)
combined_mnli_matched_df['confidence_margin_neutral'] = combined_mnli_matched_df[['Deberta_Neutral', 'Roberta_Neutral', 'Albert_Neutral']].apply(calculate_margin, axis=1)
combined_mnli_matched_df['confidence_margin_contradiction'] = combined_mnli_matched_df[['Deberta_Contradiction', 'Roberta_Contradiction', 'Albert_Contradiction']].apply(calculate_margin, axis=1)

# Applying to a sample DataFrame with made-up column names
combined_mnli_mismatched_df['confidence_margin_entailment'] = combined_mnli_mismatched_df[['Deberta_Entailment', 'Roberta_Entailment', 'Albert_Entailment']].apply(calculate_margin, axis=1)
combined_mnli_mismatched_df['confidence_margin_neutral'] = combined_mnli_mismatched_df[['Deberta_Neutral', 'Roberta_Neutral', 'Albert_Neutral']].apply(calculate_margin, axis=1)
combined_mnli_mismatched_df['confidence_margin_contradiction'] = combined_mnli_mismatched_df[['Deberta_Contradiction', 'Roberta_Contradiction', 'Albert_Contradiction']].apply(calculate_margin, axis=1)

# Applying to a sample DataFrame with made-up column names
combined_anli_r1_df['confidence_margin_entailment'] = combined_anli_r1_df[['Deberta_Entailment', 'Roberta_Entailment', 'Albert_Entailment']].apply(calculate_margin, axis=1)
combined_anli_r1_df['confidence_margin_neutral'] = combined_anli_r1_df[['Deberta_Neutral', 'Roberta_Neutral', 'Albert_Neutral']].apply(calculate_margin, axis=1)
combined_anli_r1_df['confidence_margin_contradiction'] = combined_anli_r1_df[['Deberta_Contradiction', 'Roberta_Contradiction', 'Albert_Contradiction']].apply(calculate_margin, axis=1)


# Applying to a sample DataFrame with made-up column names
combined_anli_r2_df['confidence_margin_entailment'] = combined_anli_r2_df[['Deberta_Entailment', 'Roberta_Entailment', 'Albert_Entailment']].apply(calculate_margin, axis=1)
combined_anli_r2_df['confidence_margin_neutral'] = combined_anli_r2_df[['Deberta_Neutral', 'Roberta_Neutral', 'Albert_Neutral']].apply(calculate_margin, axis=1)
combined_anli_r2_df['confidence_margin_contradiction'] = combined_anli_r2_df[['Deberta_Contradiction', 'Roberta_Contradiction', 'Albert_Contradiction']].apply(calculate_margin, axis=1)


# Applying to a sample DataFrame with made-up column names
combined_anli_r3_df['confidence_margin_entailment'] = combined_anli_r3_df[['Deberta_Entailment', 'Roberta_Entailment', 'Albert_Entailment']].apply(calculate_margin, axis=1)
combined_anli_r3_df['confidence_margin_neutral'] = combined_anli_r3_df[['Deberta_Neutral', 'Roberta_Neutral', 'Albert_Neutral']].apply(calculate_margin, axis=1)
combined_anli_r3_df['confidence_margin_contradiction'] = combined_anli_r3_df[['Deberta_Contradiction', 'Roberta_Contradiction', 'Albert_Contradiction']].apply(calculate_margin, axis=1)

# %%
combined_anli_r3_df
# Out:
#       Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0               0.005921         0.960529               0.033551
# 1               0.009586         0.934714               0.055700
# 2               0.003428         0.976393               0.020179
# 3               0.004633         0.023985               0.971382
# 4               0.017428         0.633695               0.348877
# ...                  ...              ...                    ...
# 1195            0.150312         0.806051               0.043637
# 1196            0.971834         0.026294               0.001872
# 1197            0.973818         0.025074               0.001109
# 1198            0.341781         0.226539               0.431681
# 1199            0.472737         0.477215               0.050049
#
#       Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0               0.022959         0.976533               0.000509
# 1               0.999611         0.000205               0.000185
# 2               0.002020         0.997897               0.000083
# 3               0.974441         0.024459               0.001100
# 4               0.984416         0.011166               0.004419
# ...                  ...              ...                    ...
# 1195            0.032452         0.068553               0.898994
# 1196            0.009070         0.824654               0.166276
# 1197            0.000352         0.000972               0.998677
# 1198            0.006147         0.073669               0.920184
# 1199            0.000420         0.991832               0.007748
#
#       Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label  \
# 0              0.001848        0.998084              0.000067           0
# 1              0.951772        0.048075              0.000153           0
# 2              0.001014        0.998984              0.000002           0
# 3              0.996749        0.000989              0.002262           0
# 4              0.000518        0.128416              0.871066           0
# ...                 ...             ...                   ...         ...
# 1195           0.122045        0.254093              0.623862           2
# 1196           0.001115        0.003229              0.995656           2
# 1197           0.310862        0.618914              0.070225           2
# 1198           0.054172        0.317935              0.627893           2
# 1199           0.015091        0.121354              0.863554           2
#
#       confidence_margin_entailment  confidence_margin_neutral  \
# 0                         0.017038                   0.021552
# 1                         0.047839                   0.886640
# 2                         0.001408                   0.001087
# 3                         0.022308                   0.000474
# 4                         0.966988                   0.505279
# ...                            ...                        ...
# 1195                      0.028268                   0.551958
# 1196                      0.962764                   0.798360
# 1197                      0.662956                   0.593840
# 1198                      0.287609                   0.091397
# 1199                      0.457646                   0.514617
#
#       confidence_margin_contradiction
# 0                            0.033042
# 1                            0.055515
# 2                            0.020096
# 3                            0.969120
# 4                            0.522189
# ...                               ...
# 1195                         0.275132
# 1196                         0.829379
# 1197                         0.928452
# 1198                         0.292291
# 1199                         0.813506
#
# [1200 rows x 13 columns]

# %%
import matplotlib.pyplot as plt

# Plot histograms for the confidence margins
def plot_confidence_margins(df):
    plt.figure(figsize=(15, 5))
    plt.subplot(1, 3, 1)
    plt.hist(df['confidence_margin_entailment'], bins=50, alpha=0.75, label='Entailment')
    plt.title('Confidence Margin Histogram - Entailment')
    plt.xlabel('Margin')
    plt.ylabel('Frequency')
    
    plt.subplot(1, 3, 2)
    plt.hist(df['confidence_margin_neutral'], bins=50, alpha=0.75, label='Neutral', color='green')
    plt.title('Confidence Margin Histogram - Neutral')
    plt.xlabel('Margin')
    plt.ylabel('Frequency')
    
    plt.subplot(1, 3, 3)
    plt.hist(df['confidence_margin_contradiction'], bins=50, alpha=0.75, label='Contradiction', color='red')
    plt.title('Confidence Margin Histogram - Contradiction')
    plt.xlabel('Margin')
    plt.ylabel('Frequency')
    
    plt.tight_layout()
    plt.show()

plot_confidence_margins(combined_snli_df)

# %%
# Define thresholds based on the distribution
confidence_threshold = 0.8

# Apply threshold and create a new copy of the DataFrame
high_confidence_snli = combined_snli_df[
    (combined_snli_df['confidence_margin_entailment'] >= confidence_threshold) | 
    (combined_snli_df['confidence_margin_neutral'] >= confidence_threshold) |
    (combined_snli_df['confidence_margin_contradiction'] >= confidence_threshold)
].copy()


# Apply threshold and create a new copy of the DataFrame
high_confidence_mnli_matched = combined_mnli_matched_df[
    (combined_mnli_matched_df['confidence_margin_entailment'] >= confidence_threshold) | 
    (combined_mnli_matched_df['confidence_margin_neutral'] >= confidence_threshold) |
    (combined_mnli_matched_df['confidence_margin_contradiction'] >= confidence_threshold)
].copy()

# Apply threshold and create a new copy of the DataFrame
high_confidence_mnli_mismatched = combined_mnli_mismatched_df[
    (combined_mnli_mismatched_df['confidence_margin_entailment'] >= confidence_threshold) | 
    (combined_mnli_mismatched_df['confidence_margin_neutral'] >= confidence_threshold) |
    (combined_mnli_mismatched_df['confidence_margin_contradiction'] >= confidence_threshold)
].copy()

# Filter high confidence samples for ANLI round 1
high_confidence_anli_r1 = combined_anli_r1_df[
    (combined_anli_r1_df['confidence_margin_entailment'] >= confidence_threshold) | 
    (combined_anli_r1_df['confidence_margin_neutral'] >= confidence_threshold) |
    (combined_anli_r1_df['confidence_margin_contradiction'] >= confidence_threshold)
].copy()

# Filter high confidence samples for ANLI round 2
high_confidence_anli_r2 = combined_anli_r2_df[
    (combined_anli_r2_df['confidence_margin_entailment'] >= confidence_threshold) | 
    (combined_anli_r2_df['confidence_margin_neutral'] >= confidence_threshold) |
    (combined_anli_r2_df['confidence_margin_contradiction'] >= confidence_threshold)
].copy()

# Filter high confidence samples for ANLI round 3
high_confidence_anli_r3 = combined_anli_r3_df[
    (combined_anli_r3_df['confidence_margin_entailment'] >= confidence_threshold) | 
    (combined_anli_r3_df['confidence_margin_neutral'] >= confidence_threshold) |
    (combined_anli_r3_df['confidence_margin_contradiction'] >= confidence_threshold)
].copy()

# %%
# Majority vote logic with weights for numeric labels
def majority_vote_with_threshold(row):
    votes = [0, 0, 0]  # Index 0 for entailment, 1 for neutral, 2 for contradiction
    if row['confidence_margin_entailment'] >= confidence_threshold:
        votes[0] += row['confidence_margin_entailment']
    if row['confidence_margin_neutral'] >= confidence_threshold:
        votes[1] += row['confidence_margin_neutral']
    if row['confidence_margin_contradiction'] >= confidence_threshold:
        votes[2] += row['confidence_margin_contradiction']
    
    # Return the index of the highest vote
    return np.argmax(votes)

# Apply the majority vote logic using .loc
high_confidence_snli.loc[:, 'majority_vote'] = high_confidence_snli.apply(majority_vote_with_threshold, axis=1)
# Apply the majority vote logic using .loc
high_confidence_mnli_matched.loc[:, 'majority_vote'] = high_confidence_mnli_matched.apply(majority_vote_with_threshold, axis=1)
# Apply majority vote logic
high_confidence_mnli_mismatched.loc[:, 'majority_vote'] = high_confidence_mnli_mismatched.apply(majority_vote_with_threshold, axis=1)
# Apply majority vote logic
high_confidence_anli_r1.loc[:, 'majority_vote'] = high_confidence_anli_r1.apply(majority_vote_with_threshold, axis=1)
# Apply majority vote logic
high_confidence_anli_r2.loc[:, 'majority_vote'] = high_confidence_anli_r2.apply(majority_vote_with_threshold, axis=1)
# Apply majority vote logic
high_confidence_anli_r3.loc[:, 'majority_vote'] = high_confidence_anli_r3.apply(majority_vote_with_threshold, axis=1)

# %%
high_confidence_anli_r3
# Out:
#       Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 1               0.009586         0.934714               0.055700
# 3               0.004633         0.023985               0.971382
# 4               0.017428         0.633695               0.348877
# 5               0.002461         0.150678               0.846861
# 8               0.131793         0.776056               0.092151
# ...                  ...              ...                    ...
# 1193            0.957103         0.040533               0.002363
# 1194            0.945850         0.052813               0.001337
# 1196            0.971834         0.026294               0.001872
# 1197            0.973818         0.025074               0.001109
# 1199            0.472737         0.477215               0.050049
#
#       Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 1               0.999611         0.000205               0.000185
# 3               0.974441         0.024459               0.001100
# 4               0.984416         0.011166               0.004419
# 5               0.999220         0.000554               0.000227
# 8               0.000384         0.002570               0.997046
# ...                  ...              ...                    ...
# 1193            0.000066         0.000316               0.999618
# 1194            0.000607         0.000853               0.998540
# 1196            0.009070         0.824654               0.166276
# 1197            0.000352         0.000972               0.998677
# 1199            0.000420         0.991832               0.007748
#
#       Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label  \
# 1              0.951772        0.048075              0.000153           0
# 3              0.996749        0.000989              0.002262           0
# 4              0.000518        0.128416              0.871066           0
# 5              0.985221        0.014745              0.000034           0
# 8              0.049409        0.904356              0.046236           0
# ...                 ...             ...                   ...         ...
# 1193           0.009265        0.016116              0.974619           2
# 1194           0.000205        0.000291              0.999504           2
# 1196           0.001115        0.003229              0.995656           2
# 1197           0.310862        0.618914              0.070225           2
# 1199           0.015091        0.121354              0.863554           2
#
#       confidence_margin_entailment  confidence_margin_neutral  \
# 1                         0.047839                   0.886640
# 3                         0.022308                   0.000474
# 4                         0.966988                   0.505279
# 5                         0.013998                   0.135933
# 8                         0.082384                   0.128299
# ...                            ...                        ...
# 1193                      0.947838                   0.024417
# 1194                      0.945243                   0.051960
# 1196                      0.962764                   0.798360
# 1197                      0.662956                   0.593840
# 1199                      0.457646                   0.514617
#
#       confidence_margin_contradiction  majority_vote
# 1                            0.055515              1
# 3                            0.969120              2
# 4                            0.522189              0
# 5                            0.846635              2
# 8                            0.904895              2
# ...                               ...            ...
# 1193                         0.024999              0
# 1194                         0.000965              0
# 1196                         0.829379              0
# 1197                         0.928452              2
# 1199                         0.813506              2
#
# [530 rows x 14 columns]

# %%
high_confidence_mnli_mismatched
# Out:
#       Deberta_Entailment  Deberta_Neutral  Deberta_Contradiction  \
# 0               0.999667         0.000160               0.000173
# 1               0.998119         0.000962               0.000919
# 2               0.000552         0.004809               0.994639
# 3               0.827653         0.171961               0.000386
# 4               0.000292         0.002875               0.996833
# ...                  ...              ...                    ...
# 9824            0.000760         0.013837               0.985402
# 9825            0.000145         0.003906               0.995949
# 9826            0.996226         0.003656               0.000118
# 9828            0.997044         0.001226               0.001730
# 9829            0.999685         0.000112               0.000202
#
#       Roberta_Entailment  Roberta_Neutral  Roberta_Contradiction  \
# 0               0.000068         0.000402               0.999529
# 1               0.000183         0.001511               0.998306
# 2               0.986062         0.012020               0.001918
# 3               0.000478         0.270953               0.728569
# 4               0.975167         0.021904               0.002929
# ...                  ...              ...                    ...
# 9824            0.972984         0.025382               0.001634
# 9825            0.952827         0.045891               0.001281
# 9826            0.000353         0.104717               0.894930
# 9828            0.000364         0.000717               0.998919
# 9829            0.000085         0.000289               0.999626
#
#       Albert_Entailment  Albert_Neutral  Albert_Contradiction  True_Label  \
# 0              0.000894        0.003787              0.995318           2
# 1              0.006421        0.010224              0.983355           2
# 2              0.975041        0.023354              0.001605           0
# 3              0.001722        0.796122              0.202156           2
# 4              0.965952        0.032748              0.001300           0
# ...                 ...             ...                   ...         ...
# 9824           0.925212        0.069991              0.004798           0
# 9825           0.965645        0.032757              0.001598           0
# 9826           0.004991        0.039946              0.955062           2
# 9828           0.019078        0.039258              0.941663           2
# 9829           0.000420        0.001810              0.997770           2
#
#       confidence_margin_entailment  confidence_margin_neutral  \
# 0                         0.998773                   0.003385
# 1                         0.991698                   0.008714
# 2                         0.011021                   0.011334
# 3                         0.825931                   0.525168
# 4                         0.009215                   0.010844
# ...                            ...                        ...
# 9824                      0.047772                   0.044608
# 9825                      0.012818                   0.013134
# 9826                      0.991234                   0.064771
# 9828                      0.977966                   0.038033
# 9829                      0.999265                   0.001521
#
#       confidence_margin_contradiction  majority_vote
# 0                            0.004211              0
# 1                            0.014951              0
# 2                            0.992721              2
# 3                            0.526413              0
# 4                            0.993904              2
# ...                               ...            ...
# 9824                         0.980605              2
# 9825                         0.994351              2
# 9826                         0.060132              0
# 9828                         0.057256              0
# 9829                         0.001856              0
#
# [5910 rows x 14 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf



# Features and Labels
X_snli = high_confidence_snli.drop(['True_Label','confidence_margin_entailment','confidence_margin_neutral','confidence_margin_contradiction','majority_vote'], axis=1).values
y_snli = high_confidence_snli['True_Label'].values

# Features and Labels
X_mnli_matched = high_confidence_mnli_matched.drop(['True_Label','confidence_margin_entailment','confidence_margin_neutral','confidence_margin_contradiction','majority_vote'], axis=1).values
y_mnli_matched = high_confidence_mnli_matched['True_Label'].values

# Features and Labels
X_mnli_mismatched = high_confidence_mnli_mismatched.drop(['True_Label','confidence_margin_entailment','confidence_margin_neutral','confidence_margin_contradiction','majority_vote'], axis=1).values
y_mnli_mismatched = high_confidence_mnli_mismatched['True_Label'].values

# Features and Labels
X_anli_r1 = high_confidence_anli_r1.drop(['True_Label','confidence_margin_entailment','confidence_margin_neutral','confidence_margin_contradiction','majority_vote'], axis=1).values
y_anli_r1 = high_confidence_anli_r1['True_Label'].values

# Features and Labels
X_anli_r2 = high_confidence_anli_r2.drop(['True_Label','confidence_margin_entailment','confidence_margin_neutral','confidence_margin_contradiction','majority_vote'], axis=1).values
y_anli_r2 = high_confidence_anli_r2['True_Label'].values

# Features and Labels
X_anli_r3 = high_confidence_anli_r3.drop(['True_Label','confidence_margin_entailment','confidence_margin_neutral','confidence_margin_contradiction','majority_vote'], axis=1).values
y_anli_r3 = high_confidence_anli_r3['True_Label'].values

# %%
# Extract only the additional features from each dataset
features_snli = high_confidence_snli[['confidence_margin_entailment', 'confidence_margin_neutral', 'confidence_margin_contradiction']].values
features_mnli_matched = high_confidence_mnli_matched[[ 'confidence_margin_entailment', 'confidence_margin_neutral', 'confidence_margin_contradiction']].values
features_mnli_mismatched = high_confidence_mnli_mismatched[[ 'confidence_margin_entailment', 'confidence_margin_neutral', 'confidence_margin_contradiction']].values
features_anli_r1 = high_confidence_anli_r1[[ 'confidence_margin_entailment', 'confidence_margin_neutral', 'confidence_margin_contradiction']].values
features_anli_r2 = high_confidence_anli_r2[[ 'confidence_margin_entailment', 'confidence_margin_neutral', 'confidence_margin_contradiction']].values
features_anli_r3 = high_confidence_anli_r3[[ 'confidence_margin_entailment', 'confidence_margin_neutral', 'confidence_margin_contradiction']].values

# %%
X_snli
# Out:
# array([[9.9878270e-01, 7.6433434e-04, 4.5297167e-04, ..., 4.6765395e-03,
#         6.0480673e-02, 9.3484277e-01],
#        [5.0442386e-04, 4.3001700e-03, 9.9519530e-01, ..., 9.7817034e-01,
#         2.1051416e-02, 7.7824460e-04],
#        [9.8957914e-01, 5.4418677e-03, 4.9790350e-03, ..., 8.5550435e-02,
#         7.5036585e-02, 8.3941300e-01],
#        ...,
#        [7.0376875e-04, 9.7931010e-03, 9.8950315e-01, ..., 8.9463750e-01,
#         1.0409502e-01, 1.2674012e-03],
#        [9.9917114e-01, 4.9286430e-04, 3.3603658e-04, ..., 8.3751883e-04,
#         2.6697412e-03, 9.9649280e-01],
#        [2.6664520e-04, 2.1777824e-03, 9.9755560e-01, ..., 9.8434700e-01,
#         1.5223468e-02, 4.2961346e-04]])

# %%
features_snli
# Out:
# array([[9.94106161e-01, 5.59870956e-02, 6.04100800e-02],
#        [5.73736000e-03, 5.89017100e-03, 9.94264296e-01],
#        [9.04028705e-01, 1.89172950e-02, 3.66324000e-02],
#        ...,
#        [1.13691360e-01, 1.12957690e-01, 9.87502096e-01],
#        [9.98333621e-01, 1.90469200e-03, 2.68793000e-03],
#        [9.45200000e-04, 6.61004000e-04, 9.96841898e-01]])

# %%
# One-hot encode labels for each dataset using TensorFlow/Keras utility
y_encoded_snli = tf.keras.utils.to_categorical(y_snli)
y_encoded_mnli_matched = tf.keras.utils.to_categorical(y_mnli_matched)
y_encoded_mnli_mismatched = tf.keras.utils.to_categorical(y_mnli_mismatched)
y_encoded_anli_r1 = tf.keras.utils.to_categorical(y_anli_r1)
y_encoded_anli_r2 = tf.keras.utils.to_categorical(y_anli_r2)
y_encoded_anli_r3 = tf.keras.utils.to_categorical(y_anli_r3)

# %%
X_snli_rnn = X_snli.reshape(X_snli.shape[0], 1, X_snli.shape[1])
X_mnli_matched_rnn = X_mnli_matched.reshape(X_mnli_matched.shape[0], 1, X_mnli_matched.shape[1])
X_mnli_mismatched_rnn = X_mnli_mismatched.reshape(X_mnli_mismatched.shape[0], 1, X_mnli_mismatched.shape[1])
X_anli_r1_rnn = X_anli_r1.reshape(X_anli_r1.shape[0], 1, X_anli_r1.shape[1])
X_anli_r2_rnn = X_anli_r2.reshape(X_anli_r2.shape[0], 1, X_anli_r2.shape[1])
X_anli_r3_rnn = X_anli_r3.reshape(X_anli_r3.shape[0], 1, X_anli_r3.shape[1])

# %%
# Reshape feature arrays to match the RNN input shape
features_snli = features_snli.reshape(features_snli.shape[0], 1, features_snli.shape[1])
features_mnli_matched = features_mnli_matched.reshape(features_mnli_matched.shape[0], 1, features_mnli_matched.shape[1])
features_mnli_mismatched = features_mnli_mismatched.reshape(features_mnli_mismatched.shape[0], 1, features_mnli_mismatched.shape[1])
features_anli_r1 = features_anli_r1.reshape(features_anli_r1.shape[0], 1, features_anli_r1.shape[1])
features_anli_r2 = features_anli_r2.reshape(features_anli_r2.shape[0], 1, features_anli_r2.shape[1])
features_anli_r3 = features_anli_r3.reshape(features_anli_r3.shape[0], 1, features_anli_r3.shape[1])

# %%
features_snli.shape
# Out:
# (6032, 1, 3)

# %%
X_snli_rnn
# Out:
# array([[[9.9878270e-01, 7.6433434e-04, 4.5297167e-04, ...,
#          4.6765395e-03, 6.0480673e-02, 9.3484277e-01]],
#
#        [[5.0442386e-04, 4.3001700e-03, 9.9519530e-01, ...,
#          9.7817034e-01, 2.1051416e-02, 7.7824460e-04]],
#
#        [[9.8957914e-01, 5.4418677e-03, 4.9790350e-03, ...,
#          8.5550435e-02, 7.5036585e-02, 8.3941300e-01]],
#
#        ...,
#
#        [[7.0376875e-04, 9.7931010e-03, 9.8950315e-01, ...,
#          8.9463750e-01, 1.0409502e-01, 1.2674012e-03]],
#
#        [[9.9917114e-01, 4.9286430e-04, 3.3603658e-04, ...,
#          8.3751883e-04, 2.6697412e-03, 9.9649280e-01]],
#
#        [[2.6664520e-04, 2.1777824e-03, 9.9755560e-01, ...,
#          9.8434700e-01, 1.5223468e-02, 4.2961346e-04]]])

# %%
X_snli_rnn.shape
# Out:
# (6032, 1, 9)

# %%
from sklearn.model_selection import train_test_split

def prepare_data_splits(X_rnn, features, y_encoded, test_size=0.1, random_state=42):
    # Split the data for the RNN inputs
    X_train_rnn, X_val_rnn, y_train, y_val = train_test_split(
        X_rnn, y_encoded, test_size=test_size, random_state=random_state, stratify=y_encoded)

    # Split the data for the additional features
    features_train, features_val, _, _ = train_test_split(
        features, y_encoded, test_size=test_size, random_state=random_state, stratify=y_encoded)

    return X_train_rnn, X_val_rnn, features_train, features_val, y_train, y_val

# Example for SNLI data
X_train_snli_rnn, X_val_snli_rnn, features_train_snli, features_val_snli, y_train_snli, y_val_snli = prepare_data_splits(X_snli_rnn, features_snli, y_encoded_snli)
# Example for MNLI-m data
X_train_mnli_matched_rnn, X_val_mnli_matched_rnn, features_train_mnli_matched, features_val_mnli_matched, y_train_mnli_matched, y_val_mnli_matched = prepare_data_splits(X_mnli_matched_rnn, features_mnli_matched, y_encoded_mnli_matched)
# Example for MNLI-mm data
X_train_mnli_mismatched_rnn, X_val_mnli_mismatched_rnn, features_train_mnli_mismatched, features_val_mnli_mismatched, y_train_mnli_mismatched, y_val_mnli_mismatched = prepare_data_splits(X_mnli_mismatched_rnn, features_mnli_mismatched, y_encoded_mnli_mismatched)
# Example for ANLI round 1 data
X_train_anli_r1_rnn, X_val_anli_r1_rnn, features_train_anli_r1, features_val_anli_r1, y_train_anli_r1, y_val_anli_r1 = prepare_data_splits(X_anli_r1_rnn, features_anli_r1, y_encoded_anli_r1)
# Example for ANLI round 2 data
X_train_anli_r2_rnn, X_val_anli_r2_rnn, features_train_anli_r2, features_val_anli_r2, y_train_anli_r2, y_val_anli_r2 = prepare_data_splits(X_anli_r2_rnn, features_anli_r2, y_encoded_anli_r2)
# Example for ANLI round 3 data
X_train_anli_r3_rnn, X_val_anli_r3_rnn, features_train_anli_r3, features_val_anli_r3, y_train_anli_r3, y_val_anli_r3 = prepare_data_splits(X_anli_r3_rnn, features_anli_r3, y_encoded_anli_r3)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, Concatenate, Flatten, Attention
from tensorflow.keras.callbacks import EarlyStopping

def build_and_train_attention_lstm_model(X_train_rnn, features_train, y_train, X_val_rnn, features_val, y_val, epochs=20, batch_size=32):
    sequence_input_shape = X_train_rnn.shape[1:]
    features_input_shape = features_train.shape[1:]

    # Define input layer for sequence data
    sequence_input = Input(shape=sequence_input_shape, name='sequence_input')
    
    # LSTM layer that returns sequences for attention processing
    lstm = LSTM(64, return_sequences=True)(sequence_input)
    
    # Applying attention mechanism on LSTM output
    attention = Attention()([lstm, lstm])
    attention = Flatten()(attention)
    
    # Define input layer for feature data
    features_input = Input(shape=features_input_shape, name='features_input')
    features_layer = Dense(32, activation='relu')(features_input)
    features_layer = Dropout(0.2)(features_layer)
    features_layer = Flatten()(features_layer)

    # Concatenate attention output and features
    concatenated = Concatenate()([attention, features_layer])
    
    # Output layer
    final_output = Dense(3, activation='softmax')(concatenated)

    # Build and compile the model
    model = Model(inputs=[sequence_input, features_input], outputs=final_output)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Early stopping to prevent overfitting
    early_stopping = EarlyStopping(monitor='val_loss', patience=3)

    # Train the model
    history = model.fit(
        [X_train_rnn, features_train], y_train,
        validation_data=([X_val_rnn, features_val], y_val),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=[early_stopping]
    )

    # Evaluate the model
    evaluation = model.evaluate([X_val_rnn, features_val], y_val, verbose=1)
    
    return model, history, evaluation

# %%
# Training and evaluation for the SNLI data with LSTM
model_snli_lstm, history_snli_lstm, evaluation_snli_lstm = build_and_train_attention_lstm_model(
    X_train_snli_rnn, features_train_snli, y_train_snli, 
    X_val_snli_rnn, features_val_snli, y_val_snli, 
    epochs=20, batch_size=32
)

print("Evaluation on SNLI Validation Data with attention LSTM:", evaluation_snli_lstm)
print("History keys:", history_snli_lstm.history.keys())
# Out:
# Epoch 1/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7851 - loss: 0.7209 - val_accuracy: 0.9536 - val_loss: 0.1695
# Epoch 2/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9538 - loss: 0.1654 - val_accuracy: 0.9603 - val_loss: 0.1293
# Epoch 3/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9680 - loss: 0.1197 - val_accuracy: 0.9619 - val_loss: 0.1212
# Epoch 4/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9580 - loss: 0.1451 - val_accuracy: 0.9636 - val_loss: 0.1179
# Epoch 5/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9654 - loss: 0.1257 - val_accuracy: 0.9619 - val_loss: 0.1179
# Epoch 6/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9640 - loss: 0.1297 - val_accuracy: 0.9619 - val_loss: 0.1185
# Epoch 7/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9625 - loss: 0.1314 - val_accuracy: 0.9652 - val_loss: 0.1172
# Epoch 8/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9577 - loss: 0.1495 - val_accuracy: 0.9636 - val_loss: 0.1172
# Epoch 9/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9624 - loss: 0.1346 - val_accuracy: 0.9636 - val_loss: 0.1176
# Epoch 10/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9583 - loss: 0.1341 - val_accuracy: 0.9636 - val_loss: 0.1175
# Epoch 11/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9594 - loss: 0.1396 - val_accuracy: 0.9636 - val_loss: 0.1177
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9610 - loss: 0.1063
# Evaluation on SNLI Validation Data with attention LSTM: [0.1176544725894928, 0.9635761380195618]
# History keys: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Train and evaluate LSTM model on MNLI Matched data
model_mnli_matched_lstm, history_mnli_matched_lstm, evaluation_mnli_matched_lstm = build_and_train_attention_lstm_model(
    X_train_mnli_matched_rnn, features_train_mnli_matched, y_train_mnli_matched,
    X_val_mnli_matched_rnn, features_val_mnli_matched, y_val_mnli_matched,
    epochs=20, batch_size=32
)

print("Evaluation on MNLI Matched Validation Data with attention LSTM:", evaluation_mnli_matched_lstm)
print("History keys:", history_mnli_matched_lstm.history.keys())
# Out:
# Epoch 1/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8090 - loss: 0.7079 - val_accuracy: 0.9659 - val_loss: 0.1677
# Epoch 2/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9643 - loss: 0.1603 - val_accuracy: 0.9659 - val_loss: 0.1415
# Epoch 3/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9621 - loss: 0.1521 - val_accuracy: 0.9659 - val_loss: 0.1329
# Epoch 4/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9676 - loss: 0.1322 - val_accuracy: 0.9693 - val_loss: 0.1290
# Epoch 5/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9681 - loss: 0.1300 - val_accuracy: 0.9693 - val_loss: 0.1269
# Epoch 6/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9687 - loss: 0.1287 - val_accuracy: 0.9693 - val_loss: 0.1249
# Epoch 7/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9622 - loss: 0.1460 - val_accuracy: 0.9693 - val_loss: 0.1244
# Epoch 8/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9677 - loss: 0.1297 - val_accuracy: 0.9693 - val_loss: 0.1244
# Epoch 9/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9649 - loss: 0.1392 - val_accuracy: 0.9693 - val_loss: 0.1238
# Epoch 10/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9673 - loss: 0.1348 - val_accuracy: 0.9710 - val_loss: 0.1235
# Epoch 11/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9659 - loss: 0.1357 - val_accuracy: 0.9727 - val_loss: 0.1238
# Epoch 12/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9680 - loss: 0.1288 - val_accuracy: 0.9693 - val_loss: 0.1235
# Epoch 13/20
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9621 - loss: 0.1426 - val_accuracy: 0.9693 - val_loss: 0.1236
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9668 - loss: 0.1439
# Evaluation on MNLI Matched Validation Data with attention LSTM: [0.12362799048423767, 0.9692832827568054]
# History keys: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Train and evaluate LSTM model on MNLI Mismatched data
model_mnli_mismatched_lstm, history_mnli_mismatched_lstm, evaluation_mnli_mismatched_lstm = build_and_train_attention_lstm_model(
    X_train_mnli_mismatched_rnn, features_train_mnli_mismatched, y_train_mnli_mismatched,
    X_val_mnli_mismatched_rnn, features_val_mnli_mismatched, y_val_mnli_mismatched,
    epochs=20, batch_size=32
)

print("Evaluation on MNLI Mismatched Validation Data with attention LSTM:", evaluation_mnli_mismatched_lstm)

print("History keys:", history_mnli_mismatched_lstm.history.keys())
# Out:
# Epoch 1/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8154 - loss: 0.6890 - val_accuracy: 0.9628 - val_loss: 0.1744
# Epoch 2/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9680 - loss: 0.1431 - val_accuracy: 0.9628 - val_loss: 0.1555
# Epoch 3/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9722 - loss: 0.1135 - val_accuracy: 0.9628 - val_loss: 0.1490
# Epoch 4/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9669 - loss: 0.1221 - val_accuracy: 0.9628 - val_loss: 0.1481
# Epoch 5/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9704 - loss: 0.1131 - val_accuracy: 0.9628 - val_loss: 0.1476
# Epoch 6/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9687 - loss: 0.1154 - val_accuracy: 0.9628 - val_loss: 0.1480
# Epoch 7/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9673 - loss: 0.1225 - val_accuracy: 0.9645 - val_loss: 0.1481
# Epoch 8/20
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9648 - loss: 0.1252 - val_accuracy: 0.9645 - val_loss: 0.1507
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9504 - loss: 0.1913
# Evaluation on MNLI Mismatched Validation Data with attention LSTM: [0.1507212519645691, 0.9644669890403748]
# History keys: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Train and evaluate LSTM model on ANLI Round 1 data
model_anli_r1_lstm, history_anli_r1_lstm, evaluation_anli_r1_lstm = build_and_train_attention_lstm_model(
    X_train_anli_r1_rnn, features_train_anli_r1, y_train_anli_r1,
    X_val_anli_r1_rnn, features_val_anli_r1, y_val_anli_r1,
    epochs=20, batch_size=32
)
print("Evaluation on ANLI Round 1 Validation Data with attention LSTM:", evaluation_anli_r1_lstm)

print("History keys:", history_anli_r1_lstm.history.keys())
# Out:
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.2449 - loss: 1.1151 - val_accuracy: 0.6279 - val_loss: 1.0794
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5944 - loss: 1.0530 - val_accuracy: 0.7674 - val_loss: 1.0198
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6953 - loss: 0.9928 - val_accuracy: 0.7442 - val_loss: 0.9627
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7312 - loss: 0.9234 - val_accuracy: 0.7209 - val_loss: 0.9049
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6910 - loss: 0.8869 - val_accuracy: 0.7209 - val_loss: 0.8452
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6879 - loss: 0.8327 - val_accuracy: 0.6977 - val_loss: 0.7866
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7626 - loss: 0.7543 - val_accuracy: 0.6977 - val_loss: 0.7324
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8192 - loss: 0.6852 - val_accuracy: 0.6977 - val_loss: 0.6835
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7986 - loss: 0.6588 - val_accuracy: 0.6977 - val_loss: 0.6435
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7515 - loss: 0.6670 - val_accuracy: 0.6977 - val_loss: 0.6112
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8299 - loss: 0.5601 - val_accuracy: 0.6977 - val_loss: 0.5854
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7672 - loss: 0.5837 - val_accuracy: 0.7209 - val_loss: 0.5653
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7956 - loss: 0.5459 - val_accuracy: 0.7209 - val_loss: 0.5492
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8276 - loss: 0.5257 - val_accuracy: 0.7442 - val_loss: 0.5390
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8164 - loss: 0.5271 - val_accuracy: 0.7442 - val_loss: 0.5286
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8100 - loss: 0.5277 - val_accuracy: 0.7442 - val_loss: 0.5222
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8233 - loss: 0.4852 - val_accuracy: 0.7442 - val_loss: 0.5136
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8072 - loss: 0.5029 - val_accuracy: 0.7442 - val_loss: 0.5130
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8123 - loss: 0.4992 - val_accuracy: 0.7442 - val_loss: 0.5085
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8291 - loss: 0.4716 - val_accuracy: 0.7442 - val_loss: 0.5025
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7461 - loss: 0.5551
# Evaluation on ANLI Round 1 Validation Data with attention LSTM: [0.5025266408920288, 0.7441860437393188]
# History keys: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Train and evaluate LSTM model on ANLI Round 2 data
model_anli_r2_lstm, history_anli_r2_lstm, evaluation_anli_r2_lstm = build_and_train_attention_lstm_model(
    X_train_anli_r2_rnn, features_train_anli_r2, y_train_anli_r2,
    X_val_anli_r2_rnn, features_val_anli_r2, y_val_anli_r2,
    epochs=20, batch_size=32
)

print("Evaluation on ANLI Round 2 Validation Data with attention LSTM:", evaluation_anli_r2_lstm)

print("History keys:", history_anli_r2_lstm.history.keys())
# Out:
# Epoch 1/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.3879 - loss: 1.0893 - val_accuracy: 0.5333 - val_loss: 1.0591
# Epoch 2/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5296 - loss: 1.0513 - val_accuracy: 0.5556 - val_loss: 1.0259
# Epoch 3/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5463 - loss: 1.0124 - val_accuracy: 0.5556 - val_loss: 0.9937
# Epoch 4/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5630 - loss: 0.9890 - val_accuracy: 0.5556 - val_loss: 0.9568
# Epoch 5/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5783 - loss: 0.9470 - val_accuracy: 0.6889 - val_loss: 0.9167
# Epoch 6/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5808 - loss: 0.9139 - val_accuracy: 0.6889 - val_loss: 0.8763
# Epoch 7/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6781 - loss: 0.8442 - val_accuracy: 0.6889 - val_loss: 0.8370
# Epoch 8/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6713 - loss: 0.8303 - val_accuracy: 0.6889 - val_loss: 0.8015
# Epoch 9/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6540 - loss: 0.7919 - val_accuracy: 0.6889 - val_loss: 0.7721
# Epoch 10/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6697 - loss: 0.7871 - val_accuracy: 0.7111 - val_loss: 0.7468
# Epoch 11/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7205 - loss: 0.7390 - val_accuracy: 0.7333 - val_loss: 0.7277
# Epoch 12/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7083 - loss: 0.7421 - val_accuracy: 0.7333 - val_loss: 0.7116
# Epoch 13/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7356 - loss: 0.6999 - val_accuracy: 0.7111 - val_loss: 0.6977
# Epoch 14/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7187 - loss: 0.7345 - val_accuracy: 0.7333 - val_loss: 0.6899
# Epoch 15/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7508 - loss: 0.6933 - val_accuracy: 0.7333 - val_loss: 0.6823
# Epoch 16/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7656 - loss: 0.6418 - val_accuracy: 0.7333 - val_loss: 0.6774
# Epoch 17/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7342 - loss: 0.6972 - val_accuracy: 0.7333 - val_loss: 0.6718
# Epoch 18/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7789 - loss: 0.6429 - val_accuracy: 0.7333 - val_loss: 0.6698
# Epoch 19/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7433 - loss: 0.6753 - val_accuracy: 0.7333 - val_loss: 0.6659
# Epoch 20/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7495 - loss: 0.6735 - val_accuracy: 0.7333 - val_loss: 0.6656
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7285 - loss: 0.6594
# Evaluation on ANLI Round 2 Validation Data with attention LSTM: [0.6656368374824524, 0.7333333492279053]
# History keys: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Train and evaluate LSTM model on ANLI Round 3 data
model_anli_r3_lstm, history_anli_r3_lstm, evaluation_anli_r3_lstm = build_and_train_attention_lstm_model(
    X_train_anli_r3_rnn, features_train_anli_r3, y_train_anli_r3,
    X_val_anli_r3_rnn, features_val_anli_r3, y_val_anli_r3,
    epochs=20, batch_size=32
)


print("Evaluation on ANLI Round 3 Validation Data with attention LSTM:", evaluation_anli_r3_lstm)
print("History keys:", history_anli_r3_lstm.history.keys())
# Out:
# Epoch 1/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.3479 - loss: 1.0846 - val_accuracy: 0.6038 - val_loss: 1.0328
# Epoch 2/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6148 - loss: 1.0170 - val_accuracy: 0.6038 - val_loss: 0.9773
# Epoch 3/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6238 - loss: 0.9649 - val_accuracy: 0.6415 - val_loss: 0.9265
# Epoch 4/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6422 - loss: 0.9180 - val_accuracy: 0.6792 - val_loss: 0.8779
# Epoch 5/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6288 - loss: 0.8767 - val_accuracy: 0.6792 - val_loss: 0.8339
# Epoch 6/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6662 - loss: 0.8193 - val_accuracy: 0.6604 - val_loss: 0.7959
# Epoch 7/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6783 - loss: 0.7816 - val_accuracy: 0.6604 - val_loss: 0.7655
# Epoch 8/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6432 - loss: 0.7995 - val_accuracy: 0.6415 - val_loss: 0.7429
# Epoch 9/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7006 - loss: 0.7223 - val_accuracy: 0.6415 - val_loss: 0.7265
# Epoch 10/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6923 - loss: 0.7306 - val_accuracy: 0.6792 - val_loss: 0.7168
# Epoch 11/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7198 - loss: 0.6735 - val_accuracy: 0.6792 - val_loss: 0.7055
# Epoch 12/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6991 - loss: 0.7008 - val_accuracy: 0.6792 - val_loss: 0.6979
# Epoch 13/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7333 - loss: 0.6602 - val_accuracy: 0.6604 - val_loss: 0.6927
# Epoch 14/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7611 - loss: 0.6208 - val_accuracy: 0.6604 - val_loss: 0.6906
# Epoch 15/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7121 - loss: 0.6651 - val_accuracy: 0.6604 - val_loss: 0.6830
# Epoch 16/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7288 - loss: 0.6745 - val_accuracy: 0.6604 - val_loss: 0.6828
# Epoch 17/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7070 - loss: 0.6895 - val_accuracy: 0.6604 - val_loss: 0.6783
# Epoch 18/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7298 - loss: 0.6761 - val_accuracy: 0.6604 - val_loss: 0.6790
# Epoch 19/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7474 - loss: 0.6374 - val_accuracy: 0.6604 - val_loss: 0.6763
# Epoch 20/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7627 - loss: 0.6567 - val_accuracy: 0.6604 - val_loss: 0.6779
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6903 - loss: 0.6360
# Evaluation on ANLI Round 3 Validation Data with attention LSTM: [0.6778753995895386, 0.6603773832321167]
# History keys: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# Combining all datasets for a comprehensive training set
X_rnn_all_tasks = np.concatenate([
    X_snli_rnn, X_mnli_matched_rnn, X_mnli_mismatched_rnn,
    X_anli_r1_rnn, X_anli_r2_rnn, X_anli_r3_rnn
])

features_all_tasks = np.concatenate([
    features_snli, features_mnli_matched, features_mnli_mismatched,
    features_anli_r1, features_anli_r2, features_anli_r3
])

y_encoded_all_tasks = np.concatenate([
    y_encoded_snli, y_encoded_mnli_matched, y_encoded_mnli_mismatched,
    y_encoded_anli_r1, y_encoded_anli_r2, y_encoded_anli_r3
])

# Prepare data splits for combined dataset
X_train_all_rnn, X_val_all_rnn, features_train_all, features_val_all, y_train_all, y_val_all = prepare_data_splits(
    X_rnn_all_tasks, features_all_tasks, y_encoded_all_tasks
)

# Train and evaluate the LSTM model using the combined data from all tasks
model_all, history_all, evaluation_all = build_and_train_attention_lstm_model(
    X_train_all_rnn, features_train_all, y_train_all,
    X_val_all_rnn, features_val_all, y_val_all,
    epochs=20, batch_size=32
)

print("Evaluation on All Tasks Validation Data with attention LSTM:", evaluation_all)
print("History keys:", history_all.history.keys())
# Out:
# Epoch 1/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8887 - loss: 0.4524 - val_accuracy: 0.9464 - val_loss: 0.1719
# Epoch 2/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9468 - loss: 0.1782 - val_accuracy: 0.9438 - val_loss: 0.1726
# Epoch 3/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9472 - loss: 0.1763 - val_accuracy: 0.9464 - val_loss: 0.1721
# Epoch 4/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9490 - loss: 0.1724 - val_accuracy: 0.9474 - val_loss: 0.1717
# Epoch 5/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9454 - loss: 0.1776 - val_accuracy: 0.9469 - val_loss: 0.1715
# Epoch 6/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9462 - loss: 0.1762 - val_accuracy: 0.9474 - val_loss: 0.1704
# Epoch 7/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9440 - loss: 0.1845 - val_accuracy: 0.9458 - val_loss: 0.1700
# Epoch 8/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9485 - loss: 0.1776 - val_accuracy: 0.9474 - val_loss: 0.1700
# Epoch 9/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9461 - loss: 0.1829 - val_accuracy: 0.9464 - val_loss: 0.1698
# Epoch 10/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9485 - loss: 0.1759 - val_accuracy: 0.9474 - val_loss: 0.1698
# Epoch 11/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9462 - loss: 0.1811 - val_accuracy: 0.9484 - val_loss: 0.1687
# Epoch 12/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9488 - loss: 0.1708 - val_accuracy: 0.9458 - val_loss: 0.1694
# Epoch 13/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9483 - loss: 0.1663 - val_accuracy: 0.9490 - val_loss: 0.1697
# Epoch 14/20
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9451 - loss: 0.1757 - val_accuracy: 0.9474 - val_loss: 0.1689
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9471 - loss: 0.1604
# Evaluation on All Tasks Validation Data with attention LSTM: [0.1689344048500061, 0.9473958611488342]
# History keys: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# After training the model
model_all.save('attentionLSTM_feature_ensemble.h5')  # Saves the model in HDF5 format

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    plt.show()

plot_training_history(history_snli_lstm)

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    plt.show()

plot_training_history(history_mnli_matched_lstm)

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    plt.show()

plot_training_history(history_mnli_mismatched_lstm)

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    plt.show()

plot_training_history(history_anli_r1_lstm)

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    plt.show()

plot_training_history(history_anli_r2_lstm)

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    plt.show()

plot_training_history(history_anli_r3_lstm)

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    # Plot training & validation loss values
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    plt.show()

plot_training_history(history_all)

# %%
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, Concatenate, Flatten, Attention
from tensorflow.keras.models import Model
from sklearn.model_selection import StratifiedKFold

def create_attention_lstm_model(sequence_input_shape, features_input_shape):
    sequence_input = Input(shape=sequence_input_shape, name='sequence_input')
    lstm = LSTM(64, return_sequences=True)(sequence_input)  # Keep sequences for attention
    attention = Attention()([lstm, lstm])  # Self-attention
    attention = Flatten()(attention)
    
    features_input = Input(shape=features_input_shape, name='features_input')
    features = Dense(32, activation='relu')(features_input)
    features = Dropout(0.2)(features)
    features = Flatten()(features)
    
    concatenated = Concatenate()([attention, features])
    final_output = Dense(3, activation='softmax')(concatenated)
    
    model = Model(inputs=[sequence_input, features_input], outputs=final_output)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model



def cross_validate_attention_lstm_model(X_rnn, features, y_encoded, num_folds=5):
    y_single = np.argmax(y_encoded, axis=1)  # Convert labels for stratified split
    kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)
    fold_no = 1
    acc_per_fold = []
    loss_per_fold = []
    histories = []

    for train, test in kfold.split(X_rnn, y_single):
        X_train_rnn, X_test_rnn = X_rnn[train], X_rnn[test]
        features_train, features_test = features[train], features[test]
        y_train, y_test = y_encoded[train], y_encoded[test]

        model = create_attention_lstm_model(X_train_rnn.shape[1:], features_train.shape[1:])

        print(f'Training on fold {fold_no}...')
        history = model.fit([X_train_rnn, features_train], y_train, epochs=20, batch_size=32, verbose=1, validation_data=([X_test_rnn, features_test], y_test))
        histories.append(history)

        scores = model.evaluate([X_test_rnn, features_test], y_test, verbose=0)
        print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
        acc_per_fold.append(scores[1] * 100)
        loss_per_fold.append(scores[0])

        fold_no += 1

    print('------------------------------------------------------------------------')
    print('Score per fold')
    for i in range(len(acc_per_fold)):
        print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
    print('------------------------------------------------------------------------')
    print('Average scores for all folds:')
    print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
    print(f'> Loss: {np.mean(loss_per_fold)}')
    print('------------------------------------------------------------------------')
    
    return histories

# %%
histories_snli = cross_validate_attention_lstm_model(X_snli_rnn, features_snli, y_encoded_snli)
# Out:
# Training on fold 1...
# Epoch 1/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8617 - loss: 0.7223 - val_accuracy: 0.9544 - val_loss: 0.1765
# Epoch 2/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9513 - loss: 0.1798 - val_accuracy: 0.9544 - val_loss: 0.1335
# Epoch 3/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9595 - loss: 0.1456 - val_accuracy: 0.9635 - val_loss: 0.1208
# Epoch 4/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9608 - loss: 0.1416 - val_accuracy: 0.9627 - val_loss: 0.1166
# Epoch 5/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9610 - loss: 0.1370 - val_accuracy: 0.9644 - val_loss: 0.1160
# Epoch 6/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9635 - loss: 0.1399 - val_accuracy: 0.9627 - val_loss: 0.1172
# Epoch 7/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9619 - loss: 0.1398 - val_accuracy: 0.9627 - val_loss: 0.1171
# Epoch 8/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9620 - loss: 0.1376 - val_accuracy: 0.9627 - val_loss: 0.1177
# Epoch 9/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9655 - loss: 0.1229 - val_accuracy: 0.9627 - val_loss: 0.1173
# Epoch 10/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9602 - loss: 0.1388 - val_accuracy: 0.9627 - val_loss: 0.1168
# Epoch 11/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9612 - loss: 0.1377 - val_accuracy: 0.9635 - val_loss: 0.1169
# Epoch 12/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9632 - loss: 0.1333 - val_accuracy: 0.9644 - val_loss: 0.1180
# Epoch 13/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9615 - loss: 0.1407 - val_accuracy: 0.9619 - val_loss: 0.1166
# Epoch 14/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9642 - loss: 0.1307 - val_accuracy: 0.9611 - val_loss: 0.1174
# Epoch 15/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9614 - loss: 0.1427 - val_accuracy: 0.9627 - val_loss: 0.1177
# Epoch 16/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9644 - loss: 0.1283 - val_accuracy: 0.9619 - val_loss: 0.1182
# Epoch 17/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9601 - loss: 0.1338 - val_accuracy: 0.9635 - val_loss: 0.1183
# Epoch 18/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9605 - loss: 0.1331 - val_accuracy: 0.9644 - val_loss: 0.1178
# Epoch 19/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9577 - loss: 0.1444 - val_accuracy: 0.9635 - val_loss: 0.1181
# Epoch 20/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9641 - loss: 0.1255 - val_accuracy: 0.9635 - val_loss: 0.1175
# Score for fold 1: loss of 0.11753278225660324; compile_metrics of 96.35459780693054%
# Training on fold 2...
# Epoch 1/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9189 - loss: 0.7092 - val_accuracy: 0.9544 - val_loss: 0.1853
# Epoch 2/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9504 - loss: 0.1838 - val_accuracy: 0.9544 - val_loss: 0.1442
# Epoch 3/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9518 - loss: 0.1599 - val_accuracy: 0.9602 - val_loss: 0.1276
# Epoch 4/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9593 - loss: 0.1460 - val_accuracy: 0.9635 - val_loss: 0.1231
# Epoch 5/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9652 - loss: 0.1264 - val_accuracy: 0.9619 - val_loss: 0.1228
# Epoch 6/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9577 - loss: 0.1422 - val_accuracy: 0.9627 - val_loss: 0.1224
# Epoch 7/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9644 - loss: 0.1275 - val_accuracy: 0.9627 - val_loss: 0.1221
# Epoch 8/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9587 - loss: 0.1416 - val_accuracy: 0.9644 - val_loss: 0.1218
# Epoch 9/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9654 - loss: 0.1301 - val_accuracy: 0.9619 - val_loss: 0.1241
# Epoch 10/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9600 - loss: 0.1378 - val_accuracy: 0.9635 - val_loss: 0.1227
# Epoch 11/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9632 - loss: 0.1258 - val_accuracy: 0.9619 - val_loss: 0.1234
# Epoch 12/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9654 - loss: 0.1240 - val_accuracy: 0.9602 - val_loss: 0.1237
# Epoch 13/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9605 - loss: 0.1411 - val_accuracy: 0.9627 - val_loss: 0.1220
# Epoch 14/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9611 - loss: 0.1355 - val_accuracy: 0.9627 - val_loss: 0.1217
# Epoch 15/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9578 - loss: 0.1383 - val_accuracy: 0.9619 - val_loss: 0.1216
# Epoch 16/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9610 - loss: 0.1334 - val_accuracy: 0.9627 - val_loss: 0.1216
# Epoch 17/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9612 - loss: 0.1339 - val_accuracy: 0.9602 - val_loss: 0.1248
# Epoch 18/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9642 - loss: 0.1184 - val_accuracy: 0.9619 - val_loss: 0.1226
# Epoch 19/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9616 - loss: 0.1294 - val_accuracy: 0.9619 - val_loss: 0.1217
# Epoch 20/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9620 - loss: 0.1329 - val_accuracy: 0.9627 - val_loss: 0.1229
# Score for fold 2: loss of 0.12288542836904526; compile_metrics of 96.27174735069275%
# Training on fold 3...
# Epoch 1/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8521 - loss: 0.7084 - val_accuracy: 0.9519 - val_loss: 0.1849
# Epoch 2/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9512 - loss: 0.1739 - val_accuracy: 0.9527 - val_loss: 0.1537
# Epoch 3/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9578 - loss: 0.1373 - val_accuracy: 0.9619 - val_loss: 0.1440
# Epoch 4/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9618 - loss: 0.1319 - val_accuracy: 0.9627 - val_loss: 0.1432
# Epoch 5/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9602 - loss: 0.1442 - val_accuracy: 0.9602 - val_loss: 0.1436
# Epoch 6/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9600 - loss: 0.1358 - val_accuracy: 0.9602 - val_loss: 0.1457
# Epoch 7/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9607 - loss: 0.1314 - val_accuracy: 0.9594 - val_loss: 0.1443
# Epoch 8/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9634 - loss: 0.1284 - val_accuracy: 0.9594 - val_loss: 0.1434
# Epoch 9/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9588 - loss: 0.1303 - val_accuracy: 0.9594 - val_loss: 0.1433
# Epoch 10/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9647 - loss: 0.1283 - val_accuracy: 0.9594 - val_loss: 0.1436
# Epoch 11/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9615 - loss: 0.1262 - val_accuracy: 0.9594 - val_loss: 0.1431
# Epoch 12/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9590 - loss: 0.1329 - val_accuracy: 0.9594 - val_loss: 0.1431
# Epoch 13/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9595 - loss: 0.1391 - val_accuracy: 0.9585 - val_loss: 0.1428
# Epoch 14/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9612 - loss: 0.1409 - val_accuracy: 0.9594 - val_loss: 0.1428
# Epoch 15/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9579 - loss: 0.1451 - val_accuracy: 0.9577 - val_loss: 0.1436
# Epoch 16/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9608 - loss: 0.1273 - val_accuracy: 0.9577 - val_loss: 0.1430
# Epoch 17/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9590 - loss: 0.1319 - val_accuracy: 0.9585 - val_loss: 0.1432
# Epoch 18/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9576 - loss: 0.1395 - val_accuracy: 0.9585 - val_loss: 0.1429
# Epoch 19/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9591 - loss: 0.1303 - val_accuracy: 0.9602 - val_loss: 0.1425
# Epoch 20/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9619 - loss: 0.1337 - val_accuracy: 0.9585 - val_loss: 0.1433
# Score for fold 3: loss of 0.14325261116027832; compile_metrics of 95.85406184196472%
# Training on fold 4...
# Epoch 1/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7428 - loss: 0.7704 - val_accuracy: 0.9536 - val_loss: 0.1942
# Epoch 2/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9501 - loss: 0.1865 - val_accuracy: 0.9536 - val_loss: 0.1526
# Epoch 3/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9605 - loss: 0.1330 - val_accuracy: 0.9627 - val_loss: 0.1418
# Epoch 4/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9595 - loss: 0.1380 - val_accuracy: 0.9627 - val_loss: 0.1414
# Epoch 5/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9653 - loss: 0.1238 - val_accuracy: 0.9627 - val_loss: 0.1414
# Epoch 6/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9611 - loss: 0.1364 - val_accuracy: 0.9619 - val_loss: 0.1411
# Epoch 7/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9561 - loss: 0.1431 - val_accuracy: 0.9610 - val_loss: 0.1400
# Epoch 8/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9647 - loss: 0.1260 - val_accuracy: 0.9619 - val_loss: 0.1389
# Epoch 9/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9618 - loss: 0.1296 - val_accuracy: 0.9602 - val_loss: 0.1400
# Epoch 10/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9573 - loss: 0.1356 - val_accuracy: 0.9610 - val_loss: 0.1401
# Epoch 11/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9606 - loss: 0.1347 - val_accuracy: 0.9627 - val_loss: 0.1415
# Epoch 12/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9633 - loss: 0.1373 - val_accuracy: 0.9627 - val_loss: 0.1411
# Epoch 13/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9631 - loss: 0.1254 - val_accuracy: 0.9619 - val_loss: 0.1393
# Epoch 14/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9612 - loss: 0.1381 - val_accuracy: 0.9610 - val_loss: 0.1396
# Epoch 15/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9609 - loss: 0.1301 - val_accuracy: 0.9602 - val_loss: 0.1389
# Epoch 16/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9615 - loss: 0.1343 - val_accuracy: 0.9610 - val_loss: 0.1390
# Epoch 17/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9637 - loss: 0.1210 - val_accuracy: 0.9619 - val_loss: 0.1392
# Epoch 18/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9636 - loss: 0.1321 - val_accuracy: 0.9635 - val_loss: 0.1400
# Epoch 19/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9603 - loss: 0.1272 - val_accuracy: 0.9610 - val_loss: 0.1388
# Epoch 20/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9570 - loss: 0.1428 - val_accuracy: 0.9602 - val_loss: 0.1391
# Score for fold 4: loss of 0.13908042013645172; compile_metrics of 96.01989984512329%
# Training on fold 5...
# Epoch 1/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8034 - loss: 0.7227 - val_accuracy: 0.9519 - val_loss: 0.1924
# Epoch 2/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9566 - loss: 0.1659 - val_accuracy: 0.9519 - val_loss: 0.1590
# Epoch 3/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9537 - loss: 0.1502 - val_accuracy: 0.9585 - val_loss: 0.1506
# Epoch 4/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9619 - loss: 0.1364 - val_accuracy: 0.9610 - val_loss: 0.1499
# Epoch 5/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9602 - loss: 0.1400 - val_accuracy: 0.9585 - val_loss: 0.1499
# Epoch 6/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9613 - loss: 0.1276 - val_accuracy: 0.9577 - val_loss: 0.1502
# Epoch 7/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9622 - loss: 0.1299 - val_accuracy: 0.9594 - val_loss: 0.1512
# Epoch 8/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9640 - loss: 0.1247 - val_accuracy: 0.9585 - val_loss: 0.1505
# Epoch 9/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9638 - loss: 0.1161 - val_accuracy: 0.9577 - val_loss: 0.1504
# Epoch 10/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9616 - loss: 0.1312 - val_accuracy: 0.9577 - val_loss: 0.1524
# Epoch 11/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9640 - loss: 0.1301 - val_accuracy: 0.9585 - val_loss: 0.1517
# Epoch 12/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9623 - loss: 0.1308 - val_accuracy: 0.9594 - val_loss: 0.1516
# Epoch 13/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9638 - loss: 0.1225 - val_accuracy: 0.9594 - val_loss: 0.1513
# Epoch 14/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9664 - loss: 0.1226 - val_accuracy: 0.9594 - val_loss: 0.1521
# Epoch 15/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9670 - loss: 0.1212 - val_accuracy: 0.9561 - val_loss: 0.1508
# Epoch 16/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9635 - loss: 0.1355 - val_accuracy: 0.9569 - val_loss: 0.1511
# Epoch 17/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9630 - loss: 0.1295 - val_accuracy: 0.9577 - val_loss: 0.1518
# Epoch 18/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9625 - loss: 0.1260 - val_accuracy: 0.9577 - val_loss: 0.1515
# Epoch 19/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9637 - loss: 0.1213 - val_accuracy: 0.9569 - val_loss: 0.1511
# Epoch 20/20
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9612 - loss: 0.1304 - val_accuracy: 0.9577 - val_loss: 0.1515
# Score for fold 5: loss of 0.15154938399791718; compile_metrics of 95.77114582061768%
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.11753278225660324 - Accuracy: 96.35459780693054%
# > Fold 2 - Loss: 0.12288542836904526 - Accuracy: 96.27174735069275%
# > Fold 3 - Loss: 0.14325261116027832 - Accuracy: 95.85406184196472%
# > Fold 4 - Loss: 0.13908042013645172 - Accuracy: 96.01989984512329%
# > Fold 5 - Loss: 0.15154938399791718 - Accuracy: 95.77114582061768%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 96.0542905330658 (+- 0.22755970759915048)
# > Loss: 0.13486012518405915
# ------------------------------------------------------------------------

# %%
histories_mnli_matched = cross_validate_attention_lstm_model(X_mnli_matched_rnn, features_mnli_matched, y_encoded_mnli_matched)
# Out:
# Training on fold 1...
# Epoch 1/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.6917 - loss: 0.8260 - val_accuracy: 0.9659 - val_loss: 0.1792
# Epoch 2/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9670 - loss: 0.1568 - val_accuracy: 0.9659 - val_loss: 0.1434
# Epoch 3/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9609 - loss: 0.1611 - val_accuracy: 0.9659 - val_loss: 0.1377
# Epoch 4/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9648 - loss: 0.1423 - val_accuracy: 0.9667 - val_loss: 0.1361
# Epoch 5/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9665 - loss: 0.1327 - val_accuracy: 0.9667 - val_loss: 0.1354
# Epoch 6/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9659 - loss: 0.1357 - val_accuracy: 0.9667 - val_loss: 0.1360
# Epoch 7/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9702 - loss: 0.1190 - val_accuracy: 0.9659 - val_loss: 0.1360
# Epoch 8/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9649 - loss: 0.1355 - val_accuracy: 0.9667 - val_loss: 0.1367
# Epoch 9/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9704 - loss: 0.1222 - val_accuracy: 0.9659 - val_loss: 0.1380
# Epoch 10/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9606 - loss: 0.1339 - val_accuracy: 0.9667 - val_loss: 0.1368
# Epoch 11/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9686 - loss: 0.1267 - val_accuracy: 0.9667 - val_loss: 0.1358
# Epoch 12/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9672 - loss: 0.1266 - val_accuracy: 0.9659 - val_loss: 0.1376
# Epoch 13/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9691 - loss: 0.1255 - val_accuracy: 0.9650 - val_loss: 0.1388
# Epoch 14/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9671 - loss: 0.1248 - val_accuracy: 0.9667 - val_loss: 0.1363
# Epoch 15/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9642 - loss: 0.1341 - val_accuracy: 0.9676 - val_loss: 0.1353
# Epoch 16/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9643 - loss: 0.1463 - val_accuracy: 0.9667 - val_loss: 0.1358
# Epoch 17/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9696 - loss: 0.1216 - val_accuracy: 0.9642 - val_loss: 0.1399
# Epoch 18/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9622 - loss: 0.1433 - val_accuracy: 0.9667 - val_loss: 0.1348
# Epoch 19/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9651 - loss: 0.1314 - val_accuracy: 0.9667 - val_loss: 0.1346
# Epoch 20/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9661 - loss: 0.1326 - val_accuracy: 0.9667 - val_loss: 0.1355
# Score for fold 1: loss of 0.13549590110778809; compile_metrics of 96.67235612869263%
# Training on fold 2...
# Epoch 1/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8197 - loss: 0.7182 - val_accuracy: 0.9633 - val_loss: 0.1772
# Epoch 2/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9622 - loss: 0.1719 - val_accuracy: 0.9633 - val_loss: 0.1540
# Epoch 3/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9656 - loss: 0.1447 - val_accuracy: 0.9633 - val_loss: 0.1481
# Epoch 4/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9637 - loss: 0.1401 - val_accuracy: 0.9633 - val_loss: 0.1455
# Epoch 5/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9609 - loss: 0.1412 - val_accuracy: 0.9624 - val_loss: 0.1448
# Epoch 6/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9636 - loss: 0.1428 - val_accuracy: 0.9641 - val_loss: 0.1437
# Epoch 7/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9674 - loss: 0.1280 - val_accuracy: 0.9650 - val_loss: 0.1428
# Epoch 8/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9689 - loss: 0.1243 - val_accuracy: 0.9658 - val_loss: 0.1429
# Epoch 9/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9646 - loss: 0.1296 - val_accuracy: 0.9641 - val_loss: 0.1437
# Epoch 10/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9668 - loss: 0.1297 - val_accuracy: 0.9650 - val_loss: 0.1433
# Epoch 11/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9648 - loss: 0.1359 - val_accuracy: 0.9658 - val_loss: 0.1424
# Epoch 12/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9695 - loss: 0.1254 - val_accuracy: 0.9650 - val_loss: 0.1417
# Epoch 13/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9689 - loss: 0.1203 - val_accuracy: 0.9641 - val_loss: 0.1431
# Epoch 14/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9676 - loss: 0.1253 - val_accuracy: 0.9641 - val_loss: 0.1424
# Epoch 15/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9684 - loss: 0.1343 - val_accuracy: 0.9650 - val_loss: 0.1417
# Epoch 16/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9652 - loss: 0.1298 - val_accuracy: 0.9658 - val_loss: 0.1421
# Epoch 17/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9666 - loss: 0.1397 - val_accuracy: 0.9641 - val_loss: 0.1431
# Epoch 18/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9655 - loss: 0.1337 - val_accuracy: 0.9641 - val_loss: 0.1423
# Epoch 19/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9689 - loss: 0.1202 - val_accuracy: 0.9641 - val_loss: 0.1428
# Epoch 20/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9662 - loss: 0.1333 - val_accuracy: 0.9658 - val_loss: 0.1410
# Score for fold 2: loss of 0.1409989893436432; compile_metrics of 96.58411741256714%
# Training on fold 3...
# Epoch 1/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8034 - loss: 0.7527 - val_accuracy: 0.9650 - val_loss: 0.1731
# Epoch 2/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9690 - loss: 0.1477 - val_accuracy: 0.9641 - val_loss: 0.1489
# Epoch 3/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9629 - loss: 0.1515 - val_accuracy: 0.9641 - val_loss: 0.1422
# Epoch 4/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9650 - loss: 0.1393 - val_accuracy: 0.9641 - val_loss: 0.1382
# Epoch 5/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9662 - loss: 0.1359 - val_accuracy: 0.9658 - val_loss: 0.1354
# Epoch 6/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9653 - loss: 0.1346 - val_accuracy: 0.9658 - val_loss: 0.1338
# Epoch 7/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9662 - loss: 0.1340 - val_accuracy: 0.9684 - val_loss: 0.1334
# Epoch 8/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9651 - loss: 0.1334 - val_accuracy: 0.9684 - val_loss: 0.1324
# Epoch 9/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9655 - loss: 0.1360 - val_accuracy: 0.9684 - val_loss: 0.1323
# Epoch 10/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9599 - loss: 0.1526 - val_accuracy: 0.9684 - val_loss: 0.1325
# Epoch 11/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9663 - loss: 0.1281 - val_accuracy: 0.9684 - val_loss: 0.1315
# Epoch 12/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9683 - loss: 0.1215 - val_accuracy: 0.9684 - val_loss: 0.1313
# Epoch 13/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9661 - loss: 0.1270 - val_accuracy: 0.9684 - val_loss: 0.1313
# Epoch 14/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9702 - loss: 0.1218 - val_accuracy: 0.9684 - val_loss: 0.1311
# Epoch 15/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9646 - loss: 0.1377 - val_accuracy: 0.9684 - val_loss: 0.1310
# Epoch 16/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9665 - loss: 0.1286 - val_accuracy: 0.9684 - val_loss: 0.1311
# Epoch 17/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9662 - loss: 0.1324 - val_accuracy: 0.9675 - val_loss: 0.1316
# Epoch 18/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9646 - loss: 0.1332 - val_accuracy: 0.9684 - val_loss: 0.1308
# Epoch 19/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9648 - loss: 0.1431 - val_accuracy: 0.9684 - val_loss: 0.1309
# Epoch 20/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9644 - loss: 0.1348 - val_accuracy: 0.9684 - val_loss: 0.1306
# Score for fold 3: loss of 0.1306016445159912; compile_metrics of 96.84031009674072%
# Training on fold 4...
# Epoch 1/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7060 - loss: 0.7934 - val_accuracy: 0.9650 - val_loss: 0.1723
# Epoch 2/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9637 - loss: 0.1674 - val_accuracy: 0.9658 - val_loss: 0.1424
# Epoch 3/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9595 - loss: 0.1620 - val_accuracy: 0.9658 - val_loss: 0.1356
# Epoch 4/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9651 - loss: 0.1314 - val_accuracy: 0.9650 - val_loss: 0.1323
# Epoch 5/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9647 - loss: 0.1427 - val_accuracy: 0.9658 - val_loss: 0.1322
# Epoch 6/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9672 - loss: 0.1254 - val_accuracy: 0.9667 - val_loss: 0.1304
# Epoch 7/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9656 - loss: 0.1323 - val_accuracy: 0.9667 - val_loss: 0.1303
# Epoch 8/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9684 - loss: 0.1215 - val_accuracy: 0.9667 - val_loss: 0.1297
# Epoch 9/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9656 - loss: 0.1336 - val_accuracy: 0.9658 - val_loss: 0.1297
# Epoch 10/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9722 - loss: 0.1108 - val_accuracy: 0.9675 - val_loss: 0.1296
# Epoch 11/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9651 - loss: 0.1339 - val_accuracy: 0.9667 - val_loss: 0.1289
# Epoch 12/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9659 - loss: 0.1325 - val_accuracy: 0.9667 - val_loss: 0.1294
# Epoch 13/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9655 - loss: 0.1328 - val_accuracy: 0.9667 - val_loss: 0.1288
# Epoch 14/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9655 - loss: 0.1355 - val_accuracy: 0.9658 - val_loss: 0.1299
# Epoch 15/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9670 - loss: 0.1332 - val_accuracy: 0.9667 - val_loss: 0.1292
# Epoch 16/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9675 - loss: 0.1299 - val_accuracy: 0.9658 - val_loss: 0.1298
# Epoch 17/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9714 - loss: 0.1194 - val_accuracy: 0.9667 - val_loss: 0.1285
# Epoch 18/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9670 - loss: 0.1264 - val_accuracy: 0.9667 - val_loss: 0.1288
# Epoch 19/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9675 - loss: 0.1297 - val_accuracy: 0.9658 - val_loss: 0.1303
# Epoch 20/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9670 - loss: 0.1321 - val_accuracy: 0.9658 - val_loss: 0.1305
# Score for fold 4: loss of 0.13046538829803467; compile_metrics of 96.58411741256714%
# Training on fold 5...
# Epoch 1/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8328 - loss: 0.7367 - val_accuracy: 0.9675 - val_loss: 0.1655
# Epoch 2/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9633 - loss: 0.1668 - val_accuracy: 0.9675 - val_loss: 0.1337
# Epoch 3/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9607 - loss: 0.1596 - val_accuracy: 0.9675 - val_loss: 0.1262
# Epoch 4/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9659 - loss: 0.1329 - val_accuracy: 0.9675 - val_loss: 0.1245
# Epoch 5/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9661 - loss: 0.1319 - val_accuracy: 0.9667 - val_loss: 0.1244
# Epoch 6/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9638 - loss: 0.1361 - val_accuracy: 0.9667 - val_loss: 0.1246
# Epoch 7/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9692 - loss: 0.1262 - val_accuracy: 0.9667 - val_loss: 0.1263
# Epoch 8/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9644 - loss: 0.1409 - val_accuracy: 0.9667 - val_loss: 0.1250
# Epoch 9/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9709 - loss: 0.1236 - val_accuracy: 0.9667 - val_loss: 0.1253
# Epoch 10/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9636 - loss: 0.1376 - val_accuracy: 0.9658 - val_loss: 0.1257
# Epoch 11/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9683 - loss: 0.1294 - val_accuracy: 0.9667 - val_loss: 0.1264
# Epoch 12/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9637 - loss: 0.1399 - val_accuracy: 0.9667 - val_loss: 0.1256
# Epoch 13/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9644 - loss: 0.1406 - val_accuracy: 0.9675 - val_loss: 0.1255
# Epoch 14/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9640 - loss: 0.1409 - val_accuracy: 0.9658 - val_loss: 0.1246
# Epoch 15/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9657 - loss: 0.1334 - val_accuracy: 0.9667 - val_loss: 0.1245
# Epoch 16/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9696 - loss: 0.1268 - val_accuracy: 0.9667 - val_loss: 0.1247
# Epoch 17/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9647 - loss: 0.1423 - val_accuracy: 0.9675 - val_loss: 0.1253
# Epoch 18/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9647 - loss: 0.1398 - val_accuracy: 0.9675 - val_loss: 0.1243
# Epoch 19/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9655 - loss: 0.1336 - val_accuracy: 0.9667 - val_loss: 0.1247
# Epoch 20/20
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9691 - loss: 0.1391 - val_accuracy: 0.9667 - val_loss: 0.1245
# Score for fold 5: loss of 0.12447082996368408; compile_metrics of 96.66951298713684%
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.13549590110778809 - Accuracy: 96.67235612869263%
# > Fold 2 - Loss: 0.1409989893436432 - Accuracy: 96.58411741256714%
# > Fold 3 - Loss: 0.1306016445159912 - Accuracy: 96.84031009674072%
# > Fold 4 - Loss: 0.13046538829803467 - Accuracy: 96.58411741256714%
# > Fold 5 - Loss: 0.12447082996368408 - Accuracy: 96.66951298713684%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 96.6700828075409 (+- 0.0935552467140795)
# > Loss: 0.13240655064582824
# ------------------------------------------------------------------------

# %%
histories_mnli_mismatched = cross_validate_attention_lstm_model(X_mnli_mismatched_rnn, features_mnli_mismatched, y_encoded_mnli_mismatched)
# Out:
# Training on fold 1...
# Epoch 1/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9288 - loss: 0.6815 - val_accuracy: 0.9645 - val_loss: 0.1689
# Epoch 2/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9645 - loss: 0.1542 - val_accuracy: 0.9645 - val_loss: 0.1444
# Epoch 3/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9676 - loss: 0.1279 - val_accuracy: 0.9645 - val_loss: 0.1378
# Epoch 4/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9676 - loss: 0.1198 - val_accuracy: 0.9653 - val_loss: 0.1348
# Epoch 5/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9645 - loss: 0.1231 - val_accuracy: 0.9670 - val_loss: 0.1337
# Epoch 6/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9621 - loss: 0.1325 - val_accuracy: 0.9653 - val_loss: 0.1364
# Epoch 7/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9671 - loss: 0.1184 - val_accuracy: 0.9662 - val_loss: 0.1338
# Epoch 8/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9649 - loss: 0.1293 - val_accuracy: 0.9645 - val_loss: 0.1355
# Epoch 9/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9682 - loss: 0.1148 - val_accuracy: 0.9628 - val_loss: 0.1334
# Epoch 10/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9636 - loss: 0.1258 - val_accuracy: 0.9653 - val_loss: 0.1355
# Epoch 11/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9644 - loss: 0.1356 - val_accuracy: 0.9619 - val_loss: 0.1331
# Epoch 12/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9645 - loss: 0.1257 - val_accuracy: 0.9628 - val_loss: 0.1335
# Epoch 13/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9634 - loss: 0.1220 - val_accuracy: 0.9628 - val_loss: 0.1328
# Epoch 14/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9691 - loss: 0.1118 - val_accuracy: 0.9645 - val_loss: 0.1342
# Epoch 15/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9647 - loss: 0.1240 - val_accuracy: 0.9628 - val_loss: 0.1327
# Epoch 16/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9658 - loss: 0.1141 - val_accuracy: 0.9628 - val_loss: 0.1332
# Epoch 17/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9675 - loss: 0.1166 - val_accuracy: 0.9636 - val_loss: 0.1349
# Epoch 18/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9671 - loss: 0.1109 - val_accuracy: 0.9628 - val_loss: 0.1327
# Epoch 19/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9673 - loss: 0.1087 - val_accuracy: 0.9619 - val_loss: 0.1320
# Epoch 20/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9651 - loss: 0.1145 - val_accuracy: 0.9628 - val_loss: 0.1340
# Score for fold 1: loss of 0.13401083648204803; compile_metrics of 96.2774932384491%
# Training on fold 2...
# Epoch 1/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8535 - loss: 0.7057 - val_accuracy: 0.9679 - val_loss: 0.1613
# Epoch 2/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9630 - loss: 0.1646 - val_accuracy: 0.9679 - val_loss: 0.1299
# Epoch 3/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9618 - loss: 0.1504 - val_accuracy: 0.9679 - val_loss: 0.1212
# Epoch 4/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9652 - loss: 0.1346 - val_accuracy: 0.9679 - val_loss: 0.1167
# Epoch 5/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9715 - loss: 0.1123 - val_accuracy: 0.9679 - val_loss: 0.1147
# Epoch 6/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9669 - loss: 0.1233 - val_accuracy: 0.9679 - val_loss: 0.1137
# Epoch 7/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9658 - loss: 0.1243 - val_accuracy: 0.9695 - val_loss: 0.1136
# Epoch 8/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9647 - loss: 0.1244 - val_accuracy: 0.9679 - val_loss: 0.1139
# Epoch 9/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9678 - loss: 0.1217 - val_accuracy: 0.9662 - val_loss: 0.1131
# Epoch 10/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9671 - loss: 0.1232 - val_accuracy: 0.9695 - val_loss: 0.1121
# Epoch 11/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9698 - loss: 0.1065 - val_accuracy: 0.9645 - val_loss: 0.1131
# Epoch 12/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9675 - loss: 0.1186 - val_accuracy: 0.9662 - val_loss: 0.1125
# Epoch 13/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9637 - loss: 0.1200 - val_accuracy: 0.9662 - val_loss: 0.1122
# Epoch 14/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9669 - loss: 0.1174 - val_accuracy: 0.9662 - val_loss: 0.1113
# Epoch 15/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9627 - loss: 0.1280 - val_accuracy: 0.9653 - val_loss: 0.1118
# Epoch 16/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9622 - loss: 0.1342 - val_accuracy: 0.9704 - val_loss: 0.1106
# Epoch 17/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9608 - loss: 0.1297 - val_accuracy: 0.9695 - val_loss: 0.1107
# Epoch 18/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9677 - loss: 0.1128 - val_accuracy: 0.9670 - val_loss: 0.1112
# Epoch 19/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9659 - loss: 0.1181 - val_accuracy: 0.9695 - val_loss: 0.1106
# Epoch 20/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9682 - loss: 0.1105 - val_accuracy: 0.9670 - val_loss: 0.1118
# Score for fold 2: loss of 0.11183380335569382; compile_metrics of 96.70050740242004%
# Training on fold 3...
# Epoch 1/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8738 - loss: 0.7210 - val_accuracy: 0.9662 - val_loss: 0.1677
# Epoch 2/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9687 - loss: 0.1499 - val_accuracy: 0.9670 - val_loss: 0.1367
# Epoch 3/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9671 - loss: 0.1307 - val_accuracy: 0.9662 - val_loss: 0.1289
# Epoch 4/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9657 - loss: 0.1279 - val_accuracy: 0.9662 - val_loss: 0.1247
# Epoch 5/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9646 - loss: 0.1283 - val_accuracy: 0.9670 - val_loss: 0.1259
# Epoch 6/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9677 - loss: 0.1135 - val_accuracy: 0.9670 - val_loss: 0.1252
# Epoch 7/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9692 - loss: 0.1187 - val_accuracy: 0.9679 - val_loss: 0.1243
# Epoch 8/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9604 - loss: 0.1398 - val_accuracy: 0.9670 - val_loss: 0.1265
# Epoch 9/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9671 - loss: 0.1203 - val_accuracy: 0.9679 - val_loss: 0.1244
# Epoch 10/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9658 - loss: 0.1258 - val_accuracy: 0.9679 - val_loss: 0.1270
# Epoch 11/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9641 - loss: 0.1187 - val_accuracy: 0.9679 - val_loss: 0.1233
# Epoch 12/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9644 - loss: 0.1259 - val_accuracy: 0.9670 - val_loss: 0.1245
# Epoch 13/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9665 - loss: 0.1234 - val_accuracy: 0.9679 - val_loss: 0.1242
# Epoch 14/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9661 - loss: 0.1171 - val_accuracy: 0.9679 - val_loss: 0.1239
# Epoch 15/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9662 - loss: 0.1190 - val_accuracy: 0.9679 - val_loss: 0.1241
# Epoch 16/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9664 - loss: 0.1198 - val_accuracy: 0.9679 - val_loss: 0.1224
# Epoch 17/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9641 - loss: 0.1296 - val_accuracy: 0.9687 - val_loss: 0.1238
# Epoch 18/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9649 - loss: 0.1223 - val_accuracy: 0.9670 - val_loss: 0.1216
# Epoch 19/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9652 - loss: 0.1126 - val_accuracy: 0.9679 - val_loss: 0.1219
# Epoch 20/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9632 - loss: 0.1199 - val_accuracy: 0.9670 - val_loss: 0.1246
# Score for fold 3: loss of 0.12463667243719101; compile_metrics of 96.70050740242004%
# Training on fold 4...
# Epoch 1/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7941 - loss: 0.7575 - val_accuracy: 0.9679 - val_loss: 0.1682
# Epoch 2/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9685 - loss: 0.1490 - val_accuracy: 0.9679 - val_loss: 0.1333
# Epoch 3/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9654 - loss: 0.1388 - val_accuracy: 0.9679 - val_loss: 0.1250
# Epoch 4/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9690 - loss: 0.1168 - val_accuracy: 0.9670 - val_loss: 0.1214
# Epoch 5/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9637 - loss: 0.1322 - val_accuracy: 0.9662 - val_loss: 0.1197
# Epoch 6/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9709 - loss: 0.1137 - val_accuracy: 0.9662 - val_loss: 0.1199
# Epoch 7/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9681 - loss: 0.1308 - val_accuracy: 0.9662 - val_loss: 0.1194
# Epoch 8/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9695 - loss: 0.1109 - val_accuracy: 0.9645 - val_loss: 0.1193
# Epoch 9/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9709 - loss: 0.1119 - val_accuracy: 0.9645 - val_loss: 0.1195
# Epoch 10/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9678 - loss: 0.1137 - val_accuracy: 0.9636 - val_loss: 0.1197
# Epoch 11/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9689 - loss: 0.1175 - val_accuracy: 0.9636 - val_loss: 0.1187
# Epoch 12/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9651 - loss: 0.1225 - val_accuracy: 0.9636 - val_loss: 0.1186
# Epoch 13/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9685 - loss: 0.1155 - val_accuracy: 0.9636 - val_loss: 0.1189
# Epoch 14/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9675 - loss: 0.1193 - val_accuracy: 0.9645 - val_loss: 0.1181
# Epoch 15/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9644 - loss: 0.1188 - val_accuracy: 0.9645 - val_loss: 0.1189
# Epoch 16/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9647 - loss: 0.1264 - val_accuracy: 0.9662 - val_loss: 0.1183
# Epoch 17/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9670 - loss: 0.1128 - val_accuracy: 0.9645 - val_loss: 0.1179
# Epoch 18/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9656 - loss: 0.1180 - val_accuracy: 0.9645 - val_loss: 0.1179
# Epoch 19/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9683 - loss: 0.1129 - val_accuracy: 0.9645 - val_loss: 0.1182
# Epoch 20/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9671 - loss: 0.1249 - val_accuracy: 0.9653 - val_loss: 0.1194
# Score for fold 4: loss of 0.11938775330781937; compile_metrics of 96.53130173683167%
# Training on fold 5...
# Epoch 1/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8220 - loss: 0.7282 - val_accuracy: 0.9653 - val_loss: 0.1663
# Epoch 2/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9690 - loss: 0.1463 - val_accuracy: 0.9653 - val_loss: 0.1353
# Epoch 3/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9655 - loss: 0.1435 - val_accuracy: 0.9653 - val_loss: 0.1259
# Epoch 4/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9690 - loss: 0.1228 - val_accuracy: 0.9653 - val_loss: 0.1206
# Epoch 5/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9647 - loss: 0.1344 - val_accuracy: 0.9662 - val_loss: 0.1190
# Epoch 6/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9662 - loss: 0.1266 - val_accuracy: 0.9645 - val_loss: 0.1177
# Epoch 7/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9670 - loss: 0.1274 - val_accuracy: 0.9645 - val_loss: 0.1173
# Epoch 8/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9640 - loss: 0.1330 - val_accuracy: 0.9636 - val_loss: 0.1169
# Epoch 9/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9656 - loss: 0.1261 - val_accuracy: 0.9636 - val_loss: 0.1176
# Epoch 10/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9666 - loss: 0.1268 - val_accuracy: 0.9628 - val_loss: 0.1175
# Epoch 11/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9666 - loss: 0.1228 - val_accuracy: 0.9636 - val_loss: 0.1171
# Epoch 12/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9685 - loss: 0.1153 - val_accuracy: 0.9636 - val_loss: 0.1175
# Epoch 13/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9643 - loss: 0.1342 - val_accuracy: 0.9636 - val_loss: 0.1176
# Epoch 14/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9636 - loss: 0.1340 - val_accuracy: 0.9636 - val_loss: 0.1179
# Epoch 15/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9722 - loss: 0.1112 - val_accuracy: 0.9645 - val_loss: 0.1196
# Epoch 16/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9682 - loss: 0.1127 - val_accuracy: 0.9636 - val_loss: 0.1176
# Epoch 17/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9674 - loss: 0.1240 - val_accuracy: 0.9636 - val_loss: 0.1175
# Epoch 18/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9643 - loss: 0.1220 - val_accuracy: 0.9636 - val_loss: 0.1177
# Epoch 19/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9655 - loss: 0.1188 - val_accuracy: 0.9636 - val_loss: 0.1196
# Epoch 20/20
# 148/148 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9674 - loss: 0.1189 - val_accuracy: 0.9645 - val_loss: 0.1181
# Score for fold 5: loss of 0.11807266622781754; compile_metrics of 96.44669890403748%
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.13401083648204803 - Accuracy: 96.2774932384491%
# > Fold 2 - Loss: 0.11183380335569382 - Accuracy: 96.70050740242004%
# > Fold 3 - Loss: 0.12463667243719101 - Accuracy: 96.70050740242004%
# > Fold 4 - Loss: 0.11938775330781937 - Accuracy: 96.53130173683167%
# > Fold 5 - Loss: 0.11807266622781754 - Accuracy: 96.44669890403748%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 96.53130173683167 (+- 0.16052258887921564)
# > Loss: 0.12158834636211395
# ------------------------------------------------------------------------

# %%
histories_anli_r1 = cross_validate_attention_lstm_model(X_anli_r1_rnn, features_anli_r1, y_encoded_anli_r1)
# Out:
# Training on fold 1...
# Epoch 1/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.4597 - loss: 1.0770 - val_accuracy: 0.6860 - val_loss: 1.0331
# Epoch 2/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6015 - loss: 1.0316 - val_accuracy: 0.6047 - val_loss: 0.9744
# Epoch 3/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6031 - loss: 0.9740 - val_accuracy: 0.6163 - val_loss: 0.9200
# Epoch 4/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6449 - loss: 0.9149 - val_accuracy: 0.5814 - val_loss: 0.8694
# Epoch 5/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6707 - loss: 0.8444 - val_accuracy: 0.5930 - val_loss: 0.8207
# Epoch 6/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6705 - loss: 0.8150 - val_accuracy: 0.6512 - val_loss: 0.7728
# Epoch 7/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6821 - loss: 0.7716 - val_accuracy: 0.6977 - val_loss: 0.7281
# Epoch 8/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7536 - loss: 0.6978 - val_accuracy: 0.7558 - val_loss: 0.6842
# Epoch 9/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7747 - loss: 0.6794 - val_accuracy: 0.7558 - val_loss: 0.6486
# Epoch 10/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7965 - loss: 0.6275 - val_accuracy: 0.7674 - val_loss: 0.6154
# Epoch 11/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7747 - loss: 0.6283 - val_accuracy: 0.7674 - val_loss: 0.5901
# Epoch 12/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7910 - loss: 0.6051 - val_accuracy: 0.7674 - val_loss: 0.5671
# Epoch 13/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8305 - loss: 0.5005 - val_accuracy: 0.7674 - val_loss: 0.5476
# Epoch 14/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8147 - loss: 0.5372 - val_accuracy: 0.7674 - val_loss: 0.5335
# Epoch 15/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7711 - loss: 0.5723 - val_accuracy: 0.7907 - val_loss: 0.5221
# Epoch 16/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8174 - loss: 0.5004 - val_accuracy: 0.7907 - val_loss: 0.5125
# Epoch 17/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8440 - loss: 0.4869 - val_accuracy: 0.7907 - val_loss: 0.5061
# Epoch 18/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8445 - loss: 0.4400 - val_accuracy: 0.7791 - val_loss: 0.5018
# Epoch 19/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8089 - loss: 0.5564 - val_accuracy: 0.7791 - val_loss: 0.5004
# Epoch 20/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8383 - loss: 0.4823 - val_accuracy: 0.7791 - val_loss: 0.5004
# Score for fold 1: loss of 0.5004295110702515; compile_metrics of 77.90697813034058%
# Training on fold 2...
# Epoch 1/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.3461 - loss: 1.1270 - val_accuracy: 0.5765 - val_loss: 1.0725
# Epoch 2/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5775 - loss: 1.0490 - val_accuracy: 0.6706 - val_loss: 1.0128
# Epoch 3/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7177 - loss: 0.9892 - val_accuracy: 0.6706 - val_loss: 0.9585
# Epoch 4/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6742 - loss: 0.9418 - val_accuracy: 0.6824 - val_loss: 0.9084
# Epoch 5/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7031 - loss: 0.8964 - val_accuracy: 0.6706 - val_loss: 0.8583
# Epoch 6/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7590 - loss: 0.8123 - val_accuracy: 0.6706 - val_loss: 0.8097
# Epoch 7/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7229 - loss: 0.7786 - val_accuracy: 0.6706 - val_loss: 0.7648
# Epoch 8/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7545 - loss: 0.7102 - val_accuracy: 0.6824 - val_loss: 0.7232
# Epoch 9/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7331 - loss: 0.6937 - val_accuracy: 0.7412 - val_loss: 0.6911
# Epoch 10/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7805 - loss: 0.6537 - val_accuracy: 0.7529 - val_loss: 0.6624
# Epoch 11/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7562 - loss: 0.6392 - val_accuracy: 0.7529 - val_loss: 0.6389
# Epoch 12/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7793 - loss: 0.6149 - val_accuracy: 0.7647 - val_loss: 0.6220
# Epoch 13/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8004 - loss: 0.5591 - val_accuracy: 0.7765 - val_loss: 0.6073
# Epoch 14/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7914 - loss: 0.5365 - val_accuracy: 0.7765 - val_loss: 0.5932
# Epoch 15/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7972 - loss: 0.5357 - val_accuracy: 0.7765 - val_loss: 0.5826
# Epoch 16/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7860 - loss: 0.5206 - val_accuracy: 0.8000 - val_loss: 0.5767
# Epoch 17/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7495 - loss: 0.5569 - val_accuracy: 0.7882 - val_loss: 0.5721
# Epoch 18/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7944 - loss: 0.5290 - val_accuracy: 0.7882 - val_loss: 0.5661
# Epoch 19/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7851 - loss: 0.5483 - val_accuracy: 0.8000 - val_loss: 0.5602
# Epoch 20/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7858 - loss: 0.5536 - val_accuracy: 0.7882 - val_loss: 0.5566
# Score for fold 2: loss of 0.5566102266311646; compile_metrics of 78.82353067398071%
# Training on fold 3...
# Epoch 1/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.4201 - loss: 1.0715 - val_accuracy: 0.6118 - val_loss: 1.0140
# Epoch 2/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6355 - loss: 1.0007 - val_accuracy: 0.6588 - val_loss: 0.9618
# Epoch 3/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6121 - loss: 0.9671 - val_accuracy: 0.6706 - val_loss: 0.9127
# Epoch 4/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5950 - loss: 0.9212 - val_accuracy: 0.6471 - val_loss: 0.8628
# Epoch 5/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6917 - loss: 0.8351 - val_accuracy: 0.6941 - val_loss: 0.8127
# Epoch 6/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6324 - loss: 0.8254 - val_accuracy: 0.7176 - val_loss: 0.7642
# Epoch 7/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7153 - loss: 0.7332 - val_accuracy: 0.7529 - val_loss: 0.7176
# Epoch 8/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7084 - loss: 0.7107 - val_accuracy: 0.7882 - val_loss: 0.6752
# Epoch 9/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7751 - loss: 0.6794 - val_accuracy: 0.7882 - val_loss: 0.6406
# Epoch 10/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7903 - loss: 0.6249 - val_accuracy: 0.7882 - val_loss: 0.6091
# Epoch 11/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8207 - loss: 0.5931 - val_accuracy: 0.7765 - val_loss: 0.5841
# Epoch 12/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7865 - loss: 0.6108 - val_accuracy: 0.7765 - val_loss: 0.5634
# Epoch 13/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8480 - loss: 0.5145 - val_accuracy: 0.7647 - val_loss: 0.5483
# Epoch 14/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8147 - loss: 0.5391 - val_accuracy: 0.7647 - val_loss: 0.5368
# Epoch 15/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8069 - loss: 0.5740 - val_accuracy: 0.7647 - val_loss: 0.5279
# Epoch 16/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8355 - loss: 0.4926 - val_accuracy: 0.7647 - val_loss: 0.5209
# Epoch 17/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8326 - loss: 0.5217 - val_accuracy: 0.7647 - val_loss: 0.5162
# Epoch 18/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8242 - loss: 0.4955 - val_accuracy: 0.7647 - val_loss: 0.5125
# Epoch 19/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8285 - loss: 0.4821 - val_accuracy: 0.7765 - val_loss: 0.5110
# Epoch 20/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8327 - loss: 0.4964 - val_accuracy: 0.7765 - val_loss: 0.5075
# Score for fold 3: loss of 0.5075368881225586; compile_metrics of 77.64706015586853%
# Training on fold 4...
# Epoch 1/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.4357 - loss: 1.0974 - val_accuracy: 0.4353 - val_loss: 1.0619
# Epoch 2/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4773 - loss: 1.0434 - val_accuracy: 0.5529 - val_loss: 1.0118
# Epoch 3/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6119 - loss: 0.9787 - val_accuracy: 0.5765 - val_loss: 0.9629
# Epoch 4/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6569 - loss: 0.9395 - val_accuracy: 0.7176 - val_loss: 0.9141
# Epoch 5/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7308 - loss: 0.8924 - val_accuracy: 0.7529 - val_loss: 0.8637
# Epoch 6/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7162 - loss: 0.8404 - val_accuracy: 0.7882 - val_loss: 0.8129
# Epoch 7/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7560 - loss: 0.7877 - val_accuracy: 0.7882 - val_loss: 0.7648
# Epoch 8/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7571 - loss: 0.7449 - val_accuracy: 0.8000 - val_loss: 0.7194
# Epoch 9/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7723 - loss: 0.6915 - val_accuracy: 0.8118 - val_loss: 0.6788
# Epoch 10/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8168 - loss: 0.6222 - val_accuracy: 0.8118 - val_loss: 0.6455
# Epoch 11/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7832 - loss: 0.6233 - val_accuracy: 0.7765 - val_loss: 0.6198
# Epoch 12/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8118 - loss: 0.5697 - val_accuracy: 0.7882 - val_loss: 0.5996
# Epoch 13/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8003 - loss: 0.5513 - val_accuracy: 0.8000 - val_loss: 0.5854
# Epoch 14/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8172 - loss: 0.5312 - val_accuracy: 0.7882 - val_loss: 0.5761
# Epoch 15/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8096 - loss: 0.5222 - val_accuracy: 0.7882 - val_loss: 0.5691
# Epoch 16/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8411 - loss: 0.4571 - val_accuracy: 0.7765 - val_loss: 0.5656
# Epoch 17/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7874 - loss: 0.5282 - val_accuracy: 0.7765 - val_loss: 0.5625
# Epoch 18/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8296 - loss: 0.5070 - val_accuracy: 0.7882 - val_loss: 0.5610
# Epoch 19/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8027 - loss: 0.5538 - val_accuracy: 0.7882 - val_loss: 0.5601
# Epoch 20/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8245 - loss: 0.4754 - val_accuracy: 0.7882 - val_loss: 0.5611
# Score for fold 4: loss of 0.5610843300819397; compile_metrics of 78.82353067398071%
# Training on fold 5...
# Epoch 1/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.3006 - loss: 1.1407 - val_accuracy: 0.3412 - val_loss: 1.0650
# Epoch 2/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3492 - loss: 1.0654 - val_accuracy: 0.4588 - val_loss: 0.9995
# Epoch 3/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5288 - loss: 0.9900 - val_accuracy: 0.7294 - val_loss: 0.9388
# Epoch 4/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7126 - loss: 0.9414 - val_accuracy: 0.7765 - val_loss: 0.8817
# Epoch 5/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7483 - loss: 0.8639 - val_accuracy: 0.7882 - val_loss: 0.8247
# Epoch 6/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7649 - loss: 0.8221 - val_accuracy: 0.8000 - val_loss: 0.7710
# Epoch 7/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7294 - loss: 0.7945 - val_accuracy: 0.8353 - val_loss: 0.7197
# Epoch 8/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7900 - loss: 0.7229 - val_accuracy: 0.8353 - val_loss: 0.6693
# Epoch 9/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7796 - loss: 0.6781 - val_accuracy: 0.8353 - val_loss: 0.6245
# Epoch 10/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7617 - loss: 0.6637 - val_accuracy: 0.8353 - val_loss: 0.5884
# Epoch 11/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7813 - loss: 0.6220 - val_accuracy: 0.8471 - val_loss: 0.5572
# Epoch 12/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7710 - loss: 0.5993 - val_accuracy: 0.8471 - val_loss: 0.5319
# Epoch 13/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7496 - loss: 0.6228 - val_accuracy: 0.8471 - val_loss: 0.5127
# Epoch 14/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8073 - loss: 0.5607 - val_accuracy: 0.8353 - val_loss: 0.4979
# Epoch 15/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8154 - loss: 0.5066 - val_accuracy: 0.8235 - val_loss: 0.4857
# Epoch 16/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8167 - loss: 0.5205 - val_accuracy: 0.8118 - val_loss: 0.4773
# Epoch 17/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7915 - loss: 0.5707 - val_accuracy: 0.8353 - val_loss: 0.4730
# Epoch 18/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8136 - loss: 0.5375 - val_accuracy: 0.8353 - val_loss: 0.4702
# Epoch 19/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7911 - loss: 0.5118 - val_accuracy: 0.8353 - val_loss: 0.4680
# Epoch 20/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7745 - loss: 0.5585 - val_accuracy: 0.8353 - val_loss: 0.4663
# Score for fold 5: loss of 0.466293603181839; compile_metrics of 83.52941274642944%
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.5004295110702515 - Accuracy: 77.90697813034058%
# > Fold 2 - Loss: 0.5566102266311646 - Accuracy: 78.82353067398071%
# > Fold 3 - Loss: 0.5075368881225586 - Accuracy: 77.64706015586853%
# > Fold 4 - Loss: 0.5610843300819397 - Accuracy: 78.82353067398071%
# > Fold 5 - Loss: 0.466293603181839 - Accuracy: 83.52941274642944%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 79.34610247612 (+- 2.1449508657812757)
# > Loss: 0.5183909118175507
# ------------------------------------------------------------------------

# %%
histories_anli_r2 = cross_validate_attention_lstm_model(X_anli_r2_rnn, features_anli_r2, y_encoded_anli_r2)
# Out:
# Training on fold 1...
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.3443 - loss: 1.1048 - val_accuracy: 0.7079 - val_loss: 1.0739
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5344 - loss: 1.0643 - val_accuracy: 0.6629 - val_loss: 1.0283
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5921 - loss: 1.0278 - val_accuracy: 0.6742 - val_loss: 0.9858
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6455 - loss: 0.9889 - val_accuracy: 0.6629 - val_loss: 0.9412
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6012 - loss: 0.9692 - val_accuracy: 0.6742 - val_loss: 0.8964
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6916 - loss: 0.8937 - val_accuracy: 0.6854 - val_loss: 0.8505
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6713 - loss: 0.8888 - val_accuracy: 0.6854 - val_loss: 0.8068
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6650 - loss: 0.8621 - val_accuracy: 0.6854 - val_loss: 0.7649
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6731 - loss: 0.8266 - val_accuracy: 0.6854 - val_loss: 0.7271
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6851 - loss: 0.7917 - val_accuracy: 0.7191 - val_loss: 0.6992
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7043 - loss: 0.7769 - val_accuracy: 0.7191 - val_loss: 0.6768
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7164 - loss: 0.7366 - val_accuracy: 0.7416 - val_loss: 0.6609
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7209 - loss: 0.7337 - val_accuracy: 0.7303 - val_loss: 0.6480
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7332 - loss: 0.7226 - val_accuracy: 0.7528 - val_loss: 0.6358
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7264 - loss: 0.7380 - val_accuracy: 0.7640 - val_loss: 0.6280
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7166 - loss: 0.7120 - val_accuracy: 0.7753 - val_loss: 0.6167
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7658 - loss: 0.6645 - val_accuracy: 0.7753 - val_loss: 0.6078
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7361 - loss: 0.6925 - val_accuracy: 0.7753 - val_loss: 0.6002
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7112 - loss: 0.7390 - val_accuracy: 0.7753 - val_loss: 0.5938
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7426 - loss: 0.6956 - val_accuracy: 0.7753 - val_loss: 0.5890
# Score for fold 1: loss of 0.5890011191368103; compile_metrics of 77.52808928489685%
# Training on fold 2...
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.3837 - loss: 1.0953 - val_accuracy: 0.4944 - val_loss: 1.0677
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5202 - loss: 1.0542 - val_accuracy: 0.5393 - val_loss: 1.0325
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5149 - loss: 1.0295 - val_accuracy: 0.5618 - val_loss: 0.9988
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5938 - loss: 0.9863 - val_accuracy: 0.5955 - val_loss: 0.9633
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5897 - loss: 0.9579 - val_accuracy: 0.6629 - val_loss: 0.9277
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6342 - loss: 0.9008 - val_accuracy: 0.6517 - val_loss: 0.8910
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6792 - loss: 0.8574 - val_accuracy: 0.6629 - val_loss: 0.8552
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6450 - loss: 0.8483 - val_accuracy: 0.6742 - val_loss: 0.8247
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6719 - loss: 0.8030 - val_accuracy: 0.6854 - val_loss: 0.7960
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6528 - loss: 0.8011 - val_accuracy: 0.6742 - val_loss: 0.7725
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6765 - loss: 0.7815 - val_accuracy: 0.6629 - val_loss: 0.7543
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7239 - loss: 0.7172 - val_accuracy: 0.6854 - val_loss: 0.7382
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7108 - loss: 0.7646 - val_accuracy: 0.6966 - val_loss: 0.7276
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7078 - loss: 0.7328 - val_accuracy: 0.6854 - val_loss: 0.7162
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7417 - loss: 0.7065 - val_accuracy: 0.6742 - val_loss: 0.7118
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7331 - loss: 0.6872 - val_accuracy: 0.6854 - val_loss: 0.7038
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7373 - loss: 0.7103 - val_accuracy: 0.7191 - val_loss: 0.6981
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7341 - loss: 0.6911 - val_accuracy: 0.7079 - val_loss: 0.6934
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7637 - loss: 0.6371 - val_accuracy: 0.7416 - val_loss: 0.6860
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7325 - loss: 0.6926 - val_accuracy: 0.7303 - val_loss: 0.6814
# Score for fold 2: loss of 0.6814163327217102; compile_metrics of 73.03370833396912%
# Training on fold 3...
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.2731 - loss: 1.1080 - val_accuracy: 0.5730 - val_loss: 1.0585
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5272 - loss: 1.0543 - val_accuracy: 0.6067 - val_loss: 1.0156
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5863 - loss: 1.0176 - val_accuracy: 0.6629 - val_loss: 0.9789
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5846 - loss: 0.9825 - val_accuracy: 0.6517 - val_loss: 0.9438
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6085 - loss: 0.9512 - val_accuracy: 0.6517 - val_loss: 0.9100
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6239 - loss: 0.9091 - val_accuracy: 0.6742 - val_loss: 0.8745
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6217 - loss: 0.8869 - val_accuracy: 0.6742 - val_loss: 0.8434
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6776 - loss: 0.8344 - val_accuracy: 0.6854 - val_loss: 0.8149
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6666 - loss: 0.7959 - val_accuracy: 0.6854 - val_loss: 0.7884
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6656 - loss: 0.7582 - val_accuracy: 0.6966 - val_loss: 0.7671
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6670 - loss: 0.7589 - val_accuracy: 0.7079 - val_loss: 0.7537
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6917 - loss: 0.7418 - val_accuracy: 0.7079 - val_loss: 0.7469
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7079 - loss: 0.7362 - val_accuracy: 0.7303 - val_loss: 0.7407
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7451 - loss: 0.6841 - val_accuracy: 0.6966 - val_loss: 0.7367
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7243 - loss: 0.7206 - val_accuracy: 0.7079 - val_loss: 0.7332
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7392 - loss: 0.6854 - val_accuracy: 0.7079 - val_loss: 0.7325
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7069 - loss: 0.7089 - val_accuracy: 0.7191 - val_loss: 0.7298
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7776 - loss: 0.6647 - val_accuracy: 0.7191 - val_loss: 0.7272
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7643 - loss: 0.6382 - val_accuracy: 0.7191 - val_loss: 0.7305
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7259 - loss: 0.7002 - val_accuracy: 0.7191 - val_loss: 0.7286
# Score for fold 3: loss of 0.7285749912261963; compile_metrics of 71.91011309623718%
# Training on fold 4...
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.2615 - loss: 1.1138 - val_accuracy: 0.5730 - val_loss: 1.0808
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5744 - loss: 1.0624 - val_accuracy: 0.5955 - val_loss: 1.0421
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5872 - loss: 1.0265 - val_accuracy: 0.7079 - val_loss: 1.0051
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6633 - loss: 0.9865 - val_accuracy: 0.6966 - val_loss: 0.9670
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6736 - loss: 0.9347 - val_accuracy: 0.6966 - val_loss: 0.9282
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6552 - loss: 0.9104 - val_accuracy: 0.6966 - val_loss: 0.8905
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6483 - loss: 0.8752 - val_accuracy: 0.6966 - val_loss: 0.8541
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6540 - loss: 0.8459 - val_accuracy: 0.6966 - val_loss: 0.8223
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7082 - loss: 0.7604 - val_accuracy: 0.6966 - val_loss: 0.7939
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7112 - loss: 0.7533 - val_accuracy: 0.6854 - val_loss: 0.7755
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6707 - loss: 0.7889 - val_accuracy: 0.7191 - val_loss: 0.7571
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7358 - loss: 0.7209 - val_accuracy: 0.7191 - val_loss: 0.7406
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7200 - loss: 0.7466 - val_accuracy: 0.7416 - val_loss: 0.7257
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7167 - loss: 0.7037 - val_accuracy: 0.7753 - val_loss: 0.7159
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7643 - loss: 0.6744 - val_accuracy: 0.7753 - val_loss: 0.7101
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7179 - loss: 0.7380 - val_accuracy: 0.7753 - val_loss: 0.7076
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7627 - loss: 0.6732 - val_accuracy: 0.7753 - val_loss: 0.6987
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7280 - loss: 0.7182 - val_accuracy: 0.7753 - val_loss: 0.6897
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7383 - loss: 0.6906 - val_accuracy: 0.7865 - val_loss: 0.6845
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7135 - loss: 0.7263 - val_accuracy: 0.7865 - val_loss: 0.6766
# Score for fold 4: loss of 0.6766006350517273; compile_metrics of 78.65168452262878%
# Training on fold 5...
# Epoch 1/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.4813 - loss: 1.0667 - val_accuracy: 0.4944 - val_loss: 1.0418
# Epoch 2/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5936 - loss: 1.0242 - val_accuracy: 0.5506 - val_loss: 1.0095
# Epoch 3/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5885 - loss: 0.9928 - val_accuracy: 0.5281 - val_loss: 0.9819
# Epoch 4/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5842 - loss: 0.9647 - val_accuracy: 0.5281 - val_loss: 0.9539
# Epoch 5/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6543 - loss: 0.9060 - val_accuracy: 0.5730 - val_loss: 0.9256
# Epoch 6/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6619 - loss: 0.8770 - val_accuracy: 0.6292 - val_loss: 0.9004
# Epoch 7/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6508 - loss: 0.8661 - val_accuracy: 0.6180 - val_loss: 0.8774
# Epoch 8/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6897 - loss: 0.8018 - val_accuracy: 0.6292 - val_loss: 0.8564
# Epoch 9/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6800 - loss: 0.7769 - val_accuracy: 0.6292 - val_loss: 0.8387
# Epoch 10/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7034 - loss: 0.7424 - val_accuracy: 0.6292 - val_loss: 0.8267
# Epoch 11/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6774 - loss: 0.7403 - val_accuracy: 0.6404 - val_loss: 0.8180
# Epoch 12/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6971 - loss: 0.7518 - val_accuracy: 0.6517 - val_loss: 0.8124
# Epoch 13/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6878 - loss: 0.7319 - val_accuracy: 0.6742 - val_loss: 0.8079
# Epoch 14/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7161 - loss: 0.6917 - val_accuracy: 0.6629 - val_loss: 0.8063
# Epoch 15/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7414 - loss: 0.6735 - val_accuracy: 0.6629 - val_loss: 0.8039
# Epoch 16/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7362 - loss: 0.6944 - val_accuracy: 0.6629 - val_loss: 0.8031
# Epoch 17/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7235 - loss: 0.6630 - val_accuracy: 0.6517 - val_loss: 0.8003
# Epoch 18/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7486 - loss: 0.6709 - val_accuracy: 0.6629 - val_loss: 0.7984
# Epoch 19/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7734 - loss: 0.6323 - val_accuracy: 0.6629 - val_loss: 0.7979
# Epoch 20/20
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7582 - loss: 0.6477 - val_accuracy: 0.6629 - val_loss: 0.7989
# Score for fold 5: loss of 0.7989047169685364; compile_metrics of 66.29213690757751%
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.5890011191368103 - Accuracy: 77.52808928489685%
# > Fold 2 - Loss: 0.6814163327217102 - Accuracy: 73.03370833396912%
# > Fold 3 - Loss: 0.7285749912261963 - Accuracy: 71.91011309623718%
# > Fold 4 - Loss: 0.6766006350517273 - Accuracy: 78.65168452262878%
# > Fold 5 - Loss: 0.7989047169685364 - Accuracy: 66.29213690757751%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 73.48314642906189 (+- 4.4150287685857625)
# > Loss: 0.6948995590209961
# ------------------------------------------------------------------------

# %%
histories_anli_r3 = cross_validate_attention_lstm_model(X_anli_r3_rnn, features_anli_r3, y_encoded_anli_r3)
# Out:
# Training on fold 1...
# Epoch 1/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.3052 - loss: 1.1139 - val_accuracy: 0.3585 - val_loss: 1.0765
# Epoch 2/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4709 - loss: 1.0521 - val_accuracy: 0.5000 - val_loss: 1.0324
# Epoch 3/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6102 - loss: 0.9939 - val_accuracy: 0.6226 - val_loss: 0.9902
# Epoch 4/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6432 - loss: 0.9544 - val_accuracy: 0.6226 - val_loss: 0.9501
# Epoch 5/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6385 - loss: 0.9031 - val_accuracy: 0.6226 - val_loss: 0.9098
# Epoch 6/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6402 - loss: 0.8538 - val_accuracy: 0.6509 - val_loss: 0.8713
# Epoch 7/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6952 - loss: 0.7934 - val_accuracy: 0.6981 - val_loss: 0.8379
# Epoch 8/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6647 - loss: 0.7868 - val_accuracy: 0.7075 - val_loss: 0.8129
# Epoch 9/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7085 - loss: 0.7475 - val_accuracy: 0.7075 - val_loss: 0.7906
# Epoch 10/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7019 - loss: 0.7232 - val_accuracy: 0.7075 - val_loss: 0.7752
# Epoch 11/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7145 - loss: 0.7015 - val_accuracy: 0.6887 - val_loss: 0.7647
# Epoch 12/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7268 - loss: 0.6967 - val_accuracy: 0.6792 - val_loss: 0.7568
# Epoch 13/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7287 - loss: 0.6495 - val_accuracy: 0.6792 - val_loss: 0.7501
# Epoch 14/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7471 - loss: 0.6476 - val_accuracy: 0.6698 - val_loss: 0.7437
# Epoch 15/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7367 - loss: 0.6442 - val_accuracy: 0.6509 - val_loss: 0.7405
# Epoch 16/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7720 - loss: 0.6306 - val_accuracy: 0.6604 - val_loss: 0.7351
# Epoch 17/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7219 - loss: 0.6744 - val_accuracy: 0.6792 - val_loss: 0.7328
# Epoch 18/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7353 - loss: 0.6167 - val_accuracy: 0.6887 - val_loss: 0.7281
# Epoch 19/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7405 - loss: 0.6547 - val_accuracy: 0.6981 - val_loss: 0.7263
# Epoch 20/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7379 - loss: 0.6288 - val_accuracy: 0.7075 - val_loss: 0.7226
# Score for fold 1: loss of 0.7225722074508667; compile_metrics of 70.75471878051758%
# Training on fold 2...
# Epoch 1/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.3078 - loss: 1.1137 - val_accuracy: 0.4906 - val_loss: 1.0536
# Epoch 2/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4347 - loss: 1.0459 - val_accuracy: 0.4528 - val_loss: 0.9978
# Epoch 3/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5320 - loss: 1.0020 - val_accuracy: 0.6132 - val_loss: 0.9482
# Epoch 4/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5796 - loss: 0.9559 - val_accuracy: 0.6321 - val_loss: 0.8987
# Epoch 5/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6214 - loss: 0.8913 - val_accuracy: 0.6321 - val_loss: 0.8472
# Epoch 6/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6276 - loss: 0.8753 - val_accuracy: 0.6698 - val_loss: 0.7987
# Epoch 7/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6646 - loss: 0.8091 - val_accuracy: 0.6698 - val_loss: 0.7545
# Epoch 8/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7040 - loss: 0.7578 - val_accuracy: 0.6981 - val_loss: 0.7155
# Epoch 9/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6788 - loss: 0.7714 - val_accuracy: 0.7075 - val_loss: 0.6850
# Epoch 10/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6620 - loss: 0.7612 - val_accuracy: 0.7075 - val_loss: 0.6640
# Epoch 11/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7018 - loss: 0.7429 - val_accuracy: 0.7075 - val_loss: 0.6486
# Epoch 12/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7416 - loss: 0.6542 - val_accuracy: 0.7075 - val_loss: 0.6331
# Epoch 13/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7390 - loss: 0.6751 - val_accuracy: 0.7264 - val_loss: 0.6228
# Epoch 14/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7172 - loss: 0.6797 - val_accuracy: 0.7264 - val_loss: 0.6149
# Epoch 15/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7502 - loss: 0.6718 - val_accuracy: 0.7264 - val_loss: 0.6101
# Epoch 16/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6939 - loss: 0.7350 - val_accuracy: 0.7264 - val_loss: 0.6066
# Epoch 17/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7512 - loss: 0.6670 - val_accuracy: 0.7264 - val_loss: 0.6043
# Epoch 18/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7282 - loss: 0.6632 - val_accuracy: 0.7453 - val_loss: 0.5995
# Epoch 19/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7307 - loss: 0.6936 - val_accuracy: 0.7547 - val_loss: 0.5971
# Epoch 20/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7543 - loss: 0.6791 - val_accuracy: 0.7453 - val_loss: 0.5924
# Score for fold 2: loss of 0.5924408435821533; compile_metrics of 74.52830076217651%
# Training on fold 3...
# Epoch 1/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.2778 - loss: 1.1099 - val_accuracy: 0.4528 - val_loss: 1.0604
# Epoch 2/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5005 - loss: 1.0381 - val_accuracy: 0.5472 - val_loss: 1.0121
# Epoch 3/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5323 - loss: 1.0049 - val_accuracy: 0.5566 - val_loss: 0.9659
# Epoch 4/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5605 - loss: 0.9606 - val_accuracy: 0.6038 - val_loss: 0.9195
# Epoch 5/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5839 - loss: 0.9193 - val_accuracy: 0.6132 - val_loss: 0.8721
# Epoch 6/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6040 - loss: 0.8843 - val_accuracy: 0.6604 - val_loss: 0.8259
# Epoch 7/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6626 - loss: 0.8187 - val_accuracy: 0.6604 - val_loss: 0.7824
# Epoch 8/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6845 - loss: 0.7788 - val_accuracy: 0.6698 - val_loss: 0.7471
# Epoch 9/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6727 - loss: 0.7589 - val_accuracy: 0.6792 - val_loss: 0.7191
# Epoch 10/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6920 - loss: 0.7204 - val_accuracy: 0.6887 - val_loss: 0.6980
# Epoch 11/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6949 - loss: 0.7249 - val_accuracy: 0.6887 - val_loss: 0.6834
# Epoch 12/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7246 - loss: 0.6910 - val_accuracy: 0.7075 - val_loss: 0.6727
# Epoch 13/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7217 - loss: 0.6819 - val_accuracy: 0.7075 - val_loss: 0.6663
# Epoch 14/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7333 - loss: 0.6634 - val_accuracy: 0.7170 - val_loss: 0.6620
# Epoch 15/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7337 - loss: 0.6728 - val_accuracy: 0.7358 - val_loss: 0.6611
# Epoch 16/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7322 - loss: 0.6513 - val_accuracy: 0.7170 - val_loss: 0.6584
# Epoch 17/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7470 - loss: 0.6464 - val_accuracy: 0.7547 - val_loss: 0.6566
# Epoch 18/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7213 - loss: 0.6684 - val_accuracy: 0.7264 - val_loss: 0.6579
# Epoch 19/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7573 - loss: 0.6208 - val_accuracy: 0.7170 - val_loss: 0.6604
# Epoch 20/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7280 - loss: 0.6442 - val_accuracy: 0.7170 - val_loss: 0.6612
# Score for fold 3: loss of 0.6612192392349243; compile_metrics of 71.69811129570007%
# Training on fold 4...
# Epoch 1/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.2493 - loss: 1.1284 - val_accuracy: 0.4906 - val_loss: 1.0660
# Epoch 2/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4379 - loss: 1.0612 - val_accuracy: 0.4528 - val_loss: 1.0040
# Epoch 3/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5025 - loss: 0.9985 - val_accuracy: 0.5849 - val_loss: 0.9450
# Epoch 4/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5849 - loss: 0.9521 - val_accuracy: 0.6038 - val_loss: 0.8904
# Epoch 5/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6245 - loss: 0.9002 - val_accuracy: 0.6321 - val_loss: 0.8404
# Epoch 6/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6345 - loss: 0.8607 - val_accuracy: 0.6415 - val_loss: 0.7931
# Epoch 7/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6540 - loss: 0.8192 - val_accuracy: 0.6698 - val_loss: 0.7517
# Epoch 8/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6803 - loss: 0.7822 - val_accuracy: 0.6698 - val_loss: 0.7186
# Epoch 9/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7053 - loss: 0.7341 - val_accuracy: 0.6698 - val_loss: 0.6955
# Epoch 10/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6639 - loss: 0.7423 - val_accuracy: 0.6981 - val_loss: 0.6794
# Epoch 11/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7120 - loss: 0.7212 - val_accuracy: 0.6981 - val_loss: 0.6673
# Epoch 12/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6982 - loss: 0.6780 - val_accuracy: 0.7264 - val_loss: 0.6607
# Epoch 13/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6914 - loss: 0.6996 - val_accuracy: 0.7358 - val_loss: 0.6556
# Epoch 14/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7071 - loss: 0.6925 - val_accuracy: 0.7453 - val_loss: 0.6513
# Epoch 15/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7538 - loss: 0.6371 - val_accuracy: 0.7453 - val_loss: 0.6480
# Epoch 16/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7057 - loss: 0.6860 - val_accuracy: 0.7358 - val_loss: 0.6481
# Epoch 17/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7387 - loss: 0.6506 - val_accuracy: 0.7264 - val_loss: 0.6460
# Epoch 18/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7372 - loss: 0.6317 - val_accuracy: 0.7264 - val_loss: 0.6430
# Epoch 19/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7347 - loss: 0.6381 - val_accuracy: 0.7358 - val_loss: 0.6412
# Epoch 20/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7007 - loss: 0.6702 - val_accuracy: 0.7547 - val_loss: 0.6427
# Score for fold 4: loss of 0.6427492499351501; compile_metrics of 75.47169923782349%
# Training on fold 5...
# Epoch 1/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.4603 - loss: 1.0625 - val_accuracy: 0.5660 - val_loss: 1.0145
# Epoch 2/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5756 - loss: 1.0188 - val_accuracy: 0.5755 - val_loss: 0.9622
# Epoch 3/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6012 - loss: 0.9669 - val_accuracy: 0.5755 - val_loss: 0.9163
# Epoch 4/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5766 - loss: 0.9335 - val_accuracy: 0.6132 - val_loss: 0.8769
# Epoch 5/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6045 - loss: 0.8787 - val_accuracy: 0.6415 - val_loss: 0.8396
# Epoch 6/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6607 - loss: 0.8446 - val_accuracy: 0.6509 - val_loss: 0.8086
# Epoch 7/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6607 - loss: 0.8043 - val_accuracy: 0.6604 - val_loss: 0.7878
# Epoch 8/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6625 - loss: 0.7825 - val_accuracy: 0.6698 - val_loss: 0.7741
# Epoch 9/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7249 - loss: 0.7242 - val_accuracy: 0.6981 - val_loss: 0.7667
# Epoch 10/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7111 - loss: 0.7401 - val_accuracy: 0.6887 - val_loss: 0.7623
# Epoch 11/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7329 - loss: 0.6731 - val_accuracy: 0.6792 - val_loss: 0.7616
# Epoch 12/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7220 - loss: 0.6668 - val_accuracy: 0.6887 - val_loss: 0.7624
# Epoch 13/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7581 - loss: 0.6466 - val_accuracy: 0.6792 - val_loss: 0.7647
# Epoch 14/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7610 - loss: 0.6238 - val_accuracy: 0.6981 - val_loss: 0.7611
# Epoch 15/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7545 - loss: 0.6271 - val_accuracy: 0.6981 - val_loss: 0.7593
# Epoch 16/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7239 - loss: 0.6429 - val_accuracy: 0.6981 - val_loss: 0.7606
# Epoch 17/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7360 - loss: 0.6504 - val_accuracy: 0.7075 - val_loss: 0.7529
# Epoch 18/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7039 - loss: 0.6905 - val_accuracy: 0.6981 - val_loss: 0.7458
# Epoch 19/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7453 - loss: 0.6234 - val_accuracy: 0.7075 - val_loss: 0.7529
# Epoch 20/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7373 - loss: 0.6473 - val_accuracy: 0.7075 - val_loss: 0.7552
# Score for fold 5: loss of 0.7551863193511963; compile_metrics of 70.75471878051758%
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.7225722074508667 - Accuracy: 70.75471878051758%
# > Fold 2 - Loss: 0.5924408435821533 - Accuracy: 74.52830076217651%
# > Fold 3 - Loss: 0.6612192392349243 - Accuracy: 71.69811129570007%
# > Fold 4 - Loss: 0.6427492499351501 - Accuracy: 75.47169923782349%
# > Fold 5 - Loss: 0.7551863193511963 - Accuracy: 70.75471878051758%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 72.64150977134705 (+- 1.978884222446223)
# > Loss: 0.6748335719108581
# ------------------------------------------------------------------------

# %%
X_rnn_all_tasks = np.concatenate([X_snli_rnn, X_mnli_matched_rnn, X_mnli_mismatched_rnn, X_anli_r1_rnn, X_anli_r2_rnn, X_anli_r3_rnn])
features_all_tasks = np.concatenate([features_snli, features_mnli_matched, features_mnli_mismatched, features_anli_r1, features_anli_r2, features_anli_r3])
y_encoded_all_tasks = np.concatenate([y_encoded_snli, y_encoded_mnli_matched, y_encoded_mnli_mismatched, y_encoded_anli_r1, y_encoded_anli_r2, y_encoded_anli_r3])

# Call the cross-validation function
all_histories = cross_validate_attention_lstm_model(X_rnn_all_tasks, features_all_tasks, y_encoded_all_tasks, num_folds=5)
# Out:
# Training on fold 1...
# Epoch 1/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8755 - loss: 0.5019 - val_accuracy: 0.9471 - val_loss: 0.1751
# Epoch 2/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9433 - loss: 0.1860 - val_accuracy: 0.9484 - val_loss: 0.1738
# Epoch 3/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9447 - loss: 0.1811 - val_accuracy: 0.9484 - val_loss: 0.1728
# Epoch 4/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9468 - loss: 0.1739 - val_accuracy: 0.9490 - val_loss: 0.1725
# Epoch 5/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9500 - loss: 0.1704 - val_accuracy: 0.9482 - val_loss: 0.1723
# Epoch 6/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9468 - loss: 0.1773 - val_accuracy: 0.9482 - val_loss: 0.1723
# Epoch 7/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9480 - loss: 0.1756 - val_accuracy: 0.9487 - val_loss: 0.1719
# Epoch 8/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9459 - loss: 0.1811 - val_accuracy: 0.9490 - val_loss: 0.1727
# Epoch 9/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9461 - loss: 0.1793 - val_accuracy: 0.9469 - val_loss: 0.1741
# Epoch 10/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9487 - loss: 0.1736 - val_accuracy: 0.9484 - val_loss: 0.1722
# Epoch 11/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9436 - loss: 0.1820 - val_accuracy: 0.9479 - val_loss: 0.1724
# Epoch 12/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9456 - loss: 0.1842 - val_accuracy: 0.9487 - val_loss: 0.1724
# Epoch 13/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9465 - loss: 0.1739 - val_accuracy: 0.9479 - val_loss: 0.1749
# Epoch 14/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9497 - loss: 0.1629 - val_accuracy: 0.9484 - val_loss: 0.1720
# Epoch 15/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9486 - loss: 0.1703 - val_accuracy: 0.9479 - val_loss: 0.1724
# Epoch 16/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9468 - loss: 0.1732 - val_accuracy: 0.9492 - val_loss: 0.1722
# Epoch 17/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9455 - loss: 0.1745 - val_accuracy: 0.9487 - val_loss: 0.1716
# Epoch 18/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9475 - loss: 0.1709 - val_accuracy: 0.9484 - val_loss: 0.1718
# Epoch 19/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9508 - loss: 0.1634 - val_accuracy: 0.9479 - val_loss: 0.1725
# Epoch 20/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9473 - loss: 0.1709 - val_accuracy: 0.9492 - val_loss: 0.1718
# Score for fold 1: loss of 0.17179729044437408; compile_metrics of 94.921875%
# Training on fold 2...
# Epoch 1/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8716 - loss: 0.4826 - val_accuracy: 0.9464 - val_loss: 0.1722
# Epoch 2/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9454 - loss: 0.1812 - val_accuracy: 0.9477 - val_loss: 0.1688
# Epoch 3/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9414 - loss: 0.1884 - val_accuracy: 0.9474 - val_loss: 0.1691
# Epoch 4/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9443 - loss: 0.1855 - val_accuracy: 0.9469 - val_loss: 0.1683
# Epoch 5/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9485 - loss: 0.1748 - val_accuracy: 0.9461 - val_loss: 0.1684
# Epoch 6/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9442 - loss: 0.1835 - val_accuracy: 0.9477 - val_loss: 0.1688
# Epoch 7/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9463 - loss: 0.1807 - val_accuracy: 0.9471 - val_loss: 0.1678
# Epoch 8/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9469 - loss: 0.1803 - val_accuracy: 0.9471 - val_loss: 0.1669
# Epoch 9/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9453 - loss: 0.1857 - val_accuracy: 0.9464 - val_loss: 0.1710
# Epoch 10/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9476 - loss: 0.1769 - val_accuracy: 0.9474 - val_loss: 0.1681
# Epoch 11/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9477 - loss: 0.1727 - val_accuracy: 0.9474 - val_loss: 0.1672
# Epoch 12/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9495 - loss: 0.1718 - val_accuracy: 0.9477 - val_loss: 0.1665
# Epoch 13/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9461 - loss: 0.1757 - val_accuracy: 0.9471 - val_loss: 0.1670
# Epoch 14/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9443 - loss: 0.1789 - val_accuracy: 0.9477 - val_loss: 0.1673
# Epoch 15/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9521 - loss: 0.1676 - val_accuracy: 0.9466 - val_loss: 0.1684
# Epoch 16/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9471 - loss: 0.1794 - val_accuracy: 0.9474 - val_loss: 0.1675
# Epoch 17/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9496 - loss: 0.1722 - val_accuracy: 0.9474 - val_loss: 0.1671
# Epoch 18/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9472 - loss: 0.1800 - val_accuracy: 0.9469 - val_loss: 0.1663
# Epoch 19/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9488 - loss: 0.1734 - val_accuracy: 0.9471 - val_loss: 0.1656
# Epoch 20/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9494 - loss: 0.1722 - val_accuracy: 0.9477 - val_loss: 0.1665
# Score for fold 2: loss of 0.16654756665229797; compile_metrics of 94.76562738418579%
# Training on fold 3...
# Epoch 1/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8348 - loss: 0.5344 - val_accuracy: 0.9453 - val_loss: 0.1841
# Epoch 2/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9484 - loss: 0.1777 - val_accuracy: 0.9443 - val_loss: 0.1828
# Epoch 3/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9475 - loss: 0.1800 - val_accuracy: 0.9419 - val_loss: 0.1827
# Epoch 4/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9457 - loss: 0.1797 - val_accuracy: 0.9443 - val_loss: 0.1834
# Epoch 5/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9494 - loss: 0.1726 - val_accuracy: 0.9424 - val_loss: 0.1837
# Epoch 6/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9482 - loss: 0.1759 - val_accuracy: 0.9440 - val_loss: 0.1827
# Epoch 7/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9486 - loss: 0.1706 - val_accuracy: 0.9435 - val_loss: 0.1835
# Epoch 8/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9498 - loss: 0.1698 - val_accuracy: 0.9443 - val_loss: 0.1826
# Epoch 9/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9481 - loss: 0.1734 - val_accuracy: 0.9432 - val_loss: 0.1817
# Epoch 10/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9501 - loss: 0.1705 - val_accuracy: 0.9440 - val_loss: 0.1821
# Epoch 11/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9478 - loss: 0.1766 - val_accuracy: 0.9440 - val_loss: 0.1821
# Epoch 12/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9479 - loss: 0.1731 - val_accuracy: 0.9443 - val_loss: 0.1821
# Epoch 13/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9467 - loss: 0.1732 - val_accuracy: 0.9443 - val_loss: 0.1806
# Epoch 14/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9494 - loss: 0.1696 - val_accuracy: 0.9443 - val_loss: 0.1817
# Epoch 15/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9482 - loss: 0.1708 - val_accuracy: 0.9440 - val_loss: 0.1811
# Epoch 16/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9498 - loss: 0.1704 - val_accuracy: 0.9438 - val_loss: 0.1802
# Epoch 17/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9479 - loss: 0.1726 - val_accuracy: 0.9432 - val_loss: 0.1809
# Epoch 18/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9441 - loss: 0.1854 - val_accuracy: 0.9438 - val_loss: 0.1808
# Epoch 19/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9504 - loss: 0.1670 - val_accuracy: 0.9432 - val_loss: 0.1807
# Epoch 20/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9482 - loss: 0.1723 - val_accuracy: 0.9432 - val_loss: 0.1806
# Score for fold 3: loss of 0.1806398183107376; compile_metrics of 94.32291388511658%
# Training on fold 4...
# Epoch 1/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9331 - loss: 0.4266 - val_accuracy: 0.9451 - val_loss: 0.1834
# Epoch 2/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9448 - loss: 0.1841 - val_accuracy: 0.9484 - val_loss: 0.1783
# Epoch 3/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9494 - loss: 0.1745 - val_accuracy: 0.9487 - val_loss: 0.1771
# Epoch 4/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9473 - loss: 0.1718 - val_accuracy: 0.9495 - val_loss: 0.1777
# Epoch 5/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9479 - loss: 0.1786 - val_accuracy: 0.9479 - val_loss: 0.1766
# Epoch 6/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9477 - loss: 0.1747 - val_accuracy: 0.9500 - val_loss: 0.1762
# Epoch 7/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9480 - loss: 0.1697 - val_accuracy: 0.9487 - val_loss: 0.1756
# Epoch 8/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9450 - loss: 0.1790 - val_accuracy: 0.9492 - val_loss: 0.1754
# Epoch 9/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9479 - loss: 0.1743 - val_accuracy: 0.9490 - val_loss: 0.1756
# Epoch 10/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9476 - loss: 0.1750 - val_accuracy: 0.9492 - val_loss: 0.1747
# Epoch 11/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9472 - loss: 0.1736 - val_accuracy: 0.9490 - val_loss: 0.1745
# Epoch 12/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9487 - loss: 0.1724 - val_accuracy: 0.9482 - val_loss: 0.1760
# Epoch 13/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9466 - loss: 0.1713 - val_accuracy: 0.9497 - val_loss: 0.1746
# Epoch 14/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9494 - loss: 0.1677 - val_accuracy: 0.9505 - val_loss: 0.1753
# Epoch 15/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9486 - loss: 0.1764 - val_accuracy: 0.9500 - val_loss: 0.1746
# Epoch 16/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9474 - loss: 0.1731 - val_accuracy: 0.9495 - val_loss: 0.1740
# Epoch 17/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9456 - loss: 0.1767 - val_accuracy: 0.9484 - val_loss: 0.1737
# Epoch 18/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9457 - loss: 0.1766 - val_accuracy: 0.9497 - val_loss: 0.1747
# Epoch 19/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9480 - loss: 0.1742 - val_accuracy: 0.9495 - val_loss: 0.1737
# Epoch 20/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9490 - loss: 0.1733 - val_accuracy: 0.9495 - val_loss: 0.1736
# Score for fold 4: loss of 0.17359662055969238; compile_metrics of 94.94791626930237%
# Training on fold 5...
# Epoch 1/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8902 - loss: 0.4880 - val_accuracy: 0.9508 - val_loss: 0.1837
# Epoch 2/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9491 - loss: 0.1659 - val_accuracy: 0.9484 - val_loss: 0.1820
# Epoch 3/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9443 - loss: 0.1818 - val_accuracy: 0.9482 - val_loss: 0.1811
# Epoch 4/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9474 - loss: 0.1751 - val_accuracy: 0.9469 - val_loss: 0.1833
# Epoch 5/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9458 - loss: 0.1761 - val_accuracy: 0.9482 - val_loss: 0.1812
# Epoch 6/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9462 - loss: 0.1821 - val_accuracy: 0.9482 - val_loss: 0.1810
# Epoch 7/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9504 - loss: 0.1663 - val_accuracy: 0.9471 - val_loss: 0.1805
# Epoch 8/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9467 - loss: 0.1746 - val_accuracy: 0.9469 - val_loss: 0.1796
# Epoch 9/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9484 - loss: 0.1712 - val_accuracy: 0.9479 - val_loss: 0.1792
# Epoch 10/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9478 - loss: 0.1736 - val_accuracy: 0.9471 - val_loss: 0.1802
# Epoch 11/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9473 - loss: 0.1716 - val_accuracy: 0.9482 - val_loss: 0.1788
# Epoch 12/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9463 - loss: 0.1760 - val_accuracy: 0.9471 - val_loss: 0.1799
# Epoch 13/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9502 - loss: 0.1666 - val_accuracy: 0.9471 - val_loss: 0.1792
# Epoch 14/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9467 - loss: 0.1732 - val_accuracy: 0.9479 - val_loss: 0.1788
# Epoch 15/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9465 - loss: 0.1761 - val_accuracy: 0.9482 - val_loss: 0.1786
# Epoch 16/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9431 - loss: 0.1846 - val_accuracy: 0.9479 - val_loss: 0.1783
# Epoch 17/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9492 - loss: 0.1747 - val_accuracy: 0.9466 - val_loss: 0.1786
# Epoch 18/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9497 - loss: 0.1692 - val_accuracy: 0.9482 - val_loss: 0.1815
# Epoch 19/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9442 - loss: 0.1806 - val_accuracy: 0.9482 - val_loss: 0.1776
# Epoch 20/20
# 480/480 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9444 - loss: 0.1779 - val_accuracy: 0.9476 - val_loss: 0.1778
# Score for fold 5: loss of 0.17783628404140472; compile_metrics of 94.76426243782043%
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.17179729044437408 - Accuracy: 94.921875%
# > Fold 2 - Loss: 0.16654756665229797 - Accuracy: 94.76562738418579%
# > Fold 3 - Loss: 0.1806398183107376 - Accuracy: 94.32291388511658%
# > Fold 4 - Loss: 0.17359662055969238 - Accuracy: 94.94791626930237%
# > Fold 5 - Loss: 0.17783628404140472 - Accuracy: 94.76426243782043%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 94.74451899528503 (+- 0.22423730287863725)
# > Loss: 0.17408351600170135
# ------------------------------------------------------------------------

# %%
# Function to plot k-fold histories
def plot_kfold_histories(histories):
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    
    for fold, history in enumerate(histories, start=1):
        axes[0].plot(history.history['accuracy'], label=f'Train Fold {fold}')
        axes[0].plot(history.history['val_accuracy'], label=f'Val Fold {fold}', linestyle="--")
        axes[1].plot(history.history['loss'], label=f'Train Fold {fold}')
        axes[1].plot(history.history['val_loss'], label=f'Val Fold {fold}', linestyle="--")
    
    axes[0].set_title('Model Accuracy')
    axes[0].set_ylabel('Accuracy')
    axes[0].set_xlabel('Epoch')
    axes[0].legend()
    
    axes[1].set_title('Model Loss')
    axes[1].set_ylabel('Loss')
    axes[1].set_xlabel('Epoch')
    axes[1].legend()
    
    plt.show()
    
    
# Plot the histories
plot_kfold_histories(all_histories)
